# %%
import numpy as np
from pc_kriging import PC_Kriging
import matplotlib.pyplot as plt
from scipy.stats import norm
from doepy import build
from scipy import optimize
import pandas as pd
from numpy import genfromtxt
import pickle

import matlab.engine
#to load matlab engine
eng = matlab.engine.start_matlab()

# adaptive learning - expected feasiability function --------------------------------------------------------------

def EFF(u,v,z):
    zl=-2*v
    zh=2*v
    return ((u-z)*( 2*norm.cdf((z-u)/v) - norm.cdf((zl-u)/v) - norm.cdf((zh-u)/v)) 
           -(v)*( 2*norm.pdf((z-u)/v) - norm.pdf((zl-u)/v) - norm.pdf((zh-u)/v))  
           +(2*v)*(norm.cdf((zh-u)/v) - norm.cdf((zl-u)/v)))

def U_function(u, v):
    return np.abs(u)/v

def LinearNorm(x,oldmin,oldmax,newmin,newmax):    # scaling linearly X to new domain limits
    return newmin + ((x-oldmin)*(newmax-newmin)/(oldmax-oldmin))


def VoronoiCell(x,xn):   #given x [single value] return the index of the closest xn [array]
    dist=PCK1.distance(x.reshape(1,-1),xn)
    return np.argmin(dist)

# %%
def simulator(xr1, xr2):
    #Recommended values... design domain
    # Amin1, Amax1 = [0.0,  45.0]   #Angles
    #Vmin2, Vmax2 = [0.5, 2.0]   #Velocity
    # dmin1, dmax1 = [1.3,  1.3]   #Leg diameter
    # dmin2, dmax2 = [0.4 , 0.8]   #Brace diameter
    # smin, smax = [287e6 , 347e6]   #317*10^6 flow stress
    # Emin, Emax = [210000e6, 210000e6] #210000*10^6 young modulus
    
    # fixing parameters for the solver
    Angle = 0.0
    Dleg = 1.3
    Dbra = 0.65
    YM = 210000e6

    Velocity = xr1.tolist()
    FlowStress = xr2.tolist()
    
    try:
        #wether xr is an array
        n = len(xr1)
        output = np.zeros((n, 3))
        
        for sample in range (0, len(output)):

            output[sample]  = np.array(eng.Main(Angle, Velocity[sample], Dleg, Dbra, FlowStress[sample], YM))

    except TypeError:
        #single point
        output = np.array(eng.Main(Angle, Velocity, Dleg, Dbra, FlowStress, YM))

    return output

# %%
config = {"pol_type": ['hermite', 'hermite']}   #design variables following normal distribution
PCK1 = PC_Kriging(config)
PCK_loo = PC_Kriging(config)    # for LOOCV with same 'config' as specified in the original model

# %% [markdown]
# ## Initial input parameters

# %%
dim = 2       # dimensionality

x1mean, x1sigma = 3.0 , 0.6  # Velocity, normal distribution 
x2mean, x2sigma = 317e6 , 30e6  # FlowStress, normal distribution 

# objective function to optimize length scale --------------------------------------------------------
def L_Object (l):
    v = 5/2
    N = len(xn)
    R = PCK1.matern(xn , xn, l, v)
    detR = np.linalg.det(R)
    
    modelpar2 = PCK1.train(xn, yn, p, np.array([l,v]))    # returns B, sig2, InfoMatrix(phi) , PolyIndices(alpha)
    ### ------------------Theta_ by UQLab User Manual PCK(C. Lataniotis, D. Wicaksono, S. Marelli, B. Sudret)------------------------------
    sig2 = modelpar2[1].reshape(-1)
    # return 0.5*(np.log(detR)+ N*np.log(2*np.pi*sig2)+ N)

    ### ------------------Theta_ by MLE PCK(Schobi,Sudret,Wiart)------------------------------
    FB = PCK1.InfoMat @ modelpar2[0]
    ins = (yn-FB).reshape(-1)
    R_1 = np.linalg.inv(R)
    return ((ins.T) @ R_1 @ ins) * (1/N) * (detR**(1/N))

# %% [markdown]
# # Combined BDiffer training- U - LOO - 2 LS

# %%
number_experiments = 8    
number_active_points = 45

Critic_LS1 = 3
Critic_LS2 = 2

# kernel hyperparameters-------------------------------------
v = 5/2        #Gaussian process

#truncation term-------------------------------------
p_max = 4  #for each variable → same truncation , degree of expansion
    
results_file = '_BDiff_ULOO_' + str(number_active_points)   # index for results files

for experiments in range(number_experiments):
    print('Experiment: ', experiments+1 , '#################################################################' )
    
    ActiveTrain_1 = {}   #results file { Surrogate , Pf, CoV_Pf , eLoo , mse }
    ActiveTrain_2 = {}   #results file { Surrogate , Pf, CoV_Pf , eLoo , mse }

    #INITIAL design of experiments (LHS) passive training ####################################

    n = 5      # number of initial sampling

    xn = np.zeros((int(n), dim))      #normalized training points
    xr = np.zeros((int(n), dim))      #scaled training points
    output = np.zeros((int(n), 3))        #observations [timeIndex, Penetration, MaxForce]

    # Check the variables limits for space-filling distribution
    Xdoe = build.space_filling_lhs( {'x1':[-1, 1],      
                                     'x2':[-1, 1],} , 
                                      num_samples = n )
    #------------------------------------------------------------
    xn[:,0] = Xdoe['x1']
    xn[:,1] = Xdoe['x2']
    xr[:,0] = PCK1.scalehermite(xn[:,0], x1mean, x1sigma)
    xr[:,1] = PCK1.scalehermite(xn[:,1], x2mean, x2sigma)

    #simulator execution
    output = simulator(xr[:, 0], xr[:, 1]) #velocity and flowstress 
    
    #Output = [timeIndex, Penetration, MaxForce]
    yn = output[:, 1]

    #limit state definition
    yn_1 = Critic_LS1 - yn
    yn_2 = Critic_LS2 - yn

    for points in range(number_active_points):

        # Selecting the smallest e_loo model (length and order)
        
        opt_length_it = np.zeros(p_max-1)
        eloo_results = np.zeros(p_max-1)

        mean_loo = np.zeros(len(xn))
        var_loo = np.zeros(len(xn))
        sumat_1 = np.zeros((len(xn),(p_max-1)))
        sumat_2 = np.zeros((len(xn),(p_max-1)))

        dist = PCK1.distance(xn, xn)
        lmax = np.max(dist)
        lmin = np.min(dist[dist!=0])
        bounds = [(lmin, lmax)]

        results = dict()

         ## Pool of samples for MCS -----------------------------------
        
        MCS_samples = 500000
        LOOCV = np.zeros(MCS_samples)

        MCinputs_norm = np.zeros((int(MCS_samples), dim))
        MCinputs = np.zeros((int(MCS_samples), dim))

        MCinputs_norm[:,0] = np.random.normal(0, 1, size=int(MCS_samples))
        MCinputs_norm[:,1] = np.random.normal(0, 1, size=int(MCS_samples))

        MCinputs[:,0] = PCK1.scalehermite(MCinputs_norm[:,0], x1mean, x1sigma)  
        MCinputs[:,1] = PCK1.scalehermite(MCinputs_norm[:,1], x2mean, x2sigma) 
        
        # #################################################################################################################
        # Active training of Limit State 1 ################################################################################
    
#         print('AT Limit state 1 ')

        ModelName_1 = 'PCK1_' + str(len(xn))
        
        ModelName_1 = PC_Kriging(config)

        # yn is changing for each LS (inside L_Object )
         
        yn = yn_1   #observations

        # OPTIMAL SURROGATE MODEL -----------------------------------

        for p in range(1, p_max):

            results['shgo'] = optimize.shgo(L_Object, bounds)
            opt_length = results['shgo']['x'][0]

            theta = np.array([opt_length, v])

            #Generating PCK models for each reduced design of experiments 

            for i in range (0, len(xn) ):

                yn_loo= np.delete(yn,[i])                            #y_n-i      leaving element i out the observations 
                xr_loo= np.delete(xr,[i*2,i*2+1]).reshape(-1,dim)    #x1r_n-i   leaving element i out the inputs (xr)
                xn_loo= np.delete(xn,[i*2,i*2+1]).reshape(-1,dim)    #x_n-i     leaving element i out the nomalized inputs (xn)

                #training LOO
                modelpar_loo = PCK_loo.train (xn_loo , yn_loo , p , theta )

                #predicting LOO over each removed sample
                mean_loo[i], var_loo[i] = PCK_loo.predict_fast(xn[i].reshape(1,-1))

            e_loo = np.mean (yn - mean_loo)**2              #LOO CV squared errors
            sumat_1[:,p-1] = np.divide(e_loo, var_loo)
            
            eloo_results[p-1] = e_loo
            opt_length_it[p-1] = opt_length

    #         print('Degree', p, 'MSE', "%.2f" % round(mse, 2) , 'e_LOO', "%.5f" % e_loo)

        ## training optimal model ----------------------------

        opt = np.argmin(eloo_results)    #selected based 'eloo' instead 'mse'
        opt_1 = opt 
        theta_opt = np.array([opt_length_it[opt], v]) 

        modelpar1 = ModelName_1.train (xn, yn, int(opt+1), theta_opt) 
    
        # Pf estimation ----------------------------------------------       
        # surrogate 
        meanMC_1, varMC_1 = ModelName_1.predict_fast(MCinputs_norm)    # mean, variance
        fail_samples_SUMO_1 = np.sum(np.asarray(meanMC_1) < 0 )
        fail_prob_SUMO_1 = fail_samples_SUMO_1 / MCS_samples

        cov_pf = np.sqrt((1 - fail_prob_SUMO_1 ) / (fail_prob_SUMO_1 * MCS_samples) )

        print('LS1: ','Degree', int(opt+1), 'e_LOO', np.min(eloo_results) ,'Pf_SuMO', fail_prob_SUMO_1 , 'CoV', "%.5f" % round(cov_pf, 4))

        #saving results ----------------------------

        ActiveTrain_1[str(len(xn))+'points'] = ModelName_1 , fail_prob_SUMO_1 , cov_pf , np.min(eloo_results)
        
        # #################################################################################################################
        # Active training of Limit State 2 ################################################################################
        
#         print('Training Limit state 2 ')
        
        ModelName_2 = 'PCK2_' + str(len(xn))
        
        ModelName_2 = PC_Kriging(config)
        
        # yn is changing for each LS 
        yn = yn_2

        # Selecting the smallest e_loo model (length and order) 

        # OPTIMAL SURROGATE MODEL -----------------------------------
        for p in range(1, p_max):

            results['shgo'] = optimize.shgo(L_Object, bounds)
            opt_length = results['shgo']['x'][0]

            theta = np.array([opt_length, v])

            #Generating PCK models for each reduced design of experiments 

            for i in range (0, len(xn) ):

                yn_loo= np.delete(yn,[i])                            #y_n-i      leaving element i out the observations 
                xr_loo= np.delete(xr,[i*2,i*2+1]).reshape(-1,dim)    #x1r_n-i   leaving element i out the inputs (xr)
                xn_loo= np.delete(xn,[i*2,i*2+1]).reshape(-1,dim)    #x_n-i     leaving element i out the nomalized inputs (xn)

                #training LOO
                modelpar_loo = PCK_loo.train (xn_loo , yn_loo , p , theta )

                #predicting LOO over each removed sample
                mean_loo[i], var_loo[i] = PCK_loo.predict_fast(xn[i].reshape(1,-1))

            e_loo = np.mean (yn - mean_loo)**2              #LOO CV squared errors
            sumat_2[:,p-1] = np.divide(e_loo, var_loo)
            
            eloo_results[p-1] = e_loo
            opt_length_it[p-1] = opt_length

    #         print('Degree', p, 'MSE', "%.2f" % round(mse, 2) , 'e_LOO', "%.5f" % e_loo)

        ## training optimal model ----------------------------

        opt = np.argmin(eloo_results)
        opt_2 = opt  
        theta_opt = np.array([opt_length_it[opt], v]) 

        modelpar2 = ModelName_2.train (xn, yn, int(opt+1), theta_opt) 

        # Pf estimation ----------------------------------------------
        # surrogate ls
        meanMC_2, varMC_2 = ModelName_2.predict_fast(MCinputs_norm)    # mean, variance
        fail_samples_SUMO_2 = np.sum(np.asarray(meanMC_2) < 0 )
        fail_prob_SUMO_2 = fail_samples_SUMO_2 / MCS_samples

        cov_pf = np.sqrt((1 - fail_prob_SUMO_2 ) / (fail_prob_SUMO_2 * MCS_samples) )        
        
        print('LS2: ','Degree', int(opt+1), 'e_LOO', np.min(eloo_results) ,'Pf_SuMO', fail_prob_SUMO_2 , 'CoV', "%.5f" % round(cov_pf, 4))

        #saving results ----------------------------------------------

        ActiveTrain_2[str(len(xn))+'points'] = ModelName_2 , fail_prob_SUMO_2 , cov_pf , np.min(eloo_results)
        
        # ##############################################################################
        
        if ( points == 0 ):   
            meanMC = meanMC_1
            varMC = varMC_1
            sumat = sumat_1
            opt = opt_1                 
            print ('LS 1')

            Pf1_old = fail_prob_SUMO_1
            Pf2_old = fail_prob_SUMO_2

        elif ( fail_prob_SUMO_1 == 0 ): 
            meanMC = meanMC_1
            varMC = varMC_1
            sumat = sumat_1
            opt = opt_1                 
            print ('LS 1')

            Pf1_old = fail_prob_SUMO_1
            Pf2_old = fail_prob_SUMO_2

        elif ( fail_prob_SUMO_2 == 0 ): 
            meanMC = meanMC_2
            varMC = varMC_2
            sumat = sumat_2
            opt = opt_2                 
            print ('LS 2')

            Pf1_old = fail_prob_SUMO_1
            Pf2_old = fail_prob_SUMO_2

        else:
            Pf1_new = fail_prob_SUMO_1
            Pf2_new = fail_prob_SUMO_2

            B1_old = - norm.ppf ( Pf1_old )
            B2_old = - norm.ppf ( Pf2_old )

            B1_new = - norm.ppf ( Pf1_new )
            B2_new = - norm.ppf ( Pf2_new )

            B_error1 = abs(B1_old - B1_new ) / B1_old
            B_error2 = abs(B2_old - B2_new ) / B2_old

            if (B_error1 > B_error2):

                meanMC = meanMC_1
                varMC = varMC_1
                sumat = sumat_1
                opt = opt_1                 
                print (B_error1, B_error2, 'LS 1')

                Pf1_old = fail_prob_SUMO_1
                Pf2_old = fail_prob_SUMO_2

            else:

                meanMC = meanMC_2
                varMC = varMC_2
                sumat = sumat_2
                opt = opt_2                 
                print (B_error1, B_error2, 'LS 2')

                Pf1_old = fail_prob_SUMO_1
                Pf2_old = fail_prob_SUMO_2
        
        # LOO CV errors ###################################################
        #variance enhancement based LOO CV erros around voronoi cells
        
        for k in range (0, MCS_samples):               
            voro = VoronoiCell(MCinputs[k], xr)
            LOOCV[k]= varMC[k]*(1+ sumat[voro, opt])

        ### Evaluating new points
        U_f = U_function(meanMC.reshape(-1), LOOCV.reshape(-1))
        
        candidate = MCinputs[np.argmin(U_f)]
        candidate_norm = MCinputs_norm[np.argmin(U_f)]
        
        xr = np.append(xr, candidate).reshape(-1,2)
        xn = np.append(xn, candidate_norm).reshape(-1,2)
        
        #simulator execution
        Single_yn = simulator(candidate[0], candidate[1]) #velocity and flowstress 
        
        #Output = [timeIndex, Penetration, MaxForce]
    
        yn_1 = np.append(yn_1, (Critic_LS1 - Single_yn[0,1]) )
        yn_2 = np.append(yn_2, (Critic_LS2 - Single_yn[0,1]) )

        print('number of training points: ', len(xn),'-------------------------------------------------')
        
    filename1 = 'Batch_'+ str(experiments+1) + results_file + 'p_LS1.sav'

    pickle.dump(ActiveTrain_1, open(filename1, 'wb'))
    
    filename2 = 'Batch_'+ str(experiments+1) + results_file + 'p_LS2.sav'
    pickle.dump(ActiveTrain_2, open(filename2, 'wb'))
# Out:
# Experiment:  1 #################################################################
# C:\Users\Administrator\anaconda3\envs\surrogate\lib\site-packages\ipykernel_launcher.py:13: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   del sys.path[0]
# LS1:  Degree 1 e_LOO 1.757522614227588e-06 Pf_SuMO 0.000208 CoV 0.09800
# LS2:  Degree 1 e_LOO 1.7575226142275581e-06 Pf_SuMO 0.131038 CoV 0.00360
# LS 1
# number of training points:  6 -------------------------------------------------
# LS1:  Degree 1 e_LOO 4.565669633245639e-06 Pf_SuMO 0.000282 CoV 0.08420
# LS2:  Degree 1 e_LOO 4.565669633245426e-06 Pf_SuMO 0.135366 CoV 0.00360
# 0.02304969037010084 0.017939810604656364 LS 1
# number of training points:  7 -------------------------------------------------
# LS1:  Degree 2 e_LOO 1.447771302419484e-06 Pf_SuMO 0.000596 CoV 0.05790
# LS2:  Degree 2 e_LOO 1.4477713016558675e-06 Pf_SuMO 0.142936 CoV 0.00350
# 0.06019478339754343 0.031013219675086568 LS 1
# number of training points:  8 -------------------------------------------------
# LS1:  Degree 2 e_LOO 1.728247639025024e-06 Pf_SuMO 0.000542 CoV 0.06070
# LS2:  Degree 2 e_LOO 1.728247639078647e-06 Pf_SuMO 0.142694 CoV 0.00350
# 0.00832462938255184 0.0010051288994853862 LS 1
# number of training points:  9 -------------------------------------------------
# LS1:  Degree 2 e_LOO 3.1001058369360155e-09 Pf_SuMO 0.000546 CoV 0.06050
# LS2:  Degree 2 e_LOO 3.1001058357680543e-09 Pf_SuMO 0.141754 CoV 0.00350
# 0.0006370643430387404 0.003911262060323433 LS 2
# number of training points:  10 -------------------------------------------------
# LS1:  Degree 2 e_LOO 6.014512254943882e-08 Pf_SuMO 0.000548 CoV 0.06040
# LS2:  Degree 2 e_LOO 6.014512255081636e-08 Pf_SuMO 0.140256 CoV 0.00350
# 0.0003171172127308459 0.0062451061353918595 LS 2
# number of training points:  11 -------------------------------------------------
# LS1:  Degree 2 e_LOO 3.7142690699452704e-07 Pf_SuMO 0.000608 CoV 0.05730
# LS2:  Degree 2 e_LOO 3.7142690699329646e-07 Pf_SuMO 0.140652 CoV 0.00350
# 0.009050950009352129 0.0016450185123914464 LS 1
# number of training points:  12 -------------------------------------------------
# LS1:  Degree 2 e_LOO 2.614961784436899e-06 Pf_SuMO 0.000542 CoV 0.06070
# LS2:  Degree 2 e_LOO 2.6149617844421256e-06 Pf_SuMO 0.140442 CoV 0.00350
# 0.010097230011086913 0.0008734028731385028 LS 1
# number of training points:  13 -------------------------------------------------
# LS1:  Degree 2 e_LOO 1.3724276682515258e-06 Pf_SuMO 0.00054 CoV 0.06080
# LS2:  Degree 2 e_LOO 1.3724276682540067e-06 Pf_SuMO 0.139228 CoV 0.00350
# 0.00032016457650264316 0.005062148463857907 LS 2
# number of training points:  14 -------------------------------------------------
# LS1:  Degree 2 e_LOO 1.1079684811144373e-06 Pf_SuMO 0.000534 CoV 0.06120
# LS2:  Degree 2 e_LOO 1.107968481110517e-06 Pf_SuMO 0.141026 CoV 0.00350
# 0.0009668081206762949 0.007449025642271414 LS 2
# number of training points:  15 -------------------------------------------------
# LS1:  Degree 2 e_LOO 9.468665039169573e-07 Pf_SuMO 0.000564 CoV 0.05950
# LS2:  Degree 2 e_LOO 9.468665039118772e-07 Pf_SuMO 0.140102 CoV 0.00350
# 0.004732669187315494 0.0038486438891177045 LS 1
# number of training points:  16 -------------------------------------------------
# LS1:  Degree 2 e_LOO 8.74200335711852e-07 Pf_SuMO 0.000566 CoV 0.05940
# LS2:  Degree 2 e_LOO 8.742003357112365e-07 Pf_SuMO 0.14074 CoV 0.00350
# 0.00030863348679881144 0.002649035399470684 LS 2
# number of training points:  17 -------------------------------------------------
# LS1:  Degree 2 e_LOO 8.013153402431258e-07 Pf_SuMO 0.000518 CoV 0.06210
# LS2:  Degree 2 e_LOO 8.0131534024444e-07 Pf_SuMO 0.139476 CoV 0.00350
# 0.0077042840429878395 0.005270184368602549 LS 1
# number of training points:  18 -------------------------------------------------
# LS1:  Degree 2 e_LOO 8.223229081797749e-07 Pf_SuMO 0.000578 CoV 0.05880
# LS2:  Degree 2 e_LOO 8.223229081782904e-07 Pf_SuMO 0.141056 CoV 0.00350
# 0.009462845671709583 0.006548195124170327 LS 1
# number of training points:  19 -------------------------------------------------
# LS1:  Degree 3 e_LOO 4.459439494890892e-07 Pf_SuMO 0.00055 CoV 0.06030
# LS2:  Degree 3 e_LOO 4.459439492354647e-07 Pf_SuMO 0.14151 CoV 0.00350
# 0.004338024031059403 0.0018846985486068606 LS 1
# number of training points:  20 -------------------------------------------------
# LS1:  Degree 3 e_LOO 2.3036126274963644e-07 Pf_SuMO 0.000564 CoV 0.05950
# LS2:  Degree 3 e_LOO 2.3036126232752914e-07 Pf_SuMO 0.141206 CoV 0.00350
# 0.002184426201006613 0.0012639286157686105 LS 1
# number of training points:  21 -------------------------------------------------
# LS1:  Degree 3 e_LOO 2.6964580989556996e-08 Pf_SuMO 0.000546 CoV 0.06050
# LS2:  Degree 3 e_LOO 2.6964581063052814e-08 Pf_SuMO 0.140822 CoV 0.00350
# 0.002824162428326847 0.001597162579579049 LS 1
# number of training points:  22 -------------------------------------------------
# LS1:  Degree 2 e_LOO 3.115798777105218e-09 Pf_SuMO 0.000576 CoV 0.05890
# LS2:  Degree 2 e_LOO 3.115809530040559e-09 Pf_SuMO 0.14159 CoV 0.00350
# 0.004647874801520669 0.0031862940958137928 LS 1
# number of training points:  23 -------------------------------------------------
# LS1:  Degree 2 e_LOO 1.244579683669987e-08 Pf_SuMO 0.000624 CoV 0.05660
# LS2:  Degree 2 e_LOO 1.2445628776433385e-08 Pf_SuMO 0.14131 CoV 0.00350
# 0.007023229193561169 0.0011640183328662714 LS 1
# number of training points:  24 -------------------------------------------------
# LS1:  Degree 2 e_LOO 9.509437940848093e-08 Pf_SuMO 0.000512 CoV 0.06250
# LS2:  Degree 2 e_LOO 9.50938813433309e-08 Pf_SuMO 0.141308 CoV 0.00350
# 0.017403174004913546 8.310363446083376e-06 LS 1
# number of training points:  25 -------------------------------------------------
# LS1:  Degree 2 e_LOO 1.976783770027879e-07 Pf_SuMO 0.000606 CoV 0.05740
# LS2:  Degree 2 e_LOO 1.9767707448949662e-07 Pf_SuMO 0.141718 CoV 0.00350
# 0.01455835503871525 0.0017019463484657282 LS 1
# number of training points:  26 -------------------------------------------------
# LS1:  Degree 3 e_LOO 4.9584716624086045e-09 Pf_SuMO 0.000546 CoV 0.06050
# LS2:  Degree 3 e_LOO 4.9584716361321676e-09 Pf_SuMO 0.140908 CoV 0.00350
# 0.009160313771575078 0.0033713485698040773 LS 1
# number of training points:  27 -------------------------------------------------
# LS1:  Degree 3 e_LOO 4.13271140607878e-09 Pf_SuMO 0.000584 CoV 0.05850
# LS2:  Degree 3 e_LOO 4.132711386537601e-09 Pf_SuMO 0.140312 CoV 0.00350
# 0.005849490424393298 0.002480687021394367 LS 1
# number of training points:  28 -------------------------------------------------
# LS1:  Degree 3 e_LOO 1.8919836996422297e-12 Pf_SuMO 0.000602 CoV 0.05760
# LS2:  Degree 3 e_LOO 1.8921597018063622e-12 Pf_SuMO 0.141922 CoV 0.00350
# 0.0026645502091254174 0.006668340896972324 LS 2
# number of training points:  29 -------------------------------------------------
# LS1:  Degree 3 e_LOO 6.456449961737531e-09 Pf_SuMO 0.000542 CoV 0.06070
# LS2:  Degree 3 e_LOO 6.456426328666854e-09 Pf_SuMO 0.141234 CoV 0.00350
# 0.009214231551739935 0.002862354830020942 LS 1
# number of training points:  30 -------------------------------------------------
# LS1:  Degree 2 e_LOO 3.8163543658719775e-05 Pf_SuMO 0.000536 CoV 0.06110
# LS2:  Degree 2 e_LOO 3.816349150557352e-05 Pf_SuMO 0.141332 CoV 0.00350
# 0.0009637977272809665 0.00040713002406874197 LS 1
# number of training points:  31 -------------------------------------------------
# LS1:  Degree 2 e_LOO 4.537430264635736e-05 Pf_SuMO 0.000502 CoV 0.06310
# LS2:  Degree 2 e_LOO 4.537432151829057e-05 Pf_SuMO 0.141468 CoV 0.00350
# 0.005652272758181302 0.0005649098534913275 LS 1
# number of training points:  32 -------------------------------------------------
# LS1:  Degree 2 e_LOO 3.926088530737393e-05 Pf_SuMO 0.000562 CoV 0.05960
# LS2:  Degree 2 e_LOO 3.926088272216375e-05 Pf_SuMO 0.141834 CoV 0.00350
# 0.009700189175358167 0.0015193050301027448 LS 1
# number of training points:  33 -------------------------------------------------
# LS1:  Degree 2 e_LOO 1.323084145198084e-07 Pf_SuMO 0.000642 CoV 0.05580
# LS2:  Degree 2 e_LOO 1.3230850045049898e-07 Pf_SuMO 0.138912 CoV 0.00350
# 0.011654209877207798 0.012223179086283058 LS 2
# number of training points:  34 -------------------------------------------------
# LS1:  Degree 2 e_LOO 1.6931281273230033e-07 Pf_SuMO 0.000586 CoV 0.05840
# LS2:  Degree 2 e_LOO 1.6931302327263387e-07 Pf_SuMO 0.141336 CoV 0.00350
# 0.00809936867051978 0.010029535183615306 LS 2
# number of training points:  35 -------------------------------------------------
# LS1:  Degree 2 e_LOO 2.6303982646791596e-10 Pf_SuMO 0.00049 CoV 0.06390
# LS2:  Degree 2 e_LOO 2.6305827876254035e-10 Pf_SuMO 0.141614 CoV 0.00350
# 0.015589719797208499 0.001154346680069013 LS 1
# number of training points:  36 -------------------------------------------------
# LS1:  Degree 2 e_LOO 1.7458822586885325e-09 Pf_SuMO 0.000564 CoV 0.05950
# LS2:  Degree 2 e_LOO 1.7458252960978386e-09 Pf_SuMO 0.140888 CoV 0.00350
# 0.012049950680427633 0.003021319606131976 LS 1
# number of training points:  37 -------------------------------------------------
# LS1:  Degree 2 e_LOO 1.996954479824266e-09 Pf_SuMO 0.000556 CoV 0.06000
# LS2:  Degree 2 e_LOO 1.9969620536821543e-09 Pf_SuMO 0.142656 CoV 0.00350
# 0.0012447389218870478 0.007317315598331455 LS 2
# number of training points:  38 -------------------------------------------------
# LS1:  Degree 2 e_LOO 9.294820833876966e-09 Pf_SuMO 0.00057 CoV 0.05920
# LS2:  Degree 2 e_LOO 9.294928325577282e-09 Pf_SuMO 0.141814 CoV 0.00350
# 0.0021649318270709175 0.0035027545267177266 LS 2
# number of training points:  39 -------------------------------------------------
# LS1:  Degree 2 e_LOO 5.385807192121382e-09 Pf_SuMO 0.000568 CoV 0.05930
# LS2:  Degree 2 e_LOO 5.385827636419226e-09 Pf_SuMO 0.141388 CoV 0.00350
# 0.00030691049406055183 0.0017713389143005226 LS 2
# number of training points:  40 -------------------------------------------------
# LS1:  Degree 2 e_LOO 7.504826227368128e-10 Pf_SuMO 0.000548 CoV 0.06040
# LS2:  Degree 2 e_LOO 7.505025813010438e-10 Pf_SuMO 0.141688 CoV 0.00350
# 0.003124335459337461 0.0012455912550511266 LS 1
# number of training points:  41 -------------------------------------------------
# LS1:  Degree 2 e_LOO 2.4803117832253405e-08 Pf_SuMO 0.00058 CoV 0.05870
# LS2:  Degree 2 e_LOO 2.4803107360696392e-08 Pf_SuMO 0.14222 CoV 0.00350
# 0.004935045087587153 0.002207212643778637 LS 1
# number of training points:  42 -------------------------------------------------
# LS1:  Degree 2 e_LOO 9.695817070261269e-08 Pf_SuMO 0.000552 CoV 0.06020
# LS2:  Degree 2 e_LOO 9.69582997422736e-08 Pf_SuMO 0.141778 CoV 0.00350
# 0.004325153378853616 0.0018374738100474118 LS 1
# number of training points:  43 -------------------------------------------------
# LS1:  Degree 2 e_LOO 4.336078961145637e-08 Pf_SuMO 0.000544 CoV 0.06060
# LS2:  Degree 2 e_LOO 4.336086195015695e-08 Pf_SuMO 0.14139 CoV 0.00350
# 0.0012675487336857169 0.0016132219978865082 LS 2
# number of training points:  44 -------------------------------------------------
# LS1:  Degree 2 e_LOO 3.8172467159977544e-10 Pf_SuMO 0.00055 CoV 0.06030
# LS2:  Degree 2 e_LOO 3.8172500237081714e-10 Pf_SuMO 0.141796 CoV 0.00350
# 0.0009510566103891148 0.0016852708490218314 LS 2
# number of training points:  45 -------------------------------------------------
# LS1:  Degree 2 e_LOO 1.5222116764810807e-08 Pf_SuMO 0.00055 CoV 0.06030
# LS2:  Degree 2 e_LOO 1.5222206853953215e-08 Pf_SuMO 0.14095 CoV 0.00350
# 0.0 0.003521314608685924 LS 2
# number of training points:  46 -------------------------------------------------
# LS1:  Degree 2 e_LOO 2.1792266760500845e-08 Pf_SuMO 0.000526 CoV 0.06160
# LS2:  Degree 2 e_LOO 2.1792062887785817e-08 Pf_SuMO 0.142456 CoV 0.00350
# 0.0038672674745499984 0.006236610091264029 LS 2
# number of training points:  47 -------------------------------------------------
# LS1:  Degree 2 e_LOO 8.983821295042004e-11 Pf_SuMO 0.000582 CoV 0.05860
# LS2:  Degree 2 e_LOO 8.985691359377955e-11 Pf_SuMO 0.141658 CoV 0.00350
# 0.008753882797572882 0.003319768871762507 LS 1
# number of training points:  48 -------------------------------------------------
# LS1:  Degree 2 e_LOO 5.748079196431071e-09 Pf_SuMO 0.000522 CoV 0.06190
# LS2:  Degree 2 e_LOO 5.74794209473666e-09 Pf_SuMO 0.140994 CoV 0.00350
# 0.00949482035906782 0.00276281072187476 LS 1
# number of training points:  49 -------------------------------------------------
# LS1:  Degree 2 e_LOO 1.313804433379774e-09 Pf_SuMO 0.000578 CoV 0.05880
# LS2:  Degree 2 e_LOO 1.31381281036428e-09 Pf_SuMO 0.141224 CoV 0.00350
# 0.00880704426262905 0.0009553547186482154 LS 1
# number of training points:  50 -------------------------------------------------
# Experiment:  2 #################################################################
# LS1:  Degree 1 e_LOO 2.7274954329331526e-05 Pf_SuMO 0.000338 CoV 0.07690
# LS2:  Degree 1 e_LOO 2.7274954329334833e-05 Pf_SuMO 0.145878 CoV 0.00340
# LS 1
# number of training points:  6 -------------------------------------------------
# LS1:  Degree 1 e_LOO 7.412569555298623e-07 Pf_SuMO 0.000354 CoV 0.07520
# LS2:  Degree 1 e_LOO 7.412569555297891e-07 Pf_SuMO 0.143916 CoV 0.00340
# 0.003727427466336106 0.008169000114886327 LS 2
# number of training points:  7 -------------------------------------------------
# LS1:  Degree 1 e_LOO 1.4842004673397955e-07 Pf_SuMO 0.000362 CoV 0.07430
# LS2:  Degree 1 e_LOO 1.4842004673397227e-07 Pf_SuMO 0.141896 CoV 0.00350
# 0.0018121245888383741 0.008420574180145121 LS 2
# number of training points:  8 -------------------------------------------------
# LS1:  Degree 1 e_LOO 4.5295209887631824e-07 Pf_SuMO 0.000334 CoV 0.07740
# LS2:  Degree 1 e_LOO 4.529520988765716e-07 Pf_SuMO 0.140774 CoV 0.00350
# 0.00652637334463753 0.004672910891521155 LS 1
# number of training points:  9 -------------------------------------------------
# LS1:  Degree 1 e_LOO 8.347282635989461e-07 Pf_SuMO 0.00038 CoV 0.07250
# LS2:  Degree 1 e_LOO 8.347282635990461e-07 Pf_SuMO 0.142912 CoV 0.00350
# 0.010410538464795394 0.008841498816796571 LS 1
# number of training points:  10 -------------------------------------------------
# LS1:  Degree 2 e_LOO 1.570597495373135e-06 Pf_SuMO 0.000534 CoV 0.06120
# LS2:  Degree 2 e_LOO 1.5705974953757525e-06 Pf_SuMO 0.142724 CoV 0.00350
# 0.02821347165066817 0.0007807550156081733 LS 1
# number of training points:  11 -------------------------------------------------
# LS1:  Degree 2 e_LOO 5.303927637161465e-07 Pf_SuMO 0.000566 CoV 0.05940
# LS2:  Degree 2 e_LOO 5.303927637151698e-07 Pf_SuMO 0.142068 CoV 0.00350
# 0.0050398420139211595 0.0027276668072056236 LS 1
# number of training points:  12 -------------------------------------------------
# LS1:  Degree 1 e_LOO 2.7853379069340783e-07 Pf_SuMO 0.00061 CoV 0.05720
# LS2:  Degree 1 e_LOO 2.785337906934511e-07 Pf_SuMO 0.141374 CoV 0.00350
# 0.006548841187671179 0.002887093563940265 LS 1
# number of training points:  13 -------------------------------------------------
# LS1:  Degree 2 e_LOO 2.49367318454473e-08 Pf_SuMO 0.000572 CoV 0.05910
# LS2:  Degree 2 e_LOO 2.4936731845515485e-08 Pf_SuMO 0.142672 CoV 0.00350
# 0.005665772908055785 0.0053764976403789175 LS 1
# number of training points:  14 -------------------------------------------------
# LS1:  Degree 2 e_LOO 1.459177163714457e-07 Pf_SuMO 0.000624 CoV 0.05660
# LS2:  Degree 2 e_LOO 1.4591771637176236e-07 Pf_SuMO 0.142284 CoV 0.00350
# 0.0076280165497134515 0.0016123376687825406 LS 1
# number of training points:  15 -------------------------------------------------
# LS1:  Degree 2 e_LOO 1.053680135700053e-07 Pf_SuMO 0.000596 CoV 0.05790
# LS2:  Degree 2 e_LOO 1.0536801357013599e-07 Pf_SuMO 0.14271 CoV 0.00350
# 0.004062042327317731 0.0017672381421416955 LS 1
# number of training points:  16 -------------------------------------------------
# LS1:  Degree 2 e_LOO 1.789376979176136e-08 Pf_SuMO 0.000608 CoV 0.05730
# LS2:  Degree 2 e_LOO 1.789380652289622e-08 Pf_SuMO 0.142718 CoV 0.00350
# 0.001754881189522337 3.321211684720166e-05 LS 1
# number of training points:  17 -------------------------------------------------
# LS1:  Degree 2 e_LOO 8.595292756381515e-09 Pf_SuMO 0.000516 CoV 0.06220
# LS2:  Degree 2 e_LOO 8.595189341262286e-09 Pf_SuMO 0.142316 CoV 0.00350
# 0.014390312340468973 0.0016705246523942053 LS 1
# number of training points:  18 -------------------------------------------------
# LS1:  Degree 2 e_LOO 3.9784074212459293e-08 Pf_SuMO 0.000566 CoV 0.05940
# LS2:  Degree 2 e_LOO 3.9784161987426166e-08 Pf_SuMO 0.143622 CoV 0.00350
# 0.007975318450987711 0.00540651275561639 LS 1
# number of training points:  19 -------------------------------------------------
# LS1:  Degree 2 e_LOO 3.3104735749130116e-08 Pf_SuMO 0.000556 CoV 0.06000
# LS2:  Degree 2 e_LOO 3.3104750033284746e-08 Pf_SuMO 0.144218 CoV 0.00340
# 0.001553851979440243 0.0024696148126251913 LS 2
# number of training points:  20 -------------------------------------------------
# LS1:  Degree 2 e_LOO 5.63581145171207e-08 Pf_SuMO 0.000596 CoV 0.05790
# LS2:  Degree 2 e_LOO 5.635808382202648e-08 Pf_SuMO 0.143004 CoV 0.00350
# 0.006058260590963007 0.00505017732265382 LS 1
# number of training points:  21 -------------------------------------------------
# LS1:  Degree 3 e_LOO 3.362012721747671e-08 Pf_SuMO 0.00054 CoV 0.06080
# LS2:  Degree 3 e_LOO 3.362012719652701e-08 Pf_SuMO 0.141788 CoV 0.00350
# 0.008647459210495288 0.005062057611343811 LS 1
# number of training points:  22 -------------------------------------------------
# LS1:  Degree 3 e_LOO 8.897578402988157e-05 Pf_SuMO 0.000562 CoV 0.05960
# LS2:  Degree 3 e_LOO 8.897578402989951e-05 Pf_SuMO 0.141426 CoV 0.00350
# 0.003461957201218175 0.001505016302441342 LS 1
# number of training points:  23 -------------------------------------------------
# LS1:  Degree 3 e_LOO 8.138497504005565e-05 Pf_SuMO 0.000566 CoV 0.05940
# LS2:  Degree 3 e_LOO 8.13849750375217e-05 Pf_SuMO 0.1416 CoV 0.00350
# 0.0006180890500504905 0.0007226433720671429 LS 2
# number of training points:  24 -------------------------------------------------
# LS1:  Degree 3 e_LOO 6.177933528173602e-05 Pf_SuMO 0.000584 CoV 0.05850
# LS2:  Degree 3 e_LOO 6.177933528207355e-05 Pf_SuMO 0.142106 CoV 0.00350
# 0.0027340582422774942 0.002099585466790566 LS 1
# number of training points:  25 -------------------------------------------------
# LS1:  Degree 3 e_LOO 5.285455722875949e-05 Pf_SuMO 0.000534 CoV 0.06120
# LS2:  Degree 3 e_LOO 5.285455723060083e-05 Pf_SuMO 0.141868 CoV 0.00350
# 0.007820811478260815 0.000988996872145555 LS 1
# number of training points:  26 -------------------------------------------------
# LS1:  Degree 3 e_LOO 5.089310811044141e-05 Pf_SuMO 0.000564 CoV 0.05950
# LS2:  Degree 3 e_LOO 5.08931081076336e-05 Pf_SuMO 0.141448 CoV 0.00350
# 0.004732669187315494 0.0017463060346513345 LS 1
# number of training points:  27 -------------------------------------------------
# LS1:  Degree 3 e_LOO 4.3897604522219084e-05 Pf_SuMO 0.000542 CoV 0.06070
# LS2:  Degree 3 e_LOO 4.389759766704978e-05 Pf_SuMO 0.142504 CoV 0.00350
# 0.0034634332011625447 0.004376418601559015 LS 2
# number of training points:  28 -------------------------------------------------
# LS1:  Degree 3 e_LOO 4.225789914369169e-05 Pf_SuMO 0.000572 CoV 0.05910
# LS2:  Degree 3 e_LOO 4.225790203408049e-05 Pf_SuMO 0.141564 CoV 0.00350
# 0.00467576103250101 0.003911715492406396 LS 1
# number of training points:  29 -------------------------------------------------
# LS1:  Degree 3 e_LOO 6.668673370135499e-06 Pf_SuMO 0.000488 CoV 0.06400
# LS2:  Degree 3 e_LOO 6.6686709937672555e-06 Pf_SuMO 0.141348 CoV 0.00350
# 0.013795163208625746 0.0008978341247814614 LS 1
# number of training points:  30 -------------------------------------------------
# LS1:  Degree 3 e_LOO 2.5783444574280237e-06 Pf_SuMO 0.000578 CoV 0.05880
# LS2:  Degree 3 e_LOO 2.5783413642797357e-06 Pf_SuMO 0.141476 CoV 0.00350
# 0.014507167340119854 0.0005316846270100204 LS 1
# number of training points:  31 -------------------------------------------------
# LS1:  Degree 2 e_LOO 5.7336530153017e-05 Pf_SuMO 0.000586 CoV 0.05840
# LS2:  Degree 2 e_LOO 5.733653015302999e-05 Pf_SuMO 0.134894 CoV 0.00360
# 0.0012037571352960434 0.027790880277647114 LS 2
# number of training points:  32 -------------------------------------------------
# LS1:  Degree 2 e_LOO 5.624609753100465e-05 Pf_SuMO 0.000622 CoV 0.05670
# LS2:  Degree 2 e_LOO 5.6246097531008914e-05 Pf_SuMO 0.13523 CoV 0.00360
# 0.005241974843150544 0.001401888543936756 LS 1
# number of training points:  33 -------------------------------------------------
# LS1:  Degree 2 e_LOO 5.0957853995667355e-05 Pf_SuMO 0.000558 CoV 0.05990
# LS2:  Degree 2 e_LOO 5.095785399568292e-05 Pf_SuMO 0.137056 CoV 0.00350
# 0.009579236042405554 0.0075878108842346555 LS 1
# number of training points:  34 -------------------------------------------------
# LS1:  Degree 2 e_LOO 4.826543476481798e-05 Pf_SuMO 0.000596 CoV 0.05790
# LS2:  Degree 2 e_LOO 4.8265434764819916e-05 Pf_SuMO 0.136656 CoV 0.00360
# 0.005747715005922845 0.0016688908446882813 LS 1
# number of training points:  35 -------------------------------------------------
# LS1:  Degree 2 e_LOO 4.5920501098878945e-05 Pf_SuMO 0.000522 CoV 0.06190
# LS2:  Degree 2 e_LOO 4.592050109887045e-05 Pf_SuMO 0.136896 CoV 0.00360
# 0.01160375782217932 0.0010000655136595067 LS 1
# number of training points:  36 -------------------------------------------------
# LS1:  Degree 2 e_LOO 4.310477187769984e-05 Pf_SuMO 0.000524 CoV 0.06180
# LS2:  Degree 2 e_LOO 4.310477187771289e-05 Pf_SuMO 0.13577 CoV 0.00360
# 0.0003292746932357203 0.004707119693911621 LS 2
# number of training points:  37 -------------------------------------------------
# LS1:  Degree 2 e_LOO 4.3803587414854484e-05 Pf_SuMO 0.000592 CoV 0.05810
# LS2:  Degree 2 e_LOO 4.380358741488218e-05 Pf_SuMO 0.136936 CoV 0.00360
# 0.010559431027070442 0.004851013178297907 LS 1
# number of training points:  38 -------------------------------------------------
# LS1:  Degree 2 e_LOO 4.2555899889537556e-05 Pf_SuMO 0.000564 CoV 0.05950
# LS2:  Degree 2 e_LOO 4.255589988956465e-05 Pf_SuMO 0.136222 CoV 0.00360
# 0.00424968162257227 0.002981610819850975 LS 1
# number of training points:  39 -------------------------------------------------
# LS1:  Degree 2 e_LOO 4.1245741559883245e-05 Pf_SuMO 0.000532 CoV 0.06130
# LS2:  Degree 2 e_LOO 4.1245741559914104e-05 Pf_SuMO 0.136376 CoV 0.00360
# 0.005080905338615423 0.0006420805650794282 LS 1
# number of training points:  40 -------------------------------------------------
# LS1:  Degree 2 e_LOO 3.908210492231098e-05 Pf_SuMO 0.000582 CoV 0.05860
# LS2:  Degree 2 e_LOO 3.908210492231939e-05 Pf_SuMO 0.13575 CoV 0.00360
# 0.007783391160777419 0.002614794889250507 LS 1
# number of training points:  41 -------------------------------------------------
# LS1:  Degree 2 e_LOO 3.700369682860608e-05 Pf_SuMO 0.000556 CoV 0.06000
# LS2:  Degree 2 e_LOO 3.700369682859066e-05 Pf_SuMO 0.135948 CoV 0.00360
# 0.003997733332457765 0.0008257754044086876 LS 1
# number of training points:  42 -------------------------------------------------
# LS1:  Degree 2 e_LOO 3.519848709563591e-05 Pf_SuMO 0.000604 CoV 0.05750
# LS2:  Degree 2 e_LOO 3.519848709563502e-05 Pf_SuMO 0.136596 CoV 0.00360
# 0.00722465490440436 0.0026990243516485522 LS 1
# number of training points:  43 -------------------------------------------------
# LS1:  Degree 2 e_LOO 3.312092208171718e-05 Pf_SuMO 0.00058 CoV 0.05870
# LS2:  Degree 2 e_LOO 3.3120921356693916e-05 Pf_SuMO 0.136676 CoV 0.00360
# 0.00356901990244069 0.00033350516460063054 LS 1
# number of training points:  44 -------------------------------------------------
# LS1:  Degree 2 e_LOO 3.145220434303658e-05 Pf_SuMO 0.000542 CoV 0.06070
# LS2:  Degree 2 e_LOO 3.145220543656079e-05 Pf_SuMO 0.13695 CoV 0.00360
# 0.005919146821703815 0.0011416256306415462 LS 1
# number of training points:  45 -------------------------------------------------
# LS1:  Degree 2 e_LOO 3.127581964033133e-05 Pf_SuMO 0.000522 CoV 0.06190
# LS2:  Degree 2 e_LOO 3.127581971709935e-05 Pf_SuMO 0.137182 CoV 0.00350
# 0.0032520562763952883 0.000966515551283834 LS 1
# number of training points:  46 -------------------------------------------------
# LS1:  Degree 2 e_LOO 2.9923890270985724e-05 Pf_SuMO 0.000576 CoV 0.05890
# LS2:  Degree 2 e_LOO 2.9923890279309988e-05 Pf_SuMO 0.137136 CoV 0.00350
# 0.008506371227707327 0.00019173320693509344 LS 1
# number of training points:  47 -------------------------------------------------
# LS1:  Degree 2 e_LOO 2.8416063559087742e-05 Pf_SuMO 0.000562 CoV 0.05960
# LS2:  Degree 2 e_LOO 2.8416063608876897e-05 Pf_SuMO 0.137342 CoV 0.00350
# 0.002150435682763452 0.0008581249665429733 LS 1
# number of training points:  48 -------------------------------------------------
# LS1:  Degree 2 e_LOO 2.7301234264338107e-05 Pf_SuMO 0.000594 CoV 0.05800
# LS2:  Degree 2 e_LOO 2.7301234112488064e-05 Pf_SuMO 0.138194 CoV 0.00350
# 0.004834988608913153 0.003542876164255474 LS 1
# number of training points:  49 -------------------------------------------------
# LS1:  Degree 3 e_LOO 2.4542177698231065e-05 Pf_SuMO 0.000602 CoV 0.05760
# LS2:  Degree 3 e_LOO 2.454217769787486e-05 Pf_SuMO 0.141588 CoV 0.00350
# 0.0011767812631126857 0.014017155202388599 LS 2
# number of training points:  50 -------------------------------------------------
# Experiment:  3 #################################################################
# LS1:  Degree 1 e_LOO 4.7118329508449475e-05 Pf_SuMO 0.00023 CoV 0.09320
# LS2:  Degree 1 e_LOO 4.711832950844809e-05 Pf_SuMO 0.14187 CoV 0.00350
# LS 1
# number of training points:  6 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.002297545001047109 Pf_SuMO 0.00106 CoV 0.04340
# LS2:  Degree 1 e_LOO 0.0022975445450421467 Pf_SuMO 0.148632 CoV 0.00340
# 0.12279186010010486 0.027647566959896258 LS 1
# number of training points:  7 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.00010127059042021302 Pf_SuMO 0.000598 CoV 0.05780
# LS2:  Degree 2 e_LOO 0.00010127059041717827 Pf_SuMO 0.137278 CoV 0.00350
# 0.054329104797665145 0.048269376048818674 LS 1
# number of training points:  8 -------------------------------------------------
# LS1:  Degree 1 e_LOO 2.7495764973587042e-05 Pf_SuMO 0.000674 CoV 0.05450
# LS2:  Degree 1 e_LOO 2.7495770644255926e-05 Pf_SuMO 0.144484 CoV 0.00340
# 0.010578470231706086 0.029508953951328826 LS 2
# number of training points:  9 -------------------------------------------------
# LS1:  Degree 2 e_LOO 8.422517000192883e-07 Pf_SuMO 0.000552 CoV 0.06020
# LS2:  Degree 2 e_LOO 8.42251700019791e-07 Pf_SuMO 0.1444 CoV 0.00340
# 0.017790292577937798 0.000348461504884613 LS 1
# number of training points:  10 -------------------------------------------------
# LS1:  Degree 2 e_LOO 3.5055500413405876e-07 Pf_SuMO 0.000528 CoV 0.06150
# LS2:  Degree 2 e_LOO 3.505550041336378e-07 Pf_SuMO 0.144014 CoV 0.00340
# 0.003855227870733248 0.0016024641116694739 LS 1
# number of training points:  11 -------------------------------------------------
# LS1:  Degree 2 e_LOO 1.5920367846119413e-10 Pf_SuMO 0.000534 CoV 0.06120
# LS2:  Degree 2 e_LOO 1.5920367845645035e-10 Pf_SuMO 0.143402 CoV 0.00350
# 0.0009750147818173709 0.002542568562064197 LS 2
# number of training points:  12 -------------------------------------------------
# LS1:  Degree 2 e_LOO 8.629547385726162e-07 Pf_SuMO 0.000548 CoV 0.06040
# LS2:  Degree 2 e_LOO 8.629547385742554e-07 Pf_SuMO 0.142816 CoV 0.00350
# 0.0022383803393464744 0.002435234534375383 LS 2
# number of training points:  13 -------------------------------------------------
# LS1:  Degree 2 e_LOO 4.0107022839540717e-07 Pf_SuMO 0.000568 CoV 0.05930
# LS2:  Degree 2 e_LOO 4.0107022839413826e-07 Pf_SuMO 0.143088 CoV 0.00350
# 0.0031146043903987303 0.0011284375849191434 LS 1
# number of training points:  14 -------------------------------------------------
# LS1:  Degree 2 e_LOO 3.4984578716941563e-07 Pf_SuMO 0.000508 CoV 0.06270
# LS2:  Degree 2 e_LOO 3.498457871686158e-07 Pf_SuMO 0.142744 CoV 0.00350
# 0.009702883926112396 0.0014289972854772436 LS 1
# number of training points:  15 -------------------------------------------------
# LS1:  Degree 3 e_LOO 1.7068613938233413e-07 Pf_SuMO 0.000606 CoV 0.05740
# LS2:  Degree 3 e_LOO 1.7068613931125896e-07 Pf_SuMO 0.142188 CoV 0.00350
# 0.015221063987229444 0.0023112866506508805 LS 1
# number of training points:  16 -------------------------------------------------
# LS1:  Degree 2 e_LOO 2.8508593361121086e-07 Pf_SuMO 0.00052 CoV 0.06200
# LS2:  Degree 2 e_LOO 2.8508593361152553e-07 Pf_SuMO 0.142536 CoV 0.00350
# 0.013422330709965577 0.0014440091928007363 LS 1
# number of training points:  17 -------------------------------------------------
# LS1:  Degree 2 e_LOO 9.368598828463435e-08 Pf_SuMO 0.000584 CoV 0.05850
# LS2:  Degree 2 e_LOO 9.368598828465251e-08 Pf_SuMO 0.141098 CoV 0.00350
# 0.010030458400649 0.00599110583819597 LS 1
# number of training points:  18 -------------------------------------------------
# LS1:  Degree 2 e_LOO 2.0834825199730246e-07 Pf_SuMO 0.00052 CoV 0.06200
# LS2:  Degree 2 e_LOO 2.083483562791596e-07 Pf_SuMO 0.142308 CoV 0.00350
# 0.010132087886708349 0.005013894168298871 LS 1
# number of training points:  19 -------------------------------------------------
# LS1:  Degree 3 e_LOO 1.5011242343124548e-07 Pf_SuMO 0.000506 CoV 0.06290
# LS2:  Degree 3 e_LOO 1.5011166814755618e-07 Pf_SuMO 0.140746 CoV 0.00350
# 0.002345823946921761 0.006510594223972582 LS 2
# number of training points:  20 -------------------------------------------------
# LS1:  Degree 3 e_LOO 6.252789344987788e-08 Pf_SuMO 0.000584 CoV 0.05850
# LS2:  Degree 3 e_LOO 6.252758536999865e-08 Pf_SuMO 0.141624 CoV 0.00350
# 0.012347317713997016 0.003641882846656783 LS 1
# number of training points:  21 -------------------------------------------------
# LS1:  Degree 3 e_LOO 9.601664400240817e-09 Pf_SuMO 0.000586 CoV 0.05840
# LS2:  Degree 3 e_LOO 9.601965275658493e-09 Pf_SuMO 0.141008 CoV 0.00350
# 0.0002997799481267385 0.002562849955370804 LS 2
# number of training points:  22 -------------------------------------------------
# LS1:  Degree 3 e_LOO 1.218005821095053e-08 Pf_SuMO 0.000586 CoV 0.05840
# LS2:  Degree 3 e_LOO 1.2180047604789042e-08 Pf_SuMO 0.141682 CoV 0.00350
# 0.0 0.002796600574256286 LS 2
# number of training points:  23 -------------------------------------------------
# LS1:  Degree 3 e_LOO 2.7870084499893964e-07 Pf_SuMO 0.000562 CoV 0.05960
# LS2:  Degree 3 e_LOO 2.7870080632650594e-07 Pf_SuMO 0.140286 CoV 0.00350
# 0.003662598624627263 0.005818714556321153 LS 2
# number of training points:  24 -------------------------------------------------
# LS1:  Degree 3 e_LOO 1.8122276029397177e-07 Pf_SuMO 0.000552 CoV 0.06020
# LS2:  Degree 3 e_LOO 1.8122270283869212e-07 Pf_SuMO 0.142086 CoV 0.00350
# 0.0015632001234052474 0.007452024840233773 LS 2
# number of training points:  25 -------------------------------------------------
# LS1:  Degree 2 e_LOO 7.191591681703813e-08 Pf_SuMO 0.000512 CoV 0.06250
# LS2:  Degree 2 e_LOO 7.191586055964461e-08 Pf_SuMO 0.140622 CoV 0.00350
# 0.006516499153926655 0.0061015464830448465 LS 1
# number of training points:  26 -------------------------------------------------
# LS1:  Degree 2 e_LOO 3.289968610936691e-08 Pf_SuMO 0.00054 CoV 0.06080
# LS2:  Degree 2 e_LOO 3.289957230283239e-08 Pf_SuMO 0.139964 CoV 0.00350
# 0.004578859434284841 0.0027396868197763235 LS 1
# number of training points:  27 -------------------------------------------------
# LS1:  Degree 2 e_LOO 6.988726889706156e-08 Pf_SuMO 0.00053 CoV 0.06140
# LS2:  Degree 2 e_LOO 6.988717469365868e-08 Pf_SuMO 0.13983 CoV 0.00350
# 0.001616945343615689 0.0005574746788847815 LS 1
# number of training points:  28 -------------------------------------------------
# LS1:  Degree 2 e_LOO 6.111986461659586e-08 Pf_SuMO 0.00058 CoV 0.05870
# LS2:  Degree 2 e_LOO 6.111989637833171e-08 Pf_SuMO 0.13998 CoV 0.00350
# 0.007806817590725681 0.0006236668967900759 LS 1
# number of training points:  29 -------------------------------------------------
# LS1:  Degree 2 e_LOO 1.672849276596314e-08 Pf_SuMO 0.000528 CoV 0.06150
# LS2:  Degree 2 e_LOO 1.6728519299540787e-08 Pf_SuMO 0.14001 CoV 0.00350
# 0.008197055701438217 0.00012475667815599388 LS 1
# number of training points:  30 -------------------------------------------------
# LS1:  Degree 2 e_LOO 8.567268947705991e-10 Pf_SuMO 0.00053 CoV 0.06140
# LS2:  Degree 2 e_LOO 8.567136466662415e-10 Pf_SuMO 0.14065 CoV 0.00350
# 0.000326138790857924 0.0026574926776637775 LS 2
# number of training points:  31 -------------------------------------------------
# LS1:  Degree 2 e_LOO 1.3672039360113087e-08 Pf_SuMO 0.000554 CoV 0.06010
# LS2:  Degree 2 e_LOO 1.3672018776101205e-08 Pf_SuMO 0.140692 CoV 0.00350
# 0.003828557264061613 0.0001745745755804512 LS 1
# number of training points:  32 -------------------------------------------------
# LS1:  Degree 2 e_LOO 2.8603444415900917e-08 Pf_SuMO 0.000568 CoV 0.05930
# LS2:  Degree 2 e_LOO 2.8603394391564913e-08 Pf_SuMO 0.140954 CoV 0.00350
# 0.002171386727276717 0.001088405278920701 LS 1
# number of training points:  33 -------------------------------------------------
# LS1:  Degree 2 e_LOO 6.501583514738264e-08 Pf_SuMO 0.000594 CoV 0.05800
# LS2:  Degree 2 e_LOO 6.501598462892712e-08 Pf_SuMO 0.13995 CoV 0.00350
# 0.003912989786582162 0.004182873339084616 LS 2
# number of training points:  34 -------------------------------------------------
# LS1:  Degree 2 e_LOO 2.8526436955074998e-08 Pf_SuMO 0.000542 CoV 0.06070
# LS2:  Degree 2 e_LOO 2.8526468771879182e-08 Pf_SuMO 0.141184 CoV 0.00350
# 0.00802660715358318 0.0051168497764262156 LS 1
# number of training points:  35 -------------------------------------------------
# LS1:  Degree 2 e_LOO 4.896292523118733e-08 Pf_SuMO 0.000514 CoV 0.06240
# LS2:  Degree 2 e_LOO 4.896296775006807e-08 Pf_SuMO 0.141402 CoV 0.00350
# 0.00458525883953169 0.0009054250862667014 LS 1
# number of training points:  36 -------------------------------------------------
# LS1:  Degree 2 e_LOO 2.517973415031462e-08 Pf_SuMO 0.00057 CoV 0.05920
# LS2:  Degree 2 e_LOO 2.5179777523692654e-08 Pf_SuMO 0.141686 CoV 0.00350
# 0.00891556027379903 0.0011791944144994098 LS 1
# number of training points:  37 -------------------------------------------------
# LS1:  Degree 2 e_LOO 1.2670775683300676e-09 Pf_SuMO 0.000564 CoV 0.05950
# LS2:  Degree 2 e_LOO 1.2670766668435207e-09 Pf_SuMO 0.141914 CoV 0.00350
# 0.0009237401885318592 0.0009466353347696295 LS 2
# number of training points:  38 -------------------------------------------------
# LS1:  Degree 2 e_LOO 5.941191505906276e-09 Pf_SuMO 0.000538 CoV 0.06100
# LS2:  Degree 2 e_LOO 5.9411922293039784e-09 Pf_SuMO 0.141442 CoV 0.00350
# 0.004107082588209523 0.001962702904926192 LS 1
# number of training points:  39 -------------------------------------------------
# LS1:  Degree 2 e_LOO 9.575483502984779e-11 Pf_SuMO 0.000584 CoV 0.05850
# LS2:  Degree 2 e_LOO 9.575671226947147e-11 Pf_SuMO 0.141674 CoV 0.00350
# 0.007119689343222394 0.0009633810529132673 LS 1
# number of training points:  40 -------------------------------------------------
# LS1:  Degree 2 e_LOO 4.4227457561244984e-11 Pf_SuMO 0.000564 CoV 0.05950
# LS2:  Degree 2 e_LOO 4.4227450387412496e-11 Pf_SuMO 0.141002 CoV 0.00350
# 0.0030511289774423516 0.0027961226093351295 LS 1
# number of training points:  41 -------------------------------------------------
# LS1:  Degree 2 e_LOO 4.439533866578756e-08 Pf_SuMO 0.000534 CoV 0.06120
# LS2:  Degree 2 e_LOO 4.439537423193076e-08 Pf_SuMO 0.141594 CoV 0.00350
# 0.004755173852085588 0.002456853176481952 LS 1
# number of training points:  42 -------------------------------------------------
# LS1:  Degree 2 e_LOO 2.3022158428311362e-08 Pf_SuMO 0.000644 CoV 0.05570
# LS2:  Degree 2 e_LOO 2.3022148921301216e-08 Pf_SuMO 0.141426 CoV 0.00350
# 0.01629971856487247 0.0006982218275125528 LS 1
# number of training points:  43 -------------------------------------------------
# LS1:  Degree 3 e_LOO 9.092032727501499e-09 Pf_SuMO 0.000598 CoV 0.05780
# LS2:  Degree 3 e_LOO 9.092032744111754e-09 Pf_SuMO 0.142524 CoV 0.00350
# 0.006584198939398147 0.004550087599000654 LS 1
# number of training points:  44 -------------------------------------------------
# LS1:  Degree 2 e_LOO 4.6540190033916805e-09 Pf_SuMO 0.000522 CoV 0.06190
# LS2:  Degree 2 e_LOO 4.6540215856486415e-09 Pf_SuMO 0.141494 CoV 0.00350
# 0.0119019997311791 0.0042871102985951245 LS 1
# number of training points:  45 -------------------------------------------------
# LS1:  Degree 2 e_LOO 2.234193205112727e-09 Pf_SuMO 0.000502 CoV 0.06310
# LS2:  Degree 2 e_LOO 2.2341948812485323e-09 Pf_SuMO 0.142116 CoV 0.00350
# 0.0033585396966054194 0.002580369265272794 LS 1
# number of training points:  46 -------------------------------------------------
# LS1:  Degree 2 e_LOO 9.191378262278213e-14 Pf_SuMO 0.000556 CoV 0.06000
# LS2:  Degree 2 e_LOO 9.189440998551857e-14 Pf_SuMO 0.141212 CoV 0.00350
# 0.008774454426055714 0.003762488101911972 LS 1
# number of training points:  47 -------------------------------------------------
# LS1:  Degree 3 e_LOO 5.716377147287538e-09 Pf_SuMO 0.000556 CoV 0.06000
# LS2:  Degree 3 e_LOO 5.716377136550654e-09 Pf_SuMO 0.141616 CoV 0.00350
# 0.0 0.0016771661391537195 LS 2
# number of training points:  48 -------------------------------------------------
# LS1:  Degree 3 e_LOO 4.284745760416794e-09 Pf_SuMO 0.000586 CoV 0.05840
# LS2:  Degree 3 e_LOO 4.284745760837866e-09 Pf_SuMO 0.1414 CoV 0.00350
# 0.004579754293731765 0.0008978044731632193 LS 1
# number of training points:  49 -------------------------------------------------
# LS1:  Degree 3 e_LOO 4.7909669079061955e-09 Pf_SuMO 0.00057 CoV 0.05920
# LS2:  Degree 3 e_LOO 4.790966900741273e-09 Pf_SuMO 0.141628 CoV 0.00350
# 0.0024259326420947853 0.0009468052409631644 LS 1
# number of training points:  50 -------------------------------------------------
# Experiment:  4 #################################################################
# LS1:  Degree 1 e_LOO 4.4104802392145745e-05 Pf_SuMO 0.000214 CoV 0.09670
# LS2:  Degree 1 e_LOO 4.410480239214685e-05 Pf_SuMO 0.13085 CoV 0.00360
# LS 1
# number of training points:  6 -------------------------------------------------
# LS1:  Degree 1 e_LOO 3.038321652062622e-06 Pf_SuMO 0.00023 CoV 0.09320
# LS2:  Degree 1 e_LOO 3.0383216520622107e-06 Pf_SuMO 0.132864 CoV 0.00360
# 0.0054397072146514965 0.008399719150828733 LS 2
# number of training points:  7 -------------------------------------------------
# LS1:  Degree 1 e_LOO 1.100509049561746e-06 Pf_SuMO 0.000268 CoV 0.08640
# LS2:  Degree 1 e_LOO 1.1005090495623367e-06 Pf_SuMO 0.134816 CoV 0.00360
# 0.011686944858472806 0.008126134352408663 LS 1
# number of training points:  8 -------------------------------------------------
# LS1:  Degree 2 e_LOO 1.2320446316352718e-07 Pf_SuMO 0.000474 CoV 0.06490
# LS2:  Degree 2 e_LOO 1.232044633033557e-07 Pf_SuMO 0.13748 CoV 0.00350
# 0.04522354609502515 0.0110507862008106 LS 1
# number of training points:  9 -------------------------------------------------
# LS1:  Degree 2 e_LOO 7.171502162625487e-07 Pf_SuMO 0.00049 CoV 0.06390
# LS2:  Degree 2 e_LOO 7.171502162417157e-07 Pf_SuMO 0.13706 CoV 0.00350
# 0.002817901971873171 0.001751815453744543 LS 1
# number of training points:  10 -------------------------------------------------
# LS1:  Degree 2 e_LOO 3.2625665494863535e-05 Pf_SuMO 0.000534 CoV 0.06120
# LS2:  Degree 2 e_LOO 3.2625735482015046e-05 Pf_SuMO 0.137846 CoV 0.00350
# 0.007352076438736535 0.0032696926398115295 LS 1
# number of training points:  11 -------------------------------------------------
# LS1:  Degree 2 e_LOO 2.1244262310765688e-07 Pf_SuMO 0.000594 CoV 0.05800
# LS2:  Degree 2 e_LOO 2.124440010453401e-07 Pf_SuMO 0.137938 CoV 0.00350
# 0.009238083952590334 0.0003831322003906035 LS 1
# number of training points:  12 -------------------------------------------------
# LS1:  Degree 1 e_LOO 1.0836267682400114e-08 Pf_SuMO 0.000596 CoV 0.05790
# LS2:  Degree 1 e_LOO 1.0836267682415887e-08 Pf_SuMO 0.137916 CoV 0.00350
# 0.00029556178663527554 9.163781655932567e-05 LS 1
# number of training points:  13 -------------------------------------------------
# LS1:  Degree 1 e_LOO 2.270286616475997e-10 Pf_SuMO 0.00053 CoV 0.06140
# LS2:  Degree 1 e_LOO 2.270286616497068e-10 Pf_SuMO 0.134616 CoV 0.00360
# 0.010278387023015494 0.013859103579571824 LS 2
# number of training points:  14 -------------------------------------------------
# LS1:  Degree 2 e_LOO 3.445312408641389e-07 Pf_SuMO 0.00054 CoV 0.06080
# LS2:  Degree 2 e_LOO 3.4453221746391584e-07 Pf_SuMO 0.140792 CoV 0.00350
# 0.0016143350520702086 0.025402097058711312 LS 2
# number of training points:  15 -------------------------------------------------
# LS1:  Degree 1 e_LOO 1.250189908054169e-06 Pf_SuMO 0.000642 CoV 0.05580
# LS2:  Degree 1 e_LOO 1.2501899080541897e-06 Pf_SuMO 0.138244 CoV 0.00350
# 0.015075820702617065 0.0106567268543911 LS 1
# number of training points:  16 -------------------------------------------------
# LS1:  Degree 2 e_LOO 5.776645768730457e-06 Pf_SuMO 0.000572 CoV 0.05910
# LS2:  Degree 2 e_LOO 5.776646038804027e-06 Pf_SuMO 0.139604 CoV 0.00350
# 0.010235807295610189 0.005644362869167708 LS 1
# number of training points:  17 -------------------------------------------------
# LS1:  Degree 2 e_LOO 4.452831564391228e-06 Pf_SuMO 0.000574 CoV 0.05900
# LS2:  Degree 2 e_LOO 4.452829562889644e-06 Pf_SuMO 0.139462 CoV 0.00350
# 0.00030502286216710714 0.0005909185826051372 LS 2
# number of training points:  18 -------------------------------------------------
# LS1:  Degree 2 e_LOO 7.588878196174659e-07 Pf_SuMO 0.000592 CoV 0.05810
# LS2:  Degree 2 e_LOO 7.588873519066341e-07 Pf_SuMO 0.139934 CoV 0.00350
# 0.002702671755740127 0.0019614442791230364 LS 1
# number of training points:  19 -------------------------------------------------
# LS1:  Degree 2 e_LOO 4.935299938535152e-06 Pf_SuMO 0.00054 CoV 0.06080
# LS2:  Degree 2 e_LOO 4.93529594614889e-06 Pf_SuMO 0.13977 CoV 0.00350
# 0.008050472067143115 0.000682346525943797 LS 1
# number of training points:  20 -------------------------------------------------
# LS1:  Degree 2 e_LOO 3.920549280399082e-06 Pf_SuMO 0.00054 CoV 0.06080
# LS2:  Degree 2 e_LOO 3.920561956251495e-06 Pf_SuMO 0.140042 CoV 0.00350
# 0.0 0.001130628444401371 LS 2
# number of training points:  21 -------------------------------------------------
# LS1:  Degree 2 e_LOO 8.052979527824398e-07 Pf_SuMO 0.000626 CoV 0.05650
# LS2:  Degree 2 e_LOO 8.052895495627523e-07 Pf_SuMO 0.141954 CoV 0.00350
# 0.012864341454312178 0.007914836693531081 LS 1
# number of training points:  22 -------------------------------------------------
# LS1:  Degree 2 e_LOO 9.907239396664472e-07 Pf_SuMO 0.000608 CoV 0.05730
# LS2:  Degree 2 e_LOO 9.907183762227888e-07 Pf_SuMO 0.141102 CoV 0.00350
# 0.0025844306641322015 0.003545982499901547 LS 2
# number of training points:  23 -------------------------------------------------
# LS1:  Degree 2 e_LOO 1.2115514291999077e-07 Pf_SuMO 0.000582 CoV 0.05860
# LS2:  Degree 2 e_LOO 1.2115520550113273e-07 Pf_SuMO 0.141618 CoV 0.00350
# 0.0038507405984148247 0.0021416990448417817 LS 1
# number of training points:  24 -------------------------------------------------
# LS1:  Degree 2 e_LOO 1.1443719678411216e-06 Pf_SuMO 0.00062 CoV 0.05680
# LS2:  Degree 2 e_LOO 1.1443702995706247e-06 Pf_SuMO 0.139626 CoV 0.00350
# 0.005555552834075526 0.008315254221412703 LS 2
# number of training points:  25 -------------------------------------------------
# LS1:  Degree 2 e_LOO 1.4894810894375956e-06 Pf_SuMO 0.000502 CoV 0.06310
# LS2:  Degree 2 e_LOO 1.4894807297693602e-06 Pf_SuMO 0.140294 CoV 0.00350
# 0.018543822808193486 0.0027743029409471732 LS 1
# number of training points:  26 -------------------------------------------------
# LS1:  Degree 2 e_LOO 1.4517331535844793e-06 Pf_SuMO 0.00057 CoV 0.05920
# LS2:  Degree 2 e_LOO 1.4517320686465818e-06 Pf_SuMO 0.141166 CoV 0.00350
# 0.010920390157474482 0.0036181180827453115 LS 1
# number of training points:  27 -------------------------------------------------
# LS1:  Degree 2 e_LOO 8.220338998450069e-07 Pf_SuMO 0.000536 CoV 0.06110
# LS2:  Degree 2 e_LOO 8.220337073193757e-07 Pf_SuMO 0.14018 CoV 0.00350
# 0.005358401860645811 0.004107116266058216 LS 1
# number of training points:  28 -------------------------------------------------
# LS1:  Degree 2 e_LOO 9.544235604911339e-07 Pf_SuMO 0.000552 CoV 0.06020
# LS2:  Degree 2 e_LOO 9.544244722481247e-07 Pf_SuMO 0.139662 CoV 0.00350
# 0.002545957819555737 0.0021567007458075564 LS 1
# number of training points:  29 -------------------------------------------------
# LS1:  Degree 2 e_LOO 1.1867065598947048e-06 Pf_SuMO 0.000598 CoV 0.05780
# LS2:  Degree 2 e_LOO 1.186706679628715e-06 Pf_SuMO 0.139616 CoV 0.00350
# 0.006974640980250083 0.00019137165774844015 LS 1
# number of training points:  30 -------------------------------------------------
# LS1:  Degree 2 e_LOO 1.4594761134722302e-06 Pf_SuMO 0.000562 CoV 0.05960
# LS2:  Degree 2 e_LOO 1.4594733312322072e-06 Pf_SuMO 0.139544 CoV 0.00350
# 0.005451905722678921 0.0002995670141263866 LS 1
# number of training points:  31 -------------------------------------------------
# LS1:  Degree 2 e_LOO 1.4649995926694524e-06 Pf_SuMO 0.000558 CoV 0.05990
# LS2:  Degree 2 e_LOO 1.464998678816355e-06 Pf_SuMO 0.138918 CoV 0.00350
# 0.0006221697023806322 0.002608229788498467 LS 2
# number of training points:  32 -------------------------------------------------
# LS1:  Degree 2 e_LOO 1.0093261126050203e-06 Pf_SuMO 0.00056 CoV 0.05970
# LS2:  Degree 2 e_LOO 1.009326432635698e-06 Pf_SuMO 0.140902 CoV 0.00350
# 0.00031140471002157174 0.008217683123054913 LS 2
# number of training points:  33 -------------------------------------------------
# LS1:  Degree 2 e_LOO 2.3184209278737694e-06 Pf_SuMO 0.000542 CoV 0.06070
# LS2:  Degree 2 e_LOO 2.3184212010882077e-06 Pf_SuMO 0.14129 CoV 0.00350
# 0.0028413563011647587 0.001611126843271691 LS 1
# number of training points:  34 -------------------------------------------------
# LS1:  Degree 2 e_LOO 2.5104223147914917e-06 Pf_SuMO 0.000506 CoV 0.06290
# LS2:  Degree 2 e_LOO 2.510422053401627e-06 Pf_SuMO 0.141936 CoV 0.00350
# 0.005937805418363735 0.002680121505510617 LS 1
# number of training points:  35 -------------------------------------------------
# LS1:  Degree 2 e_LOO 1.7664320350360146e-06 Pf_SuMO 0.00057 CoV 0.05920
# LS2:  Degree 2 e_LOO 1.7664317493301027e-06 Pf_SuMO 0.14144 CoV 0.00350
# 0.010248135569274525 0.0020625913510373527 LS 1
# number of training points:  36 -------------------------------------------------
# LS1:  Degree 2 e_LOO 1.0535579628090127e-07 Pf_SuMO 0.000584 CoV 0.05850
# LS2:  Degree 2 e_LOO 1.053559360209523e-07 Pf_SuMO 0.141016 CoV 0.00350
# 0.002120917595775255 0.0017634351164183921 LS 1
# number of training points:  37 -------------------------------------------------
# LS1:  Degree 2 e_LOO 1.1575616360601588e-07 Pf_SuMO 0.000548 CoV 0.06040
# LS2:  Degree 2 e_LOO 1.1575615170321002e-07 Pf_SuMO 0.141256 CoV 0.00350
# 0.005564925188263665 0.000996853710131525 LS 1
# number of training points:  38 -------------------------------------------------
# LS1:  Degree 2 e_LOO 6.100421703582794e-07 Pf_SuMO 0.000602 CoV 0.05760
# LS2:  Degree 2 e_LOO 6.100421746377044e-07 Pf_SuMO 0.139542 CoV 0.00350
# 0.008183932425694289 0.007151719942207315 LS 1
# number of training points:  39 -------------------------------------------------
# LS1:  Degree 2 e_LOO 6.787557200522518e-07 Pf_SuMO 0.000546 CoV 0.06050
# LS2:  Degree 2 e_LOO 6.787557937293941e-07 Pf_SuMO 0.140702 CoV 0.00350
# 0.008571297150331078 0.0048121968156528685 LS 1
# number of training points:  40 -------------------------------------------------
# LS1:  Degree 2 e_LOO 7.274721115870295e-07 Pf_SuMO 0.00056 CoV 0.05970
# LS2:  Degree 2 e_LOO 7.274720269905108e-07 Pf_SuMO 0.140224 CoV 0.00350
# 0.0021976415657203796 0.001989252763523888 LS 1
# number of training points:  41 -------------------------------------------------
# LS1:  Degree 2 e_LOO 7.886736747480403e-07 Pf_SuMO 0.000468 CoV 0.06540
# LS2:  Degree 2 e_LOO 7.886736000283874e-07 Pf_SuMO 0.14114 CoV 0.00350
# 0.015523042546544758 0.003800458141048364 LS 1
# number of training points:  42 -------------------------------------------------
# LS1:  Degree 2 e_LOO 7.263870758980153e-07 Pf_SuMO 0.000576 CoV 0.05890
# LS2:  Degree 2 e_LOO 7.263870547748485e-07 Pf_SuMO 0.140156 CoV 0.00350
# 0.017703854686985522 0.004098836916783645 LS 1
# number of training points:  43 -------------------------------------------------
# LS1:  Degree 2 e_LOO 6.788819105163403e-07 Pf_SuMO 0.000502 CoV 0.06310
# LS2:  Degree 2 e_LOO 6.788818909748762e-07 Pf_SuMO 0.139852 CoV 0.00350
# 0.011966704152203536 0.0012650716917946535 LS 1
# number of training points:  44 -------------------------------------------------
# ...
# number of training points:  37 -------------------------------------------------
# LS1:  Degree 2 e_LOO 2.845705871210303e-09 Pf_SuMO 0.000614 CoV 0.05710
# LS2:  Degree 2 e_LOO 2.8457066077636743e-09 Pf_SuMO 0.14231 CoV 0.00350
# 0.007122351582640604 0.0018505869254357241 LS 1
# number of training points:  38 -------------------------------------------------
# LS1:  Degree 1 e_LOO 9.84843746911002e-10 Pf_SuMO 0.000592 CoV 0.05810
# LS2:  Degree 1 e_LOO 9.849071699867515e-10 Pf_SuMO 0.144146 CoV 0.00340
# 0.0032210168687923195 0.007591136432480649 LS 2
# number of training points:  39 -------------------------------------------------
# LS1:  Degree 2 e_LOO 3.7528152354507216e-08 Pf_SuMO 0.000554 CoV 0.06010
# LS2:  Degree 2 e_LOO 3.752815240810765e-08 Pf_SuMO 0.141644 CoV 0.00350
# 0.005814815221873907 0.01044040057582304 LS 2
# number of training points:  40 -------------------------------------------------
# LS1:  Degree 2 e_LOO 3.8138131450646673e-08 Pf_SuMO 0.000538 CoV 0.06100
# LS2:  Degree 2 e_LOO 3.813813097388193e-08 Pf_SuMO 0.14198 CoV 0.00350
# 0.002544606366471948 0.0013947184642732957 LS 1
# number of training points:  41 -------------------------------------------------
# LS1:  Degree 2 e_LOO 3.3584350272586244e-08 Pf_SuMO 0.000592 CoV 0.05810
# LS2:  Degree 2 e_LOO 3.3584351060539894e-08 Pf_SuMO 0.142936 CoV 0.00350
# 0.008304672863169719 0.003961652044118703 LS 1
# number of training points:  42 -------------------------------------------------
# LS1:  Degree 2 e_LOO 3.002206374760338e-08 Pf_SuMO 0.000642 CoV 0.05580
# LS2:  Degree 2 e_LOO 3.00220640190045e-08 Pf_SuMO 0.141716 CoV 0.00350
# 0.007146716108929627 0.005078965156128185 LS 1
# number of training points:  43 -------------------------------------------------
# LS1:  Degree 2 e_LOO 2.4002460548562955e-08 Pf_SuMO 0.00053 CoV 0.06140
# LS2:  Degree 2 e_LOO 2.4002460957618882e-08 Pf_SuMO 0.142394 CoV 0.00350
# 0.016948275204433403 0.002811925764826244 LS 1
# number of training points:  44 -------------------------------------------------
# LS1:  Degree 2 e_LOO 2.2243698258940775e-08 Pf_SuMO 0.000606 CoV 0.05740
# LS2:  Degree 2 e_LOO 2.2243698528809694e-08 Pf_SuMO 0.142566 CoV 0.00350
# 0.011623551200736522 0.0007139160840147264 LS 1
# number of training points:  45 -------------------------------------------------
# LS1:  Degree 2 e_LOO 1.1370560289519708e-08 Pf_SuMO 0.000608 CoV 0.05730
# LS2:  Degree 2 e_LOO 1.1370560111593773e-08 Pf_SuMO 0.142348 CoV 0.00350
# 0.00029067138161297933 0.0009055925000258654 LS 2
# number of training points:  46 -------------------------------------------------
# LS1:  Degree 2 e_LOO 1.1754226147657182e-08 Pf_SuMO 0.00052 CoV 0.06200
# LS2:  Degree 2 e_LOO 1.1754226177151187e-08 Pf_SuMO 0.14215 CoV 0.00350
# 0.013716989227788969 0.000822579142098606 LS 1
# number of training points:  47 -------------------------------------------------
# LS1:  Degree 2 e_LOO 1.1200762080493578e-08 Pf_SuMO 0.00054 CoV 0.06080
# LS2:  Degree 2 e_LOO 1.1200762285537345e-08 Pf_SuMO 0.14243 CoV 0.00350
# 0.0032517575416587488 0.0011620606625248272 LS 1
# number of training points:  48 -------------------------------------------------
# LS1:  Degree 2 e_LOO 9.02887478776132e-09 Pf_SuMO 0.000586 CoV 0.05840
# LS2:  Degree 2 e_LOO 9.028874772689046e-09 Pf_SuMO 0.142262 CoV 0.00350
# 0.007098556661978437 0.0006978616665305274 LS 1
# number of training points:  49 -------------------------------------------------
# LS1:  Degree 2 e_LOO 7.266437842724142e-09 Pf_SuMO 0.000564 CoV 0.05950
# LS2:  Degree 2 e_LOO 7.266438056823401e-09 Pf_SuMO 0.1421 CoV 0.00350
# 0.0033519137621028186 0.0006729966893656563 LS 1
# number of training points:  50 -------------------------------------------------
# Experiment:  8 #################################################################
# LS1:  Degree 1 e_LOO 6.97630768654039e-06 Pf_SuMO 0.000254 CoV 0.08870
# LS2:  Degree 1 e_LOO 6.97630768653918e-06 Pf_SuMO 0.143368 CoV 0.00350
# LS 1
# number of training points:  6 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.00016598078263673605 Pf_SuMO 0.000366 CoV 0.07390
# LS2:  Degree 1 e_LOO 0.00016598078263674163 Pf_SuMO 0.147008 CoV 0.00340
# 0.02853381026083549 0.01497871227151721 LS 1
# number of training points:  7 -------------------------------------------------
# LS1:  Degree 1 e_LOO 5.3428374756404285e-05 Pf_SuMO 0.000552 CoV 0.06020
# LS2:  Degree 1 e_LOO 5.3428410910855795e-05 Pf_SuMO 0.146472 CoV 0.00340
# 0.03396692876137075 0.002223181099627725 LS 1
# number of training points:  8 -------------------------------------------------
# LS1:  Degree 2 e_LOO 3.0393187310126718e-06 Pf_SuMO 0.00058 CoV 0.05870
# LS2:  Degree 2 e_LOO 3.0393187310296454e-06 Pf_SuMO 0.142054 CoV 0.00350
# 0.004306526989095605 0.0184954799433069 LS 2
# number of training points:  9 -------------------------------------------------
# LS1:  Degree 2 e_LOO 1.3734652493368704e-05 Pf_SuMO 0.000592 CoV 0.05810
# LS2:  Degree 2 e_LOO 1.3734652493467578e-05 Pf_SuMO 0.140992 CoV 0.00350
# 0.0017948164481199904 0.0044219391522707175 LS 2
# number of training points:  10 -------------------------------------------------
# LS1:  Degree 2 e_LOO 7.098815588076358e-07 Pf_SuMO 0.000554 CoV 0.06010
# LS2:  Degree 2 e_LOO 7.098815588031734e-07 Pf_SuMO 0.13952 CoV 0.00350
# 0.005814815221873907 0.006139466712573972 LS 2
# number of training points:  11 -------------------------------------------------
# LS1:  Degree 2 e_LOO 7.670884879985998e-06 Pf_SuMO 0.000548 CoV 0.06040
# LS2:  Degree 2 e_LOO 7.670884880033741e-06 Pf_SuMO 0.14249 CoV 0.00350
# 0.0009461645915127789 0.012267586751238187 LS 2
# number of training points:  12 -------------------------------------------------
# LS1:  Degree 2 e_LOO 4.8781963046407096e-06 Pf_SuMO 0.000502 CoV 0.06310
# LS2:  Degree 2 e_LOO 4.8781963046326365e-06 Pf_SuMO 0.142898 CoV 0.00350
# 0.00758273143538511 0.0016924326284954373 LS 1
# number of training points:  13 -------------------------------------------------
# LS1:  Degree 1 e_LOO 2.4197901241234174e-07 Pf_SuMO 0.000522 CoV 0.06190
# LS2:  Degree 1 e_LOO 2.419790124120078e-07 Pf_SuMO 0.14237 CoV 0.00350
# 0.0033472976645227653 0.0021945446076262667 LS 1
# number of training points:  14 -------------------------------------------------
# LS1:  Degree 1 e_LOO 7.293388787780058e-11 Pf_SuMO 0.000542 CoV 0.06070
# LS2:  Degree 1 e_LOO 7.293388787969688e-11 Pf_SuMO 0.14172 CoV 0.00350
# 0.0032415146882084724 0.002703259941326393 LS 1
# number of training points:  15 -------------------------------------------------
# LS1:  Degree 3 e_LOO 3.007074930867985e-07 Pf_SuMO 0.000502 CoV 0.06310
# LS2:  Degree 3 e_LOO 3.0070749311668774e-07 Pf_SuMO 0.141984 CoV 0.00350
# 0.006621518133100576 0.0010959867915028459 LS 1
# number of training points:  16 -------------------------------------------------
# LS1:  Degree 3 e_LOO 2.4018796602767115e-07 Pf_SuMO 0.000546 CoV 0.06050
# LS2:  Degree 3 e_LOO 2.401879662002376e-07 Pf_SuMO 0.141496 CoV 0.00350
# 0.007210835796160231 0.0020292239166981667 LS 1
# number of training points:  17 -------------------------------------------------
# LS1:  Degree 3 e_LOO 7.497030307823802e-07 Pf_SuMO 0.000562 CoV 0.05960
# LS2:  Degree 3 e_LOO 7.49703030700932e-07 Pf_SuMO 0.141004 CoV 0.00350
# 0.0025074340745794245 0.0020465105584854012 LS 1
# number of training points:  18 -------------------------------------------------
# LS1:  Degree 3 e_LOO 7.473821791485496e-07 Pf_SuMO 0.000642 CoV 0.05580
# LS2:  Degree 3 e_LOO 7.473821792740267e-07 Pf_SuMO 0.140956 CoV 0.00350
# 0.011654209877207798 0.0001995103476854414 LS 1
# number of training points:  19 -------------------------------------------------
# LS1:  Degree 3 e_LOO 6.357279298032985e-07 Pf_SuMO 0.000554 CoV 0.06010
# LS2:  Degree 3 e_LOO 6.357279297842326e-07 Pf_SuMO 0.141154 CoV 0.00350
# 0.013054830498224541 0.0008225193608643603 LS 1
# number of training points:  20 -------------------------------------------------
# LS1:  Degree 3 e_LOO 5.292873990356821e-07 Pf_SuMO 0.000576 CoV 0.05890
# LS2:  Degree 3 e_LOO 5.292873990649957e-07 Pf_SuMO 0.141174 CoV 0.00350
# 0.0033900657000257945 8.310760477341771e-05 LS 1
# number of training points:  21 -------------------------------------------------
# LS1:  Degree 3 e_LOO 4.6778462681424067e-07 Pf_SuMO 0.000568 CoV 0.05930
# LS2:  Degree 3 e_LOO 4.677846268739698e-07 Pf_SuMO 0.141674 CoV 0.00350
# 0.0012228244278992527 0.0020752739627449414 LS 2
# number of training points:  22 -------------------------------------------------
# LS1:  Degree 2 e_LOO 1.624583835250422e-07 Pf_SuMO 0.000526 CoV 0.06160
# LS2:  Degree 2 e_LOO 1.624584586389435e-07 Pf_SuMO 0.141988 CoV 0.00350
# 0.0066853224235909284 0.0013034417496003172 LS 1
# number of training points:  23 -------------------------------------------------
# LS1:  Degree 1 e_LOO 1.9730741325629996e-07 Pf_SuMO 0.000588 CoV 0.05830
# LS2:  Degree 1 e_LOO 1.9721490673335756e-07 Pf_SuMO 0.14228 CoV 0.00350
# 0.009645088127485423 0.0012119475111527162 LS 1
# number of training points:  24 -------------------------------------------------
# LS1:  Degree 2 e_LOO 2.1135145875699575e-07 Pf_SuMO 0.00055 CoV 0.06030
# LS2:  Degree 2 e_LOO 2.1135204210325424e-07 Pf_SuMO 0.141928 CoV 0.00350
# 0.0058491342104823535 0.0014629597520888944 LS 1
# number of training points:  25 -------------------------------------------------
# LS1:  Degree 2 e_LOO 1.4118685064730143e-07 Pf_SuMO 0.00053 CoV 0.06140
# LS2:  Degree 2 e_LOO 1.4118765436424613e-07 Pf_SuMO 0.142012 CoV 0.00350
# 0.0032115325745976386 0.0003488279882617559 LS 1
# number of training points:  26 -------------------------------------------------
# LS1:  Degree 2 e_LOO 1.3905746079398087e-07 Pf_SuMO 0.000586 CoV 0.05840
# LS2:  Degree 2 e_LOO 1.390575705546996e-07 Pf_SuMO 0.142034 CoV 0.00350
# 0.008701432265210108 9.1368499458803e-05 LS 1
# number of training points:  27 -------------------------------------------------
# LS1:  Degree 2 e_LOO 8.985049411049923e-08 Pf_SuMO 0.000542 CoV 0.06070
# LS2:  Degree 2 e_LOO 8.985073597799173e-08 Pf_SuMO 0.142284 CoV 0.00350
# 0.006826956092676464 0.0010377009655005939 LS 1
# number of training points:  28 -------------------------------------------------
# LS1:  Degree 2 e_LOO 1.2822850020236535e-07 Pf_SuMO 0.000572 CoV 0.05910
# LS2:  Degree 2 e_LOO 1.2822835891610648e-07 Pf_SuMO 0.14187 CoV 0.00350
# 0.00467576103250101 0.0017208902873373476 LS 1
# number of training points:  29 -------------------------------------------------
# LS1:  Degree 2 e_LOO 1.194529822345288e-07 Pf_SuMO 0.00052 CoV 0.06200
# LS2:  Degree 2 e_LOO 1.1945298923764186e-07 Pf_SuMO 0.142596 CoV 0.00350
# 0.008298136169553553 0.0030103750315778593 LS 1
# number of training points:  30 -------------------------------------------------
# LS1:  Degree 2 e_LOO 3.4915763518522915e-07 Pf_SuMO 0.000466 CoV 0.06550
# LS2:  Degree 2 e_LOO 3.4915742641324135e-07 Pf_SuMO 0.14277 CoV 0.00350
# 0.009395377591352849 0.0007221278421286343 LS 1
# number of training points:  31 -------------------------------------------------
# LS1:  Degree 2 e_LOO 3.371080218331412e-07 Pf_SuMO 0.000554 CoV 0.06010
# LS2:  Degree 2 e_LOO 3.3710761623998917e-07 Pf_SuMO 0.141784 CoV 0.00350
# 0.014719431250799992 0.004102925367920169 LS 1
# number of training points:  32 -------------------------------------------------
# LS1:  Degree 1 e_LOO 7.917443551903721e-06 Pf_SuMO 0.000562 CoV 0.05960
# LS2:  Degree 1 e_LOO 7.918710731618904e-06 Pf_SuMO 0.140666 CoV 0.00350
# 0.0012469201355105905 0.004656542983394346 LS 2
# number of training points:  33 -------------------------------------------------
# LS1:  Degree 1 e_LOO 6.73041654857602e-06 Pf_SuMO 0.000544 CoV 0.06060
# LS2:  Degree 1 e_LOO 6.731566905421405e-06 Pf_SuMO 0.141618 CoV 0.00350
# 0.002832730289427884 0.003948333626217735 LS 2
# number of training points:  34 -------------------------------------------------
# LS1:  Degree 1 e_LOO 5.003894431114988e-06 Pf_SuMO 0.000584 CoV 0.05850
# LS2:  Degree 1 e_LOO 5.0041003948421375e-06 Pf_SuMO 0.141418 CoV 0.00350
# 0.006165721863215997 0.0008312675261888447 LS 1
# number of training points:  35 -------------------------------------------------
# LS1:  Degree 2 e_LOO 2.5147478415146025e-08 Pf_SuMO 0.000544 CoV 0.06060
# LS2:  Degree 2 e_LOO 2.5147529480949483e-08 Pf_SuMO 0.141316 CoV 0.00350
# 0.0062039738403623385 0.0004239008551288383 LS 1
# number of training points:  36 -------------------------------------------------
# LS1:  Degree 2 e_LOO 4.160577284139388e-08 Pf_SuMO 0.000576 CoV 0.05890
# LS2:  Degree 2 e_LOO 4.1610486487307084e-08 Pf_SuMO 0.14151 CoV 0.00350
# 0.004964488464798994 0.0008057235590438732 LS 1
# number of training points:  37 -------------------------------------------------
# LS1:  Degree 2 e_LOO 3.546638839626823e-08 Pf_SuMO 0.00059 CoV 0.05820
# LS2:  Degree 2 e_LOO 3.5466420151580294e-08 Pf_SuMO 0.14252 CoV 0.00350
# 0.002102658504711779 0.0041860780085973695 LS 2
# number of training points:  38 -------------------------------------------------
# LS1:  Degree 2 e_LOO 8.199811616253604e-08 Pf_SuMO 0.000544 CoV 0.06060
# LS2:  Degree 2 e_LOO 8.19982387566444e-08 Pf_SuMO 0.142448 CoV 0.00350
# 0.00710685937951327 0.0002989992883675328 LS 1
# number of training points:  39 -------------------------------------------------
# LS1:  Degree 2 e_LOO 9.641096625423647e-08 Pf_SuMO 0.000562 CoV 0.05960
# LS2:  Degree 2 e_LOO 9.641108641447517e-08 Pf_SuMO 0.142014 CoV 0.00350
# 0.0028247285951769133 0.0018039310392441023 LS 1
# number of training points:  40 -------------------------------------------------
# LS1:  Degree 2 e_LOO 1.9847771846541718e-07 Pf_SuMO 0.000574 CoV 0.05900
# LS2:  Degree 2 e_LOO 1.9847783744169624e-07 Pf_SuMO 0.14219 CoV 0.00350
# 0.001842246658782856 0.0007306790360906141 LS 1
# number of training points:  41 -------------------------------------------------
# LS1:  Degree 2 e_LOO 1.9589106968755044e-07 Pf_SuMO 0.000576 CoV 0.05890
# LS2:  Degree 2 e_LOO 1.9589146833198977e-07 Pf_SuMO 0.142324 CoV 0.00350
# 0.0003041348648726364 0.0005563086320245032 LS 2
# number of training points:  42 -------------------------------------------------
# LS1:  Degree 2 e_LOO 5.059845974113415e-08 Pf_SuMO 0.000564 CoV 0.05950
# LS2:  Degree 2 e_LOO 5.0598497435661256e-08 Pf_SuMO 0.14234 CoV 0.00350
# 0.001840218911942685 6.643818402138867e-05 LS 1
# number of training points:  43 -------------------------------------------------
# LS1:  Degree 2 e_LOO 1.3491642977618805e-08 Pf_SuMO 0.000562 CoV 0.05960
# LS2:  Degree 2 e_LOO 1.3491360603446343e-08 Pf_SuMO 0.141534 CoV 0.00350
# 0.00030964695264248894 0.003353353131137732 LS 2
# number of training points:  44 -------------------------------------------------
# LS1:  Degree 2 e_LOO 2.010803147001993e-08 Pf_SuMO 0.000542 CoV 0.06070
# LS2:  Degree 2 e_LOO 2.0107794806782876e-08 Pf_SuMO 0.141684 CoV 0.00350
# 0.003152809990514232 0.0006229617062773307 LS 1
# number of training points:  45 -------------------------------------------------
# LS1:  Degree 2 e_LOO 9.9167647219618e-09 Pf_SuMO 0.00059 CoV 0.05820
# LS2:  Degree 2 e_LOO 9.916593479135319e-09 Pf_SuMO 0.141424 CoV 0.00350
# 0.007373530457687004 0.0010807579256195481 LS 1
# number of training points:  46 -------------------------------------------------
# LS1:  Degree 2 e_LOO 9.831526418215425e-09 Pf_SuMO 0.000564 CoV 0.05950
# LS2:  Degree 2 e_LOO 9.83104234532929e-09 Pf_SuMO 0.14172 CoV 0.00350
# 0.0039511854102610424 0.0012289671883640625 LS 1
# number of training points:  47 -------------------------------------------------
# LS1:  Degree 3 e_LOO 1.321635617575147e-05 Pf_SuMO 0.00055 CoV 0.06030
# LS2:  Degree 3 e_LOO 1.3216352318162448e-05 Pf_SuMO 0.140686 CoV 0.00350
# 0.0021892083651188416 0.004305985345540885 LS 2
# number of training points:  48 -------------------------------------------------
# LS1:  Degree 3 e_LOO 1.2587028404167568e-05 Pf_SuMO 0.0006 CoV 0.05770
# LS2:  Degree 3 e_LOO 1.2587037651161375e-05 Pf_SuMO 0.14237 CoV 0.00350
# 0.007579399326197479 0.006971936318065039 LS 1
# number of training points:  49 -------------------------------------------------
# LS1:  Degree 3 e_LOO 1.2187630567562299e-05 Pf_SuMO 0.000534 CoV 0.06120
# LS2:  Degree 3 e_LOO 1.2187631019421391e-05 Pf_SuMO 0.142112 CoV 0.00350
# 0.010217199888876996 0.0010719843450750983 LS 1
# number of training points:  50 -------------------------------------------------

# %% [markdown]
# # Combined sequential training- U - LOO - 2 LS

# %%
number_experiments = 10    
number_active_points = 45

Critic_LS1 = 3
Critic_LS2 = 2

# kernel hyperparameters-------------------------------------
v = 5/2        #Gaussian process
#truncation term-------------------------------------
p_max = 4  #for each variable → same truncation , degree of expansion
    
results_file = '_seq_ULOO_' + str(number_active_points)   # index for results files

for experiments in range(number_experiments):
    print('Experiment: ', experiments+1 , '#################################################################' )
    
    ActiveTrain_1 = {}   #results file { Surrogate , Pf, CoV_Pf , eLoo , mse }
    ActiveTrain_2 = {}   #results file { Surrogate , Pf, CoV_Pf , eLoo , mse }

    #INITIAL design of experiments (LHS) passive training ####################################

    n = 5      # number of initial sampling

    xn = np.zeros((int(n), dim))      #normalized training points
    xr = np.zeros((int(n), dim))      #scaled training points
    output = np.zeros((int(n), 3))        #observations [timeIndex, Penetration, MaxForce]

    # Check the variables limits for space-filling distribution
    Xdoe = build.space_filling_lhs( {'x1':[-1, 1],      
                                     'x2':[-1, 1],} , 
                                      num_samples = n )
    #------------------------------------------------------------
    xn[:,0] = Xdoe['x1']
    xn[:,1] = Xdoe['x2']
    xr[:,0] = PCK1.scalehermite(xn[:,0], x1mean, x1sigma)
    xr[:,1] = PCK1.scalehermite(xn[:,1], x2mean, x2sigma)

    #simulator execution
    output = simulator(xr[:, 0], xr[:, 1]) #velocity and flowstress 
    
    #Output = [timeIndex, Penetration, MaxForce]
    yn = output[:, 1]

    #limit state definition
    yn_1 = Critic_LS1 - yn
    yn_2 = Critic_LS2 - yn

    for points in range(number_active_points):

        # Selecting the smallest e_loo model (length and order)
        
        opt_length_it = np.zeros(p_max-1)
        eloo_results = np.zeros(p_max-1)

        mean_loo = np.zeros(len(xn))
        var_loo = np.zeros(len(xn))
        sumat_1 = np.zeros((len(xn),(p_max-1)))
        sumat_2 = np.zeros((len(xn),(p_max-1)))

        dist = PCK1.distance(xn, xn)
        lmax = np.max(dist)
        lmin = np.min(dist[dist!=0])
        bounds = [(lmin, lmax)]

        results = dict()

         ## Pool of samples for MCS -----------------------------------
        
        MCS_samples = 500000
        LOOCV = np.zeros(MCS_samples)

        MCinputs_norm = np.zeros((int(MCS_samples), dim))
        MCinputs = np.zeros((int(MCS_samples), dim))

        MCinputs_norm[:,0] = np.random.normal(0, 1, size=int(MCS_samples))
        MCinputs_norm[:,1] = np.random.normal(0, 1, size=int(MCS_samples))

        MCinputs[:,0] = PCK1.scalehermite(MCinputs_norm[:,0], x1mean, x1sigma)  
        MCinputs[:,1] = PCK1.scalehermite(MCinputs_norm[:,1], x2mean, x2sigma) 
        
        # #################################################################################################################
        # Active training of Limit State 1 ################################################################################
    
#         print('AT Limit state 1 ')

        ModelName_1 = 'PCK1_' + str(len(xn))
        
        ModelName_1 = PC_Kriging(config)

        # yn is changing for each LS (inside L_Object )
         
        yn = yn_1   #observations

        # OPTIMAL SURROGATE MODEL -----------------------------------

        for p in range(1, p_max):

            results['shgo'] = optimize.shgo(L_Object, bounds)
            opt_length = results['shgo']['x'][0]

            theta = np.array([opt_length, v])

            #Generating PCK models for each reduced design of experiments 

            for i in range (0, len(xn) ):

                yn_loo= np.delete(yn,[i])                            #y_n-i      leaving element i out the observations 
                xr_loo= np.delete(xr,[i*2,i*2+1]).reshape(-1,dim)    #x1r_n-i   leaving element i out the inputs (xr)
                xn_loo= np.delete(xn,[i*2,i*2+1]).reshape(-1,dim)    #x_n-i     leaving element i out the nomalized inputs (xn)

                #training LOO
                modelpar_loo = PCK_loo.train (xn_loo , yn_loo , p , theta )

                #predicting LOO over each removed sample
                mean_loo[i], var_loo[i] = PCK_loo.predict_fast(xn[i].reshape(1,-1))

            e_loo = np.mean (yn - mean_loo)**2              #LOO CV squared errors
            sumat_1[:,p-1] = np.divide(e_loo, var_loo)
            
            eloo_results[p-1] = e_loo
            opt_length_it[p-1] = opt_length

    #         print('Degree', p, 'MSE', "%.2f" % round(mse, 2) , 'e_LOO', "%.5f" % e_loo)

        ## training optimal model ----------------------------

        opt = np.argmin(eloo_results)    #selected based 'eloo' instead 'mse'
        opt_1 = opt 
        theta_opt = np.array([opt_length_it[opt], v]) 

        modelpar1 = ModelName_1.train (xn, yn, int(opt+1), theta_opt) 
    
        # Pf estimation ----------------------------------------------       
        # surrogate 
        meanMC_1, varMC_1 = ModelName_1.predict_fast(MCinputs_norm)    # mean, variance
        fail_samples_SUMO_1 = np.sum(np.asarray(meanMC_1) < 0 )
        fail_prob_SUMO_1 = fail_samples_SUMO_1 / MCS_samples

        cov_pf = np.sqrt((1 - fail_prob_SUMO_1 ) / (fail_prob_SUMO_1 * MCS_samples) )

        print('LS1: ','Degree', int(opt+1), 'e_LOO', np.min(eloo_results) ,'Pf_SuMO', fail_prob_SUMO_1 , 'CoV', "%.5f" % round(cov_pf, 4))

        #saving results ----------------------------

        ActiveTrain_1[str(len(xn))+'points'] = ModelName_1 , fail_prob_SUMO_1 , cov_pf , np.min(eloo_results)
        
        # #################################################################################################################
        # Active training of Limit State 2 ################################################################################
        
#         print('Training Limit state 2 ')
        
        ModelName_2 = 'PCK2_' + str(len(xn))
        
        ModelName_2 = PC_Kriging(config)
        
        # yn is changing for each LS 
        yn = yn_2

        # Selecting the smallest e_loo model (length and order) 

        # OPTIMAL SURROGATE MODEL -----------------------------------
        for p in range(1, p_max):

            results['shgo'] = optimize.shgo(L_Object, bounds)
            opt_length = results['shgo']['x'][0]

            theta = np.array([opt_length, v])

            #Generating PCK models for each reduced design of experiments 

            for i in range (0, len(xn) ):

                yn_loo= np.delete(yn,[i])                            #y_n-i      leaving element i out the observations 
                xr_loo= np.delete(xr,[i*2,i*2+1]).reshape(-1,dim)    #x1r_n-i   leaving element i out the inputs (xr)
                xn_loo= np.delete(xn,[i*2,i*2+1]).reshape(-1,dim)    #x_n-i     leaving element i out the nomalized inputs (xn)

                #training LOO
                modelpar_loo = PCK_loo.train (xn_loo , yn_loo , p , theta )

                #predicting LOO over each removed sample
                mean_loo[i], var_loo[i] = PCK_loo.predict_fast(xn[i].reshape(1,-1))

            e_loo = np.mean (yn - mean_loo)**2              #LOO CV squared errors
            sumat_2[:,p-1] = np.divide(e_loo, var_loo)
            
            eloo_results[p-1] = e_loo
            opt_length_it[p-1] = opt_length

    #         print('Degree', p, 'MSE', "%.2f" % round(mse, 2) , 'e_LOO', "%.5f" % e_loo)

        ## training optimal model ----------------------------

        opt = np.argmin(eloo_results)
        opt_2 = opt  
        theta_opt = np.array([opt_length_it[opt], v]) 

        modelpar2 = ModelName_2.train (xn, yn, int(opt+1), theta_opt) 

        # Pf estimation ----------------------------------------------
        # surrogate ls
        meanMC_2, varMC_2 = ModelName_2.predict_fast(MCinputs_norm)    # mean, variance
        fail_samples_SUMO_2 = np.sum(np.asarray(meanMC_2) < 0 )
        fail_prob_SUMO_2 = fail_samples_SUMO_2 / MCS_samples

        cov_pf = np.sqrt((1 - fail_prob_SUMO_2 ) / (fail_prob_SUMO_2 * MCS_samples) )        
        
        print('LS2: ','Degree', int(opt+1), 'e_LOO', np.min(eloo_results) ,'Pf_SuMO', fail_prob_SUMO_2 , 'CoV', "%.5f" % round(cov_pf, 4))

        #saving results ----------------------------------------------

        ActiveTrain_2[str(len(xn))+'points'] = ModelName_2 , fail_prob_SUMO_2 , cov_pf , np.min(eloo_results)

        # ##############################################################################
        
        #Selecting the limit state to improve (1 each loop for sequential)
        
        if ( len(xn) % 2 == 0 ):   #even number
            meanMC = meanMC_1
            varMC = varMC_1
            sumat = sumat_1
            opt = opt_1                     
            print ('LS 1')

        else:    #odd number
            meanMC = meanMC_2
            varMC = varMC_2
            sumat = sumat_2
            opt = opt_2   
            print ('LS 2')
        
        # LOO CV errors ###################################################
        #variance enhancement based LOO CV erros around voronoi cells
        
        for k in range (0, MCS_samples):               
            voro = VoronoiCell(MCinputs[k], xr)
            LOOCV[k]= varMC[k]*(1+ sumat[voro, opt])

        ### Evaluating new points
        U_f = U_function(meanMC.reshape(-1), LOOCV.reshape(-1))
        
        candidate = MCinputs[np.argmin(U_f)]
        candidate_norm = MCinputs_norm[np.argmin(U_f)]
        
        xr = np.append(xr, candidate).reshape(-1,2)
        xn = np.append(xn, candidate_norm).reshape(-1,2)
        
        #simulator execution
        Single_yn = simulator(candidate[0], candidate[1]) #velocity and flowstress 
        
        #Output = [timeIndex, Penetration, MaxForce]
    
        yn_1 = np.append(yn_1, (Critic_LS1 - Single_yn[0,1]) )
        yn_2 = np.append(yn_2, (Critic_LS2 - Single_yn[0,1]) )

        print('number of training points: ', len(xn),'-------------------------------------------------')
        
    filename1 = 'Batch_'+ str(experiments+1) + results_file + 'p_LS1.sav'

    pickle.dump(ActiveTrain_1, open(filename1, 'wb'))
    
    filename2 = 'Batch_'+ str(experiments+1) + results_file + 'p_LS2.sav'
    pickle.dump(ActiveTrain_2, open(filename2, 'wb'))

# %% [markdown]
# # Active training- U - LOO - 2 LS

# %%
number_experiments = 10    
number_active_points = 45

training_limitstate = 1

Critic_LS1 = 3
Critic_LS2 = 2

# kernel hyperparameters-------------------------------------
v = 5/2        #Gaussian process
#truncation term-------------------------------------
p_max = 4  #for each variable → same truncation , degree of expansion
    
results_file = '_AT'+ str(training_limitstate) +'_U_LOO_' + str(number_active_points)    # index for results files

for experiments in range(number_experiments):
    print('Experiment: ', experiments+1 , '#################################################################' )
    
    ActiveTrain_1 = {}   #results file { Surrogate , Pf, CoV_Pf , eLoo , mse }
    ActiveTrain_2 = {}   #results file { Surrogate , Pf, CoV_Pf , eLoo , mse }

    #INITIAL design of experiments (LHS) passive training ####################################

    n = 5      # number of initial sampling

    xn = np.zeros((int(n), dim))      #normalized training points
    xr = np.zeros((int(n), dim))      #scaled training points
    output = np.zeros((int(n), 3))        #observations [timeIndex, Penetration, MaxForce]

    # Check the variables limits for space-filling distribution
    Xdoe = build.space_filling_lhs( {'x1':[-1, 1],      
                                     'x2':[-1, 1],} , 
                                      num_samples = n )
    #------------------------------------------------------------
    xn[:,0] = Xdoe['x1']
    xn[:,1] = Xdoe['x2']
    xr[:,0] = PCK1.scalehermite(xn[:,0], x1mean, x1sigma)
    xr[:,1] = PCK1.scalehermite(xn[:,1], x2mean, x2sigma)

    #simulator execution
    output = simulator(xr[:, 0], xr[:, 1]) #velocity and flowstress 
    
    #Output = [timeIndex, Penetration, MaxForce]
    yn = output[:, 1]

    #limit state definition
    yn_1 = Critic_LS1 - yn
    yn_2 = Critic_LS2 - yn

    for points in range(number_active_points):

        # Selecting the smallest e_loo model (length and order)
        
        opt_length_it = np.zeros(p_max-1)
        eloo_results = np.zeros(p_max-1)

        mean_loo = np.zeros(len(xn))
        var_loo = np.zeros(len(xn))
        sumat_1 = np.zeros((len(xn),(p_max-1)))
        sumat_2 = np.zeros((len(xn),(p_max-1)))

        dist = PCK1.distance(xn, xn)
        lmax = np.max(dist)
        lmin = np.min(dist[dist!=0])
        bounds = [(lmin, lmax)]

        results = dict()

         ## Pool of samples for MCS -----------------------------------
        
        MCS_samples = 500000
        LOOCV = np.zeros(MCS_samples)

        MCinputs_norm = np.zeros((int(MCS_samples), dim))
        MCinputs = np.zeros((int(MCS_samples), dim))

        MCinputs_norm[:,0] = np.random.normal(0, 1, size=int(MCS_samples))
        MCinputs_norm[:,1] = np.random.normal(0, 1, size=int(MCS_samples))

        MCinputs[:,0] = PCK1.scalehermite(MCinputs_norm[:,0], x1mean, x1sigma)  
        MCinputs[:,1] = PCK1.scalehermite(MCinputs_norm[:,1], x2mean, x2sigma) 
        
        # #################################################################################################################
        # Active training of Limit State 1 ################################################################################
    
#         print('AT Limit state 1 ')

        ModelName_1 = 'PCK1_' + str(len(xn))
        
        ModelName_1 = PC_Kriging(config)

        # yn is changing for each LS (inside L_Object )
         
        yn = yn_1   #observations

        # OPTIMAL SURROGATE MODEL -----------------------------------

        for p in range(1, p_max):

            results['shgo'] = optimize.shgo(L_Object, bounds)
            opt_length = results['shgo']['x'][0]

            theta = np.array([opt_length, v])

            #Generating PCK models for each reduced design of experiments 

            for i in range (0, len(xn) ):

                yn_loo= np.delete(yn,[i])                            #y_n-i      leaving element i out the observations 
                xr_loo= np.delete(xr,[i*2,i*2+1]).reshape(-1,dim)    #x1r_n-i   leaving element i out the inputs (xr)
                xn_loo= np.delete(xn,[i*2,i*2+1]).reshape(-1,dim)    #x_n-i     leaving element i out the nomalized inputs (xn)

                #training LOO
                modelpar_loo = PCK_loo.train (xn_loo , yn_loo , p , theta )

                #predicting LOO over each removed sample
                mean_loo[i], var_loo[i] = PCK_loo.predict_fast(xn[i].reshape(1,-1))

            e_loo = np.mean (yn - mean_loo)**2              #LOO CV squared errors
            sumat_1[:,p-1] = np.divide(e_loo, var_loo)
            
            eloo_results[p-1] = e_loo
            opt_length_it[p-1] = opt_length

    #         print('Degree', p, 'MSE', "%.2f" % round(mse, 2) , 'e_LOO', "%.5f" % e_loo)

        ## training optimal model ----------------------------

        opt = np.argmin(eloo_results)    #selected based 'eloo' instead 'mse'
        opt_1 = opt 
        theta_opt = np.array([opt_length_it[opt], v]) 

        modelpar1 = ModelName_1.train (xn, yn, int(opt+1), theta_opt) 
    
        # Pf estimation ----------------------------------------------       
        # surrogate 
        meanMC_1, varMC_1 = ModelName_1.predict_fast(MCinputs_norm)    # mean, variance
        fail_samples_SUMO_1 = np.sum(np.asarray(meanMC_1) < 0 )
        fail_prob_SUMO_1 = fail_samples_SUMO_1 / MCS_samples

        cov_pf = np.sqrt((1 - fail_prob_SUMO_1 ) / (fail_prob_SUMO_1 * MCS_samples) )

        print('LS1: ','Degree', int(opt+1), 'e_LOO', np.min(eloo_results) ,'Pf_SuMO', fail_prob_SUMO_1 , 'CoV', "%.5f" % round(cov_pf, 4))

        #saving results ----------------------------

        ActiveTrain_1[str(len(xn))+'points'] = ModelName_1 , fail_prob_SUMO_1 , cov_pf , np.min(eloo_results)
        
        # #################################################################################################################
        # Active training of Limit State 2 ################################################################################
        
#         print('Training Limit state 2 ')
        
        ModelName_2 = 'PCK2_' + str(len(xn))
        
        ModelName_2 = PC_Kriging(config)
        
        # yn is changing for each LS 
        yn = yn_2

        # Selecting the smallest e_loo model (length and order) 

        # OPTIMAL SURROGATE MODEL -----------------------------------
        for p in range(1, p_max):

            results['shgo'] = optimize.shgo(L_Object, bounds)
            opt_length = results['shgo']['x'][0]

            theta = np.array([opt_length, v])

            #Generating PCK models for each reduced design of experiments 

            for i in range (0, len(xn) ):

                yn_loo= np.delete(yn,[i])                            #y_n-i      leaving element i out the observations 
                xr_loo= np.delete(xr,[i*2,i*2+1]).reshape(-1,dim)    #x1r_n-i   leaving element i out the inputs (xr)
                xn_loo= np.delete(xn,[i*2,i*2+1]).reshape(-1,dim)    #x_n-i     leaving element i out the nomalized inputs (xn)

                #training LOO
                modelpar_loo = PCK_loo.train (xn_loo , yn_loo , p , theta )

                #predicting LOO over each removed sample
                mean_loo[i], var_loo[i] = PCK_loo.predict_fast(xn[i].reshape(1,-1))

            e_loo = np.mean (yn - mean_loo)**2              #LOO CV squared errors
            sumat_2[:,p-1] = np.divide(e_loo, var_loo)
            
            eloo_results[p-1] = e_loo
            opt_length_it[p-1] = opt_length

    #         print('Degree', p, 'MSE', "%.2f" % round(mse, 2) , 'e_LOO', "%.5f" % e_loo)

        ## training optimal model ----------------------------

        opt = np.argmin(eloo_results)
        opt_2 = opt  
        theta_opt = np.array([opt_length_it[opt], v]) 

        modelpar2 = ModelName_2.train (xn, yn, int(opt+1), theta_opt) 

        # Pf estimation ----------------------------------------------
        # surrogate ls
        meanMC_2, varMC_2 = ModelName_2.predict_fast(MCinputs_norm)    # mean, variance
        fail_samples_SUMO_2 = np.sum(np.asarray(meanMC_2) < 0 )
        fail_prob_SUMO_2 = fail_samples_SUMO_2 / MCS_samples

        cov_pf = np.sqrt((1 - fail_prob_SUMO_2 ) / (fail_prob_SUMO_2 * MCS_samples) )        
        
        print('LS2: ','Degree', int(opt+1), 'e_LOO', np.min(eloo_results) ,'Pf_SuMO', fail_prob_SUMO_2 , 'CoV', "%.5f" % round(cov_pf, 4))

        #saving results ----------------------------------------------

        ActiveTrain_2[str(len(xn))+'points'] = ModelName_2 , fail_prob_SUMO_2 , cov_pf , np.min(eloo_results)

        # ##############################################################################
        
        #Selecting the limit state to improve (1 each loop for sequential)
        
        #choosing the limit state to improve
        if (training_limitstate == 1):
            meanMC = meanMC_1
            varMC = varMC_1
            sumat = sumat_1
            opt = opt_1                     
            
        elif (training_limitstate == 2):
            meanMC = meanMC_2
            varMC = varMC_2
            sumat = sumat_2
            opt = opt_2
        
        # LOO CV errors ###################################################
        #variance enhancement based LOO CV erros around voronoi cells
        
        for k in range (0, MCS_samples):               
            voro = VoronoiCell(MCinputs[k], xr)
            LOOCV[k]= varMC[k]*(1+ sumat[voro, opt])

        ### Evaluating new points
        U_f = U_function(meanMC.reshape(-1), LOOCV.reshape(-1))
        
        candidate = MCinputs[np.argmin(U_f)]
        candidate_norm = MCinputs_norm[np.argmin(U_f)]
        
        xr = np.append(xr, candidate).reshape(-1,2)
        xn = np.append(xn, candidate_norm).reshape(-1,2)
        
        #simulator execution
        Single_yn = simulator(candidate[0], candidate[1]) #velocity and flowstress 
        
        #Output = [timeIndex, Penetration, MaxForce]
    
        yn_1 = np.append(yn_1, (Critic_LS1 - Single_yn[0,1]) )
        yn_2 = np.append(yn_2, (Critic_LS2 - Single_yn[0,1]) )

        print('number of training points: ', len(xn),'-------------------------------------------------')
        
    filename1 = 'Batch_'+ str(experiments+1) + results_file + 'p_LS1.sav'

    pickle.dump(ActiveTrain_1, open(filename1, 'wb'))
    
    filename2 = 'Batch_'+ str(experiments+1) + results_file + 'p_LS2.sav'
    pickle.dump(ActiveTrain_2, open(filename2, 'wb'))
