# %%
import numpy as np
from pc_kriging import PC_Kriging
import matplotlib.pyplot as plt
from scipy.stats import norm
from doepy import build
from scipy import optimize
import pandas as pd
from numpy import genfromtxt
import pickle

from scipy.special import eval_legendre, eval_hermitenorm
import scipy.special

# adaptive learning - expected feasiability function --------------------------------------------------------------

def EFF(u,v,z):
    zl=-2*v
    zh=2*v
    return ((u-z)*( 2*norm.cdf((z-u)/v) - norm.cdf((zl-u)/v) - norm.cdf((zh-u)/v)) 
           -(v)*( 2*norm.pdf((z-u)/v) - norm.pdf((zl-u)/v) - norm.pdf((zh-u)/v))  
           +(2*v)*(norm.cdf((zh-u)/v) - norm.cdf((zl-u)/v)))

def U_function(u, v):
    return np.abs(u)/v

def LinearNorm(x,oldmin,oldmax,newmin,newmax):    # scaling linearly X to new domain limits
    return newmin + ((x-oldmin)*(newmax-newmin)/(oldmax-oldmin))


def VoronoiCell(x,xn):   #given x [single value] return the index of the closest xn [array]
    dist=PCK1.distance(x.reshape(1,-1),xn)
    return np.argmin(dist)

# %% [markdown]
# # Limit State 1

# %%
# #ground truth function 1 ----------------------------------------------------
# https://rprepo.readthedocs.io/en/latest/reliability_problems.html#rp201

def gfun_53(x):
    """Performance function for reliability problem 53.

    Parameters
    ----------
        x : numpy.array of float(s)
            Values of independent variables: columns are the different parameters/random variables (x1, x2,...xn) and rows are different parameter/random variables sets for different calls.

    Returns
    -------
        g_val_sys : numpy.array of float(s)
            Performance function value for the system.
        g_val_comp : numpy.array of float(s)
            Performance function value for each component.
        msg : str
            Accompanying diagnostic message, e.g. warning.
    """
#     import numpy as np
    # expected number of random variables/columns
    nrv_e = 2

    g = float('nan')
    msg = 'Ok'
    x = np.array(x, dtype='f')

    n_dim = len(x.shape)
    if n_dim == 1:
        x = np.array(x)[np.newaxis]
    elif n_dim > 2:
        msg = 'Only available for 1D and 2D arrays.'
        return float('nan'), float('nan'), msg

    nrv_p = x.shape[1]
    if nrv_p != nrv_e:
        msg = f'The number of random variables (x, columns) is expected to be {nrv_e} but {nrv_p} is provided!'
    else:
        g = np.sin(5*x[:, 0]/2) + 2 - (x[:, 0]**2 + 4)*(x[:, 1] - 1)/20

    g_val_sys = g
    g_val_comp = g
    return g_val_sys, g_val_comp, msg

# %% [markdown]
# # Limit State 2

# %%
# ground truth function 2 ----------------------------------------------------
# https://rprepo.readthedocs.io/en/latest/reliability_problems.html#rp201

def LState2(x):
    #"""Modified Performance function for reliability problem 53""""
  
    # expected number of random variables/columns
    nrv_e = 2

    g = float('nan')
    msg = 'Ok'
    x = np.array(x, dtype='f')

    n_dim = len(x.shape)
    if n_dim == 1:
        x = np.array(x)[np.newaxis]
    elif n_dim > 2:
        msg = 'Only available for 1D and 2D arrays.'
        return float('nan'), float('nan'), msg

    nrv_p = x.shape[1]
    if nrv_p != nrv_e:
        msg = f'The number of random variables (x, columns) is expected to be {nrv_e} but {nrv_p} is provided!'
    else:
        #new limit state -----------------------------------------------------
        g = np.sin(2.0*x[:, 0]) -0.5 - (x[:, 0]**2 + 4)*(-1.0*x[:, 1] - 1)/20
        
    g_val_sys = g
    g_val_comp = g
    return g_val_sys, g_val_comp, msg

# %%
config = {"pol_type": ['hermite', 'hermite']}   #design variables following normal distribution
PCK1 = PC_Kriging(config)
PCK_loo = PC_Kriging(config)    # for LOOCV with same 'config' as specified in the original model

# %%
# objective function to optimize length scale --------------------------------------------------------
def L_Object (l):
    v = 5/2
    N = len(xn)
    R = PCK1.matern(xn , xn, l, v)
    detR = np.linalg.det(R)
    
    modelpar2 = PCK1.train(xn, yn, p, np.array([l,v]))    # returns B, sig2, InfoMatrix(phi) , PolyIndices(alpha)
    ### ------------------Theta_ by UQLab User Manual PCK(C. Lataniotis, D. Wicaksono, S. Marelli, B. Sudret)------------------------------
    sig2 = modelpar2[1].reshape(-1)
    # return 0.5*(np.log(detR)+ N*np.log(2*np.pi*sig2)+ N)

    ### ------------------Theta_ by MLE PCK(Schobi,Sudret,Wiart)------------------------------
    FB = PCK1.InfoMat @ modelpar2[0]
    ins = (yn-FB).reshape(-1)
    R_1 = np.linalg.inv(R)
    return ((ins.T) @ R_1 @ ins) * (1/N) * (detR**(1/N))

# %% [markdown]
# ## Loading initial parameters and generating test points

# %%
function_1 = gfun_53   #ground truth function 1 
function_2 = LState2   #ground truth function 2

dim = 2       # dimensionality

x1mean, x1sigma = 1.5 , 1.0  # normal distribution 
x2mean, x2sigma = 2.5 , 1.0  # normal distribution 

ntest = 5000  # test points

# TEST POINTS -------------------------------------------------
XR = np.zeros((int(ntest), dim))   #normalized test points
XN = np.zeros((int(ntest), dim))  #scaled test points
YN_1 = np.zeros(int(ntest))
YN_2 = np.zeros(int(ntest))
#variable 1 ---------------------------------------------------
XN[:,0] = np.random.normal(0,1,ntest)  
XR[:,0] = PCK1.scalehermite(XN[:,0], x1mean, x1sigma)  
#variable 2 ---------------------------------------------------
XN[:,1] = np.random.normal(0,1,ntest)  
XR[:,1] = PCK1.scalehermite(XN[:,1], x2mean, x2sigma)  

YN_1 = function_1(XR)[0]
YN_2 = function_2(XR)[0]

# %%
fail_samples_1 = np.sum(YN_1 < 0 )
Pf_ref_1 = fail_samples_1/ntest

fail_samples_2 = np.sum(YN_2 < 0 )
Pf_ref_2 = fail_samples_2/ntest

Pf_ref_1, Pf_ref_2
# Out:
# (0.036, 0.1424)

# %%
# %matplotlib notebook

fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(XR[:,0],XR[:,1], YN_1)
ax.scatter(XR[:,0],XR[:,1], YN_2)             #plotting the last trained surrogate
# ax.scatter(xr[:,0],xr[:,1], yn, color='red')   #observation points 
ax.set_xlabel('X1')
ax.set_ylabel('X2')
ax.set_zlabel('G_System')
# Out:
# <img src="data:image/png;base64,..." width="800">
# Text(0.5, 0, 'G_System')

# %% [markdown]
# # Active training - U - 2 LS

# %%
number_experiments = 15
number_active_points = 40

training_limitstate = 1

results_file = '_AT1_U_' + str(number_active_points)   # index for results files

for experiments in range(number_experiments):
    print('Experiment: ', experiments+1 , '#################################################################' )
    
    ActiveTrain_1 = {}   #results file { Surrogate , Pf, CoV_Pf , eLoo , mse }
    ActiveTrain_2 = {}   #results file { Surrogate , Pf, CoV_Pf , eLoo , mse }

    #INITIAL design of experiments (LHS) passive training ####################################

    n = 10       # number of initial sampling

    xn = np.zeros((int(n), dim))      #normalized training points
    xr = np.zeros((int(n), dim))      #scaled training points
    yn = np.zeros((int(n)))           #observations

    # Check the variables limits for space-filling distribution
    Xdoe = build.space_filling_lhs( {'x1':[-1, 1],      
                                     'x2':[-1, 1],} , 
                                      num_samples = n )
    #------------------------------------------------------------
    xn[:,0] = Xdoe['x1']
    xn[:,1] = Xdoe['x2']
    xr[:,0] = PCK1.scalehermite(xn[:,0], x1mean, x1sigma)
    xr[:,1] = PCK1.scalehermite(xn[:,1], x2mean, x2sigma)

    yn_1 = function_1(xr)[0]
    yn_2 = function_2(xr)[0]
    
    # kernel hyperparameters-------------------------------------
    v = 5/2        #Gaussian process
    #truncation term-------------------------------------
    p_max = 5  #for each variable → same truncation , degree of expansion
    
    for points in range(number_active_points):

        # Selecting the smallest e_loo model (length and order)
        
        mse_results = np.zeros(p_max-1)
        opt_length_it = np.zeros(p_max-1)
        eloo_results = np.zeros(p_max-1)

        mean_loo = np.zeros(len(xn))
        var_loo = np.zeros(len(xn))

        dist = PCK1.distance(xr, xr)
        lmax = np.max(dist)
        lmin = np.min(dist[dist!=0])
        bounds = [(lmin, lmax)]

        results = dict()
        
        # ##############################################################################
        # Active training of Limit State 1 #############################################

        ModelName_1 = 'PCK1_' + str(len(xn))
        
        ModelName_1 = PC_Kriging(config)

        # yn is changing for each LS (inside L_Object )
        yn = yn_1    #observations
        YN = YN_1    #test points

        # OPTIMAL SURROGATE MODEL -----------------------------------
        for p in range(1, p_max):

            results['shgo'] = optimize.shgo(L_Object, bounds)
            opt_length = results['shgo']['x'][0]

            theta = np.array([opt_length, v])

            #Generating PCK models for each reduced design of experiments 

            for i in range (0, len(xn) ):

                yn_loo= np.delete(yn,[i])                            #y_n-i      leaving element i out the observations 
                xr_loo= np.delete(xr,[i*2,i*2+1]).reshape(-1,dim)    #x1r_n-i   leaving element i out the inputs (xr)
                xn_loo= np.delete(xn,[i*2,i*2+1]).reshape(-1,dim)    #x_n-i     leaving element i out the nomalized inputs (xn)

                #training LOO
                modelpar_loo = PCK_loo.train (xn_loo , yn_loo , p , theta )

                #predicting LOO over each removed sample
                mean_loo[i], var_loo[i] = PCK_loo.predict_fast(xn[i].reshape(1,-1))

            e_loo = np.mean (yn - mean_loo)**2              #LOO CV squared errors

            eloo_results[p-1] = e_loo

            #--------------------------------------- error over a set of test points
            modelpar1 = ModelName_1.train (xn, yn, p, theta) 
            mean0, var0 = ModelName_1.predict_fast(XN)    # test points predictions mean, variance

            mse = np.mean ((YN - mean0)**2)

            mse_results[p-1] = mse
            opt_length_it[p-1] = opt_length

    #         print('Degree', p, 'MSE', "%.2f" % round(mse, 2) , 'e_LOO', "%.5f" % e_loo)

        ## training optimal model ----------------------------

        opt = np.argmin(eloo_results)    #selected based 'eloo' instead 'mse'
        theta_opt = np.array([opt_length_it[opt], v]) 

        modelpar1 = ModelName_1.train (xn, yn, int(opt+1), theta_opt) 

        ## Pool of samples for MCS -----------------------------------
        MCS_samples = 100000

        MCinputs_norm = np.zeros((int(MCS_samples), dim))
        MCinputs = np.zeros((int(MCS_samples), dim))

        MCinputs_norm[:,0] = np.random.normal(0, 1, size=int(MCS_samples))
        MCinputs_norm[:,1] = np.random.normal(0, 1, size=int(MCS_samples))

        MCinputs[:,0] = PCK1.scalehermite(MCinputs_norm[:,0], x1mean, x1sigma)  
        MCinputs[:,1] = PCK1.scalehermite(MCinputs_norm[:,1], x2mean, x2sigma)  
    
        # Pf estimation ----------------------------------------------
        
            # ground truth ls
        ymc_1 = function_1(MCinputs)[0]  
        fail_samples_1 = np.sum(ymc_1 < 0 )
        Pf_ref_1 = fail_samples_1 / MCS_samples
        
            # surrogate ls
        meanMC_1, varMC_1 = ModelName_1.predict_fast(MCinputs_norm)    # mean, variance
        fail_samples_SUMO_1 = np.sum(np.asarray(meanMC_1) < 0 )
        fail_prob_SUMO_1 = fail_samples_SUMO_1 / MCS_samples

        cov_pf = np.sqrt((1 - fail_prob_SUMO_1 ) / (fail_prob_SUMO_1 * MCS_samples) )

        print('LS1: ','Degree', int(opt+1), 'e_LOO', np.min(eloo_results), 'Pf_ref',
                  Pf_ref_1 ,'Pf', fail_prob_SUMO_1 , 'CoV', "%.5f" % round(cov_pf, 4))

        #saving results ----------------------------

        ActiveTrain_1[str(len(xn))+'points'] = ModelName_1 , fail_prob_SUMO_1 , cov_pf , np.min(eloo_results), np.min(mse_results)
        
        # ##############################################################################
        # Active training of Limit State 2 #############################################
        
        ModelName_2 = 'PCK2_' + str(len(xn))
        
        ModelName_2 = PC_Kriging(config)
        
        # yn is changing for each LS 
        yn = yn_2
        YN = YN_2
        # Selecting the smallest e_loo model (length and order) 

        # OPTIMAL SURROGATE MODEL -----------------------------------
        for p in range(1, p_max):
            
            # results = dict()
            # bounds = [(lmin, lmax)]
            
            results['shgo'] = optimize.shgo(L_Object, bounds)
            opt_length = results['shgo']['x'][0]

            theta = np.array([opt_length, v])

            #Generating PCK models for each reduced design of experiments 

            for i in range (0, len(xn) ):

                yn_loo= np.delete(yn,[i])                            #y_n-i      leaving element i out the observations 
                xr_loo= np.delete(xr,[i*2,i*2+1]).reshape(-1,dim)    #x1r_n-i   leaving element i out the inputs (xr)
                xn_loo= np.delete(xn,[i*2,i*2+1]).reshape(-1,dim)    #x_n-i     leaving element i out the nomalized inputs (xn)

                #training LOO
                modelpar_loo = PCK_loo.train (xn_loo , yn_loo , p , theta )

                #predicting LOO over each removed sample
                mean_loo[i], var_loo[i] = PCK_loo.predict_fast(xn[i].reshape(1,-1))

            e_loo = np.mean (yn - mean_loo)**2              #LOO CV squared errors

            eloo_results[p-1] = e_loo

            #--------------------------------------- error over a set of test points
            modelpar2 = ModelName_2.train (xn, yn, p, theta) 
            mean0, var0 = ModelName_2.predict_fast(XN)    # test points predictions mean, variance

            mse = np.mean ((YN - mean0)**2)

            mse_results[p-1] = mse
            opt_length_it[p-1] = opt_length

    #         print('Degree', p, 'MSE', "%.2f" % round(mse, 2) , 'e_LOO', "%.5f" % e_loo)

        ## training optimal model ----------------------------

        opt = np.argmin(eloo_results)    
        theta_opt = np.array([opt_length_it[opt], v]) 

        modelpar2 = ModelName_2.train (xn, yn, int(opt+1), theta_opt) 

        # Pf estimation ----------------------------------------------
        
            # ground truth ls
        ymc_2 = function_2(MCinputs)[0]  
        fail_samples_2 = np.sum(ymc_2 < 0 )
        Pf_ref_2 = fail_samples_2 / MCS_samples
        
            # surrogate ls
        meanMC_2, varMC_2 = ModelName_2.predict_fast(MCinputs_norm)    # mean, variance
        fail_samples_SUMO_2 = np.sum(np.asarray(meanMC_2) < 0 )
        fail_prob_SUMO_2 = fail_samples_SUMO_2 / MCS_samples

        cov_pf = np.sqrt((1 - fail_prob_SUMO_2 ) / (fail_prob_SUMO_2 * MCS_samples) )        
        
        print('LS2: ','Degree', int(opt+1), 'e_LOO', np.min(eloo_results) , 'Pf_ref', 
              Pf_ref_2 ,'Pf', fail_prob_SUMO_2 , 'CoV', "%.5f" % round(cov_pf, 4))

        #saving results ----------------------------

        ActiveTrain_2[str(len(xn))+'points'] = ModelName_2 , fail_prob_SUMO_2 , cov_pf , np.min(eloo_results), np.min(mse_results)

        # ##############################################################################
        
        ### Evaluating new points
        U_f = U_function(meanMC_1.reshape(-1), varMC_1.reshape(-1))
        xr = np.append(xr, MCinputs[np.argmin(U_f)]).reshape(-1,2)
        xn = np.append(xn, MCinputs_norm[np.argmin(U_f)]).reshape(-1,2)
        
        yn_1 = function_1(xr)[0]
        yn_2 = function_2(xr)[0]
    
    
        print('number of training points: ', len(xn),'-------------------------------------------------')
    
    filename1 = 'Batch_'+ str(experiments+1) + results_file + 'p_LS1.sav'
    pickle.dump(ActiveTrain_1, open(filename1, 'wb'))
           
    filename2 = 'Batch_'+ str(experiments+1) + results_file + 'p_LS2.sav'
    pickle.dump(ActiveTrain_2, open(filename2, 'wb'))
# Out:
# Experiment:  1 #################################################################
# C:\Users\Administrator\anaconda3\envs\surrogate\lib\site-packages\ipykernel_launcher.py:8: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# LS1:  Degree 1 e_LOO 0.0005310139758624356 Pf_ref 0.0312 Pf 0.07626 CoV 0.01100
# LS2:  Degree 1 e_LOO 3.7256850858465416e-07 Pf_ref 0.14911 Pf 0.1641 CoV 0.00710
# number of training points:  11 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.007535818069791081 Pf_ref 0.0318 Pf 0.06274 CoV 0.01220
# LS2:  Degree 1 e_LOO 6.934874867001844e-05 Pf_ref 0.14773 Pf 0.16445 CoV 0.00710
# number of training points:  12 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.0006870222202275544 Pf_ref 0.03066 Pf 0.0071 CoV 0.03740
# LS2:  Degree 1 e_LOO 9.009508432261465e-06 Pf_ref 0.14707 Pf 0.15149 CoV 0.00750
# number of training points:  13 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.002353799020640022 Pf_ref 0.03134 Pf 0.07577 CoV 0.01100
# LS2:  Degree 1 e_LOO 1.9492491680647635e-05 Pf_ref 0.14925 Pf 0.1526 CoV 0.00750
# number of training points:  14 -------------------------------------------------
# LS1:  Degree 3 e_LOO 0.003020048287755464 Pf_ref 0.03135 Pf 0.07012 CoV 0.01150
# LS2:  Degree 1 e_LOO 0.00033553231602314205 Pf_ref 0.14813 Pf 0.08912 CoV 0.01010
# number of training points:  15 -------------------------------------------------
# LS1:  Degree 1 e_LOO 4.9823714621821286e-05 Pf_ref 0.03136 Pf 0.02341 CoV 0.02040
# LS2:  Degree 1 e_LOO 0.0013314660941022075 Pf_ref 0.14909 Pf 0.06956 CoV 0.01160
# number of training points:  16 -------------------------------------------------
# LS1:  Degree 3 e_LOO 2.3149823810643442e-05 Pf_ref 0.03142 Pf 0.06167 CoV 0.01230
# LS2:  Degree 1 e_LOO 0.0005109169273058962 Pf_ref 0.14922 Pf 0.07802 CoV 0.01090
# number of training points:  17 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.0005212105421623541 Pf_ref 0.03258 Pf 0.02958 CoV 0.01810
# LS2:  Degree 1 e_LOO 0.0001705584799713415 Pf_ref 0.14812 Pf 0.07581 CoV 0.01100
# number of training points:  18 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.0004493617233183622 Pf_ref 0.03209 Pf 0.02629 CoV 0.01920
# LS2:  Degree 1 e_LOO 0.00020579415810040004 Pf_ref 0.14856 Pf 0.07601 CoV 0.01100
# number of training points:  19 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.00034993582422825336 Pf_ref 0.03161 Pf 0.02413 CoV 0.02010
# LS2:  Degree 1 e_LOO 0.00014190356134460743 Pf_ref 0.15035 Pf 0.0817 CoV 0.01060
# number of training points:  20 -------------------------------------------------
# LS1:  Degree 1 e_LOO 3.5787491064167315e-06 Pf_ref 0.03116 Pf 0.02462 CoV 0.01990
# LS2:  Degree 1 e_LOO 7.652093507214633e-06 Pf_ref 0.14793 Pf 0.09224 CoV 0.00990
# number of training points:  21 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.011706466973608826 Pf_ref 0.03092 Pf 0.02898 CoV 0.01830
# LS2:  Degree 1 e_LOO 0.003764046299774713 Pf_ref 0.14906 Pf 0.11504 CoV 0.00880
# number of training points:  22 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.008864398234751396 Pf_ref 0.03104 Pf 0.03561 CoV 0.01650
# LS2:  Degree 1 e_LOO 7.877180173683074e-06 Pf_ref 0.15198 Pf 0.13344 CoV 0.00810
# number of training points:  23 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.0034213818940912236 Pf_ref 0.03129 Pf 0.03564 CoV 0.01640
# LS2:  Degree 2 e_LOO 0.0011674879947300993 Pf_ref 0.14764 Pf 0.06562 CoV 0.01190
# number of training points:  24 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.003298063747114409 Pf_ref 0.03158 Pf 0.03543 CoV 0.01650
# LS2:  Degree 2 e_LOO 0.0004934584585862864 Pf_ref 0.14655 Pf 0.07409 CoV 0.01120
# number of training points:  25 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.007454076643693075 Pf_ref 0.03158 Pf 0.03201 CoV 0.01740
# LS2:  Degree 2 e_LOO 0.00017468539348194966 Pf_ref 0.1468 Pf 0.07435 CoV 0.01120
# number of training points:  26 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.009101253816120959 Pf_ref 0.03086 Pf 0.03173 CoV 0.01750
# LS2:  Degree 2 e_LOO 8.012457910320448e-05 Pf_ref 0.14952 Pf 0.06889 CoV 0.01160
# number of training points:  27 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.008130817716083288 Pf_ref 0.03103 Pf 0.03318 CoV 0.01710
# LS2:  Degree 1 e_LOO 2.8365797203315206e-05 Pf_ref 0.14864 Pf 0.12858 CoV 0.00820
# number of training points:  28 -------------------------------------------------
# LS1:  Degree 3 e_LOO 0.005723703931702647 Pf_ref 0.03064 Pf 0.06861 CoV 0.01170
# LS2:  Degree 1 e_LOO 5.063027083144507e-06 Pf_ref 0.1483 Pf 0.12727 CoV 0.00830
# number of training points:  29 -------------------------------------------------
# LS1:  Degree 3 e_LOO 1.0837718524759717e-05 Pf_ref 0.03185 Pf 0.03756 CoV 0.01600
# LS2:  Degree 1 e_LOO 0.000414195532195093 Pf_ref 0.14849 Pf 0.09028 CoV 0.01000
# number of training points:  30 -------------------------------------------------
# LS1:  Degree 3 e_LOO 0.00024915275959747134 Pf_ref 0.03188 Pf 0.03308 CoV 0.01710
# LS2:  Degree 1 e_LOO 2.755593823436002e-05 Pf_ref 0.14755 Pf 0.09096 CoV 0.01000
# number of training points:  31 -------------------------------------------------
# LS1:  Degree 3 e_LOO 0.00033483703025431256 Pf_ref 0.03205 Pf 0.03388 CoV 0.01690
# LS2:  Degree 1 e_LOO 1.5761855441944905e-06 Pf_ref 0.14702 Pf 0.09073 CoV 0.01000
# number of training points:  32 -------------------------------------------------
# LS1:  Degree 3 e_LOO 0.000291892775227035 Pf_ref 0.03145 Pf 0.03226 CoV 0.01730
# LS2:  Degree 1 e_LOO 2.5085999379627933e-05 Pf_ref 0.1476 Pf 0.09211 CoV 0.00990
# number of training points:  33 -------------------------------------------------
# LS1:  Degree 3 e_LOO 0.0003844777367524567 Pf_ref 0.0321 Pf 0.03412 CoV 0.01680
# LS2:  Degree 1 e_LOO 4.973309302940733e-05 Pf_ref 0.14789 Pf 0.09376 CoV 0.00980
# number of training points:  34 -------------------------------------------------
# LS1:  Degree 3 e_LOO 0.0004007756742139637 Pf_ref 0.03216 Pf 0.03412 CoV 0.01680
# LS2:  Degree 1 e_LOO 4.064880691113191e-05 Pf_ref 0.14744 Pf 0.09419 CoV 0.00980
# number of training points:  35 -------------------------------------------------
# LS1:  Degree 3 e_LOO 0.000634405453377391 Pf_ref 0.03087 Pf 0.03261 CoV 0.01720
# LS2:  Degree 2 e_LOO 0.0002057392472592905 Pf_ref 0.14798 Pf 0.07927 CoV 0.01080
# number of training points:  36 -------------------------------------------------
# LS1:  Degree 3 e_LOO 0.00015257878015045092 Pf_ref 0.02951 Pf 0.03039 CoV 0.01790
# LS2:  Degree 2 e_LOO 2.2386545696933806e-05 Pf_ref 0.15014 Pf 0.08312 CoV 0.01050
# number of training points:  37 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.0007313664727577329 Pf_ref 0.03166 Pf 0.03239 CoV 0.01730
# LS2:  Degree 4 e_LOO 5.647859860972923e-05 Pf_ref 0.14884 Pf 0.1874 CoV 0.00660
# number of training points:  38 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.0007326562235626016 Pf_ref 0.03102 Pf 0.03185 CoV 0.01740
# LS2:  Degree 4 e_LOO 7.449069867068007e-07 Pf_ref 0.1487 Pf 0.18541 CoV 0.00660
# number of training points:  39 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.0009067037460880952 Pf_ref 0.03079 Pf 0.03121 CoV 0.01760
# LS2:  Degree 4 e_LOO 2.6784196649586124e-05 Pf_ref 0.14699 Pf 0.18423 CoV 0.00670
# number of training points:  40 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.0009834783067474713 Pf_ref 0.03138 Pf 0.03154 CoV 0.01750
# LS2:  Degree 4 e_LOO 7.156447129244487e-08 Pf_ref 0.14922 Pf 0.18669 CoV 0.00660
# number of training points:  41 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.0005367010203651931 Pf_ref 0.0308 Pf 0.03132 CoV 0.01760
# LS2:  Degree 4 e_LOO 1.1087754426399352e-06 Pf_ref 0.14765 Pf 0.18544 CoV 0.00660
# number of training points:  42 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.00046665878437728155 Pf_ref 0.03122 Pf 0.03162 CoV 0.01750
# LS2:  Degree 4 e_LOO 1.1354845705708029e-05 Pf_ref 0.14772 Pf 0.18574 CoV 0.00660
# number of training points:  43 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.0018855209346251773 Pf_ref 0.03164 Pf 0.03196 CoV 0.01740
# LS2:  Degree 4 e_LOO 0.00026161674436576146 Pf_ref 0.15092 Pf 0.18894 CoV 0.00660
# number of training points:  44 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.0026278172658930204 Pf_ref 0.03147 Pf 0.03164 CoV 0.01750
# LS2:  Degree 4 e_LOO 0.0001191920811337238 Pf_ref 0.14897 Pf 0.1878 CoV 0.00660
# number of training points:  45 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.0025360048167108996 Pf_ref 0.0312 Pf 0.03155 CoV 0.01750
# LS2:  Degree 4 e_LOO 0.0001439872587515891 Pf_ref 0.14939 Pf 0.18556 CoV 0.00660
# number of training points:  46 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.003685179081495918 Pf_ref 0.03149 Pf 0.03171 CoV 0.01750
# LS2:  Degree 4 e_LOO 0.00010894449975864775 Pf_ref 0.15034 Pf 0.18645 CoV 0.00660
# number of training points:  47 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.004894888292229198 Pf_ref 0.03145 Pf 0.03164 CoV 0.01750
# LS2:  Degree 4 e_LOO 8.587961847072424e-05 Pf_ref 0.14724 Pf 0.18433 CoV 0.00670
# number of training points:  48 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.004607856983903226 Pf_ref 0.03107 Pf 0.03145 CoV 0.01750
# LS2:  Degree 4 e_LOO 0.00010559938882979362 Pf_ref 0.14765 Pf 0.18415 CoV 0.00670
# number of training points:  49 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.004715798538534134 Pf_ref 0.03081 Pf 0.03099 CoV 0.01770
# LS2:  Degree 4 e_LOO 0.00013594624298480436 Pf_ref 0.14917 Pf 0.18575 CoV 0.00660
# number of training points:  50 -------------------------------------------------
# Experiment:  2 #################################################################
# C:\Users\Administrator\anaconda3\envs\surrogate\lib\site-packages\ipykernel_launcher.py:137: RuntimeWarning: divide by zero encountered in double_scalars
# LS1:  Degree 2 e_LOO 0.00868840975736237 Pf_ref 0.03096 Pf 0.0 CoV inf
# LS2:  Degree 1 e_LOO 0.0001814570964093569 Pf_ref 0.14727 Pf 0.17556 CoV 0.00690
# number of training points:  11 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.02308716253015366 Pf_ref 0.03097 Pf 0.03486 CoV 0.01660
# LS2:  Degree 2 e_LOO 0.01715457374584051 Pf_ref 0.14735 Pf 0.17826 CoV 0.00680
# number of training points:  12 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.004352020219141112 Pf_ref 0.03056 Pf 0.02499 CoV 0.01980
# LS2:  Degree 3 e_LOO 0.00928061042847266 Pf_ref 0.14849 Pf 0.18844 CoV 0.00660
# number of training points:  13 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.01839363360173786 Pf_ref 0.03083 Pf 0.02864 CoV 0.01840
# LS2:  Degree 3 e_LOO 0.006413940765786705 Pf_ref 0.14521 Pf 0.18358 CoV 0.00670
# number of training points:  14 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.0076941488391723874 Pf_ref 0.03132 Pf 0.00508 CoV 0.04430
# LS2:  Degree 1 e_LOO 0.0007947212797948959 Pf_ref 0.14767 Pf 0.14728 CoV 0.00760
# number of training points:  15 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.0035629770958909898 Pf_ref 0.03095 Pf 0.01702 CoV 0.02400
# LS2:  Degree 1 e_LOO 6.711803724766104e-06 Pf_ref 0.14804 Pf 0.11931 CoV 0.00860
# number of training points:  16 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.01059877402934308 Pf_ref 0.03162 Pf 0.01024 CoV 0.03110
# LS2:  Degree 1 e_LOO 0.00028829564536843837 Pf_ref 0.14691 Pf 0.12163 CoV 0.00850
# number of training points:  17 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.008657960791486499 Pf_ref 0.03284 Pf 0.01353 CoV 0.02700
# LS2:  Degree 2 e_LOO 0.00023655795830877742 Pf_ref 0.14902 Pf 0.10016 CoV 0.00950
# number of training points:  18 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.0052220764270735 Pf_ref 0.03137 Pf 0.01018 CoV 0.03120
# LS2:  Degree 2 e_LOO 0.0001954276158179468 Pf_ref 0.14694 Pf 0.09679 CoV 0.00970
# number of training points:  19 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.0036925603348645112 Pf_ref 0.03178 Pf 0.00881 CoV 0.03350
# LS2:  Degree 2 e_LOO 0.00011489538446207314 Pf_ref 0.14742 Pf 0.09748 CoV 0.00960
# number of training points:  20 -------------------------------------------------
# LS1:  Degree 3 e_LOO 0.0006887674774327906 Pf_ref 0.03146 Pf 0.0087 CoV 0.03380
# LS2:  Degree 2 e_LOO 6.322602198658757e-06 Pf_ref 0.14973 Pf 0.09651 CoV 0.00970
# number of training points:  21 -------------------------------------------------
# LS1:  Degree 3 e_LOO 0.0007821815189852329 Pf_ref 0.03101 Pf 0.00853 CoV 0.03410
# LS2:  Degree 2 e_LOO 9.405459413144645e-07 Pf_ref 0.14652 Pf 0.095 CoV 0.00980
# number of training points:  22 -------------------------------------------------
# LS1:  Degree 3 e_LOO 0.000595624679137777 Pf_ref 0.03138 Pf 0.0085 CoV 0.03420
# LS2:  Degree 2 e_LOO 3.631868720074923e-05 Pf_ref 0.14722 Pf 0.09512 CoV 0.00980
# number of training points:  23 -------------------------------------------------
# LS1:  Degree 3 e_LOO 0.0007875391082276404 Pf_ref 0.0309 Pf 0.00797 CoV 0.03530
# LS2:  Degree 2 e_LOO 1.3536429961812382e-05 Pf_ref 0.14725 Pf 0.09645 CoV 0.00970
# number of training points:  24 -------------------------------------------------
# LS1:  Degree 3 e_LOO 0.00018565982869520143 Pf_ref 0.03153 Pf 0.00834 CoV 0.03450
# LS2:  Degree 2 e_LOO 0.0005052300309144051 Pf_ref 0.14692 Pf 0.08724 CoV 0.01020
# number of training points:  25 -------------------------------------------------
# LS1:  Degree 3 e_LOO 1.401674208222291e-05 Pf_ref 0.0315 Pf 0.00874 CoV 0.03370
# LS2:  Degree 2 e_LOO 0.00027073402113065323 Pf_ref 0.14829 Pf 0.09341 CoV 0.00990
# number of training points:  26 -------------------------------------------------
# LS1:  Degree 3 e_LOO 9.330967179341623e-06 Pf_ref 0.03117 Pf 0.00825 CoV 0.03470
# LS2:  Degree 2 e_LOO 0.00024010629411139794 Pf_ref 0.14966 Pf 0.09357 CoV 0.00980
# number of training points:  27 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.0003189631856015563 Pf_ref 0.03243 Pf 0.0084 CoV 0.03440
# LS2:  Degree 2 e_LOO 0.001109044556474941 Pf_ref 0.14947 Pf 0.09556 CoV 0.00970
# number of training points:  28 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.0031571750681545015 Pf_ref 0.03117 Pf 0.00773 CoV 0.03580
# LS2:  Degree 2 e_LOO 0.0006710740582450307 Pf_ref 0.14983 Pf 0.09678 CoV 0.00970
# number of training points:  29 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.002588994410521419 Pf_ref 0.03178 Pf 0.00803 CoV 0.03510
# LS2:  Degree 2 e_LOO 0.0006315300902547979 Pf_ref 0.14716 Pf 0.09316 CoV 0.00990
# number of training points:  30 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.0022336225834657403 Pf_ref 0.03134 Pf 0.00811 CoV 0.03500
# LS2:  Degree 2 e_LOO 0.0007322304156504555 Pf_ref 0.14736 Pf 0.09149 CoV 0.01000
# number of training points:  31 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.01311489084525646 Pf_ref 0.03058 Pf 0.00753 CoV 0.03630
# LS2:  Degree 1 e_LOO 5.376861742007983e-05 Pf_ref 0.14656 Pf 0.12944 CoV 0.00820
# number of training points:  32 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.01204432607618981 Pf_ref 0.03177 Pf 0.00818 CoV 0.03480
# LS2:  Degree 1 e_LOO 6.88897852400059e-06 Pf_ref 0.14807 Pf 0.12954 CoV 0.00820
# number of training points:  33 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.009401400452025418 Pf_ref 0.03109 Pf 0.01409 CoV 0.02650
# LS2:  Degree 1 e_LOO 4.146890007169288e-06 Pf_ref 0.14822 Pf 0.12958 CoV 0.00820
# number of training points:  34 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.008559801064820863 Pf_ref 0.03231 Pf 0.03076 CoV 0.01780
# LS2:  Degree 1 e_LOO 9.070357041727261e-07 Pf_ref 0.14892 Pf 0.12867 CoV 0.00820
# number of training points:  35 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.008549435376771402 Pf_ref 0.03152 Pf 0.02937 CoV 0.01820
# LS2:  Degree 2 e_LOO 8.425159473741615e-09 Pf_ref 0.14955 Pf 0.09337 CoV 0.00990
# number of training points:  36 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.008922893608280556 Pf_ref 0.03158 Pf 0.03094 CoV 0.01770
# LS2:  Degree 1 e_LOO 4.764480983403524e-06 Pf_ref 0.14677 Pf 0.11951 CoV 0.00860
# number of training points:  37 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.00832850070756705 Pf_ref 0.03072 Pf 0.03044 CoV 0.01780
# LS2:  Degree 1 e_LOO 1.4776129685798464e-05 Pf_ref 0.14706 Pf 0.12083 CoV 0.00850
# number of training points:  38 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.008185180734096086 Pf_ref 0.03159 Pf 0.03119 CoV 0.01760
# LS2:  Degree 1 e_LOO 1.8341729050643978e-05 Pf_ref 0.15072 Pf 0.12347 CoV 0.00840
# number of training points:  39 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.007795757058013431 Pf_ref 0.03172 Pf 0.0313 CoV 0.01760
# LS2:  Degree 1 e_LOO 2.5723908105315528e-05 Pf_ref 0.14869 Pf 0.1222 CoV 0.00850
# number of training points:  40 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.005863470568940518 Pf_ref 0.03103 Pf 0.03087 CoV 0.01770
# LS2:  Degree 1 e_LOO 1.113462112329237e-06 Pf_ref 0.14856 Pf 0.12396 CoV 0.00840
# number of training points:  41 -------------------------------------------------
# LS1:  Degree 3 e_LOO 0.0012463575912898665 Pf_ref 0.02991 Pf 0.02978 CoV 0.01800
# LS2:  Degree 2 e_LOO 6.938237228085761e-08 Pf_ref 0.1494 Pf 0.0878 CoV 0.01020
# number of training points:  42 -------------------------------------------------
# LS1:  Degree 3 e_LOO 0.0010802317281000033 Pf_ref 0.03121 Pf 0.03103 CoV 0.01770
# LS2:  Degree 2 e_LOO 4.134428889466071e-09 Pf_ref 0.14709 Pf 0.08722 CoV 0.01020
# number of training points:  43 -------------------------------------------------
# LS1:  Degree 3 e_LOO 0.000843786421378893 Pf_ref 0.03148 Pf 0.03138 CoV 0.01760
# LS2:  Degree 1 e_LOO 1.0300386636224677e-07 Pf_ref 0.14777 Pf 0.12464 CoV 0.00840
# number of training points:  44 -------------------------------------------------
# LS1:  Degree 3 e_LOO 0.0004266168665121389 Pf_ref 0.03176 Pf 0.03153 CoV 0.01750
# LS2:  Degree 2 e_LOO 0.003693782994920522 Pf_ref 0.14884 Pf 0.09249 CoV 0.00990
# number of training points:  45 -------------------------------------------------
# LS1:  Degree 2 e_LOO 4.026568681108207e-09 Pf_ref 0.0303 Pf 0.03019 CoV 0.01790
# LS2:  Degree 2 e_LOO 2.7483229669924098e-05 Pf_ref 0.14838 Pf 0.10194 CoV 0.00940
# number of training points:  46 -------------------------------------------------
# LS1:  Degree 2 e_LOO 6.442647576772438e-06 Pf_ref 0.03102 Pf 0.03089 CoV 0.01770
# LS2:  Degree 3 e_LOO 2.0945082454903606e-05 Pf_ref 0.14996 Pf 0.0722 CoV 0.01130
# number of training points:  47 -------------------------------------------------
# LS1:  Degree 2 e_LOO 2.531384445996712e-05 Pf_ref 0.03134 Pf 0.03108 CoV 0.01770
# LS2:  Degree 3 e_LOO 3.814191744846698e-07 Pf_ref 0.14816 Pf 0.06994 CoV 0.01150
# number of training points:  48 -------------------------------------------------
# LS1:  Degree 1 e_LOO 5.032670845862675e-09 Pf_ref 0.0313 Pf 0.031 CoV 0.01770
# LS2:  Degree 3 e_LOO 9.84262783176533e-07 Pf_ref 0.14984 Pf 0.07164 CoV 0.01140
# number of training points:  49 -------------------------------------------------
# LS1:  Degree 1 e_LOO 1.3924461484830946e-06 Pf_ref 0.03093 Pf 0.0308 CoV 0.01770
# LS2:  Degree 3 e_LOO 2.955828426231548e-06 Pf_ref 0.14932 Pf 0.07141 CoV 0.01140
# number of training points:  50 -------------------------------------------------
# Experiment:  3 #################################################################
# LS1:  Degree 1 e_LOO 0.0034070237602017257 Pf_ref 0.03142 Pf 0.00129 CoV 0.08800
# LS2:  Degree 1 e_LOO 3.592302706490467e-05 Pf_ref 0.15098 Pf 0.2023 CoV 0.00630
# number of training points:  11 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.0025194217346485833 Pf_ref 0.03176 Pf 0.00012 CoV 0.28870
# LS2:  Degree 1 e_LOO 0.05401059731916975 Pf_ref 0.1476 Pf 0.17922 CoV 0.00680
# number of training points:  12 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.0012839967023475503 Pf_ref 0.03119 Pf 0.00025 CoV 0.20000
# LS2:  Degree 1 e_LOO 0.0009073252960152956 Pf_ref 0.14724 Pf 0.17614 CoV 0.00680
# number of training points:  13 -------------------------------------------------
# LS1:  Degree 1 e_LOO 1.846072726452703e-07 Pf_ref 0.03117 Pf 0.0 CoV inf
# LS2:  Degree 1 e_LOO 0.0009179731422387253 Pf_ref 0.14967 Pf 0.1893 CoV 0.00650
# number of training points:  14 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.01472143739678781 Pf_ref 0.0306 Pf 0.05445 CoV 0.01320
# LS2:  Degree 2 e_LOO 0.027126712424432785 Pf_ref 0.14701 Pf 0.10118 CoV 0.00940
# number of training points:  15 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.008034291523151538 Pf_ref 0.03058 Pf 0.07245 CoV 0.01130
# LS2:  Degree 1 e_LOO 0.042873909203725184 Pf_ref 0.14733 Pf 0.20393 CoV 0.00620
# number of training points:  16 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.017836386005140207 Pf_ref 0.03118 Pf 0.02615 CoV 0.01930
# LS2:  Degree 1 e_LOO 0.03960850168912672 Pf_ref 0.14838 Pf 0.20513 CoV 0.00620
# number of training points:  17 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.0193049863930378 Pf_ref 0.03073 Pf 0.01986 CoV 0.02220
# LS2:  Degree 1 e_LOO 0.07406929786480988 Pf_ref 0.1496 Pf 0.20451 CoV 0.00620
# number of training points:  18 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.018280515136915622 Pf_ref 0.03174 Pf 0.01913 CoV 0.02260
# LS2:  Degree 1 e_LOO 0.07488437552539214 Pf_ref 0.14739 Pf 0.19783 CoV 0.00640
# number of training points:  19 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.00544781761145463 Pf_ref 0.03107 Pf 0.01849 CoV 0.02300
# LS2:  Degree 2 e_LOO 0.012941713058931095 Pf_ref 0.1486 Pf 0.11009 CoV 0.00900
# number of training points:  20 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.004701033537165426 Pf_ref 0.03176 Pf 0.02348 CoV 0.02040
# LS2:  Degree 2 e_LOO 0.016721870861563543 Pf_ref 0.14731 Pf 0.11348 CoV 0.00880
# number of training points:  21 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.0059920961985534685 Pf_ref 0.03038 Pf 0.02479 CoV 0.01980
# LS2:  Degree 2 e_LOO 0.005600249903191661 Pf_ref 0.14942 Pf 0.1143 CoV 0.00880
# number of training points:  22 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.004637679143550696 Pf_ref 0.03183 Pf 0.0201 CoV 0.02210
# LS2:  Degree 2 e_LOO 0.0042887913865966715 Pf_ref 0.14758 Pf 0.11395 CoV 0.00880
# number of training points:  23 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.003167259839760759 Pf_ref 0.03203 Pf 0.01983 CoV 0.02220
# LS2:  Degree 2 e_LOO 0.0014325430436474365 Pf_ref 0.15025 Pf 0.11603 CoV 0.00870
# number of training points:  24 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.003377277162063958 Pf_ref 0.03182 Pf 0.01937 CoV 0.02250
# LS2:  Degree 2 e_LOO 0.0024501098336179986 Pf_ref 0.14812 Pf 0.10806 CoV 0.00910
# number of training points:  25 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.006216102213276925 Pf_ref 0.03058 Pf 0.0196 CoV 0.02240
# LS2:  Degree 2 e_LOO 0.0012895109202442515 Pf_ref 0.14918 Pf 0.10774 CoV 0.00910
# number of training points:  26 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.006137649051024915 Pf_ref 0.03055 Pf 0.01966 CoV 0.02230
# LS2:  Degree 4 e_LOO 2.2844531275199547e-05 Pf_ref 0.14898 Pf 0.20935 CoV 0.00610
# number of training points:  27 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.004416482948181939 Pf_ref 0.03151 Pf 0.02319 CoV 0.02050
# LS2:  Degree 2 e_LOO 0.0025695019981764092 Pf_ref 0.14814 Pf 0.10758 CoV 0.00910
# number of training points:  28 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.003763605342403015 Pf_ref 0.03127 Pf 0.02826 CoV 0.01850
# LS2:  Degree 2 e_LOO 0.0024730603484816706 Pf_ref 0.14799 Pf 0.10724 CoV 0.00910
# number of training points:  29 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.003746820588243613 Pf_ref 0.03118 Pf 0.02778 CoV 0.01870
# LS2:  Degree 2 e_LOO 0.0024956998160624157 Pf_ref 0.14977 Pf 0.11013 CoV 0.00900
# number of training points:  30 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.003479223541417239 Pf_ref 0.03205 Pf 0.03184 CoV 0.01740
# LS2:  Degree 2 e_LOO 0.0025923558475399694 Pf_ref 0.15052 Pf 0.10806 CoV 0.00910
# number of training points:  31 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.0024526593666058293 Pf_ref 0.03176 Pf 0.03108 CoV 0.01770
# LS2:  Degree 2 e_LOO 0.0017017606946442294 Pf_ref 0.14928 Pf 0.10817 CoV 0.00910
# number of training points:  32 -------------------------------------------------
# LS1:  Degree 3 e_LOO 3.717319516944586e-06 Pf_ref 0.03243 Pf 0.03016 CoV 0.01790
# LS2:  Degree 2 e_LOO 0.0013423748788753901 Pf_ref 0.14932 Pf 0.10712 CoV 0.00910
# number of training points:  33 -------------------------------------------------
# LS1:  Degree 4 e_LOO 0.0014208696465614222 Pf_ref 0.03061 Pf 0.02802 CoV 0.01860
# LS2:  Degree 2 e_LOO 0.003077893978688255 Pf_ref 0.14847 Pf 0.10698 CoV 0.00910
# number of training points:  34 -------------------------------------------------
# LS1:  Degree 4 e_LOO 0.0020024750176415923 Pf_ref 0.03142 Pf 0.02796 CoV 0.01860
# LS2:  Degree 4 e_LOO 0.0002517614589399541 Pf_ref 0.14915 Pf 0.16281 CoV 0.00720
# number of training points:  35 -------------------------------------------------
# LS1:  Degree 4 e_LOO 0.0016925926508398795 Pf_ref 0.0307 Pf 0.0274 CoV 0.01880
# LS2:  Degree 4 e_LOO 0.00046705648187443096 Pf_ref 0.14847 Pf 0.15725 CoV 0.00730
# number of training points:  36 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.00016159549668506566 Pf_ref 0.03067 Pf 0.0285 CoV 0.01850
# LS2:  Degree 2 e_LOO 6.339408129454982e-05 Pf_ref 0.14919 Pf 0.11538 CoV 0.00880
# number of training points:  37 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.00040320925364251706 Pf_ref 0.03162 Pf 0.02863 CoV 0.01840
# LS2:  Degree 2 e_LOO 1.1865620115956507e-05 Pf_ref 0.15037 Pf 0.11687 CoV 0.00870
# number of training points:  38 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.0003881333040695162 Pf_ref 0.03171 Pf 0.03111 CoV 0.01760
# LS2:  Degree 2 e_LOO 2.216460880084754e-05 Pf_ref 0.14917 Pf 0.11797 CoV 0.00860
# number of training points:  39 -------------------------------------------------
# LS1:  Degree 4 e_LOO 0.000235627734678219 Pf_ref 0.03161 Pf 0.0328 CoV 0.01720
# LS2:  Degree 2 e_LOO 3.511969560156005e-05 Pf_ref 0.15041 Pf 0.11829 CoV 0.00860
# number of training points:  40 -------------------------------------------------
# LS1:  Degree 2 e_LOO 8.712295316668064e-05 Pf_ref 0.03107 Pf 0.03138 CoV 0.01760
# LS2:  Degree 2 e_LOO 3.659834771656571e-05 Pf_ref 0.14659 Pf 0.11638 CoV 0.00870
# number of training points:  41 -------------------------------------------------
# LS1:  Degree 2 e_LOO 9.667283138715618e-05 Pf_ref 0.031 Pf 0.03122 CoV 0.01760
# LS2:  Degree 2 e_LOO 2.2141345313821713e-05 Pf_ref 0.14923 Pf 0.11811 CoV 0.00860
# number of training points:  42 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.00010768677653933797 Pf_ref 0.03179 Pf 0.03192 CoV 0.01740
# LS2:  Degree 2 e_LOO 1.089461067197871e-05 Pf_ref 0.14784 Pf 0.12 CoV 0.00860
# number of training points:  43 -------------------------------------------------
# LS1:  Degree 2 e_LOO 1.5328651143462963e-05 Pf_ref 0.03141 Pf 0.03152 CoV 0.01750
# LS2:  Degree 2 e_LOO 0.0004728770841789645 Pf_ref 0.14882 Pf 0.1187 CoV 0.00860
# number of training points:  44 -------------------------------------------------
# LS1:  Degree 2 e_LOO 1.4208963409574313e-06 Pf_ref 0.03112 Pf 0.03148 CoV 0.01750
# LS2:  Degree 2 e_LOO 0.0003677272464649635 Pf_ref 0.14862 Pf 0.11914 CoV 0.00860
# number of training points:  45 -------------------------------------------------
# LS1:  Degree 2 e_LOO 1.8650932088759317e-06 Pf_ref 0.03159 Pf 0.03174 CoV 0.01750
# LS2:  Degree 2 e_LOO 0.000308183020499035 Pf_ref 0.14959 Pf 0.12012 CoV 0.00860
# number of training points:  46 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.00010545023924048077 Pf_ref 0.03181 Pf 0.03184 CoV 0.01740
# LS2:  Degree 2 e_LOO 0.0002235774806987538 Pf_ref 0.14827 Pf 0.12104 CoV 0.00850
# number of training points:  47 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.00014141919187868465 Pf_ref 0.03195 Pf 0.03204 CoV 0.01740
# LS2:  Degree 2 e_LOO 0.00018267078538640775 Pf_ref 0.1472 Pf 0.11921 CoV 0.00860
# number of training points:  48 -------------------------------------------------
# LS1:  Degree 2 e_LOO 7.600889363942519e-05 Pf_ref 0.03083 Pf 0.03105 CoV 0.01770
# LS2:  Degree 2 e_LOO 0.00016138214268831552 Pf_ref 0.14748 Pf 0.12095 CoV 0.00850
# number of training points:  49 -------------------------------------------------
# LS1:  Degree 2 e_LOO 5.0164166422581665e-05 Pf_ref 0.03045 Pf 0.03063 CoV 0.01780
# LS2:  Degree 2 e_LOO 0.00012978575724695223 Pf_ref 0.14824 Pf 0.12194 CoV 0.00850
# number of training points:  50 -------------------------------------------------
# Experiment:  4 #################################################################
# LS1:  Degree 1 e_LOO 0.008121065858940037 Pf_ref 0.02998 Pf 0.03778 CoV 0.01600
# LS2:  Degree 1 e_LOO 0.00028141597034053034 Pf_ref 0.14723 Pf 0.10287 CoV 0.00930
# number of training points:  11 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.009824476674620032 Pf_ref 0.03186 Pf 0.14371 CoV 0.00770
# LS2:  Degree 1 e_LOO 0.025805933276329643 Pf_ref 0.14769 Pf 0.04307 CoV 0.01490
# number of training points:  12 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.009224966960273423 Pf_ref 0.03089 Pf 0.00021 CoV 0.21820
# LS2:  Degree 3 e_LOO 0.0016660929370083798 Pf_ref 0.1495 Pf 0.18501 CoV 0.00660
# number of training points:  13 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.002338649939871621 Pf_ref 0.03092 Pf 0.00167 CoV 0.07730
# LS2:  Degree 1 e_LOO 0.0030527459009730144 Pf_ref 0.14788 Pf 0.11824 CoV 0.00860
# number of training points:  14 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.0006390605271518341 Pf_ref 0.03195 Pf 0.0072 CoV 0.03710
# LS2:  Degree 1 e_LOO 0.005982892701463176 Pf_ref 0.14702 Pf 0.1263 CoV 0.00830
# number of training points:  15 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.00019941892920368566 Pf_ref 0.03149 Pf 0.00785 CoV 0.03560
# LS2:  Degree 1 e_LOO 0.00891609887939926 Pf_ref 0.14978 Pf 0.12823 CoV 0.00820
# number of training points:  16 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.0073639989779520675 Pf_ref 0.03133 Pf 0.01452 CoV 0.02610
# LS2:  Degree 2 e_LOO 0.016941280020989033 Pf_ref 0.14704 Pf 0.06202 CoV 0.01230
# number of training points:  17 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.0059265401986954925 Pf_ref 0.03197 Pf 0.02313 CoV 0.02060
# LS2:  Degree 2 e_LOO 0.013263529882398676 Pf_ref 0.14838 Pf 0.05949 CoV 0.01260
# number of training points:  18 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.004746985450617971 Pf_ref 0.03173 Pf 0.02774 CoV 0.01870
# LS2:  Degree 2 e_LOO 0.015928012687274413 Pf_ref 0.14784 Pf 0.06454 CoV 0.01200
# number of training points:  19 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.0029582260899385713 Pf_ref 0.03229 Pf 0.0221 CoV 0.02100
# LS2:  Degree 1 e_LOO 0.015168605464279505 Pf_ref 0.15012 Pf 0.11778 CoV 0.00870
# number of training points:  20 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.0034398756372619205 Pf_ref 0.03116 Pf 0.02181 CoV 0.02120
# LS2:  Degree 1 e_LOO 0.010190402338556254 Pf_ref 0.14761 Pf 0.12124 CoV 0.00850
# number of training points:  21 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.0017710138533030707 Pf_ref 0.03085 Pf 0.01881 CoV 0.02280
# LS2:  Degree 1 e_LOO 0.007137263978108649 Pf_ref 0.14824 Pf 0.12504 CoV 0.00840
# number of training points:  22 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.0019578167948130472 Pf_ref 0.03207 Pf 0.02009 CoV 0.02210
# LS2:  Degree 1 e_LOO 0.006132275151797202 Pf_ref 0.14965 Pf 0.12807 CoV 0.00830
# number of training points:  23 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.0018825888069196012 Pf_ref 0.0323 Pf 0.02095 CoV 0.02160
# LS2:  Degree 1 e_LOO 0.003722142021843968 Pf_ref 0.14914 Pf 0.13109 CoV 0.00810
# number of training points:  24 -------------------------------------------------
# LS1:  Degree 4 e_LOO 0.00038189516233282073 Pf_ref 0.03134 Pf 0.11201 CoV 0.00890
# LS2:  Degree 2 e_LOO 0.0014842565254109983 Pf_ref 0.14806 Pf 0.07764 CoV 0.01090
# number of training points:  25 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.00020556015459349965 Pf_ref 0.03181 Pf 0.02157 CoV 0.02130
# LS2:  Degree 2 e_LOO 0.0006087723536214511 Pf_ref 0.14853 Pf 0.0836 CoV 0.01050
# number of training points:  26 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.00024046137220513374 Pf_ref 0.03016 Pf 0.02077 CoV 0.02170
# LS2:  Degree 2 e_LOO 0.0006294615809255419 Pf_ref 0.14829 Pf 0.0823 CoV 0.01060
# number of training points:  27 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.0001666597043310472 Pf_ref 0.03215 Pf 0.02101 CoV 0.02160
# LS2:  Degree 2 e_LOO 6.612112166725271e-06 Pf_ref 0.14993 Pf 0.08509 CoV 0.01040
# number of training points:  28 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.00010563457330251618 Pf_ref 0.03076 Pf 0.01954 CoV 0.02240
# LS2:  Degree 2 e_LOO 1.0623505058822368e-06 Pf_ref 0.14977 Pf 0.08678 CoV 0.01030
# number of training points:  29 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.00011072364521719437 Pf_ref 0.03086 Pf 0.02126 CoV 0.02150
# LS2:  Degree 2 e_LOO 1.3364472934765509e-06 Pf_ref 0.14798 Pf 0.08563 CoV 0.01030
# number of training points:  30 -------------------------------------------------
# LS1:  Degree 2 e_LOO 9.326025622545743e-05 Pf_ref 0.03036 Pf 0.02204 CoV 0.02110
# LS2:  Degree 2 e_LOO 2.4382350167495235e-06 Pf_ref 0.15005 Pf 0.09027 CoV 0.01000
# number of training points:  31 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.00040119384375274366 Pf_ref 0.03244 Pf 0.0238 CoV 0.02030
# LS2:  Degree 2 e_LOO 9.04310671659113e-07 Pf_ref 0.14778 Pf 0.09057 CoV 0.01000
# number of training points:  32 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.00019122716656630795 Pf_ref 0.03176 Pf 0.02422 CoV 0.02010
# LS2:  Degree 2 e_LOO 2.87894062591171e-07 Pf_ref 0.1497 Pf 0.08993 CoV 0.01010
# number of training points:  33 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.0026549791533301654 Pf_ref 0.03234 Pf 0.02942 CoV 0.01820
# LS2:  Degree 1 e_LOO 0.0018040199445223638 Pf_ref 0.14805 Pf 0.1186 CoV 0.00860
# number of training points:  34 -------------------------------------------------
# LS1:  Degree 1 e_LOO 3.633944207881533e-06 Pf_ref 0.03138 Pf 0.03153 CoV 0.01750
# LS2:  Degree 1 e_LOO 0.0005130611350347042 Pf_ref 0.15014 Pf 0.12456 CoV 0.00840
# number of training points:  35 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.00012259556958303365 Pf_ref 0.03193 Pf 0.03153 CoV 0.01750
# LS2:  Degree 3 e_LOO 4.771795716227512e-05 Pf_ref 0.14943 Pf 0.09074 CoV 0.01000
# number of training points:  36 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.00018735272249005214 Pf_ref 0.03123 Pf 0.03059 CoV 0.01780
# LS2:  Degree 1 e_LOO 2.7813893976735944e-05 Pf_ref 0.14862 Pf 0.11938 CoV 0.00860
# number of training points:  37 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.00015877862358551172 Pf_ref 0.0312 Pf 0.03095 CoV 0.01770
# LS2:  Degree 1 e_LOO 2.4342679407250235e-05 Pf_ref 0.14722 Pf 0.12112 CoV 0.00850
# number of training points:  38 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.0013965933993032888 Pf_ref 0.03152 Pf 0.03009 CoV 0.01800
# LS2:  Degree 1 e_LOO 2.1492535483457946e-05 Pf_ref 0.14838 Pf 0.12211 CoV 0.00850
# number of training points:  39 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.0014138116199864954 Pf_ref 0.03151 Pf 0.03022 CoV 0.01790
# LS2:  Degree 1 e_LOO 1.3050005522912567e-05 Pf_ref 0.14511 Pf 0.12033 CoV 0.00860
# number of training points:  40 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.00045554734462510677 Pf_ref 0.03188 Pf 0.03101 CoV 0.01770
# LS2:  Degree 1 e_LOO 8.316460894663161e-05 Pf_ref 0.14865 Pf 0.12187 CoV 0.00850
# number of training points:  41 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.0005236912727796218 Pf_ref 0.03085 Pf 0.03042 CoV 0.01790
# LS2:  Degree 1 e_LOO 6.138610326479271e-05 Pf_ref 0.14813 Pf 0.12395 CoV 0.00840
# number of training points:  42 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.0006926864532933136 Pf_ref 0.03172 Pf 0.03134 CoV 0.01760
# LS2:  Degree 1 e_LOO 4.598610701814575e-05 Pf_ref 0.1507 Pf 0.12627 CoV 0.00830
# number of training points:  43 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.0005558017778341625 Pf_ref 0.02996 Pf 0.02956 CoV 0.01810
# LS2:  Degree 1 e_LOO 3.113744772331486e-05 Pf_ref 0.14809 Pf 0.12684 CoV 0.00830
# number of training points:  44 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.0007788646723435283 Pf_ref 0.03161 Pf 0.03155 CoV 0.01750
# LS2:  Degree 1 e_LOO 3.159841072399168e-05 Pf_ref 0.14659 Pf 0.1243 CoV 0.00840
# number of training points:  45 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.0001990718856854526 Pf_ref 0.03001 Pf 0.02997 CoV 0.01800
# LS2:  Degree 1 e_LOO 0.00011801155637233761 Pf_ref 0.14754 Pf 0.12005 CoV 0.00860
# number of training points:  46 -------------------------------------------------
# LS1:  Degree 4 e_LOO 3.488681309943462e-05 Pf_ref 0.03078 Pf 0.03832 CoV 0.01580
# LS2:  Degree 1 e_LOO 9.029017673221882e-05 Pf_ref 0.14819 Pf 0.12146 CoV 0.00850
# number of training points:  47 -------------------------------------------------
# LS1:  Degree 2 e_LOO 1.0066587495693324e-05 Pf_ref 0.03155 Pf 0.03149 CoV 0.01750
# LS2:  Degree 1 e_LOO 2.6580378387207328e-06 Pf_ref 0.14965 Pf 0.12877 CoV 0.00820
# number of training points:  48 -------------------------------------------------
# LS1:  Degree 2 e_LOO 9.951376965688362e-07 Pf_ref 0.0312 Pf 0.03106 CoV 0.01770
# LS2:  Degree 1 e_LOO 1.5485593026374396e-06 Pf_ref 0.14702 Pf 0.1271 CoV 0.00830
# number of training points:  49 -------------------------------------------------
# LS1:  Degree 2 e_LOO 1.4368875016502583e-05 Pf_ref 0.03149 Pf 0.03158 CoV 0.01750
# LS2:  Degree 1 e_LOO 3.197681646790992e-06 Pf_ref 0.14668 Pf 0.12701 CoV 0.00830
# number of training points:  50 -------------------------------------------------
# Experiment:  5 #################################################################
# LS1:  Degree 1 e_LOO 0.009293867618486646 Pf_ref 0.03126 Pf 0.04518 CoV 0.01450
# LS2:  Degree 1 e_LOO 0.0008797991637226772 Pf_ref 0.14785 Pf 0.17538 CoV 0.00690
# number of training points:  11 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.0008702327182280425 Pf_ref 0.03173 Pf 0.0 CoV inf
# LS2:  Degree 1 e_LOO 0.03584096791928211 Pf_ref 0.14818 Pf 0.06506 CoV 0.01200
# number of training points:  12 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.0015158879137152604 Pf_ref 0.03202 Pf 0.00547 CoV 0.04260
# LS2:  Degree 1 e_LOO 0.03487444188529718 Pf_ref 0.14949 Pf 0.06424 CoV 0.01210
# number of training points:  13 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.003493511917787344 Pf_ref 0.03075 Pf 0.00157 CoV 0.07970
# LS2:  Degree 2 e_LOO 0.005935103203230066 Pf_ref 0.14791 Pf 0.10629 CoV 0.00920
# number of training points:  14 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.001416199502460694 Pf_ref 0.0312 Pf 0.01694 CoV 0.02410
# LS2:  Degree 2 e_LOO 0.000701500491204626 Pf_ref 0.14925 Pf 0.10952 CoV 0.00900
# number of training points:  15 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.0007748945670621423 Pf_ref 0.03087 Pf 0.00744 CoV 0.03650
# LS2:  Degree 3 e_LOO 0.0009677189804176982 Pf_ref 0.14921 Pf 0.11636 CoV 0.00870
# number of training points:  16 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.0017716694754996943 Pf_ref 0.03116 Pf 0.00958 CoV 0.03220
# LS2:  Degree 1 e_LOO 7.990651898431077e-08 Pf_ref 0.14923 Pf 0.09658 CoV 0.00970
# number of training points:  17 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.002191529281849463 Pf_ref 0.03098 Pf 0.01001 CoV 0.03140
# LS2:  Degree 2 e_LOO 0.0010957948217481927 Pf_ref 0.14824 Pf 0.1088 CoV 0.00910
# number of training points:  18 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.0007943889166703634 Pf_ref 0.03089 Pf 0.01087 CoV 0.03020
# LS2:  Degree 2 e_LOO 9.106904782642123e-05 Pf_ref 0.15067 Pf 0.10773 CoV 0.00910
# number of training points:  19 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.00194587626489583 Pf_ref 0.03191 Pf 0.01116 CoV 0.02980
# LS2:  Degree 1 e_LOO 0.0002516750146431728 Pf_ref 0.14867 Pf 0.09831 CoV 0.00960
# number of training points:  20 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.000728247350053906 Pf_ref 0.03076 Pf 0.00978 CoV 0.03180
# LS2:  Degree 2 e_LOO 0.0001373626847334235 Pf_ref 0.14716 Pf 0.1089 CoV 0.00900
# number of training points:  21 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.00045905344049572037 Pf_ref 0.03113 Pf 0.00949 CoV 0.03230
# LS2:  Degree 1 e_LOO 3.915425695043264e-06 Pf_ref 0.14841 Pf 0.09536 CoV 0.00970
# number of training points:  22 -------------------------------------------------
# LS1:  Degree 4 e_LOO 0.0009870073264717936 Pf_ref 0.03087 Pf 0.00816 CoV 0.03490
# LS2:  Degree 4 e_LOO 4.287271853653829e-05 Pf_ref 0.14891 Pf 0.17983 CoV 0.00680
# number of training points:  23 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.0015041114964704178 Pf_ref 0.03277 Pf 0.01092 CoV 0.03010
# LS2:  Degree 1 e_LOO 0.03160525737731716 Pf_ref 0.14664 Pf 0.06381 CoV 0.01210
# number of training points:  24 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.0002292928869986316 Pf_ref 0.03235 Pf 0.01318 CoV 0.02740
# LS2:  Degree 1 e_LOO 0.02592895068773666 Pf_ref 0.14864 Pf 0.06596 CoV 0.01190
# number of training points:  25 -------------------------------------------------
# LS1:  Degree 2 e_LOO 9.91409491315732e-06 Pf_ref 0.03151 Pf 0.01273 CoV 0.02780
# LS2:  Degree 1 e_LOO 0.01966739357682687 Pf_ref 0.14828 Pf 0.06743 CoV 0.01180
# number of training points:  26 -------------------------------------------------
# LS1:  Degree 2 e_LOO 6.444380614195948e-05 Pf_ref 0.03114 Pf 0.01191 CoV 0.02880
# LS2:  Degree 1 e_LOO 0.01318887594941552 Pf_ref 0.14854 Pf 0.0692 CoV 0.01160
# number of training points:  27 -------------------------------------------------
# LS1:  Degree 2 e_LOO 6.051383936030619e-05 Pf_ref 0.03104 Pf 0.01498 CoV 0.02560
# LS2:  Degree 1 e_LOO 0.01402138880567082 Pf_ref 0.14916 Pf 0.07072 CoV 0.01150
# number of training points:  28 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.00025383340138492694 Pf_ref 0.03134 Pf 0.0148 CoV 0.02580
# LS2:  Degree 1 e_LOO 0.0136300712092176 Pf_ref 0.14609 Pf 0.06882 CoV 0.01160
# number of training points:  29 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.0006585348954270968 Pf_ref 0.03182 Pf 0.01636 CoV 0.02450
# LS2:  Degree 1 e_LOO 0.012074687476944556 Pf_ref 0.14762 Pf 0.07032 CoV 0.01150
# number of training points:  30 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.0012414457746015952 Pf_ref 0.03179 Pf 0.02207 CoV 0.02110
# LS2:  Degree 1 e_LOO 0.011193596160183011 Pf_ref 0.15063 Pf 0.07355 CoV 0.01120
# number of training points:  31 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.0012377694945710008 Pf_ref 0.03145 Pf 0.02852 CoV 0.01850
# LS2:  Degree 1 e_LOO 0.010504223018367977 Pf_ref 0.15079 Pf 0.07388 CoV 0.01120
# number of training points:  32 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.0010232990570839854 Pf_ref 0.03135 Pf 0.03039 CoV 0.01790
# LS2:  Degree 2 e_LOO 0.0073899239857994885 Pf_ref 0.14936 Pf 0.10771 CoV 0.00910
# number of training points:  33 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.001442489978242859 Pf_ref 0.0312 Pf 0.03002 CoV 0.01800
# LS2:  Degree 2 e_LOO 0.00806534686093816 Pf_ref 0.14859 Pf 0.10593 CoV 0.00920
# number of training points:  34 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.0014511462416825424 Pf_ref 0.03098 Pf 0.02984 CoV 0.01800
# LS2:  Degree 2 e_LOO 0.005478739702834214 Pf_ref 0.148 Pf 0.10506 CoV 0.00920
# number of training points:  35 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.0014109676661031455 Pf_ref 0.03089 Pf 0.03059 CoV 0.01780
# LS2:  Degree 2 e_LOO 0.0033386966878454043 Pf_ref 0.15001 Pf 0.10317 CoV 0.00930
# number of training points:  36 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.0013588542115865968 Pf_ref 0.0314 Pf 0.03137 CoV 0.01760
# LS2:  Degree 2 e_LOO 0.001775582690367557 Pf_ref 0.14911 Pf 0.10152 CoV 0.00940
# number of training points:  37 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.0012482026683831276 Pf_ref 0.03168 Pf 0.0316 CoV 0.01750
# LS2:  Degree 2 e_LOO 0.0007370640515533129 Pf_ref 0.14818 Pf 0.09881 CoV 0.00960
# number of training points:  38 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.0011686460594562726 Pf_ref 0.03072 Pf 0.03072 CoV 0.01780
# LS2:  Degree 2 e_LOO 0.00019841817077473987 Pf_ref 0.14926 Pf 0.09868 CoV 0.00960
# number of training points:  39 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.0011860066532302772 Pf_ref 0.03127 Pf 0.0311 CoV 0.01770
# LS2:  Degree 2 e_LOO 3.267760976903507e-06 Pf_ref 0.14966 Pf 0.0971 CoV 0.00960
# number of training points:  40 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.001481620113216322 Pf_ref 0.0317 Pf 0.03154 CoV 0.01750
# LS2:  Degree 2 e_LOO 5.75369034823401e-05 Pf_ref 0.14676 Pf 0.09447 CoV 0.00980
# number of training points:  41 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.0014051034974036393 Pf_ref 0.03185 Pf 0.03171 CoV 0.01750
# LS2:  Degree 2 e_LOO 1.6459065959773758e-05 Pf_ref 0.14964 Pf 0.09473 CoV 0.00980
# number of training points:  42 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.0017920494648711502 Pf_ref 0.03228 Pf 0.03223 CoV 0.01730
# LS2:  Degree 2 e_LOO 0.00031979653023856265 Pf_ref 0.14762 Pf 0.09225 CoV 0.00990
# number of training points:  43 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.001703922021480311 Pf_ref 0.03105 Pf 0.03093 CoV 0.01770
# LS2:  Degree 2 e_LOO 0.0008160653359011508 Pf_ref 0.14792 Pf 0.09198 CoV 0.00990
# number of training points:  44 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.0001347662349996079 Pf_ref 0.03201 Pf 0.03195 CoV 0.01740
# ...
# number of training points:  25 -------------------------------------------------
# LS1:  Degree 1 e_LOO 2.8437489861962326e-05 Pf_ref 0.03118 Pf 0.03218 CoV 0.01730
# LS2:  Degree 4 e_LOO 0.0016504232382074456 Pf_ref 0.1481 Pf 0.16574 CoV 0.00710
# number of training points:  26 -------------------------------------------------
# LS1:  Degree 1 e_LOO 1.1925911406560841e-05 Pf_ref 0.03051 Pf 0.03011 CoV 0.01790
# LS2:  Degree 1 e_LOO 0.0014281162249342749 Pf_ref 0.1482 Pf 0.16568 CoV 0.00710
# number of training points:  27 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.0007237207539197773 Pf_ref 0.03226 Pf 0.03186 CoV 0.01740
# LS2:  Degree 4 e_LOO 9.869024002408329e-06 Pf_ref 0.14844 Pf 0.17054 CoV 0.00700
# number of training points:  28 -------------------------------------------------
# LS1:  Degree 4 e_LOO 0.00044549047861149857 Pf_ref 0.03117 Pf 0.0785 CoV 0.01080
# LS2:  Degree 4 e_LOO 0.000336179584947631 Pf_ref 0.15112 Pf 0.17228 CoV 0.00690
# number of training points:  29 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.00023805463094280342 Pf_ref 0.03212 Pf 0.03217 CoV 0.01730
# LS2:  Degree 4 e_LOO 9.422458156423595e-05 Pf_ref 0.1478 Pf 0.16434 CoV 0.00710
# number of training points:  30 -------------------------------------------------
# LS1:  Degree 1 e_LOO 7.962174300019593e-05 Pf_ref 0.03135 Pf 0.03078 CoV 0.01770
# LS2:  Degree 4 e_LOO 0.00011626960526970524 Pf_ref 0.14879 Pf 0.16539 CoV 0.00710
# number of training points:  31 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.000821210708912295 Pf_ref 0.03115 Pf 0.03107 CoV 0.01770
# LS2:  Degree 4 e_LOO 1.925291839259354e-05 Pf_ref 0.14789 Pf 0.16878 CoV 0.00700
# number of training points:  32 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.0002900783017712824 Pf_ref 0.03156 Pf 0.03162 CoV 0.01750
# LS2:  Degree 4 e_LOO 7.170330748727628e-05 Pf_ref 0.14763 Pf 0.16615 CoV 0.00710
# number of training points:  33 -------------------------------------------------
# LS1:  Degree 1 e_LOO 7.658133552835468e-05 Pf_ref 0.03224 Pf 0.03215 CoV 0.01740
# LS2:  Degree 4 e_LOO 8.381648968111894e-05 Pf_ref 0.1479 Pf 0.16812 CoV 0.00700
# number of training points:  34 -------------------------------------------------
# LS1:  Degree 1 e_LOO 1.3382830537133228e-05 Pf_ref 0.03159 Pf 0.03139 CoV 0.01760
# LS2:  Degree 2 e_LOO 0.00011373589226235156 Pf_ref 0.14742 Pf 0.15552 CoV 0.00740
# number of training points:  35 -------------------------------------------------
# LS1:  Degree 1 e_LOO 4.729113457455982e-05 Pf_ref 0.03102 Pf 0.03104 CoV 0.01770
# LS2:  Degree 2 e_LOO 0.00011803077556320623 Pf_ref 0.14851 Pf 0.15678 CoV 0.00730
# number of training points:  36 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.00019608793028813538 Pf_ref 0.03117 Pf 0.03106 CoV 0.01770
# LS2:  Degree 2 e_LOO 3.718339917434081e-05 Pf_ref 0.1482 Pf 0.16067 CoV 0.00720
# number of training points:  37 -------------------------------------------------
# LS1:  Degree 1 e_LOO 1.2975848178218368e-06 Pf_ref 0.03023 Pf 0.02996 CoV 0.01800
# LS2:  Degree 4 e_LOO 5.831295223282293e-05 Pf_ref 0.14614 Pf 0.15853 CoV 0.00730
# number of training points:  38 -------------------------------------------------
# LS1:  Degree 1 e_LOO 2.4443096972082856e-05 Pf_ref 0.03069 Pf 0.03026 CoV 0.01790
# LS2:  Degree 4 e_LOO 3.700457587932101e-05 Pf_ref 0.1496 Pf 0.16205 CoV 0.00720
# number of training points:  39 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.0006884542713093552 Pf_ref 0.03128 Pf 0.03075 CoV 0.01780
# LS2:  Degree 2 e_LOO 0.00038029410189983665 Pf_ref 0.14729 Pf 0.1616 CoV 0.00720
# number of training points:  40 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.00019487758173627058 Pf_ref 0.03197 Pf 0.0315 CoV 0.01750
# LS2:  Degree 2 e_LOO 0.00039361410764112895 Pf_ref 0.14737 Pf 0.16198 CoV 0.00720
# number of training points:  41 -------------------------------------------------
# LS1:  Degree 1 e_LOO 2.3357882756896806e-06 Pf_ref 0.03125 Pf 0.0309 CoV 0.01770
# LS2:  Degree 2 e_LOO 0.00011492296834375362 Pf_ref 0.14709 Pf 0.1612 CoV 0.00720
# number of training points:  42 -------------------------------------------------
# LS1:  Degree 1 e_LOO 1.9368999948621543e-05 Pf_ref 0.03131 Pf 0.03086 CoV 0.01770
# LS2:  Degree 2 e_LOO 8.464559665038921e-05 Pf_ref 0.14962 Pf 0.16361 CoV 0.00710
# number of training points:  43 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.00016790692814397105 Pf_ref 0.03173 Pf 0.03145 CoV 0.01750
# LS2:  Degree 2 e_LOO 2.1416191503964826e-05 Pf_ref 0.14789 Pf 0.16169 CoV 0.00720
# number of training points:  44 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.00013597968688391356 Pf_ref 0.032 Pf 0.0316 CoV 0.01750
# LS2:  Degree 2 e_LOO 4.0179933202688176e-06 Pf_ref 0.14868 Pf 0.16203 CoV 0.00720
# number of training points:  45 -------------------------------------------------
# LS1:  Degree 1 e_LOO 8.745425237757696e-05 Pf_ref 0.03171 Pf 0.03142 CoV 0.01760
# LS2:  Degree 2 e_LOO 6.422492427283143e-06 Pf_ref 0.14888 Pf 0.16343 CoV 0.00720
# number of training points:  46 -------------------------------------------------
# LS1:  Degree 1 e_LOO 4.8536804841909337e-05 Pf_ref 0.03165 Pf 0.0316 CoV 0.01750
# LS2:  Degree 2 e_LOO 2.0864229201521724e-05 Pf_ref 0.14851 Pf 0.16135 CoV 0.00720
# number of training points:  47 -------------------------------------------------
# LS1:  Degree 1 e_LOO 2.3353157441650935e-05 Pf_ref 0.03083 Pf 0.03052 CoV 0.01780
# LS2:  Degree 2 e_LOO 2.526905369783752e-05 Pf_ref 0.14896 Pf 0.16229 CoV 0.00720
# number of training points:  48 -------------------------------------------------
# LS1:  Degree 1 e_LOO 1.7557221065219795e-05 Pf_ref 0.03142 Pf 0.03122 CoV 0.01760
# LS2:  Degree 2 e_LOO 2.5539652785976896e-05 Pf_ref 0.14941 Pf 0.16389 CoV 0.00710
# number of training points:  49 -------------------------------------------------
# LS1:  Degree 1 e_LOO 4.418601245302895e-06 Pf_ref 0.03188 Pf 0.0315 CoV 0.01750
# LS2:  Degree 2 e_LOO 1.0853311095991728e-06 Pf_ref 0.14738 Pf 0.16087 CoV 0.00720
# number of training points:  50 -------------------------------------------------
# Experiment:  15 #################################################################
# LS1:  Degree 1 e_LOO 0.008352299201091146 Pf_ref 0.03186 Pf 0.1044 CoV 0.00930
# LS2:  Degree 1 e_LOO 1.4441366525350407e-05 Pf_ref 0.14631 Pf 0.19075 CoV 0.00650
# number of training points:  11 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.0025078177103097406 Pf_ref 0.0313 Pf 0.0 CoV inf
# LS2:  Degree 2 e_LOO 0.001897485051958559 Pf_ref 0.1478 Pf 0.07707 CoV 0.01090
# number of training points:  12 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.0015703422943851861 Pf_ref 0.03116 Pf 0.00562 CoV 0.04210
# LS2:  Degree 1 e_LOO 0.00035996776104568246 Pf_ref 0.14845 Pf 0.0976 CoV 0.00960
# number of training points:  13 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.00041615097646210253 Pf_ref 0.03083 Pf 0.01396 CoV 0.02660
# LS2:  Degree 1 e_LOO 7.997712226585328e-05 Pf_ref 0.14779 Pf 0.09619 CoV 0.00970
# number of training points:  14 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.00038721806010386675 Pf_ref 0.032 Pf 0.02 CoV 0.02210
# LS2:  Degree 1 e_LOO 0.0004112226087343325 Pf_ref 0.14842 Pf 0.09483 CoV 0.00980
# number of training points:  15 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.0003404699908368725 Pf_ref 0.03092 Pf 0.02239 CoV 0.02090
# LS2:  Degree 1 e_LOO 0.0014428360970268539 Pf_ref 0.14846 Pf 0.09959 CoV 0.00950
# number of training points:  16 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.002161251800148659 Pf_ref 0.03094 Pf 0.01808 CoV 0.02330
# LS2:  Degree 2 e_LOO 8.32582264510433e-06 Pf_ref 0.15029 Pf 0.09543 CoV 0.00970
# number of training points:  17 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.0018086418718739584 Pf_ref 0.03061 Pf 0.02044 CoV 0.02190
# LS2:  Degree 2 e_LOO 4.213457285698165e-06 Pf_ref 0.14693 Pf 0.09642 CoV 0.00970
# number of training points:  18 -------------------------------------------------
# LS1:  Degree 3 e_LOO 0.0004413552338438392 Pf_ref 0.03138 Pf 0.04072 CoV 0.01530
# LS2:  Degree 2 e_LOO 2.0773249810344932e-05 Pf_ref 0.14809 Pf 0.09738 CoV 0.00960
# number of training points:  19 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.00221500805120568 Pf_ref 0.03086 Pf 0.02302 CoV 0.02060
# LS2:  Degree 1 e_LOO 0.0015597720026536896 Pf_ref 0.14861 Pf 0.15437 CoV 0.00740
# number of training points:  20 -------------------------------------------------
# LS1:  Degree 1 e_LOO 3.562687887746967e-05 Pf_ref 0.03073 Pf 0.02257 CoV 0.02080
# LS2:  Degree 2 e_LOO 7.391625580824892e-05 Pf_ref 0.1477 Pf 0.17478 CoV 0.00690
# number of training points:  21 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.00015587226259043671 Pf_ref 0.03252 Pf 0.02381 CoV 0.02020
# LS2:  Degree 2 e_LOO 0.00015344677266692755 Pf_ref 0.14663 Pf 0.16778 CoV 0.00700
# number of training points:  22 -------------------------------------------------
# LS1:  Degree 1 e_LOO 9.71362094807963e-05 Pf_ref 0.03105 Pf 0.02272 CoV 0.02070
# LS2:  Degree 3 e_LOO 0.00011046022395657915 Pf_ref 0.14829 Pf 0.09953 CoV 0.00950
# number of training points:  23 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.0007396295208570242 Pf_ref 0.03166 Pf 0.02354 CoV 0.02040
# LS2:  Degree 3 e_LOO 0.0004762665255575986 Pf_ref 0.14884 Pf 0.09673 CoV 0.00970
# number of training points:  24 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.0019085205318825388 Pf_ref 0.03124 Pf 0.02373 CoV 0.02030
# LS2:  Degree 3 e_LOO 0.00029368747596291523 Pf_ref 0.14712 Pf 0.09889 CoV 0.00950
# number of training points:  25 -------------------------------------------------
# LS1:  Degree 2 e_LOO 4.174797947100052e-06 Pf_ref 0.03214 Pf 0.02424 CoV 0.02010
# LS2:  Degree 4 e_LOO 0.001648689053542331 Pf_ref 0.1476 Pf 0.15219 CoV 0.00750
# number of training points:  26 -------------------------------------------------
# LS1:  Degree 2 e_LOO 4.757695951722459e-05 Pf_ref 0.03161 Pf 0.02475 CoV 0.01990
# LS2:  Degree 4 e_LOO 0.0008568245562565415 Pf_ref 0.14693 Pf 0.15922 CoV 0.00730
# number of training points:  27 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.00015809393522856955 Pf_ref 0.03056 Pf 0.02324 CoV 0.02050
# LS2:  Degree 4 e_LOO 0.0001341304674274048 Pf_ref 0.14847 Pf 0.15541 CoV 0.00740
# number of training points:  28 -------------------------------------------------
# LS1:  Degree 4 e_LOO 2.7448701540395163e-06 Pf_ref 0.03152 Pf 0.06067 CoV 0.01240
# LS2:  Degree 1 e_LOO 0.0004053589568526532 Pf_ref 0.14877 Pf 0.15089 CoV 0.00750
# number of training points:  29 -------------------------------------------------
# LS1:  Degree 1 e_LOO 1.0042978083254728e-05 Pf_ref 0.03054 Pf 0.02357 CoV 0.02040
# LS2:  Degree 1 e_LOO 0.00018944634243322497 Pf_ref 0.14716 Pf 0.1523 CoV 0.00750
# number of training points:  30 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.0004135411863928518 Pf_ref 0.03085 Pf 0.02395 CoV 0.02020
# LS2:  Degree 2 e_LOO 5.777461525492553e-05 Pf_ref 0.148 Pf 0.16911 CoV 0.00700
# number of training points:  31 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.00010955056852210277 Pf_ref 0.031 Pf 0.02611 CoV 0.01930
# LS2:  Degree 1 e_LOO 0.00013045706126686788 Pf_ref 0.14892 Pf 0.15286 CoV 0.00740
# number of training points:  32 -------------------------------------------------
# LS1:  Degree 1 e_LOO 3.360130825515038e-06 Pf_ref 0.03196 Pf 0.0263 CoV 0.01920
# LS2:  Degree 1 e_LOO 2.6872713464264288e-05 Pf_ref 0.14842 Pf 0.15038 CoV 0.00750
# number of training points:  33 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.0002871309996765775 Pf_ref 0.03186 Pf 0.03149 CoV 0.01750
# LS2:  Degree 1 e_LOO 8.816601957553495e-06 Pf_ref 0.1479 Pf 0.15254 CoV 0.00750
# number of training points:  34 -------------------------------------------------
# LS1:  Degree 2 e_LOO 4.813109582540591e-07 Pf_ref 0.03173 Pf 0.03174 CoV 0.01750
# LS2:  Degree 1 e_LOO 0.0013680525361747767 Pf_ref 0.14558 Pf 0.15927 CoV 0.00730
# number of training points:  35 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.000687071579270771 Pf_ref 0.03107 Pf 0.03187 CoV 0.01740
# LS2:  Degree 4 e_LOO 4.502226611761258e-05 Pf_ref 0.14881 Pf 0.1431 CoV 0.00770
# number of training points:  36 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.0001690179548584798 Pf_ref 0.03133 Pf 0.03565 CoV 0.01640
# LS2:  Degree 2 e_LOO 0.00017232358600889432 Pf_ref 0.14936 Pf 0.16792 CoV 0.00700
# number of training points:  37 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.00013319106317428292 Pf_ref 0.0322 Pf 0.03282 CoV 0.01720
# LS2:  Degree 2 e_LOO 0.00011097130734823674 Pf_ref 0.14863 Pf 0.16839 CoV 0.00700
# number of training points:  38 -------------------------------------------------
# LS1:  Degree 1 e_LOO 8.026503179041772e-06 Pf_ref 0.03264 Pf 0.03341 CoV 0.01700
# LS2:  Degree 2 e_LOO 0.00028572507923627197 Pf_ref 0.1476 Pf 0.15289 CoV 0.00740
# number of training points:  39 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.00014175148972650714 Pf_ref 0.03027 Pf 0.03054 CoV 0.01780
# LS2:  Degree 2 e_LOO 0.00036560765415953524 Pf_ref 0.14726 Pf 0.15091 CoV 0.00750
# number of training points:  40 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.0001487073608089495 Pf_ref 0.03147 Pf 0.03151 CoV 0.01750
# LS2:  Degree 2 e_LOO 0.0003516615275346191 Pf_ref 0.14762 Pf 0.15062 CoV 0.00750
# number of training points:  41 -------------------------------------------------
# LS1:  Degree 1 e_LOO 9.600908119531959e-05 Pf_ref 0.03039 Pf 0.03042 CoV 0.01790
# LS2:  Degree 2 e_LOO 0.0003897036290614451 Pf_ref 0.14525 Pf 0.14736 CoV 0.00760
# number of training points:  42 -------------------------------------------------
# LS1:  Degree 3 e_LOO 0.00047868894125356815 Pf_ref 0.0316 Pf 0.03146 CoV 0.01750
# LS2:  Degree 2 e_LOO 0.00020057011616845326 Pf_ref 0.14633 Pf 0.14683 CoV 0.00760
# number of training points:  43 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.00048503260078672613 Pf_ref 0.03231 Pf 0.03215 CoV 0.01740
# LS2:  Degree 2 e_LOO 3.503059126321873e-06 Pf_ref 0.14705 Pf 0.1478 CoV 0.00760
# number of training points:  44 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.0005037484819207789 Pf_ref 0.03102 Pf 0.03082 CoV 0.01770
# LS2:  Degree 2 e_LOO 2.6270429541942513e-05 Pf_ref 0.14754 Pf 0.14854 CoV 0.00760
# number of training points:  45 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.00030462853324044446 Pf_ref 0.03002 Pf 0.0302 CoV 0.01790
# LS2:  Degree 2 e_LOO 4.370057032268632e-05 Pf_ref 0.14925 Pf 0.1463 CoV 0.00760
# number of training points:  46 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.00025423392646913066 Pf_ref 0.03185 Pf 0.03192 CoV 0.01740
# LS2:  Degree 2 e_LOO 3.8741724768543027e-05 Pf_ref 0.14844 Pf 0.1462 CoV 0.00760
# number of training points:  47 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.00020533510709443926 Pf_ref 0.03107 Pf 0.03113 CoV 0.01760
# LS2:  Degree 2 e_LOO 3.402677252191764e-05 Pf_ref 0.14823 Pf 0.1451 CoV 0.00770
# number of training points:  48 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.0001606673944682423 Pf_ref 0.03157 Pf 0.03159 CoV 0.01750
# LS2:  Degree 2 e_LOO 2.9086080154350356e-05 Pf_ref 0.14928 Pf 0.1454 CoV 0.00770
# number of training points:  49 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.00010873076291191356 Pf_ref 0.03042 Pf 0.03043 CoV 0.01790
# LS2:  Degree 2 e_LOO 1.7161630878241897e-05 Pf_ref 0.14918 Pf 0.14575 CoV 0.00770
# number of training points:  50 -------------------------------------------------

# %% [markdown]
# # Active training - EFF - 2 LS

# %%
number_experiments = 15
number_active_points = 40

training_limitstate = 1

results_file = '_AT'+ str(training_limitstate) +'_EFF_' + str(number_active_points)    # index for results files

for experiments in range(number_experiments):
    print('Experiment: ', experiments+1 , '#################################################################' )
    
    ActiveTrain_1 = {}   #results file { Surrogate , Pf, CoV_Pf , eLoo , mse }
    ActiveTrain_2 = {}   #results file { Surrogate , Pf, CoV_Pf , eLoo , mse }

    #INITIAL design of experiments (LHS) passive training ####################################

    n = 10       # number of initial sampling

    xn = np.zeros((int(n), dim))      #normalized training points
    xr = np.zeros((int(n), dim))      #scaled training points
    yn = np.zeros((int(n)))           #observations

    # Check the variables limits for space-filling distribution
    Xdoe = build.space_filling_lhs( {'x1':[-1, 1],      
                                     'x2':[-1, 1],} , 
                                      num_samples = n )
    #------------------------------------------------------------
    xn[:,0] = Xdoe['x1']
    xn[:,1] = Xdoe['x2']
    xr[:,0] = PCK1.scalehermite(xn[:,0], x1mean, x1sigma)
    xr[:,1] = PCK1.scalehermite(xn[:,1], x2mean, x2sigma)

    yn_1 = function_1(xr)[0]
    yn_2 = function_2(xr)[0]
    
    # kernel hyperparameters-------------------------------------
    v = 5/2        #Gaussian process
    #truncation term-------------------------------------
    p_max = 5  #for each variable → same truncation , degree of expansion
    
    for points in range(number_active_points):

        # Selecting the smallest e_loo model (length and order)
        
        mse_results = np.zeros(p_max-1)
        opt_length_it = np.zeros(p_max-1)
        eloo_results = np.zeros(p_max-1)

        mean_loo = np.zeros(len(xn))
        var_loo = np.zeros(len(xn))

        dist = PCK1.distance(xn, xn)
        lmax = np.max(dist)
        lmin = np.min(dist[dist!=0])
        bounds = [(lmin, lmax)]

        results = dict()
        
        # ##############################################################################
        # Active training of Limit State 1 #############################################

        ModelName_1 = 'PCK1_' + str(len(xn))
        
        ModelName_1 = PC_Kriging(config)

        # yn is changing for each LS (inside L_Object )
        yn = yn_1    #observations
        YN = YN_1    #test points

        # OPTIMAL SURROGATE MODEL -----------------------------------
        for p in range(1, p_max):

            results['shgo'] = optimize.shgo(L_Object, bounds)
            opt_length = results['shgo']['x'][0]

            theta = np.array([opt_length, v])

            #Generating PCK models for each reduced design of experiments 

            for i in range (0, len(xn) ):

                yn_loo= np.delete(yn,[i])                            #y_n-i      leaving element i out the observations 
                xr_loo= np.delete(xr,[i*2,i*2+1]).reshape(-1,dim)    #x1r_n-i   leaving element i out the inputs (xr)
                xn_loo= np.delete(xn,[i*2,i*2+1]).reshape(-1,dim)    #x_n-i     leaving element i out the nomalized inputs (xn)

                #training LOO
                modelpar_loo = PCK_loo.train (xn_loo , yn_loo , p , theta )

                #predicting LOO over each removed sample
                mean_loo[i], var_loo[i] = PCK_loo.predict_fast(xn[i].reshape(1,-1))

            e_loo = np.mean (yn - mean_loo)**2              #LOO CV squared errors

            eloo_results[p-1] = e_loo

            #--------------------------------------- error over a set of test points
            modelpar1 = ModelName_1.train (xn, yn, p, theta) 
            mean0, var0 = ModelName_1.predict_fast(XN)    # test points predictions mean, variance

            mse = np.mean ((YN - mean0)**2)

            mse_results[p-1] = mse
            opt_length_it[p-1] = opt_length

    #         print('Degree', p, 'MSE', "%.2f" % round(mse, 2) , 'e_LOO', "%.5f" % e_loo)

        ## training optimal model ----------------------------

        opt = np.argmin(eloo_results)    #selected based 'eloo' instead 'mse'
        theta_opt = np.array([opt_length_it[opt], v]) 

        modelpar1 = ModelName_1.train (xn, yn, int(opt+1), theta_opt) 

        ## Pool of samples for MCS -----------------------------------
        MCS_samples = 100000

        MCinputs_norm = np.zeros((int(MCS_samples), dim))
        MCinputs = np.zeros((int(MCS_samples), dim))

        MCinputs_norm[:,0] = np.random.normal(0, 1, size=int(MCS_samples))
        MCinputs_norm[:,1] = np.random.normal(0, 1, size=int(MCS_samples))

        MCinputs[:,0] = PCK1.scalehermite(MCinputs_norm[:,0], x1mean, x1sigma)  
        MCinputs[:,1] = PCK1.scalehermite(MCinputs_norm[:,1], x2mean, x2sigma)  
    
        # Pf estimation ----------------------------------------------
        
            # ground truth ls
        ymc_1 = function_1(MCinputs)[0]  
        fail_samples_1 = np.sum(ymc_1 < 0 )
        Pf_ref_1 = fail_samples_1 / MCS_samples
        
            # surrogate ls
        meanMC_1, varMC_1 = ModelName_1.predict_fast(MCinputs_norm)    # mean, variance
        fail_samples_SUMO_1 = np.sum(np.asarray(meanMC_1) < 0 )
        fail_prob_SUMO_1 = fail_samples_SUMO_1 / MCS_samples

        cov_pf = np.sqrt((1 - fail_prob_SUMO_1 ) / (fail_prob_SUMO_1 * MCS_samples) )

        print('LS1: ','Degree', int(opt+1), 'e_LOO', np.min(eloo_results), 'Pf_ref',
                  Pf_ref_1 ,'Pf', fail_prob_SUMO_1 , 'CoV', "%.5f" % round(cov_pf, 4))

        #saving results ----------------------------

        ActiveTrain_1[str(len(xn))+'points'] = ModelName_1 , fail_prob_SUMO_1 , cov_pf , np.min(eloo_results), np.min(mse_results)
        
        # ##############################################################################
        # Active training of Limit State 2 #############################################
        
        ModelName_2 = 'PCK2_' + str(len(xn))
        
        ModelName_2 = PC_Kriging(config)
        
        # yn is changing for each LS 
        yn = yn_2
        YN = YN_2
        # Selecting the smallest e_loo model (length and order) 

        # OPTIMAL SURROGATE MODEL -----------------------------------
        for p in range(1, p_max):
            
            # results = dict()
            # bounds = [(lmin, lmax)]
            
            results['shgo'] = optimize.shgo(L_Object, bounds)
            opt_length = results['shgo']['x'][0]

            theta = np.array([opt_length, v])

            #Generating PCK models for each reduced design of experiments 

            for i in range (0, len(xn) ):

                yn_loo= np.delete(yn,[i])                            #y_n-i      leaving element i out the observations 
                xr_loo= np.delete(xr,[i*2,i*2+1]).reshape(-1,dim)    #x1r_n-i   leaving element i out the inputs (xr)
                xn_loo= np.delete(xn,[i*2,i*2+1]).reshape(-1,dim)    #x_n-i     leaving element i out the nomalized inputs (xn)

                #training LOO
                modelpar_loo = PCK_loo.train (xn_loo , yn_loo , p , theta )

                #predicting LOO over each removed sample
                mean_loo[i], var_loo[i] = PCK_loo.predict_fast(xn[i].reshape(1,-1))

            e_loo = np.mean (yn - mean_loo)**2              #LOO CV squared errors

            eloo_results[p-1] = e_loo

            #--------------------------------------- error over a set of test points
            modelpar2 = ModelName_2.train (xn, yn, p, theta) 
            mean0, var0 = ModelName_2.predict_fast(XN)    # test points predictions mean, variance

            mse = np.mean ((YN - mean0)**2)

            mse_results[p-1] = mse
            opt_length_it[p-1] = opt_length

    #         print('Degree', p, 'MSE', "%.2f" % round(mse, 2) , 'e_LOO', "%.5f" % e_loo)

        ## training optimal model ----------------------------

        opt = np.argmin(eloo_results)    
        theta_opt = np.array([opt_length_it[opt], v]) 

        modelpar2 = ModelName_2.train (xn, yn, int(opt+1), theta_opt) 

        # Pf estimation ----------------------------------------------
        
            # ground truth ls
        ymc_2 = function_2(MCinputs)[0]  
        fail_samples_2 = np.sum(ymc_2 < 0 )
        Pf_ref_2 = fail_samples_2 / MCS_samples
        
            # surrogate ls
        meanMC_2, varMC_2 = ModelName_2.predict_fast(MCinputs_norm)    # mean, variance
        fail_samples_SUMO_2 = np.sum(np.asarray(meanMC_2) < 0 )
        fail_prob_SUMO_2 = fail_samples_SUMO_2 / MCS_samples

        cov_pf = np.sqrt((1 - fail_prob_SUMO_2 ) / (fail_prob_SUMO_2 * MCS_samples) )        
        
        print('LS2: ','Degree', int(opt+1), 'e_LOO', np.min(eloo_results) , 'Pf_ref', 
              Pf_ref_2 ,'Pf', fail_prob_SUMO_2 , 'CoV', "%.5f" % round(cov_pf, 4))

        #saving results ----------------------------

        ActiveTrain_2[str(len(xn))+'points'] = ModelName_2 , fail_prob_SUMO_2 , cov_pf , np.min(eloo_results), np.min(mse_results)

        # ##############################################################################
        if (training_limitstate == 1):
            meanMC = meanMC_1
            varMC = varMC_1
        elif (training_limitstate == 2):
            meanMC = meanMC_2
            varMC = varMC_2
            
        ### Evaluating new points
        eff1 = EFF(meanMC.reshape(-1),varMC.reshape(-1) , 0 )

        xr = np.append(xr, MCinputs[np.argmax(eff1)]).reshape(-1,2)
        xn = np.append(xn, MCinputs_norm[np.argmax(eff1)]).reshape(-1,2)
        
        yn_1 = function_1(xr)[0]
        yn_2 = function_2(xr)[0]
    
        print('number of training points: ', len(xn),'-------------------------------------------------')
    
    filename1 = 'Batch_'+ str(experiments+1) + results_file + 'p_LS1.sav'
    pickle.dump(ActiveTrain_1, open(filename1, 'wb'))
           
    filename2 = 'Batch_'+ str(experiments+1) + results_file + 'p_LS2.sav'
    pickle.dump(ActiveTrain_2, open(filename2, 'wb'))
# Out:
# Experiment:  1 #################################################################
# C:\Users\Administrator\anaconda3\envs\surrogate\lib\site-packages\ipykernel_launcher.py:8: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# LS1:  Degree 1 e_LOO 0.00011460057026544751 Pf_ref 0.03055 Pf 0.07512 CoV 0.01110
# LS2:  Degree 1 e_LOO 0.0012086912382140598 Pf_ref 0.14786 Pf 0.20424 CoV 0.00620
# number of training points:  11 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.012427527518721527 Pf_ref 0.03119 Pf 0.13448 CoV 0.00800
# LS2:  Degree 2 e_LOO 0.03256625991432418 Pf_ref 0.14772 Pf 0.19428 CoV 0.00640
# number of training points:  12 -------------------------------------------------
# LS1:  Degree 1 e_LOO 5.2005261442776487e-05 Pf_ref 0.03199 Pf 0.08774 CoV 0.01020
# LS2:  Degree 2 e_LOO 0.002257746910224223 Pf_ref 0.14721 Pf 0.18434 CoV 0.00670
# number of training points:  13 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.0017824591183833167 Pf_ref 0.03149 Pf 0.08677 CoV 0.01030
# LS2:  Degree 2 e_LOO 0.09625015574644365 Pf_ref 0.14953 Pf 0.18293 CoV 0.00670
# number of training points:  14 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.007446943667055054 Pf_ref 0.03167 Pf 0.06914 CoV 0.01160
# LS2:  Degree 1 e_LOO 0.03995911123012551 Pf_ref 0.14779 Pf 0.23982 CoV 0.00560
# number of training points:  15 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.027096066998146356 Pf_ref 0.03122 Pf 0.04946 CoV 0.01390
# LS2:  Degree 2 e_LOO 0.005699569492378013 Pf_ref 0.14751 Pf 0.08362 CoV 0.01050
# number of training points:  16 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.006157533098045652 Pf_ref 0.03202 Pf 0.07707 CoV 0.01090
# LS2:  Degree 1 e_LOO 0.012759290089598412 Pf_ref 0.14799 Pf 0.23501 CoV 0.00570
# number of training points:  17 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.0024006941557098028 Pf_ref 0.032 Pf 0.08163 CoV 0.01060
# LS2:  Degree 2 e_LOO 0.01328360933610867 Pf_ref 0.14705 Pf 0.09558 CoV 0.00970
# number of training points:  18 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.01430764590178224 Pf_ref 0.03209 Pf 0.08333 CoV 0.01050
# LS2:  Degree 1 e_LOO 0.026902879754974445 Pf_ref 0.14767 Pf 0.2074 CoV 0.00620
# number of training points:  19 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.018723187754934995 Pf_ref 0.03125 Pf 0.08627 CoV 0.01030
# C:\Users\Administrator\anaconda3\envs\surrogate\lib\site-packages\scipy\optimize\optimize.py:283: RuntimeWarning: Values in x were outside bounds during a minimize step, clipping to bounds
#   "minimize step, clipping to bounds", RuntimeWarning)
# LS2:  Degree 3 e_LOO 0.000653721468081389 Pf_ref 0.14744 Pf 0.07301 CoV 0.01130
# number of training points:  20 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.023779588626137736 Pf_ref 0.03115 Pf 0.08777 CoV 0.01020
# LS2:  Degree 3 e_LOO 0.00015704741165396507 Pf_ref 0.14734 Pf 0.07282 CoV 0.01130
# number of training points:  21 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.015058622917939165 Pf_ref 0.03168 Pf 0.08848 CoV 0.01010
# LS2:  Degree 2 e_LOO 0.001823754830377253 Pf_ref 0.14861 Pf 0.08453 CoV 0.01040
# number of training points:  22 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.01778443360071336 Pf_ref 0.03209 Pf 0.07056 CoV 0.01150
# LS2:  Degree 2 e_LOO 0.006093110380543345 Pf_ref 0.14636 Pf 0.13355 CoV 0.00810
# number of training points:  23 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.01010302010390506 Pf_ref 0.0306 Pf 0.0708 CoV 0.01150
# LS2:  Degree 2 e_LOO 0.0001641522205985812 Pf_ref 0.14861 Pf 0.10966 CoV 0.00900
# number of training points:  24 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.0008960953963550282 Pf_ref 0.03133 Pf 0.02891 CoV 0.01830
# LS2:  Degree 2 e_LOO 0.0008370200080968015 Pf_ref 0.14966 Pf 0.10488 CoV 0.00920
# number of training points:  25 -------------------------------------------------
# LS1:  Degree 3 e_LOO 0.00013251387040223502 Pf_ref 0.03147 Pf 0.03424 CoV 0.01680
# LS2:  Degree 3 e_LOO 2.2700975018959223e-05 Pf_ref 0.14946 Pf 0.07117 CoV 0.01140
# number of training points:  26 -------------------------------------------------
# LS1:  Degree 3 e_LOO 0.0015646594014812614 Pf_ref 0.03183 Pf 0.03448 CoV 0.01670
# LS2:  Degree 3 e_LOO 0.005018840578487539 Pf_ref 0.1478 Pf 0.06792 CoV 0.01170
# number of training points:  27 -------------------------------------------------
# LS1:  Degree 3 e_LOO 0.0014079672802717726 Pf_ref 0.03167 Pf 0.03163 CoV 0.01750
# LS2:  Degree 3 e_LOO 4.3319420672942325e-05 Pf_ref 0.14824 Pf 0.06467 CoV 0.01200
# number of training points:  28 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.00275549251789817 Pf_ref 0.03176 Pf 0.02077 CoV 0.02170
# LS2:  Degree 3 e_LOO 0.0002002642391255898 Pf_ref 0.14982 Pf 0.066 CoV 0.01190
# number of training points:  29 -------------------------------------------------
# LS1:  Degree 3 e_LOO 0.0014833554877544482 Pf_ref 0.0309 Pf 0.01603 CoV 0.02480
# LS2:  Degree 3 e_LOO 0.0013362449001789538 Pf_ref 0.15083 Pf 0.07015 CoV 0.01150
# number of training points:  30 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.001550647803701801 Pf_ref 0.03074 Pf 0.01794 CoV 0.02340
# LS2:  Degree 3 e_LOO 0.00247051880008764 Pf_ref 0.1499 Pf 0.0688 CoV 0.01160
# number of training points:  31 -------------------------------------------------
# LS1:  Degree 3 e_LOO 2.5215359698028465e-05 Pf_ref 0.03177 Pf 0.01348 CoV 0.02710
# LS2:  Degree 1 e_LOO 0.0021433867379183715 Pf_ref 0.1494 Pf 0.0861 CoV 0.01030
# number of training points:  32 -------------------------------------------------
# LS1:  Degree 3 e_LOO 3.680612713439346e-06 Pf_ref 0.03149 Pf 0.0138 CoV 0.02670
# LS2:  Degree 4 e_LOO 0.0016767722373096947 Pf_ref 0.14821 Pf 0.10319 CoV 0.00930
# number of training points:  33 -------------------------------------------------
# LS1:  Degree 3 e_LOO 0.0001576883527330246 Pf_ref 0.03068 Pf 0.01305 CoV 0.02750
# LS2:  Degree 4 e_LOO 0.0015968741949618575 Pf_ref 0.14854 Pf 0.10485 CoV 0.00920
# number of training points:  34 -------------------------------------------------
# LS1:  Degree 3 e_LOO 0.0004980961985759948 Pf_ref 0.03102 Pf 0.01317 CoV 0.02740
# LS2:  Degree 4 e_LOO 0.0002576072799137666 Pf_ref 0.14875 Pf 0.1068 CoV 0.00910
# number of training points:  35 -------------------------------------------------
# LS1:  Degree 3 e_LOO 0.00035282577467379486 Pf_ref 0.03217 Pf 0.01343 CoV 0.02710
# LS2:  Degree 3 e_LOO 0.0001893232942738811 Pf_ref 0.14598 Pf 0.0662 CoV 0.01190
# number of training points:  36 -------------------------------------------------
# LS1:  Degree 3 e_LOO 0.00045167897870222973 Pf_ref 0.03151 Pf 0.01293 CoV 0.02760
# LS2:  Degree 3 e_LOO 6.960169157306761e-05 Pf_ref 0.1478 Pf 0.06682 CoV 0.01180
# number of training points:  37 -------------------------------------------------
# LS1:  Degree 3 e_LOO 0.00014501123161551134 Pf_ref 0.03255 Pf 0.01301 CoV 0.02750
# LS2:  Degree 3 e_LOO 1.3195152060433814e-05 Pf_ref 0.14757 Pf 0.06701 CoV 0.01180
# number of training points:  38 -------------------------------------------------
# LS1:  Degree 3 e_LOO 0.00018693836787568824 Pf_ref 0.03114 Pf 0.0132 CoV 0.02730
# LS2:  Degree 3 e_LOO 0.0002670597606343031 Pf_ref 0.14615 Pf 0.0691 CoV 0.01160
# number of training points:  39 -------------------------------------------------
# LS1:  Degree 3 e_LOO 0.0002491209106462873 Pf_ref 0.02977 Pf 0.01751 CoV 0.02370
# LS2:  Degree 3 e_LOO 0.00020051628744193904 Pf_ref 0.15011 Pf 0.07123 CoV 0.01140
# number of training points:  40 -------------------------------------------------
# LS1:  Degree 4 e_LOO 1.602233423580417e-05 Pf_ref 0.03159 Pf 0.01905 CoV 0.02270
# LS2:  Degree 4 e_LOO 1.9337108443898085e-05 Pf_ref 0.14787 Pf 0.10319 CoV 0.00930
# number of training points:  41 -------------------------------------------------
# LS1:  Degree 3 e_LOO 0.0002439902415635622 Pf_ref 0.03151 Pf 0.01797 CoV 0.02340
# LS2:  Degree 3 e_LOO 4.018446303802751e-05 Pf_ref 0.14763 Pf 0.07081 CoV 0.01150
# number of training points:  42 -------------------------------------------------
# LS1:  Degree 3 e_LOO 0.00038367199400317635 Pf_ref 0.0309 Pf 0.01721 CoV 0.02390
# LS2:  Degree 3 e_LOO 9.455770175298601e-06 Pf_ref 0.14823 Pf 0.07004 CoV 0.01150
# number of training points:  43 -------------------------------------------------
# LS1:  Degree 3 e_LOO 0.0006232483742703517 Pf_ref 0.031 Pf 0.01723 CoV 0.02390
# LS2:  Degree 3 e_LOO 2.3264680273021344e-06 Pf_ref 0.14905 Pf 0.06995 CoV 0.01150
# number of training points:  44 -------------------------------------------------
# LS1:  Degree 3 e_LOO 0.0006865891367449196 Pf_ref 0.03122 Pf 0.01802 CoV 0.02330
# LS2:  Degree 3 e_LOO 3.001892874686021e-05 Pf_ref 0.14625 Pf 0.0725 CoV 0.01130
# number of training points:  45 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.0004770933267555518 Pf_ref 0.03203 Pf 0.02458 CoV 0.01990
# LS2:  Degree 3 e_LOO 0.00011771820624896849 Pf_ref 0.14665 Pf 0.0707 CoV 0.01150
# number of training points:  46 -------------------------------------------------
# LS1:  Degree 4 e_LOO 0.00023656212927987592 Pf_ref 0.03137 Pf 0.01861 CoV 0.02300
# LS2:  Degree 3 e_LOO 0.00024152087990330148 Pf_ref 0.14879 Pf 0.0738 CoV 0.01120
# number of training points:  47 -------------------------------------------------
# LS1:  Degree 4 e_LOO 2.835312237327511e-05 Pf_ref 0.03124 Pf 0.01771 CoV 0.02360
# LS2:  Degree 1 e_LOO 0.00018795398358637983 Pf_ref 0.1481 Pf 0.1005 CoV 0.00950
# number of training points:  48 -------------------------------------------------
# LS1:  Degree 4 e_LOO 6.839870717142196e-05 Pf_ref 0.03178 Pf 0.01763 CoV 0.02360
# LS2:  Degree 3 e_LOO 0.00014436323070503147 Pf_ref 0.14692 Pf 0.0855 CoV 0.01030
# number of training points:  49 -------------------------------------------------
# LS1:  Degree 4 e_LOO 0.00015163787372969725 Pf_ref 0.0304 Pf 0.01707 CoV 0.02400
# LS2:  Degree 3 e_LOO 6.51870662455583e-06 Pf_ref 0.14829 Pf 0.08753 CoV 0.01020
# number of training points:  50 -------------------------------------------------
# Experiment:  2 #################################################################
# LS1:  Degree 1 e_LOO 0.0024912593142650636 Pf_ref 0.0314 Pf 0.06909 CoV 0.01160
# LS2:  Degree 1 e_LOO 0.0004449546061161989 Pf_ref 0.1474 Pf 0.13547 CoV 0.00800
# number of training points:  11 -------------------------------------------------
# C:\Users\Administrator\anaconda3\envs\surrogate\lib\site-packages\ipykernel_launcher.py:137: RuntimeWarning: divide by zero encountered in double_scalars
# LS1:  Degree 2 e_LOO 0.15368453852106792 Pf_ref 0.03095 Pf 0.0 CoV inf
# LS2:  Degree 1 e_LOO 4.818156018213772e-07 Pf_ref 0.1487 Pf 0.13216 CoV 0.00810
# number of training points:  12 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.13972971333530487 Pf_ref 0.03085 Pf 0.02495 CoV 0.01980
# LS2:  Degree 1 e_LOO 0.2006450331556217 Pf_ref 0.1489 Pf 0.16838 CoV 0.00700
# number of training points:  13 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.006372196960294035 Pf_ref 0.03167 Pf 0.03565 CoV 0.01640
# LS2:  Degree 1 e_LOO 0.09463824799396821 Pf_ref 0.14841 Pf 0.16876 CoV 0.00700
# number of training points:  14 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.0008198265360052524 Pf_ref 0.03153 Pf 0.02298 CoV 0.02060
# LS2:  Degree 1 e_LOO 0.007246559777990371 Pf_ref 0.14919 Pf 0.19799 CoV 0.00640
# number of training points:  15 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.0006620423963982615 Pf_ref 0.03232 Pf 0.00552 CoV 0.04240
# LS2:  Degree 3 e_LOO 0.0035434600732749187 Pf_ref 0.14752 Pf 0.08669 CoV 0.01030
# number of training points:  16 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.0032165621467370106 Pf_ref 0.0314 Pf 0.00368 CoV 0.05200
# LS2:  Degree 1 e_LOO 0.00042798007554771994 Pf_ref 0.14858 Pf 0.19548 CoV 0.00640
# number of training points:  17 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.0063385408243262055 Pf_ref 0.03234 Pf 0.01571 CoV 0.02500
# LS2:  Degree 2 e_LOO 0.0008060724024922522 Pf_ref 0.1485 Pf 0.08059 CoV 0.01070
# number of training points:  18 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.0082797256983911 Pf_ref 0.03121 Pf 0.02178 CoV 0.02120
# LS2:  Degree 2 e_LOO 0.0064182478079919305 Pf_ref 0.14904 Pf 0.04126 CoV 0.01520
# number of training points:  19 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.0074403641285808175 Pf_ref 0.03151 Pf 0.02226 CoV 0.02100
# LS2:  Degree 2 e_LOO 0.0007356055226670035 Pf_ref 0.14812 Pf 0.05958 CoV 0.01260
# number of training points:  20 -------------------------------------------------
# LS1:  Degree 3 e_LOO 0.00010198219695051895 Pf_ref 0.0319 Pf 0.05704 CoV 0.01290
# LS2:  Degree 2 e_LOO 0.004371092092482134 Pf_ref 0.14855 Pf 0.04725 CoV 0.01420
# number of training points:  21 -------------------------------------------------
# LS1:  Degree 2 e_LOO 2.0528720152501936e-05 Pf_ref 0.03175 Pf 0.02276 CoV 0.02070
# LS2:  Degree 2 e_LOO 0.0030825319137913585 Pf_ref 0.14763 Pf 0.05188 CoV 0.01350
# number of training points:  22 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.0006531452797736073 Pf_ref 0.0312 Pf 0.02226 CoV 0.02100
# LS2:  Degree 2 e_LOO 0.0023841583870110364 Pf_ref 0.1489 Pf 0.04838 CoV 0.01400
# number of training points:  23 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.00028992960990005605 Pf_ref 0.03045 Pf 0.02174 CoV 0.02120
# LS2:  Degree 3 e_LOO 0.00016645631347781287 Pf_ref 0.14877 Pf 0.01885 CoV 0.02280
# number of training points:  24 -------------------------------------------------
# LS1:  Degree 2 e_LOO 4.650972195463171e-06 Pf_ref 0.03249 Pf 0.02238 CoV 0.02090
# LS2:  Degree 3 e_LOO 0.0010096819139243816 Pf_ref 0.14829 Pf 0.00595 CoV 0.04090
# number of training points:  25 -------------------------------------------------
# LS1:  Degree 2 e_LOO 1.6839969707880318e-05 Pf_ref 0.03085 Pf 0.02151 CoV 0.02130
# LS2:  Degree 1 e_LOO 3.689718556516235e-05 Pf_ref 0.14951 Pf 0.14298 CoV 0.00770
# number of training points:  26 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.00014557918889741215 Pf_ref 0.03091 Pf 0.02167 CoV 0.02120
# LS2:  Degree 1 e_LOO 0.002979889379497954 Pf_ref 0.15068 Pf 0.14084 CoV 0.00780
# number of training points:  27 -------------------------------------------------
# LS1:  Degree 4 e_LOO 2.706487883109251e-05 Pf_ref 0.03209 Pf 0.09806 CoV 0.00960
# LS2:  Degree 4 e_LOO 0.000649224762519135 Pf_ref 0.14837 Pf 0.03162 CoV 0.01750
# number of training points:  28 -------------------------------------------------
# LS1:  Degree 3 e_LOO 5.6143318748274216e-06 Pf_ref 0.03108 Pf 0.02721 CoV 0.01890
# LS2:  Degree 2 e_LOO 0.00825251814844542 Pf_ref 0.14647 Pf 0.03518 CoV 0.01660
# number of training points:  29 -------------------------------------------------
# LS1:  Degree 2 e_LOO 1.5919621626525001e-06 Pf_ref 0.03185 Pf 0.01366 CoV 0.02690
# LS2:  Degree 2 e_LOO 0.006149674313430262 Pf_ref 0.14904 Pf 0.03214 CoV 0.01740
# number of training points:  30 -------------------------------------------------
# LS1:  Degree 2 e_LOO 2.0558708455719896e-06 Pf_ref 0.0319 Pf 0.01264 CoV 0.02790
# LS2:  Degree 4 e_LOO 2.459664700243705e-05 Pf_ref 0.14929 Pf 0.0029 CoV 0.05860
# number of training points:  31 -------------------------------------------------
# LS1:  Degree 2 e_LOO 9.671117895812768e-06 Pf_ref 0.03023 Pf 0.01366 CoV 0.02690
# LS2:  Degree 4 e_LOO 0.0005532686793904335 Pf_ref 0.14802 Pf 0.00432 CoV 0.04800
# number of training points:  32 -------------------------------------------------
# LS1:  Degree 2 e_LOO 3.1715655070376766e-06 Pf_ref 0.03032 Pf 0.00911 CoV 0.03300
# LS2:  Degree 4 e_LOO 0.0006635054809146807 Pf_ref 0.15027 Pf 0.00429 CoV 0.04820
# number of training points:  33 -------------------------------------------------
# LS1:  Degree 2 e_LOO 1.4480561039824258e-05 Pf_ref 0.03112 Pf 0.01048 CoV 0.03070
# LS2:  Degree 4 e_LOO 0.00013616620208802886 Pf_ref 0.14869 Pf 0.00431 CoV 0.04810
# number of training points:  34 -------------------------------------------------
# LS1:  Degree 2 e_LOO 3.4788099154669037e-06 Pf_ref 0.03153 Pf 0.01154 CoV 0.02930
# LS2:  Degree 4 e_LOO 9.762987395747861e-05 Pf_ref 0.14848 Pf 0.00268 CoV 0.06100
# number of training points:  35 -------------------------------------------------
# LS1:  Degree 2 e_LOO 3.5091612315923233e-07 Pf_ref 0.03165 Pf 0.01065 CoV 0.03050
# LS2:  Degree 4 e_LOO 0.0004950728735158095 Pf_ref 0.1492 Pf 0.00338 CoV 0.05430
# number of training points:  36 -------------------------------------------------
# LS1:  Degree 2 e_LOO 2.4978956124594188e-05 Pf_ref 0.0307 Pf 0.01925 CoV 0.02260
# LS2:  Degree 4 e_LOO 0.0003176578062357568 Pf_ref 0.14876 Pf 0.0029 CoV 0.05860
# number of training points:  37 -------------------------------------------------
# LS1:  Degree 3 e_LOO 1.830895779985762e-05 Pf_ref 0.03159 Pf 0.01837 CoV 0.02310
# LS2:  Degree 4 e_LOO 0.00013924931643745624 Pf_ref 0.14933 Pf 0.00295 CoV 0.05810
# number of training points:  38 -------------------------------------------------
# LS1:  Degree 3 e_LOO 8.872002053842994e-05 Pf_ref 0.03111 Pf 0.01728 CoV 0.02380
# LS2:  Degree 4 e_LOO 0.00021179394778210464 Pf_ref 0.14972 Pf 0.0029 CoV 0.05860
# number of training points:  39 -------------------------------------------------
# LS1:  Degree 3 e_LOO 0.0005002187148607917 Pf_ref 0.03208 Pf 0.0183 CoV 0.02320
# LS2:  Degree 4 e_LOO 0.00027638211908100486 Pf_ref 0.14903 Pf 0.003 CoV 0.05760
# number of training points:  40 -------------------------------------------------
# LS1:  Degree 3 e_LOO 0.00037050189317967814 Pf_ref 0.031 Pf 0.01784 CoV 0.02350
# LS2:  Degree 4 e_LOO 3.531965845492232e-06 Pf_ref 0.14835 Pf 0.0036 CoV 0.05260
# number of training points:  41 -------------------------------------------------
# LS1:  Degree 3 e_LOO 3.797130454275089e-06 Pf_ref 0.02998 Pf 0.01737 CoV 0.02380
# LS2:  Degree 3 e_LOO 0.0020340536373336577 Pf_ref 0.14893 Pf 0.00534 CoV 0.04320
# number of training points:  42 -------------------------------------------------
# LS1:  Degree 3 e_LOO 3.136105244432874e-05 Pf_ref 0.03166 Pf 0.01843 CoV 0.02310
# LS2:  Degree 3 e_LOO 0.001937517480673541 Pf_ref 0.14867 Pf 0.0059 CoV 0.04100
# number of training points:  43 -------------------------------------------------
# LS1:  Degree 3 e_LOO 0.0002252314345727331 Pf_ref 0.03166 Pf 0.01974 CoV 0.02230
# LS2:  Degree 3 e_LOO 0.0020528165983738477 Pf_ref 0.14974 Pf 0.00627 CoV 0.03980
# number of training points:  44 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.0002946628119879933 Pf_ref 0.0316 Pf 0.03168 CoV 0.01750
# LS2:  Degree 4 e_LOO 0.0015723814478731779 Pf_ref 0.14864 Pf 0.00853 CoV 0.03410
# number of training points:  45 -------------------------------------------------
# LS1:  Degree 1 e_LOO 2.8111729744720115e-05 Pf_ref 0.03203 Pf 0.03188 CoV 0.01740
# LS2:  Degree 3 e_LOO 0.0012165057879900602 Pf_ref 0.14795 Pf 0.00222 CoV 0.06700
# number of training points:  46 -------------------------------------------------
# LS1:  Degree 1 e_LOO 3.549916103186251e-07 Pf_ref 0.03108 Pf 0.03105 CoV 0.01770
# LS2:  Degree 4 e_LOO 4.030028783508871e-07 Pf_ref 0.14879 Pf 0.00228 CoV 0.06620
# number of training points:  47 -------------------------------------------------
# LS1:  Degree 4 e_LOO 5.4495481681977385e-05 Pf_ref 0.03068 Pf 0.02755 CoV 0.01880
# LS2:  Degree 4 e_LOO 2.5843958621973485e-05 Pf_ref 0.14615 Pf 0.00257 CoV 0.06230
# number of training points:  48 -------------------------------------------------
# LS1:  Degree 4 e_LOO 4.051098704725603e-05 Pf_ref 0.03082 Pf 0.02782 CoV 0.01870
# LS2:  Degree 1 e_LOO 1.714353687741469e-08 Pf_ref 0.14845 Pf 0.03815 CoV 0.01590
# number of training points:  49 -------------------------------------------------
# LS1:  Degree 4 e_LOO 0.00011938316556977595 Pf_ref 0.03112 Pf 0.02802 CoV 0.01860
# LS2:  Degree 1 e_LOO 6.372956242285528e-06 Pf_ref 0.15051 Pf 0.03945 CoV 0.01560
# number of training points:  50 -------------------------------------------------
# Experiment:  3 #################################################################
# LS1:  Degree 2 e_LOO 0.00014729005606972968 Pf_ref 0.03197 Pf 0.04994 CoV 0.01380
# LS2:  Degree 1 e_LOO 0.0002978229660177083 Pf_ref 0.14827 Pf 0.20686 CoV 0.00620
# number of training points:  11 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.17558660344297128 Pf_ref 0.03181 Pf 3e-05 CoV 0.57730
# LS2:  Degree 1 e_LOO 0.007408866216323557 Pf_ref 0.14961 Pf 0.18081 CoV 0.00670
# number of training points:  12 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.09337935577392761 Pf_ref 0.03049 Pf 1e-05 CoV 1.00000
# LS2:  Degree 1 e_LOO 0.010097027070694932 Pf_ref 0.14867 Pf 0.16663 CoV 0.00710
# number of training points:  13 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.004701302083881117 Pf_ref 0.03043 Pf 4e-05 CoV 0.50000
# LS2:  Degree 1 e_LOO 0.049848886420514174 Pf_ref 0.14979 Pf 0.11587 CoV 0.00870
# number of training points:  14 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.08820224979737194 Pf_ref 0.03173 Pf 0.00338 CoV 0.05430
# LS2:  Degree 2 e_LOO 0.05371089652497277 Pf_ref 0.14856 Pf 0.11781 CoV 0.00870
# number of training points:  15 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.0442667973928127 Pf_ref 0.03016 Pf 0.00484 CoV 0.04530
# LS2:  Degree 2 e_LOO 0.0011005622830952432 Pf_ref 0.14594 Pf 0.11716 CoV 0.00870
# number of training points:  16 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.005576083312123551 Pf_ref 0.03188 Pf 0.00668 CoV 0.03860
# LS2:  Degree 3 e_LOO 1.0320856141583265e-06 Pf_ref 0.14867 Pf 0.19237 CoV 0.00650
# number of training points:  17 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.0026733276623979274 Pf_ref 0.0312 Pf 0.00635 CoV 0.03960
# LS2:  Degree 2 e_LOO 0.0013685503691138977 Pf_ref 0.14726 Pf 0.13855 CoV 0.00790
# number of training points:  18 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.0003481839305671496 Pf_ref 0.03067 Pf 0.01914 CoV 0.02260
# LS2:  Degree 2 e_LOO 0.0008203329968922804 Pf_ref 0.14947 Pf 0.12737 CoV 0.00830
# number of training points:  19 -------------------------------------------------
# LS1:  Degree 2 e_LOO 1.3305820741940875e-05 Pf_ref 0.03042 Pf 0.02617 CoV 0.01930
# LS2:  Degree 2 e_LOO 0.0024956575274722595 Pf_ref 0.14966 Pf 0.13449 CoV 0.00800
# number of training points:  20 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.00023712894933011612 Pf_ref 0.03175 Pf 0.02566 CoV 0.01950
# LS2:  Degree 2 e_LOO 0.0007922333873554798 Pf_ref 0.14807 Pf 0.13394 CoV 0.00800
# number of training points:  21 -------------------------------------------------
# LS1:  Degree 2 e_LOO 1.586798195760867e-05 Pf_ref 0.03064 Pf 0.02749 CoV 0.01880
# LS2:  Degree 3 e_LOO 9.101466494096322e-05 Pf_ref 0.14519 Pf 0.09389 CoV 0.00980
# number of training points:  22 -------------------------------------------------
# LS1:  Degree 3 e_LOO 0.0026298487490110144 Pf_ref 0.03169 Pf 0.05317 CoV 0.01330
# LS2:  Degree 3 e_LOO 0.0018418683171813315 Pf_ref 0.1466 Pf 0.09567 CoV 0.00970
# number of training points:  23 -------------------------------------------------
# LS1:  Degree 3 e_LOO 0.0034434704693127724 Pf_ref 0.0313 Pf 0.0447 CoV 0.01460
# LS2:  Degree 3 e_LOO 0.0015541681991551235 Pf_ref 0.14783 Pf 0.0497 CoV 0.01380
# number of training points:  24 -------------------------------------------------
# LS1:  Degree 3 e_LOO 7.634292353531925e-06 Pf_ref 0.03098 Pf 0.04488 CoV 0.01460
# LS2:  Degree 3 e_LOO 0.0001215114567714862 Pf_ref 0.15001 Pf 0.05418 CoV 0.01320
# number of training points:  25 -------------------------------------------------
# LS1:  Degree 3 e_LOO 7.771432568246157e-05 Pf_ref 0.03127 Pf 0.04873 CoV 0.01400
# LS2:  Degree 3 e_LOO 0.001293791947930903 Pf_ref 0.14855 Pf 0.05734 CoV 0.01280
# number of training points:  26 -------------------------------------------------
# LS1:  Degree 3 e_LOO 0.0001207749542745592 Pf_ref 0.0313 Pf 0.04699 CoV 0.01420
# LS2:  Degree 3 e_LOO 0.00022239130028979347 Pf_ref 0.15027 Pf 0.05503 CoV 0.01310
# number of training points:  27 -------------------------------------------------
# LS1:  Degree 3 e_LOO 0.00020967164319239982 Pf_ref 0.0307 Pf 0.04557 CoV 0.01450
# LS2:  Degree 3 e_LOO 3.5041248398824805e-06 Pf_ref 0.14837 Pf 0.04893 CoV 0.01390
# number of training points:  28 -------------------------------------------------
# LS1:  Degree 3 e_LOO 1.2734294999921482e-05 Pf_ref 0.03069 Pf 0.04615 CoV 0.01440
# LS2:  Degree 3 e_LOO 2.2829352155301493e-05 Pf_ref 0.15083 Pf 0.05073 CoV 0.01370
# number of training points:  29 -------------------------------------------------
# LS1:  Degree 3 e_LOO 0.0006470950550920563 Pf_ref 0.03191 Pf 0.04862 CoV 0.01400
# LS2:  Degree 3 e_LOO 0.0002147412368563832 Pf_ref 0.14724 Pf 0.04739 CoV 0.01420
# number of training points:  30 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.0005306313668189556 Pf_ref 0.03147 Pf 0.02981 CoV 0.01800
# LS2:  Degree 3 e_LOO 1.889153308415114e-05 Pf_ref 0.14873 Pf 0.04956 CoV 0.01380
# number of training points:  31 -------------------------------------------------
# LS1:  Degree 2 e_LOO 1.4695989633572894e-05 Pf_ref 0.03077 Pf 0.02743 CoV 0.01880
# LS2:  Degree 3 e_LOO 0.0015242192171944704 Pf_ref 0.14849 Pf 0.05272 CoV 0.01340
# number of training points:  32 -------------------------------------------------
# LS1:  Degree 2 e_LOO 1.4965606217815344e-06 Pf_ref 0.03122 Pf 0.01854 CoV 0.02300
# LS2:  Degree 3 e_LOO 0.0010672870845968845 Pf_ref 0.14879 Pf 0.05191 CoV 0.01350
# number of training points:  33 -------------------------------------------------
# LS1:  Degree 2 e_LOO 1.4520709045729629e-06 Pf_ref 0.03124 Pf 0.01676 CoV 0.02420
# LS2:  Degree 3 e_LOO 0.0005262528027738996 Pf_ref 0.14863 Pf 0.05224 CoV 0.01350
# number of training points:  34 -------------------------------------------------
# LS1:  Degree 1 e_LOO 1.112126059535628e-06 Pf_ref 0.03102 Pf 0.01809 CoV 0.02330
# LS2:  Degree 3 e_LOO 0.0016322528134074979 Pf_ref 0.14851 Pf 0.05558 CoV 0.01300
# number of training points:  35 -------------------------------------------------
# LS1:  Degree 3 e_LOO 4.4187990982838374e-05 Pf_ref 0.03151 Pf 0.01564 CoV 0.02510
# LS2:  Degree 3 e_LOO 0.00014441853441873973 Pf_ref 0.14639 Pf 0.0589 CoV 0.01260
# number of training points:  36 -------------------------------------------------
# LS1:  Degree 4 e_LOO 0.00018641352073406014 Pf_ref 0.03259 Pf 0.01609 CoV 0.02470
# LS2:  Degree 3 e_LOO 0.00010233098421603882 Pf_ref 0.15001 Pf 0.06218 CoV 0.01230
# number of training points:  37 -------------------------------------------------
# LS1:  Degree 4 e_LOO 1.4079607271705692e-05 Pf_ref 0.03187 Pf 0.01575 CoV 0.02500
# LS2:  Degree 4 e_LOO 0.0006986927902015151 Pf_ref 0.14641 Pf 0.10412 CoV 0.00930
# number of training points:  38 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.0005200606281759578 Pf_ref 0.03184 Pf 0.01887 CoV 0.02280
# LS2:  Degree 4 e_LOO 0.00035436744608361597 Pf_ref 0.14781 Pf 0.10991 CoV 0.00900
# number of training points:  39 -------------------------------------------------
# LS1:  Degree 4 e_LOO 4.682493741110694e-05 Pf_ref 0.03163 Pf 0.01558 CoV 0.02510
# LS2:  Degree 4 e_LOO 0.0007231200362186331 Pf_ref 0.15172 Pf 0.10406 CoV 0.00930
# number of training points:  40 -------------------------------------------------
# LS1:  Degree 4 e_LOO 2.1052151429932203e-05 Pf_ref 0.03187 Pf 0.01605 CoV 0.02480
# LS2:  Degree 4 e_LOO 2.4763430595986987e-05 Pf_ref 0.14932 Pf 0.09916 CoV 0.00950
# number of training points:  41 -------------------------------------------------
# LS1:  Degree 4 e_LOO 0.00010331392859903995 Pf_ref 0.03144 Pf 0.01652 CoV 0.02440
# LS2:  Degree 4 e_LOO 1.96034254453852e-05 Pf_ref 0.14555 Pf 0.10182 CoV 0.00940
# number of training points:  42 -------------------------------------------------
# LS1:  Degree 4 e_LOO 8.459039810857454e-05 Pf_ref 0.02969 Pf 0.01611 CoV 0.02470
# LS2:  Degree 4 e_LOO 0.0001286690264385285 Pf_ref 0.14668 Pf 0.10427 CoV 0.00930
# number of training points:  43 -------------------------------------------------
# LS1:  Degree 3 e_LOO 3.3888482536914784e-06 Pf_ref 0.03148 Pf 0.01625 CoV 0.02460
# LS2:  Degree 2 e_LOO 0.00038702603910159144 Pf_ref 0.14664 Pf 0.1151 CoV 0.00880
# number of training points:  44 -------------------------------------------------
# LS1:  Degree 4 e_LOO 7.662359465956824e-05 Pf_ref 0.0312 Pf 0.01805 CoV 0.02330
# LS2:  Degree 2 e_LOO 0.00022429001087619514 Pf_ref 0.15049 Pf 0.11761 CoV 0.00870
# number of training points:  45 -------------------------------------------------
# LS1:  Degree 3 e_LOO 4.6618514345034974e-05 Pf_ref 0.03064 Pf 0.0177 CoV 0.02360
# LS2:  Degree 2 e_LOO 0.00015823935925248766 Pf_ref 0.1498 Pf 0.11828 CoV 0.00860
# number of training points:  46 -------------------------------------------------
# LS1:  Degree 3 e_LOO 9.4228761987695e-05 Pf_ref 0.03144 Pf 0.01883 CoV 0.02280
# LS2:  Degree 2 e_LOO 2.2314985860221604e-05 Pf_ref 0.14977 Pf 0.11802 CoV 0.00860
# number of training points:  47 -------------------------------------------------
# LS1:  Degree 3 e_LOO 2.0285190274458963e-05 Pf_ref 0.03136 Pf 0.0184 CoV 0.02310
# LS2:  Degree 2 e_LOO 2.897789844105144e-05 Pf_ref 0.14905 Pf 0.11666 CoV 0.00870
# number of training points:  48 -------------------------------------------------
# LS1:  Degree 3 e_LOO 6.151124965270243e-06 Pf_ref 0.03123 Pf 0.01776 CoV 0.02350
# LS2:  Degree 2 e_LOO 6.806578922972834e-05 Pf_ref 0.14921 Pf 0.11528 CoV 0.00880
# number of training points:  49 -------------------------------------------------
# LS1:  Degree 3 e_LOO 1.2095076252603778e-06 Pf_ref 0.03122 Pf 0.01803 CoV 0.02330
# LS2:  Degree 4 e_LOO 0.0001714084099647477 Pf_ref 0.14695 Pf 0.10456 CoV 0.00930
# number of training points:  50 -------------------------------------------------
# Experiment:  4 #################################################################
# LS1:  Degree 1 e_LOO 0.009480395036794289 Pf_ref 0.03136 Pf 0.05213 CoV 0.01350
# LS2:  Degree 1 e_LOO 4.5106189602237285e-07 Pf_ref 0.14973 Pf 0.0566 CoV 0.01290
# number of training points:  11 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.09667765275003767 Pf_ref 0.03065 Pf 0.04652 CoV 0.01430
# LS2:  Degree 1 e_LOO 0.00375562731725125 Pf_ref 0.14951 Pf 0.09658 CoV 0.00970
# number of training points:  12 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.015792355532411696 Pf_ref 0.03064 Pf 0.06664 CoV 0.01180
# LS2:  Degree 2 e_LOO 0.015361263746981822 Pf_ref 0.14933 Pf 0.08279 CoV 0.01050
# number of training points:  13 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.045357377926544235 Pf_ref 0.03152 Pf 0.01331 CoV 0.02720
# LS2:  Degree 1 e_LOO 0.02503355268485246 Pf_ref 0.14922 Pf 0.07275 CoV 0.01130
# number of training points:  14 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.029782733599597908 Pf_ref 0.0312 Pf 0.01366 CoV 0.02690
# LS2:  Degree 1 e_LOO 0.0008005250111537216 Pf_ref 0.14834 Pf 0.08588 CoV 0.01030
# number of training points:  15 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.04208425998882444 Pf_ref 0.03054 Pf 0.03175 CoV 0.01750
# LS2:  Degree 1 e_LOO 0.012937039249470548 Pf_ref 0.1488 Pf 0.08808 CoV 0.01020
# number of training points:  16 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.03342110551312237 Pf_ref 0.03214 Pf 0.02562 CoV 0.01950
# LS2:  Degree 1 e_LOO 0.005100589874995187 Pf_ref 0.14805 Pf 0.08632 CoV 0.01030
# number of training points:  17 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.029287352696888487 Pf_ref 0.03274 Pf 0.02658 CoV 0.01910
# LS2:  Degree 1 e_LOO 0.0017801384065882727 Pf_ref 0.14795 Pf 0.09401 CoV 0.00980
# number of training points:  18 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.022120134871083524 Pf_ref 0.03031 Pf 0.03478 CoV 0.01670
# LS2:  Degree 1 e_LOO 4.3815104083871425e-05 Pf_ref 0.14827 Pf 0.09727 CoV 0.00960
# number of training points:  19 -------------------------------------------------
# LS1:  Degree 1 e_LOO 2.3742572322858655e-05 Pf_ref 0.03121 Pf 0.02301 CoV 0.02060
# LS2:  Degree 2 e_LOO 0.04092893252862793 Pf_ref 0.14774 Pf 0.0286 CoV 0.01840
# number of training points:  20 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.0007182046888105816 Pf_ref 0.0312 Pf 0.02343 CoV 0.02040
# LS2:  Degree 2 e_LOO 3.111937894926005e-05 Pf_ref 0.14717 Pf 0.04221 CoV 0.01510
# number of training points:  21 -------------------------------------------------
# LS1:  Degree 2 e_LOO 1.186820009041259e-07 Pf_ref 0.03124 Pf 0.02499 CoV 0.01980
# LS2:  Degree 2 e_LOO 0.002908231732426829 Pf_ref 0.14639 Pf 0.0426 CoV 0.01500
# number of training points:  22 -------------------------------------------------
# LS1:  Degree 3 e_LOO 0.0006074654816332289 Pf_ref 0.03124 Pf 0.01488 CoV 0.02570
# LS2:  Degree 2 e_LOO 0.0027257071647983208 Pf_ref 0.14734 Pf 0.03884 CoV 0.01570
# number of training points:  23 -------------------------------------------------
# LS1:  Degree 1 e_LOO 1.959262733246338e-06 Pf_ref 0.03182 Pf 0.01018 CoV 0.03120
# LS2:  Degree 2 e_LOO 0.00432478423429916 Pf_ref 0.148 Pf 0.0211 CoV 0.02150
# number of training points:  24 -------------------------------------------------
# LS1:  Degree 1 e_LOO 5.950933758523571e-08 Pf_ref 0.03241 Pf 0.01333 CoV 0.02720
# LS2:  Degree 4 e_LOO 0.0002808036008847567 Pf_ref 0.14655 Pf 0.00123 CoV 0.09010
# number of training points:  25 -------------------------------------------------
# LS1:  Degree 1 e_LOO 1.6337049647074913e-05 Pf_ref 0.03193 Pf 0.01301 CoV 0.02750
# LS2:  Degree 2 e_LOO 0.0024363698926131395 Pf_ref 0.14711 Pf 0.03716 CoV 0.01610
# number of training points:  26 -------------------------------------------------
# LS1:  Degree 1 e_LOO 2.7858251902075726e-05 Pf_ref 0.03214 Pf 0.01348 CoV 0.02710
# LS2:  Degree 2 e_LOO 0.0004133646435027894 Pf_ref 0.1482 Pf 0.0309 CoV 0.01770
# number of training points:  27 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.00026855481998258065 Pf_ref 0.03111 Pf 0.01267 CoV 0.02790
# LS2:  Degree 2 e_LOO 0.0002673193073044415 Pf_ref 0.14915 Pf 0.03039 CoV 0.01790
# number of training points:  28 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.0004141063871049958 Pf_ref 0.03049 Pf 0.01163 CoV 0.02920
# LS2:  Degree 2 e_LOO 0.0006019396699816138 Pf_ref 0.147 Pf 0.03193 CoV 0.01740
# number of training points:  29 -------------------------------------------------
# LS1:  Degree 1 e_LOO 4.841093331865998e-06 Pf_ref 0.03114 Pf 0.01287 CoV 0.02770
# LS2:  Degree 2 e_LOO 8.166368670137681e-06 Pf_ref 0.14751 Pf 0.02885 CoV 0.01830
# number of training points:  30 -------------------------------------------------
# LS1:  Degree 1 e_LOO 4.220407508915622e-06 Pf_ref 0.03111 Pf 0.01253 CoV 0.02810
# LS2:  Degree 2 e_LOO 6.369567213322105e-05 Pf_ref 0.14801 Pf 0.01078 CoV 0.03030
# number of training points:  31 -------------------------------------------------
# LS1:  Degree 1 e_LOO 1.2241555248186684e-05 Pf_ref 0.03204 Pf 0.0122 CoV 0.02850
# LS2:  Degree 2 e_LOO 0.0002625610727650535 Pf_ref 0.14708 Pf 0.01165 CoV 0.02910
# number of training points:  32 -------------------------------------------------
# LS1:  Degree 1 e_LOO 9.067822927253005e-05 Pf_ref 0.03158 Pf 0.01196 CoV 0.02870
# LS2:  Degree 2 e_LOO 3.789678325759383e-05 Pf_ref 0.14958 Pf 0.01445 CoV 0.02610
# number of training points:  33 -------------------------------------------------
# LS1:  Degree 1 e_LOO 9.945770356416284e-05 Pf_ref 0.03158 Pf 0.01219 CoV 0.02850
# LS2:  Degree 2 e_LOO 3.948310406763339e-05 Pf_ref 0.14807 Pf 0.013 CoV 0.02760
# number of training points:  34 -------------------------------------------------
# LS1:  Degree 1 e_LOO 2.2960901196917835e-05 Pf_ref 0.03213 Pf 0.01209 CoV 0.02860
# LS2:  Degree 3 e_LOO 1.8912624970272228e-05 Pf_ref 0.14885 Pf 0.02198 CoV 0.02110
# number of training points:  35 -------------------------------------------------
# LS1:  Degree 1 e_LOO 4.3008886311354986e-08 Pf_ref 0.03044 Pf 0.01167 CoV 0.02910
# LS2:  Degree 3 e_LOO 4.778614624057683e-06 Pf_ref 0.14939 Pf 0.00376 CoV 0.05150
# number of training points:  36 -------------------------------------------------
# LS1:  Degree 1 e_LOO 1.9929210388821153e-05 Pf_ref 0.03098 Pf 0.01255 CoV 0.02810
# LS2:  Degree 3 e_LOO 6.284753179836462e-10 Pf_ref 0.14698 Pf 0.02318 CoV 0.02050
# number of training points:  37 -------------------------------------------------
# LS1:  Degree 4 e_LOO 3.549298344836825e-05 Pf_ref 0.03064 Pf 0.01618 CoV 0.02470
# LS2:  Degree 3 e_LOO 1.6291761798217116e-05 Pf_ref 0.14852 Pf 0.02296 CoV 0.02060
# number of training points:  38 -------------------------------------------------
# LS1:  Degree 4 e_LOO 3.7628941831142553e-07 Pf_ref 0.03024 Pf 0.01638 CoV 0.02450
# LS2:  Degree 3 e_LOO 9.711645113137942e-06 Pf_ref 0.14585 Pf 0.02246 CoV 0.02090
# number of training points:  39 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.00035434043538057136 Pf_ref 0.03188 Pf 0.01288 CoV 0.02770
# LS2:  Degree 3 e_LOO 1.992254792196543e-05 Pf_ref 0.14944 Pf 0.02344 CoV 0.02040
# number of training points:  40 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.0006614778532499691 Pf_ref 0.03191 Pf 0.01193 CoV 0.02880
# LS2:  Degree 2 e_LOO 6.258183257402838e-07 Pf_ref 0.14899 Pf 0.02244 CoV 0.02090
# number of training points:  41 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.0007015756211137911 Pf_ref 0.03116 Pf 0.01204 CoV 0.02860
# LS2:  Degree 2 e_LOO 8.888049512777261e-09 Pf_ref 0.15132 Pf 0.02318 CoV 0.02050
# number of training points:  42 -------------------------------------------------
# LS1:  Degree 3 e_LOO 0.0005920456745316435 Pf_ref 0.03072 Pf 0.01559 CoV 0.02510
# LS2:  Degree 3 e_LOO 4.4993374994140585e-05 Pf_ref 0.14689 Pf 0.02338 CoV 0.02040
# number of training points:  43 -------------------------------------------------
# LS1:  Degree 1 e_LOO 7.35069324411142e-05 Pf_ref 0.032 Pf 0.011 CoV 0.03000
# LS2:  Degree 2 e_LOO 5.369892604186256e-05 Pf_ref 0.14947 Pf 0.02278 CoV 0.02070
# number of training points:  44 -------------------------------------------------
# LS1:  Degree 1 e_LOO 4.231728652807813e-05 Pf_ref 0.03095 Pf 0.01083 CoV 0.03020
# LS2:  Degree 2 e_LOO 1.569084962030191e-05 Pf_ref 0.14933 Pf 0.02143 CoV 0.02140
# number of training points:  45 -------------------------------------------------
# LS1:  Degree 1 e_LOO 1.316036372217229e-08 Pf_ref 0.03009 Pf 0.01024 CoV 0.03110
# LS2:  Degree 3 e_LOO 8.923582095826949e-05 Pf_ref 0.14704 Pf 0.02207 CoV 0.02110
# number of training points:  46 -------------------------------------------------
# LS1:  Degree 1 e_LOO 4.719550985689631e-05 Pf_ref 0.03177 Pf 0.01158 CoV 0.02920
# LS2:  Degree 3 e_LOO 4.8063883432536855e-06 Pf_ref 0.14611 Pf 0.02143 CoV 0.02140
# number of training points:  47 -------------------------------------------------
# LS1:  Degree 4 e_LOO 5.586523173657726e-05 Pf_ref 0.03042 Pf 0.01197 CoV 0.02870
# LS2:  Degree 3 e_LOO 2.5598247302775685e-05 Pf_ref 0.14875 Pf 0.04109 CoV 0.01530
# number of training points:  48 -------------------------------------------------
# LS1:  Degree 4 e_LOO 2.5196905934441787e-05 Pf_ref 0.03062 Pf 0.01182 CoV 0.02890
# LS2:  Degree 3 e_LOO 1.3717493362223494e-05 Pf_ref 0.14807 Pf 0.04018 CoV 0.01550
# number of training points:  49 -------------------------------------------------
# LS1:  Degree 2 e_LOO 5.513661290889913e-06 Pf_ref 0.03045 Pf 0.01342 CoV 0.02710
# LS2:  Degree 2 e_LOO 1.3388410763790798e-06 Pf_ref 0.14972 Pf 0.04411 CoV 0.01470
# number of training points:  50 -------------------------------------------------
# Experiment:  5 #################################################################
# LS1:  Degree 2 e_LOO 0.0006134024979113762 Pf_ref 0.03134 Pf 0.0 CoV inf
# LS2:  Degree 2 e_LOO 1.6813805698337647e-05 Pf_ref 0.14784 Pf 0.18517 CoV 0.00660
# number of training points:  11 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.021439169900691966 Pf_ref 0.03097 Pf 0.04321 CoV 0.01490
# LS2:  Degree 2 e_LOO 0.0004258784796476641 Pf_ref 0.14753 Pf 0.18875 CoV 0.00660
# number of training points:  12 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.02630099993960073 Pf_ref 0.03135 Pf 0.00076 CoV 0.11470
# LS2:  Degree 1 e_LOO 0.031374175549713945 Pf_ref 0.14962 Pf 0.07141 CoV 0.01140
# number of training points:  13 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.024706973851205568 Pf_ref 0.03128 Pf 0.02595 CoV 0.01940
# LS2:  Degree 2 e_LOO 5.6329462340578544e-05 Pf_ref 0.15082 Pf 0.12724 CoV 0.00830
# number of training points:  14 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.00019908610819947362 Pf_ref 0.03081 Pf 0.02929 CoV 0.01820
# LS2:  Degree 2 e_LOO 0.026192564414843907 Pf_ref 0.14983 Pf 0.1005 CoV 0.00950
# number of training points:  15 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.00132304341053492 Pf_ref 0.03136 Pf 0.01047 CoV 0.03070
# LS2:  Degree 2 e_LOO 0.02534360575206326 Pf_ref 0.14921 Pf 0.1189 CoV 0.00860
# number of training points:  16 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.013247131518070304 Pf_ref 0.03163 Pf 0.0105 CoV 0.03070
# LS2:  Degree 2 e_LOO 0.006041751394215267 Pf_ref 0.14674 Pf 0.11195 CoV 0.00890
# number of training points:  17 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.0003320018301802243 Pf_ref 0.03096 Pf 0.01099 CoV 0.03000
# LS2:  Degree 2 e_LOO 0.006351016187461694 Pf_ref 0.14662 Pf 0.11309 CoV 0.00890
# number of training points:  18 -------------------------------------------------
# LS1:  Degree 2 e_LOO 5.309149232042779e-05 Pf_ref 0.03178 Pf 0.01357 CoV 0.02700
# LS2:  Degree 2 e_LOO 7.594828749064727e-05 Pf_ref 0.14869 Pf 0.13102 CoV 0.00810
# number of training points:  19 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.0008493386910459418 Pf_ref 0.03139 Pf 0.02527 CoV 0.01960
# LS2:  Degree 2 e_LOO 0.003327003805761408 Pf_ref 0.14775 Pf 0.11777 CoV 0.00870
# number of training points:  20 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.0019028598297091658 Pf_ref 0.03136 Pf 0.02318 CoV 0.02050
# LS2:  Degree 2 e_LOO 0.004246833664791059 Pf_ref 0.1482 Pf 0.11817 CoV 0.00860
# number of training points:  21 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.001936907420369021 Pf_ref 0.03168 Pf 0.02457 CoV 0.01990
# LS2:  Degree 2 e_LOO 0.001690444224552471 Pf_ref 0.14836 Pf 0.12065 CoV 0.00850
# number of training points:  22 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.0016441183853430053 Pf_ref 0.03134 Pf 0.0258 CoV 0.01940
# LS2:  Degree 2 e_LOO 0.000866422477295178 Pf_ref 0.14841 Pf 0.12042 CoV 0.00850
# number of training points:  23 -------------------------------------------------
# LS1:  Degree 4 e_LOO 0.0016009904899699455 Pf_ref 0.03211 Pf 0.05363 CoV 0.01330
# LS2:  Degree 1 e_LOO 0.0024596359453333944 Pf_ref 0.1478 Pf 0.12559 CoV 0.00830
# number of training points:  24 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.004590989307783153 Pf_ref 0.03079 Pf 0.0233 CoV 0.02050
# LS2:  Degree 3 e_LOO 2.2186019042741505e-05 Pf_ref 0.14737 Pf 0.10003 CoV 0.00950
# number of training points:  25 -------------------------------------------------
# LS1:  Degree 2 e_LOO 4.9826147232752375e-08 Pf_ref 0.03161 Pf 0.0251 CoV 0.01970
# LS2:  Degree 2 e_LOO 3.860799184912864e-05 Pf_ref 0.14734 Pf 0.11646 CoV 0.00870
# number of training points:  26 -------------------------------------------------
# LS1:  Degree 2 e_LOO 8.689440124488122e-05 Pf_ref 0.03032 Pf 0.02399 CoV 0.02020
# LS2:  Degree 3 e_LOO 0.0003114970794248666 Pf_ref 0.14748 Pf 0.09036 CoV 0.01000
# number of training points:  27 -------------------------------------------------
# LS1:  Degree 2 e_LOO 6.856267892280822e-05 Pf_ref 0.03197 Pf 0.02471 CoV 0.01990
# LS2:  Degree 2 e_LOO 0.000317568683125685 Pf_ref 0.14837 Pf 0.11986 CoV 0.00860
# number of training points:  28 -------------------------------------------------
# LS1:  Degree 2 e_LOO 2.6873055028302256e-05 Pf_ref 0.03141 Pf 0.01482 CoV 0.02580
# LS2:  Degree 2 e_LOO 0.00031596500536417354 Pf_ref 0.15045 Pf 0.11859 CoV 0.00860
# number of training points:  29 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.0004267605703368733 Pf_ref 0.03161 Pf 0.01526 CoV 0.02540
# LS2:  Degree 3 e_LOO 0.00025629369228697253 Pf_ref 0.14936 Pf 0.07751 CoV 0.01090
# number of training points:  30 -------------------------------------------------
# LS1:  Degree 4 e_LOO 1.8225164178357384e-05 Pf_ref 0.0323 Pf 0.01336 CoV 0.02720
# LS2:  Degree 3 e_LOO 0.0007259279017584722 Pf_ref 0.14908 Pf 0.06092 CoV 0.01240
# number of training points:  31 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.0004148133955960091 Pf_ref 0.03137 Pf 0.01125 CoV 0.02960
# LS2:  Degree 2 e_LOO 0.00048121800374909755 Pf_ref 0.14975 Pf 0.11718 CoV 0.00870
# number of training points:  32 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.00015382549344641772 Pf_ref 0.03205 Pf 0.01203 CoV 0.02870
# LS2:  Degree 2 e_LOO 0.0003568471623742362 Pf_ref 0.14884 Pf 0.11827 CoV 0.00860
# number of training points:  33 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.00033176747400674245 Pf_ref 0.03142 Pf 0.0114 CoV 0.02940
# LS2:  Degree 2 e_LOO 0.00018002820684688109 Pf_ref 0.14749 Pf 0.10934 CoV 0.00900
# number of training points:  34 -------------------------------------------------
# LS1:  Degree 1 e_LOO 4.176849770245546e-07 Pf_ref 0.03185 Pf 0.01138 CoV 0.02950
# LS2:  Degree 4 e_LOO 0.00010643953235162391 Pf_ref 0.14677 Pf 0.11354 CoV 0.00880
# number of training points:  35 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.00023923352117023505 Pf_ref 0.03161 Pf 0.01163 CoV 0.02920
# LS2:  Degree 2 e_LOO 1.7008289300403834e-05 Pf_ref 0.14785 Pf 0.11155 CoV 0.00890
# number of training points:  36 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.0002578826254641751 Pf_ref 0.03099 Pf 0.01239 CoV 0.02820
# LS2:  Degree 3 e_LOO 2.9388651189568514e-06 Pf_ref 0.14805 Pf 0.08593 CoV 0.01030
# number of training points:  37 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.00017051629009169796 Pf_ref 0.03167 Pf 0.01211 CoV 0.02860
# LS2:  Degree 3 e_LOO 4.559332453273732e-06 Pf_ref 0.14771 Pf 0.085 CoV 0.01040
# number of training points:  38 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.00011860724144760358 Pf_ref 0.03129 Pf 0.01117 CoV 0.02980
# LS2:  Degree 3 e_LOO 9.034236013214433e-05 Pf_ref 0.15123 Pf 0.08947 CoV 0.01010
# number of training points:  39 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.0001796694860697234 Pf_ref 0.03092 Pf 0.01104 CoV 0.02990
# LS2:  Degree 3 e_LOO 1.465057349479084e-05 Pf_ref 0.14625 Pf 0.0875 CoV 0.01020
# number of training points:  40 -------------------------------------------------
# LS1:  Degree 1 e_LOO 1.8244098879481456e-05 Pf_ref 0.0324 Pf 0.01128 CoV 0.02960
# LS2:  Degree 2 e_LOO 0.00011821269467976941 Pf_ref 0.14813 Pf 0.11536 CoV 0.00880
# number of training points:  41 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.0002130651509934838 Pf_ref 0.03091 Pf 0.0112 CoV 0.02970
# LS2:  Degree 3 e_LOO 7.2168977238915e-05 Pf_ref 0.14736 Pf 0.08524 CoV 0.01040
# number of training points:  42 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.00013201546361831635 Pf_ref 0.03052 Pf 0.01119 CoV 0.02970
# LS2:  Degree 3 e_LOO 5.516049226414225e-05 Pf_ref 0.14597 Pf 0.0939 CoV 0.00980
# number of training points:  43 -------------------------------------------------
# ...
# LS1:  Degree 3 e_LOO 0.008748772184280888 Pf_ref 0.03152 Pf 0.06401 CoV 0.01210
# LS2:  Degree 3 e_LOO 0.003606635975825379 Pf_ref 0.15001 Pf 0.00694 CoV 0.03780
# number of training points:  23 -------------------------------------------------
# LS1:  Degree 3 e_LOO 0.007236061678676865 Pf_ref 0.03163 Pf 0.05142 CoV 0.01360
# LS2:  Degree 3 e_LOO 0.001582803393958567 Pf_ref 0.14945 Pf 0.02812 CoV 0.01860
# number of training points:  24 -------------------------------------------------
# LS1:  Degree 3 e_LOO 0.0036632416606719345 Pf_ref 0.03259 Pf 0.05118 CoV 0.01360
# LS2:  Degree 3 e_LOO 0.00022432160109781533 Pf_ref 0.14744 Pf 0.0258 CoV 0.01940
# number of training points:  25 -------------------------------------------------
# LS1:  Degree 3 e_LOO 0.0036282554856934524 Pf_ref 0.03152 Pf 0.06023 CoV 0.01250
# LS2:  Degree 3 e_LOO 0.00033114920142772133 Pf_ref 0.14603 Pf 0.02445 CoV 0.02000
# number of training points:  26 -------------------------------------------------
# LS1:  Degree 3 e_LOO 0.0010077821147450225 Pf_ref 0.03208 Pf 0.02965 CoV 0.01810
# LS2:  Degree 3 e_LOO 0.0008844141998207853 Pf_ref 0.14684 Pf 0.02694 CoV 0.01900
# number of training points:  27 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.0011808930261587851 Pf_ref 0.03112 Pf 0.02177 CoV 0.02120
# LS2:  Degree 4 e_LOO 0.00014388239870552434 Pf_ref 0.14875 Pf 0.02007 CoV 0.02210
# number of training points:  28 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.0008645537831991591 Pf_ref 0.03102 Pf 0.0238 CoV 0.02030
# LS2:  Degree 1 e_LOO 0.000830805243616161 Pf_ref 0.14847 Pf 0.05149 CoV 0.01360
# number of training points:  29 -------------------------------------------------
# LS1:  Degree 3 e_LOO 0.0007004972046487286 Pf_ref 0.03238 Pf 0.02213 CoV 0.02100
# LS2:  Degree 3 e_LOO 8.475211536209804e-05 Pf_ref 0.14705 Pf 0.02603 CoV 0.01930
# number of training points:  30 -------------------------------------------------
# LS1:  Degree 4 e_LOO 0.00030477239328899125 Pf_ref 0.03245 Pf 0.02102 CoV 0.02160
# LS2:  Degree 3 e_LOO 5.685374573488735e-05 Pf_ref 0.14593 Pf 0.02585 CoV 0.01940
# number of training points:  31 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.0002686674722165354 Pf_ref 0.03097 Pf 0.02408 CoV 0.02010
# LS2:  Degree 3 e_LOO 0.0005777476408486865 Pf_ref 0.14945 Pf 0.02609 CoV 0.01930
# number of training points:  32 -------------------------------------------------
# LS1:  Degree 2 e_LOO 8.123822416205173e-07 Pf_ref 0.0318 Pf 0.02373 CoV 0.02030
# LS2:  Degree 3 e_LOO 0.00027531002667818323 Pf_ref 0.14784 Pf 0.0254 CoV 0.01960
# number of training points:  33 -------------------------------------------------
# LS1:  Degree 2 e_LOO 8.07005489531763e-05 Pf_ref 0.03111 Pf 0.02553 CoV 0.01950
# LS2:  Degree 2 e_LOO 0.0003790353935853479 Pf_ref 0.14776 Pf 0.04792 CoV 0.01410
# number of training points:  34 -------------------------------------------------
# LS1:  Degree 3 e_LOO 0.0003602113103104315 Pf_ref 0.03107 Pf 0.02338 CoV 0.02040
# LS2:  Degree 2 e_LOO 9.555555645390516e-06 Pf_ref 0.14953 Pf 0.0503 CoV 0.01370
# number of training points:  35 -------------------------------------------------
# LS1:  Degree 3 e_LOO 0.00029400389458689017 Pf_ref 0.03187 Pf 0.01782 CoV 0.02350
# LS2:  Degree 2 e_LOO 5.276703664826337e-05 Pf_ref 0.14792 Pf 0.04782 CoV 0.01410
# number of training points:  36 -------------------------------------------------
# LS1:  Degree 3 e_LOO 0.0002352238107431128 Pf_ref 0.03017 Pf 0.01788 CoV 0.02340
# LS2:  Degree 2 e_LOO 4.070693282390797e-06 Pf_ref 0.14808 Pf 0.04797 CoV 0.01410
# number of training points:  37 -------------------------------------------------
# LS1:  Degree 3 e_LOO 0.0002606500222607779 Pf_ref 0.0312 Pf 0.01778 CoV 0.02350
# LS2:  Degree 2 e_LOO 0.0001400319269259629 Pf_ref 0.14907 Pf 0.04802 CoV 0.01410
# number of training points:  38 -------------------------------------------------
# LS1:  Degree 2 e_LOO 3.223272274876741e-05 Pf_ref 0.03061 Pf 0.01903 CoV 0.02270
# LS2:  Degree 2 e_LOO 3.631458305373698e-05 Pf_ref 0.14719 Pf 0.04823 CoV 0.01400
# number of training points:  39 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.00019166679093397053 Pf_ref 0.03177 Pf 0.01845 CoV 0.02310
# LS2:  Degree 2 e_LOO 4.622933849935059e-05 Pf_ref 0.15144 Pf 0.04796 CoV 0.01410
# number of training points:  40 -------------------------------------------------
# LS1:  Degree 2 e_LOO 5.067767815369669e-05 Pf_ref 0.03006 Pf 0.01761 CoV 0.02360
# LS2:  Degree 2 e_LOO 9.945223017325549e-05 Pf_ref 0.14981 Pf 0.0488 CoV 0.01400
# number of training points:  41 -------------------------------------------------
# LS1:  Degree 2 e_LOO 1.9445760959124026e-05 Pf_ref 0.03055 Pf 0.01687 CoV 0.02410
# LS2:  Degree 2 e_LOO 5.668542134050294e-05 Pf_ref 0.14744 Pf 0.04825 CoV 0.01400
# number of training points:  42 -------------------------------------------------
# LS1:  Degree 2 e_LOO 5.4915852996477026e-05 Pf_ref 0.03115 Pf 0.01795 CoV 0.02340
# LS2:  Degree 2 e_LOO 0.0006364719449569372 Pf_ref 0.14988 Pf 0.04879 CoV 0.01400
# number of training points:  43 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.00021480808391978197 Pf_ref 0.03042 Pf 0.01727 CoV 0.02390
# LS2:  Degree 4 e_LOO 0.0005662315510580791 Pf_ref 0.14861 Pf 0.02861 CoV 0.01840
# number of training points:  44 -------------------------------------------------
# LS1:  Degree 2 e_LOO 5.12816969743848e-05 Pf_ref 0.0307 Pf 0.01797 CoV 0.02340
# LS2:  Degree 3 e_LOO 0.0004973137509401647 Pf_ref 0.14954 Pf 0.02894 CoV 0.01830
# number of training points:  45 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.00017977087706280874 Pf_ref 0.03189 Pf 0.01885 CoV 0.02280
# LS2:  Degree 4 e_LOO 7.581096240524765e-05 Pf_ref 0.14802 Pf 0.03106 CoV 0.01770
# number of training points:  46 -------------------------------------------------
# LS1:  Degree 3 e_LOO 0.00042011325437808897 Pf_ref 0.03097 Pf 0.01694 CoV 0.02410
# LS2:  Degree 4 e_LOO 0.00043475556325565197 Pf_ref 0.14758 Pf 0.03138 CoV 0.01760
# number of training points:  47 -------------------------------------------------
# LS1:  Degree 2 e_LOO 6.317953294521746e-05 Pf_ref 0.03061 Pf 0.01861 CoV 0.02300
# LS2:  Degree 4 e_LOO 1.1569424760338655e-05 Pf_ref 0.14838 Pf 0.03149 CoV 0.01750
# number of training points:  48 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.00015313154810346928 Pf_ref 0.03191 Pf 0.01854 CoV 0.02300
# LS2:  Degree 3 e_LOO 0.0001448346875401879 Pf_ref 0.14732 Pf 0.03128 CoV 0.01760
# number of training points:  49 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.00013743330524748157 Pf_ref 0.03149 Pf 0.01873 CoV 0.02290
# LS2:  Degree 3 e_LOO 2.9392397119283064e-05 Pf_ref 0.14887 Pf 0.0307 CoV 0.01780
# number of training points:  50 -------------------------------------------------
# Experiment:  8 #################################################################
# LS1:  Degree 1 e_LOO 0.011775947137465308 Pf_ref 0.03099 Pf 0.08838 CoV 0.01020
# LS2:  Degree 1 e_LOO 0.0008887463054831271 Pf_ref 0.14896 Pf 0.19794 CoV 0.00640
# number of training points:  11 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.11412441051635239 Pf_ref 0.03102 Pf 0.00875 CoV 0.03370
# LS2:  Degree 2 e_LOO 0.00016192075094415405 Pf_ref 0.14884 Pf 0.15847 CoV 0.00730
# number of training points:  12 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.15637958222763784 Pf_ref 0.03078 Pf 0.0009 CoV 0.10540
# LS2:  Degree 3 e_LOO 0.007956739846198274 Pf_ref 0.1481 Pf 0.12615 CoV 0.00830
# number of training points:  13 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.031114308983127777 Pf_ref 0.03133 Pf 0.0016 CoV 0.07900
# LS2:  Degree 2 e_LOO 0.06684477347500707 Pf_ref 0.1503 Pf 0.16477 CoV 0.00710
# number of training points:  14 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.0003458508584187888 Pf_ref 0.03127 Pf 0.01692 CoV 0.02410
# LS2:  Degree 3 e_LOO 7.343671029570807e-05 Pf_ref 0.14781 Pf 0.11537 CoV 0.00880
# number of training points:  15 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.0007164543916382073 Pf_ref 0.03163 Pf 0.01964 CoV 0.02230
# LS2:  Degree 1 e_LOO 0.013809592501744208 Pf_ref 0.14728 Pf 0.07516 CoV 0.01110
# number of training points:  16 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.0011636973653633557 Pf_ref 0.03178 Pf 0.01196 CoV 0.02870
# LS2:  Degree 2 e_LOO 2.8161244266518894e-05 Pf_ref 0.14669 Pf 0.09861 CoV 0.00960
# number of training points:  17 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.0001288651993842254 Pf_ref 0.03142 Pf 0.01532 CoV 0.02540
# LS2:  Degree 3 e_LOO 0.0004975501857167366 Pf_ref 0.14861 Pf 0.1573 CoV 0.00730
# number of training points:  18 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.0009471504333198437 Pf_ref 0.03148 Pf 0.03095 CoV 0.01770
# LS2:  Degree 2 e_LOO 0.002896740082859484 Pf_ref 0.1487 Pf 0.10479 CoV 0.00920
# number of training points:  19 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.00115035445367031 Pf_ref 0.03227 Pf 0.03107 CoV 0.01770
# LS2:  Degree 2 e_LOO 0.00016287147923733423 Pf_ref 0.1479 Pf 0.10534 CoV 0.00920
# number of training points:  20 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.004833322140620135 Pf_ref 0.03125 Pf 0.03318 CoV 0.01710
# LS2:  Degree 3 e_LOO 0.007456773775825845 Pf_ref 0.14843 Pf 0.0616 CoV 0.01230
# number of training points:  21 -------------------------------------------------
# LS1:  Degree 2 e_LOO 0.001366475316570389 Pf_ref 0.03073 Pf 0.03354 CoV 0.01700
# LS2:  Degree 1 e_LOO 0.001368165230981436 Pf_ref 0.14592 Pf 0.06327 CoV 0.01220
# number of training points:  22 -------------------------------------------------
# LS1:  Degree 1 e_LOO 1.9706885964281418e-05 Pf_ref 0.03136 Pf 0.02972 CoV 0.01810
# LS2:  Degree 1 e_LOO 0.00010838235027772776 Pf_ref 0.1522 Pf 0.06372 CoV 0.01210
# number of training points:  23 -------------------------------------------------
# LS1:  Degree 3 e_LOO 2.209189251534511e-05 Pf_ref 0.03064 Pf 0.0683 CoV 0.01170
# LS2:  Degree 2 e_LOO 0.00044913952761529226 Pf_ref 0.14798 Pf 0.0905 CoV 0.01000
# number of training points:  24 -------------------------------------------------
# LS1:  Degree 3 e_LOO 0.00020314637658053585 Pf_ref 0.03249 Pf 0.04616 CoV 0.01440
# LS2:  Degree 2 e_LOO 1.217716602878376e-06 Pf_ref 0.14789 Pf 0.09302 CoV 0.00990
# number of training points:  25 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.00011211137139089556 Pf_ref 0.03041 Pf 0.02168 CoV 0.02120
# LS2:  Degree 2 e_LOO 0.00028314573871782774 Pf_ref 0.1504 Pf 0.09661 CoV 0.00970
# number of training points:  26 -------------------------------------------------
# LS1:  Degree 1 e_LOO 5.9740510149855506e-05 Pf_ref 0.03202 Pf 0.02307 CoV 0.02060
# LS2:  Degree 2 e_LOO 0.0004380495559934595 Pf_ref 0.14907 Pf 0.10252 CoV 0.00940
# number of training points:  27 -------------------------------------------------
# LS1:  Degree 1 e_LOO 4.174601502036765e-06 Pf_ref 0.03088 Pf 0.02176 CoV 0.02120
# LS2:  Degree 2 e_LOO 0.0015703278684254497 Pf_ref 0.14844 Pf 0.1013 CoV 0.00940
# number of training points:  28 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.00010211413485388348 Pf_ref 0.03174 Pf 0.02363 CoV 0.02030
# LS2:  Degree 3 e_LOO 0.0004128531032700743 Pf_ref 0.14868 Pf 0.04526 CoV 0.01450
# number of training points:  29 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.0002784744708668003 Pf_ref 0.03148 Pf 0.02315 CoV 0.02050
# LS2:  Degree 3 e_LOO 0.0003868517382277968 Pf_ref 0.14744 Pf 0.04616 CoV 0.01440
# number of training points:  30 -------------------------------------------------
# LS1:  Degree 3 e_LOO 0.0004143333269266412 Pf_ref 0.03221 Pf 0.04962 CoV 0.01380
# LS2:  Degree 3 e_LOO 5.8801716808000815e-05 Pf_ref 0.14838 Pf 0.04722 CoV 0.01420
# number of training points:  31 -------------------------------------------------
# LS1:  Degree 4 e_LOO 5.921780895280773e-07 Pf_ref 0.03023 Pf 0.04089 CoV 0.01530
# LS2:  Degree 2 e_LOO 0.0001910921252353411 Pf_ref 0.14832 Pf 0.1054 CoV 0.00920
# number of training points:  32 -------------------------------------------------
# LS1:  Degree 4 e_LOO 0.00029061557197949153 Pf_ref 0.03156 Pf 0.04256 CoV 0.01500
# LS2:  Degree 1 e_LOO 0.0011183098614035336 Pf_ref 0.14968 Pf 0.08772 CoV 0.01020
# number of training points:  33 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.00016639148303784483 Pf_ref 0.03205 Pf 0.02499 CoV 0.01980
# LS2:  Degree 1 e_LOO 0.0017574333073841876 Pf_ref 0.15023 Pf 0.09048 CoV 0.01000
# number of training points:  34 -------------------------------------------------
# LS1:  Degree 1 e_LOO 4.789625164170816e-07 Pf_ref 0.03129 Pf 0.02354 CoV 0.02040
# LS2:  Degree 3 e_LOO 0.0002899452837941326 Pf_ref 0.1503 Pf 0.04712 CoV 0.01420
# number of training points:  35 -------------------------------------------------
# LS1:  Degree 1 e_LOO 2.57853687841401e-06 Pf_ref 0.03131 Pf 0.02407 CoV 0.02010
# LS2:  Degree 2 e_LOO 0.00029250633751127576 Pf_ref 0.1487 Pf 0.10356 CoV 0.00930
# number of training points:  36 -------------------------------------------------
# LS1:  Degree 1 e_LOO 7.593246979424122e-05 Pf_ref 0.03073 Pf 0.02299 CoV 0.02060
# LS2:  Degree 2 e_LOO 2.1916387934454507e-06 Pf_ref 0.14903 Pf 0.09663 CoV 0.00970
# number of training points:  37 -------------------------------------------------
# LS1:  Degree 1 e_LOO 0.00014001090464277707 Pf_ref 0.03029 Pf 0.01535 CoV 0.02530
# LS2:  Degree 2 e_LOO 6.0244120349975694e-05 Pf_ref 0.14926 Pf 0.0963 CoV 0.00970
# number of training points:  38 -------------------------------------------------
# LS1:  Degree 1 e_LOO 7.8803942343324e-05 Pf_ref 0.03096 Pf 0.01037 CoV 0.03090
# LS2:  Degree 2 e_LOO 0.0001965257878156509 Pf_ref 0.14939 Pf 0.09445 CoV 0.00980
# number of training points:  39 -------------------------------------------------
# LS1:  Degree 3 e_LOO 4.649180459873357e-05 Pf_ref 0.0311 Pf 0.01246 CoV 0.02820
# LS2:  Degree 1 e_LOO 2.463137694133013e-06 Pf_ref 0.14952 Pf 0.0929 CoV 0.00990
# number of training points:  40 -------------------------------------------------
# LS1:  Degree 3 e_LOO 2.2125578233184257e-05 Pf_ref 0.03155 Pf 0.01312 CoV 0.02740
# LS2:  Degree 1 e_LOO 0.00024019641293864294 Pf_ref 0.14879 Pf 0.09359 CoV 0.00980
# number of training points:  41 -------------------------------------------------
# LS1:  Degree 3 e_LOO 1.1182135240624869e-05 Pf_ref 0.03129 Pf 0.01285 CoV 0.02770
# LS2:  Degree 2 e_LOO 0.0004915434794901696 Pf_ref 0.14961 Pf 0.09498 CoV 0.00980
# number of training points:  42 -------------------------------------------------
# LS1:  Degree 3 e_LOO 0.0002587134659356607 Pf_ref 0.03158 Pf 0.01283 CoV 0.02770
# LS2:  Degree 1 e_LOO 0.00017625655328519087 Pf_ref 0.14974 Pf 0.09186 CoV 0.00990
# number of training points:  43 -------------------------------------------------
# LS1:  Degree 3 e_LOO 7.779276266085586e-05 Pf_ref 0.03098 Pf 0.01242 CoV 0.02820
# LS2:  Degree 1 e_LOO 8.568234619324273e-05 Pf_ref 0.14711 Pf 0.08922 CoV 0.01010
# number of training points:  44 -------------------------------------------------
# LS1:  Degree 3 e_LOO 1.32022363112818e-05 Pf_ref 0.03182 Pf 0.00983 CoV 0.03170
# LS2:  Degree 2 e_LOO 0.000269866757484522 Pf_ref 0.14991 Pf 0.09185 CoV 0.00990
# number of training points:  45 -------------------------------------------------
# LS1:  Degree 3 e_LOO 2.257408632215046e-06 Pf_ref 0.0315 Pf 0.01094 CoV 0.03010
# LS2:  Degree 1 e_LOO 0.0005276142321139163 Pf_ref 0.14867 Pf 0.09162 CoV 0.01000
# number of training points:  46 -------------------------------------------------
# LS1:  Degree 3 e_LOO 2.99360717614842e-06 Pf_ref 0.032 Pf 0.01057 CoV 0.03060
# LS2:  Degree 2 e_LOO 0.0009804289592364943 Pf_ref 0.14891 Pf 0.09115 CoV 0.01000
# number of training points:  47 -------------------------------------------------
# LS1:  Degree 3 e_LOO 1.7802044032247842e-05 Pf_ref 0.03118 Pf 0.01064 CoV 0.03050

# %% [markdown]
# # Active training - U - LOO - 2 LS

# %%
number_experiments = 15
number_active_points = 40

training_limitstate = 2

results_file = '_AT'+ str(training_limitstate) +'_U_LOO_' + str(number_active_points)    # index for results files

for experiments in range(number_experiments):
    print('Experiment: ', experiments+1 , '#################################################################' )
    
    ActiveTrain_1 = {}   #results file { Surrogate , Pf, CoV_Pf , eLoo , mse }
    ActiveTrain_2 = {}   #results file { Surrogate , Pf, CoV_Pf , eLoo , mse }

    #INITIAL design of experiments (LHS) passive training ####################################

    n = 10       # number of initial sampling

    xn = np.zeros((int(n), dim))      #normalized training points
    xr = np.zeros((int(n), dim))      #scaled training points
    yn = np.zeros((int(n)))           #observations

    # Check the variables limits for space-filling distribution
    Xdoe = build.space_filling_lhs( {'x1':[-1, 1],      
                                     'x2':[-1, 1],} , 
                                      num_samples = n )
    #------------------------------------------------------------
    xn[:,0] = Xdoe['x1']
    xn[:,1] = Xdoe['x2']
    xr[:,0] = PCK1.scalehermite(xn[:,0], x1mean, x1sigma)
    xr[:,1] = PCK1.scalehermite(xn[:,1], x2mean, x2sigma)

    yn_1 = function_1(xr)[0]
    yn_2 = function_2(xr)[0]
    
    # kernel hyperparameters-------------------------------------
    v = 5/2        #Gaussian process
    #truncation term-------------------------------------
    p_max = 5  #for each variable → same truncation , degree of expansion
    
    for points in range(number_active_points):

        # Selecting the smallest e_loo model (length and order)
        
        mse_results = np.zeros(p_max-1)
        opt_length_it = np.zeros(p_max-1)
        eloo_results = np.zeros(p_max-1)

        mean_loo = np.zeros(len(xn))
        var_loo = np.zeros(len(xn))
        sumat_1 = np.zeros((len(xn),(p_max-1)))
        sumat_2 = np.zeros((len(xn),(p_max-1)))
        
        dist = PCK1.distance(xn, xn)
        lmax = np.max(dist)
        lmin = np.min(dist[dist!=0])
        bounds = [(lmin, lmax)]

        results = dict()
        
        # ##############################################################################
        # Active training of Limit State 1 #############################################

        ModelName_1 = 'PCK1_' + str(len(xn))
        
        ModelName_1 = PC_Kriging(config)

        # yn is changing for each LS (inside L_Object )
        yn = yn_1    #observations
        YN = YN_1    #test points

        # OPTIMAL SURROGATE MODEL -----------------------------------
        for p in range(1, p_max):

            results['shgo'] = optimize.shgo(L_Object, bounds)
            opt_length = results['shgo']['x'][0]

            theta = np.array([opt_length, v])

            #Generating PCK models for each reduced design of experiments 

            for i in range (0, len(xn) ):

                yn_loo= np.delete(yn,[i])                            #y_n-i      leaving element i out the observations 
                xr_loo= np.delete(xr,[i*2,i*2+1]).reshape(-1,dim)    #x1r_n-i   leaving element i out the inputs (xr)
                xn_loo= np.delete(xn,[i*2,i*2+1]).reshape(-1,dim)    #x_n-i     leaving element i out the nomalized inputs (xn)

                #training LOO
                modelpar_loo = PCK_loo.train (xn_loo , yn_loo , p , theta )

                #predicting LOO over each removed sample
                mean_loo[i], var_loo[i] = PCK_loo.predict_fast(xn[i].reshape(1,-1))

            e_loo = np.mean (yn - mean_loo)**2              #LOO CV squared errors
            sumat_1[:,p-1] = np.divide(e_loo, var_loo)
            eloo_results[p-1] = e_loo

            #--------------------------------------- error over a set of test points
            modelpar1 = ModelName_1.train (xn, yn, p, theta) 
            mean0, var0 = ModelName_1.predict_fast(XN)    # test points predictions mean, variance

            mse = np.mean ((YN - mean0)**2)

            mse_results[p-1] = mse
            opt_length_it[p-1] = opt_length

    #         print('Degree', p, 'MSE', "%.2f" % round(mse, 2) , 'e_LOO', "%.5f" % e_loo)

        ## training optimal model ----------------------------

        opt = np.argmin(eloo_results)    #selected based 'eloo' instead 'mse'
        opt_1 = opt                      #for LOO variance enhancement
        theta_opt = np.array([opt_length_it[opt], v]) 

        modelpar1 = ModelName_1.train (xn, yn, int(opt+1), theta_opt) 

        ## Pool of samples for MCS -----------------------------------
        MCS_samples = 100000
        LOOCV = np.zeros(MCS_samples)
        
        MCinputs_norm = np.zeros((int(MCS_samples), dim))
        MCinputs = np.zeros((int(MCS_samples), dim))

        MCinputs_norm[:,0] = np.random.normal(0, 1, size=int(MCS_samples))
        MCinputs_norm[:,1] = np.random.normal(0, 1, size=int(MCS_samples))

        MCinputs[:,0] = PCK1.scalehermite(MCinputs_norm[:,0], x1mean, x1sigma)  
        MCinputs[:,1] = PCK1.scalehermite(MCinputs_norm[:,1], x2mean, x2sigma)  
    
        # Pf estimation ----------------------------------------------
        
            # ground truth ls
        ymc_1 = function_1(MCinputs)[0]  
        fail_samples_1 = np.sum(ymc_1 < 0 )
        Pf_ref_1 = fail_samples_1 / MCS_samples
        
            # surrogate ls
        meanMC_1, varMC_1 = ModelName_1.predict_fast(MCinputs_norm)    # mean, variance
        fail_samples_SUMO_1 = np.sum(np.asarray(meanMC_1) < 0 )
        fail_prob_SUMO_1 = fail_samples_SUMO_1 / MCS_samples

        cov_pf = np.sqrt((1 - fail_prob_SUMO_1 ) / (fail_prob_SUMO_1 * MCS_samples) )

        print('LS1: ','Degree', int(opt+1), 'e_LOO', np.min(eloo_results), 'Pf_ref',
                  Pf_ref_1 ,'Pf', fail_prob_SUMO_1 , 'CoV', "%.5f" % round(cov_pf, 4))

        #saving results ----------------------------

        ActiveTrain_1[str(len(xn))+'points'] = ModelName_1 , fail_prob_SUMO_1 , cov_pf , np.min(eloo_results), np.min(mse_results)
        
        # ##############################################################################
        # Active training of Limit State 2 #############################################
        
        ModelName_2 = 'PCK2_' + str(len(xn))
        
        ModelName_2 = PC_Kriging(config)
        
        # yn is changing for each LS 
        yn = yn_2
        YN = YN_2
        # Selecting the smallest e_loo model (length and order) 

        # OPTIMAL SURROGATE MODEL -----------------------------------
        for p in range(1, p_max):
            
            # results = dict()
            # bounds = [(lmin, lmax)]
            
            results['shgo'] = optimize.shgo(L_Object, bounds)
            opt_length = results['shgo']['x'][0]

            theta = np.array([opt_length, v])

            #Generating PCK models for each reduced design of experiments 

            for i in range (0, len(xn) ):

                yn_loo= np.delete(yn,[i])                            #y_n-i      leaving element i out the observations 
                xr_loo= np.delete(xr,[i*2,i*2+1]).reshape(-1,dim)    #x1r_n-i   leaving element i out the inputs (xr)
                xn_loo= np.delete(xn,[i*2,i*2+1]).reshape(-1,dim)    #x_n-i     leaving element i out the nomalized inputs (xn)

                #training LOO
                modelpar_loo = PCK_loo.train (xn_loo , yn_loo , p , theta )

                #predicting LOO over each removed sample
                mean_loo[i], var_loo[i] = PCK_loo.predict_fast(xn[i].reshape(1,-1))

            e_loo = np.mean (yn - mean_loo)**2              #LOO CV squared errors
            sumat_2[:,p-1] = np.divide(e_loo, var_loo)
            eloo_results[p-1] = e_loo

            #--------------------------------------- error over a set of test points
            modelpar2 = ModelName_2.train (xn, yn, p, theta) 
            mean0, var0 = ModelName_2.predict_fast(XN)    # test points predictions mean, variance

            mse = np.mean ((YN - mean0)**2)

            mse_results[p-1] = mse
            opt_length_it[p-1] = opt_length

    #         print('Degree', p, 'MSE', "%.2f" % round(mse, 2) , 'e_LOO', "%.5f" % e_loo)

        ## training optimal model ----------------------------

        opt = np.argmin(eloo_results)
        opt_2 = opt                      #for LOO variance enhancement
        theta_opt = np.array([opt_length_it[opt], v]) 

        modelpar2 = ModelName_2.train (xn, yn, int(opt+1), theta_opt) 

        # Pf estimation ----------------------------------------------
        
            # ground truth ls
        ymc_2 = function_2(MCinputs)[0]  
        fail_samples_2 = np.sum(ymc_2 < 0 )
        Pf_ref_2 = fail_samples_2 / MCS_samples
        
            # surrogate ls
        meanMC_2, varMC_2 = ModelName_2.predict_fast(MCinputs_norm)    # mean, variance
        fail_samples_SUMO_2 = np.sum(np.asarray(meanMC_2) < 0 )
        fail_prob_SUMO_2 = fail_samples_SUMO_2 / MCS_samples

        cov_pf = np.sqrt((1 - fail_prob_SUMO_2 ) / (fail_prob_SUMO_2 * MCS_samples) )        
        
        print('LS2: ','Degree', int(opt+1), 'e_LOO', np.min(eloo_results) , 'Pf_ref', 
              Pf_ref_2 ,'Pf', fail_prob_SUMO_2 , 'CoV', "%.5f" % round(cov_pf, 4))

        #saving results ----------------------------

        ActiveTrain_2[str(len(xn))+'points'] = ModelName_2 , fail_prob_SUMO_2 , cov_pf , np.min(eloo_results), np.min(mse_results)

        # ##############################################################################
        #choosing the limit state to improve
        if (training_limitstate == 1):
            meanMC = meanMC_1
            varMC = varMC_1
            sumat = sumat_1
            opt = opt_1                     
            
        elif (training_limitstate == 2):
            meanMC = meanMC_2
            varMC = varMC_2
            sumat = sumat_2
            opt = opt_2
            
        # LOO CV errors ###################################################
        #variance enhancement based LOO CV erros around voronoi cells
        
        for k in range (0, MCS_samples):               
            voro = VoronoiCell(MCinputs[k], xr)
            LOOCV[k]= varMC[k]*(1+sumat[voro, opt])     
        
        ### Evaluating new points
        U_f = U_function(meanMC.reshape(-1), LOOCV.reshape(-1))
        xr = np.append(xr, MCinputs[np.argmin(U_f)]).reshape(-1,2)
        xn = np.append(xn, MCinputs_norm[np.argmin(U_f)]).reshape(-1,2)
               
        yn_1 = function_1(xr)[0]
        yn_2 = function_2(xr)[0]
    
        print('number of training points: ', len(xn),'-------------------------------------------------')
    
    filename1 = 'Batch_'+ str(experiments+1) + results_file + 'p_LS1.sav'
    pickle.dump(ActiveTrain_1, open(filename1, 'wb'))
           
    filename2 = 'Batch_'+ str(experiments+1) + results_file + 'p_LS2.sav'
    pickle.dump(ActiveTrain_2, open(filename2, 'wb'))

# %% [markdown]
# # Active training - EFF - LOO - 2 LS

# %%
number_experiments = 15
number_active_points = 40

training_limitstate = 2

results_file = '_AT'+ str(training_limitstate) +'_EFFLOO_' + str(number_active_points)    # index for results files

for experiments in range(number_experiments):
    print('Experiment: ', experiments+1 , '#################################################################' )
    
    ActiveTrain_1 = {}   #results file { Surrogate , Pf, CoV_Pf , eLoo , mse }
    ActiveTrain_2 = {}   #results file { Surrogate , Pf, CoV_Pf , eLoo , mse }

    #INITIAL design of experiments (LHS) passive training ####################################

    n = 10       # number of initial sampling

    xn = np.zeros((int(n), dim))      #normalized training points
    xr = np.zeros((int(n), dim))      #scaled training points
    yn = np.zeros((int(n)))           #observations

    # Check the variables limits for space-filling distribution
    Xdoe = build.space_filling_lhs( {'x1':[-1, 1],      
                                     'x2':[-1, 1],} , 
                                      num_samples = n )
    #------------------------------------------------------------
    xn[:,0] = Xdoe['x1']
    xn[:,1] = Xdoe['x2']
    xr[:,0] = PCK1.scalehermite(xn[:,0], x1mean, x1sigma)
    xr[:,1] = PCK1.scalehermite(xn[:,1], x2mean, x2sigma)

    yn_1 = function_1(xr)[0]
    yn_2 = function_2(xr)[0]
    
    # kernel hyperparameters-------------------------------------
    v = 5/2        #Gaussian process
    #truncation term-------------------------------------
    p_max = 5  #for each variable → same truncation , degree of expansion
    
    for points in range(number_active_points):

        # Selecting the smallest e_loo model (length and order)
        
        mse_results = np.zeros(p_max-1)
        opt_length_it = np.zeros(p_max-1)
        eloo_results = np.zeros(p_max-1)

        mean_loo = np.zeros(len(xn))
        var_loo = np.zeros(len(xn))
        sumat_1 = np.zeros((len(xn),(p_max-1)))
        sumat_2 = np.zeros((len(xn),(p_max-1)))
        
        dist = PCK1.distance(xn, xn)
        lmax = np.max(dist)
        lmin = np.min(dist[dist!=0])
        bounds = [(lmin, lmax)]

        results = dict()
        
        # ##############################################################################
        # Active training of Limit State 1 #############################################

        ModelName_1 = 'PCK1_' + str(len(xn))
        
        ModelName_1 = PC_Kriging(config)

        # yn is changing for each LS (inside L_Object )
        yn = yn_1    #observations
        YN = YN_1    #test points

        # OPTIMAL SURROGATE MODEL -----------------------------------
        for p in range(1, p_max):

            results['shgo'] = optimize.shgo(L_Object, bounds)
            opt_length = results['shgo']['x'][0]

            theta = np.array([opt_length, v])

            #Generating PCK models for each reduced design of experiments 

            for i in range (0, len(xn) ):

                yn_loo= np.delete(yn,[i])                            #y_n-i      leaving element i out the observations 
                xr_loo= np.delete(xr,[i*2,i*2+1]).reshape(-1,dim)    #x1r_n-i   leaving element i out the inputs (xr)
                xn_loo= np.delete(xn,[i*2,i*2+1]).reshape(-1,dim)    #x_n-i     leaving element i out the nomalized inputs (xn)

                #training LOO
                modelpar_loo = PCK_loo.train (xn_loo , yn_loo , p , theta )

                #predicting LOO over each removed sample
                mean_loo[i], var_loo[i] = PCK_loo.predict_fast(xn[i].reshape(1,-1))

            e_loo = np.mean (yn - mean_loo)**2              #LOO CV squared errors
            sumat_1[:,p-1] = np.divide(e_loo, var_loo)
            eloo_results[p-1] = e_loo

            #--------------------------------------- error over a set of test points
            modelpar1 = ModelName_1.train (xn, yn, p, theta) 
            mean0, var0 = ModelName_1.predict_fast(XN)    # test points predictions mean, variance

            mse = np.mean ((YN - mean0)**2)

            mse_results[p-1] = mse
            opt_length_it[p-1] = opt_length

    #         print('Degree', p, 'MSE', "%.2f" % round(mse, 2) , 'e_LOO', "%.5f" % e_loo)

        ## training optimal model ----------------------------

        opt = np.argmin(eloo_results)    #selected based 'eloo' instead 'mse'
        opt_1 = opt                      #for LOO variance enhancement
        theta_opt = np.array([opt_length_it[opt], v]) 

        modelpar1 = ModelName_1.train (xn, yn, int(opt+1), theta_opt) 

        ## Pool of samples for MCS -----------------------------------
        MCS_samples = 100000
        LOOCV = np.zeros(MCS_samples)
        
        MCinputs_norm = np.zeros((int(MCS_samples), dim))
        MCinputs = np.zeros((int(MCS_samples), dim))

        MCinputs_norm[:,0] = np.random.normal(0, 1, size=int(MCS_samples))
        MCinputs_norm[:,1] = np.random.normal(0, 1, size=int(MCS_samples))

        MCinputs[:,0] = PCK1.scalehermite(MCinputs_norm[:,0], x1mean, x1sigma)  
        MCinputs[:,1] = PCK1.scalehermite(MCinputs_norm[:,1], x2mean, x2sigma)  
    
        # Pf estimation ----------------------------------------------
        
            # ground truth ls
        ymc_1 = function_1(MCinputs)[0]  
        fail_samples_1 = np.sum(ymc_1 < 0 )
        Pf_ref_1 = fail_samples_1 / MCS_samples
        
            # surrogate ls
        meanMC_1, varMC_1 = ModelName_1.predict_fast(MCinputs_norm)    # mean, variance
        fail_samples_SUMO_1 = np.sum(np.asarray(meanMC_1) < 0 )
        fail_prob_SUMO_1 = fail_samples_SUMO_1 / MCS_samples

        cov_pf = np.sqrt((1 - fail_prob_SUMO_1 ) / (fail_prob_SUMO_1 * MCS_samples) )

        print('LS1: ','Degree', int(opt+1), 'e_LOO', np.min(eloo_results), 'Pf_ref',
                  Pf_ref_1 ,'Pf', fail_prob_SUMO_1 , 'CoV', "%.5f" % round(cov_pf, 4))

        #saving results ----------------------------

        ActiveTrain_1[str(len(xn))+'points'] = ModelName_1 , fail_prob_SUMO_1 , cov_pf , np.min(eloo_results), np.min(mse_results)
        
        # ##############################################################################
        # Active training of Limit State 2 #############################################
        
        ModelName_2 = 'PCK2_' + str(len(xn))
        
        ModelName_2 = PC_Kriging(config)
        
        # yn is changing for each LS 
        yn = yn_2
        YN = YN_2
        # Selecting the smallest e_loo model (length and order) 

        # OPTIMAL SURROGATE MODEL -----------------------------------
        for p in range(1, p_max):
            
            # results = dict()
            # bounds = [(lmin, lmax)]
            
            results['shgo'] = optimize.shgo(L_Object, bounds)
            opt_length = results['shgo']['x'][0]

            theta = np.array([opt_length, v])

            #Generating PCK models for each reduced design of experiments 

            for i in range (0, len(xn) ):

                yn_loo= np.delete(yn,[i])                            #y_n-i      leaving element i out the observations 
                xr_loo= np.delete(xr,[i*2,i*2+1]).reshape(-1,dim)    #x1r_n-i   leaving element i out the inputs (xr)
                xn_loo= np.delete(xn,[i*2,i*2+1]).reshape(-1,dim)    #x_n-i     leaving element i out the nomalized inputs (xn)

                #training LOO
                modelpar_loo = PCK_loo.train (xn_loo , yn_loo , p , theta )

                #predicting LOO over each removed sample
                mean_loo[i], var_loo[i] = PCK_loo.predict_fast(xn[i].reshape(1,-1))

            e_loo = np.mean (yn - mean_loo)**2              #LOO CV squared errors
            sumat_2[:,p-1] = np.divide(e_loo, var_loo)
            eloo_results[p-1] = e_loo

            #--------------------------------------- error over a set of test points
            modelpar2 = ModelName_2.train (xn, yn, p, theta) 
            mean0, var0 = ModelName_2.predict_fast(XN)    # test points predictions mean, variance

            mse = np.mean ((YN - mean0)**2)

            mse_results[p-1] = mse
            opt_length_it[p-1] = opt_length

    #         print('Degree', p, 'MSE', "%.2f" % round(mse, 2) , 'e_LOO', "%.5f" % e_loo)

        ## training optimal model ----------------------------

        opt = np.argmin(eloo_results)
        opt_2 = opt                      #for LOO variance enhancement
        theta_opt = np.array([opt_length_it[opt], v]) 

        modelpar2 = ModelName_2.train (xn, yn, int(opt+1), theta_opt) 

        # Pf estimation ----------------------------------------------
        
            # ground truth ls
        ymc_2 = function_2(MCinputs)[0]  
        fail_samples_2 = np.sum(ymc_2 < 0 )
        Pf_ref_2 = fail_samples_2 / MCS_samples
        
            # surrogate ls
        meanMC_2, varMC_2 = ModelName_2.predict_fast(MCinputs_norm)    # mean, variance
        fail_samples_SUMO_2 = np.sum(np.asarray(meanMC_2) < 0 )
        fail_prob_SUMO_2 = fail_samples_SUMO_2 / MCS_samples

        cov_pf = np.sqrt((1 - fail_prob_SUMO_2 ) / (fail_prob_SUMO_2 * MCS_samples) )        
        
        print('LS2: ','Degree', int(opt+1), 'e_LOO', np.min(eloo_results) , 'Pf_ref', 
              Pf_ref_2 ,'Pf', fail_prob_SUMO_2 , 'CoV', "%.5f" % round(cov_pf, 4))

        #saving results ----------------------------

        ActiveTrain_2[str(len(xn))+'points'] = ModelName_2 , fail_prob_SUMO_2 , cov_pf , np.min(eloo_results), np.min(mse_results)

        # ##############################################################################
        #choosing the limit state to improve
        if (training_limitstate == 1):
            meanMC = meanMC_1
            varMC = varMC_1
            sumat = sumat_1
            opt = opt_1                     
            
        elif (training_limitstate == 2):
            meanMC = meanMC_2
            varMC = varMC_2
            sumat = sumat_2
            opt = opt_2
            
        # LOO CV errors ###################################################
        #variance enhancement based LOO CV erros around voronoi cells
        
        for k in range (0, MCS_samples):               
            voro = VoronoiCell(MCinputs[k], xr)
            LOOCV[k]= varMC[k]*(1+sumat[voro, opt])     
        
        ### Evaluating new points
        eff1 = EFF(meanMC.reshape(-1),LOOCV.reshape(-1) , 0 )

        xr = np.append(xr, MCinputs[np.argmax(eff1)]).reshape(-1,2)
        xn = np.append(xn, MCinputs_norm[np.argmax(eff1)]).reshape(-1,2)
                      
        yn_1 = function_1(xr)[0]
        yn_2 = function_2(xr)[0]
    
        print('number of training points: ', len(xn),'-------------------------------------------------')
    
    filename1 = 'Batch_'+ str(experiments+1) + results_file + 'p_LS1.sav'
    pickle.dump(ActiveTrain_1, open(filename1, 'wb'))
           
    filename2 = 'Batch_'+ str(experiments+1) + results_file + 'p_LS2.sav'
    pickle.dump(ActiveTrain_2, open(filename2, 'wb'))
