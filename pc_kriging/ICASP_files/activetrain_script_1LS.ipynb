# %%
import numpy as np
from pc_kriging import PC_Kriging
import matplotlib.pyplot as plt
from scipy.stats import norm
from doepy import build
from scipy import optimize
import pandas as pd
from numpy import genfromtxt
import pickle

from scipy.special import eval_legendre, eval_hermitenorm
import scipy.special

# adaptive learning - expected feasiability function --------------------------------------------------------------

def EFF(u,v,z):
    zl=-2*v
    zh=2*v
    return ((u-z)*( 2*norm.cdf((z-u)/v) - norm.cdf((zl-u)/v) - norm.cdf((zh-u)/v)) 
           -(v)*( 2*norm.pdf((z-u)/v) - norm.pdf((zl-u)/v) - norm.pdf((zh-u)/v))  
           +(2*v)*(norm.cdf((zh-u)/v) - norm.cdf((zl-u)/v)))

def U_function(u, v):
    return np.abs(u)/v

def LinearNorm(x,oldmin,oldmax,newmin,newmax):    # scaling linearly X to new domain limits
    return newmin + ((x-oldmin)*(newmax-newmin)/(oldmax-oldmin))


def VoronoiCell(x,xn):   #given x [single value] return the index of the closest xn [array]
    dist=PCK1.distance(x.reshape(1,-1),xn)
    return np.argmin(dist)

# %%
# #ground truth function----------------------------------------------------
# https://rprepo.readthedocs.io/en/latest/reliability_problems.html#rp201

def gfun_53(x):
    """Performance function for reliability problem 53.

    Parameters
    ----------
        x : numpy.array of float(s)
            Values of independent variables: columns are the different parameters/random variables (x1, x2,...xn) and rows are different parameter/random variables sets for different calls.

    Returns
    -------
        g_val_sys : numpy.array of float(s)
            Performance function value for the system.
        g_val_comp : numpy.array of float(s)
            Performance function value for each component.
        msg : str
            Accompanying diagnostic message, e.g. warning.
    """
#     import numpy as np
    # expected number of random variables/columns
    nrv_e = 2

    g = float('nan')
    msg = 'Ok'
    x = np.array(x, dtype='f')

    n_dim = len(x.shape)
    if n_dim == 1:
        x = np.array(x)[np.newaxis]
    elif n_dim > 2:
        msg = 'Only available for 1D and 2D arrays.'
        return float('nan'), float('nan'), msg

    nrv_p = x.shape[1]
    if nrv_p != nrv_e:
        msg = f'The number of random variables (x, columns) is expected to be {nrv_e} but {nrv_p} is provided!'
    else:
        g = np.sin(5*x[:, 0]/2) + 2 - (x[:, 0]**2 + 4)*(x[:, 1] - 1)/20

    g_val_sys = g
    g_val_comp = g
    return g_val_sys, g_val_comp, msg

# %%
config = {"pol_type": ['hermite', 'hermite']}   #design variables following normal distribution
PCK1 = PC_Kriging(config)
PCK_loo = PC_Kriging(config)    # for LOOCV with same 'config' as specified in the original model

# %%
# objective function to optimize length scale --------------------------------------------------------
def L_Object (l):
    v = 5/2
    N = len(xn)
    R = PCK1.matern(xn , xn, l, v)
    detR = np.linalg.det(R)
    
    modelpar2 = PCK1.train(xn, yn, p, np.array([l,v]))    # returns B, sig2, InfoMatrix(phi) , PolyIndices(alpha)
    ### ------------------Theta_ by UQLab User Manual PCK(C. Lataniotis, D. Wicaksono, S. Marelli, B. Sudret)------------------------------
    sig2 = modelpar2[1].reshape(-1)
    # return 0.5*(np.log(detR)+ N*np.log(2*np.pi*sig2)+ N)

    ### ------------------Theta_ by MLE PCK(Schobi,Sudret,Wiart)------------------------------
    FB = PCK1.InfoMat @ modelpar2[0]
    ins = (yn-FB).reshape(-1)
    R_1 = np.linalg.inv(R)
    return ((ins.T) @ R_1 @ ins) * (1/N) * (detR**(1/N))

# %% [markdown]
# ## Initial training

# %%
function = gfun_53   #choose the ground truth function
dim = 2       # dimensionality

ntest = 5000  # test points

x1mean, x1sigma = 1.5 , 1.0  # normal distribution 
x2mean, x2sigma = 2.5 , 1.0  # normal distribution 
    
# TEST POINTS -------------------------------------------------
XR = np.zeros((int(ntest), dim))   #normalized test points
XN = np.zeros((int(ntest), dim))  #scaled test points
YN = np.zeros(int(ntest)) 
#variable 1 ---------------------------------------------------
XN[:,0] = np.random.normal(0,1,ntest)  
XR[:,0] = PCK1.scalehermite(XN[:,0], x1mean, x1sigma)  
#variable 2 ---------------------------------------------------
XN[:,1] = np.random.normal(0,1,ntest)  
XR[:,1] = PCK1.scalehermite(XN[:,1], x2mean, x2sigma)  

YN = function(XR)[0]

# %% [markdown]
# # Active training - U - 1 LS

# %%
number_experiments = 15
number_active_points = 40

results_file = '_AT_U_' + str(number_active_points)   # index for results files

for experiments in range(number_experiments):
    print('Experiment: ', experiments+1 , '------------------------------------------------------------' )
    
    ActiveTrain = {}   #results file { Surrogate , Pf, CoV_Pf , eLoo , mse }

    #initial design of experiments (LHS) --------------------------------

    n = 10       # number of initial sampling

    xn = np.zeros((int(n), dim))      #normalized training points
    xr = np.zeros((int(n), dim))      #scaled training points
    yn = np.zeros((int(n)))           #observations

    mean_loo = np.zeros(len(xn))
    var_loo = np.zeros(len(xn))



    # Check the variables limits for space-filling distribution
    Xdoe = build.space_filling_lhs( {'x1':[-1, 1],      
                                     'x2':[-1, 1],} , 
                                      num_samples = n )
    #------------------------------------------------------------
    xn[:,0] = Xdoe['x1']
    xn[:,1] = Xdoe['x2']
    xr[:,0] = PCK1.scalehermite(xn[:,0], x1mean, x1sigma)
    xr[:,1] = PCK1.scalehermite(xn[:,1], x2mean, x2sigma)

    yn = function(xr)[0]

    for points in range(number_active_points):

        ModelName = 'PCK' + str(len(xn))

        ModelName = PC_Kriging(config)

        # Selecting the best model (length and order) 
        # kernel hyperparameters------------------------------
        v = 5/2
        
        #truncation term-------------------------------------
        p_max = 6  #for each variable → same truncation , degree of expansion

        mse_results = np.zeros(p_max-1)
        opt_length_it = np.zeros(p_max-1)

        mean_loo = np.zeros(len(xn))
        var_loo = np.zeros(len(xn))
        eloo_results = np.zeros(p_max-1)

        dist = PCK1.distance(xn, xn)
        lmax = np.max(dist)
        lmin = np.min(dist[dist!=0])

        # OPTIMAL SURROGATE MODEL -----------------------------------
        for p in range(1, p_max):
            results = dict()
            bounds = [(lmin, lmax)]
            results['shgo'] = optimize.shgo(L_Object, bounds)
            opt_length = results['shgo']['x'][0]

            theta = np.array([opt_length, v])

            #Generating PCK models for each reduced design of experiments 

            for i in range (0, len(xn) ):

                yn_loo= np.delete(yn,[i])                            #y_n-i      leaving element i out the observations 
                xr_loo= np.delete(xr,[i*2,i*2+1]).reshape(-1,dim)    #x1r_n-i   leaving element i out the inputs (xr)
                xn_loo= np.delete(xn,[i*2,i*2+1]).reshape(-1,dim)    #x_n-i     leaving element i out the nomalized inputs (xn)

                #training LOO
                modelpar_loo = PCK_loo.train (xn_loo , yn_loo , p , theta )

                #predicting LOO over each removed sample
                mean_loo[i], var_loo[i] = PCK_loo.predict_fast(xn[i].reshape(1,-1))

            e_loo = np.mean (yn - mean_loo)**2              #LOO CV squared errors

            eloo_results[p-1] = e_loo

            #--------------------------------------- error over a set of test points
            modelpar1 = ModelName.train (xn, yn, p, theta) 
            mean0, var0 = ModelName.predict_fast(XN)    # test points predictions mean, variance

            mse = np.mean ((YN - mean0)**2)

            mse_results[p-1] = mse
            opt_length_it[p-1] = opt_length

    #         print('Degree', p, 'MSE', "%.2f" % round(mse, 2) , 'e_LOO', "%.5f" % e_loo)

        ## training optimal model ----------------------------

        opt = np.argmin(eloo_results)    
        theta_opt = np.array([opt_length_it[opt], v]) 

        modelpar1 = ModelName.train (xn, yn, int(opt+1), theta_opt) 

        ## Pool of samples
        MCS_samples = 100000

        MCinputs_norm = np.zeros((int(MCS_samples), dim))
        MCinputs = np.zeros((int(MCS_samples), dim))

        MCinputs_norm[:,0] = np.random.normal(0, 1, size=int(MCS_samples))
        MCinputs_norm[:,1] = np.random.normal(0, 1, size=int(MCS_samples))

        MCinputs[:,0] = PCK1.scalehermite(MCinputs_norm[:,0], x1mean, x1sigma)  
        MCinputs[:,1] = PCK1.scalehermite(MCinputs_norm[:,1], x2mean, x2sigma)  

        # ---------------------------------------------------
        ymc = function(MCinputs)[0]  
        fail_samples = np.sum(ymc < 0 )
        Pf_ref = fail_samples/MCS_samples

        meanMC, varMC = ModelName.predict_fast(MCinputs_norm)    # mean, variance
        fail_samples_SUMO = np.sum(np.asarray(meanMC) < 0 )
        fail_prob_SUMO = fail_samples_SUMO / MCS_samples

        cov_pf = np.sqrt((1 - fail_prob_SUMO ) / (fail_prob_SUMO * MCS_samples) )


        print('Degree', int(opt+1), 'e_LOO', np.min(eloo_results) , 'Pf', fail_prob_SUMO , 'CoV', "%.5f" % round(cov_pf, 4))

        #saving results ----------------------------

        ActiveTrain[str(len(xn))+'points'] = ModelName , fail_prob_SUMO , cov_pf , np.min(eloo_results), np.min(mse_results)

        ### Evaluating new points
        U_f = U_function(meanMC.reshape(-1), varMC.reshape(-1))
        xr = np.append(xr, MCinputs[np.argmin(U_f)]).reshape(-1,2)
        xn = np.append(xn, MCinputs_norm[np.argmin(U_f)]).reshape(-1,2)
        yn = function(xr)[0] #Only one point needs to be evaluated here

        print('number of training points: ', len(xn))
        
    filename = 'Batch_'+ str(experiments+1) + results_file + 'p_LS1.sav'
    pickle.dump(ActiveTrain, open(filename, 'wb'))
# Out:
# Experiment:  1 ------------------------------------------------------------
# C:\Users\Administrator\anaconda3\envs\surrogate\lib\site-packages\ipykernel_launcher.py:8: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# Degree 2 e_LOO 0.00021014898237079835 Pf 0.09206 CoV 0.00990
# number of training points:  11
# Degree 1 e_LOO 0.0009081113509667807 Pf 0.06708 CoV 0.01180
# number of training points:  12
# Experiment:  2 ------------------------------------------------------------
# Degree 1 e_LOO 0.0025942726030455804 Pf 0.02479 CoV 0.01980
# number of training points:  11
# Degree 2 e_LOO 0.0002451406146415132 Pf 0.11081 CoV 0.00900
# number of training points:  12

# %% [markdown]
# # Active training - EFF - 1 LS

# %%
number_experiments = 15
number_active_points = 40

results_file = '_AT_EFF_' + str(number_active_points)    # index for results files

for experiments in range(number_experiments):
    print('Experiment: ', experiments+1 , '------------------------------------------------------------' )
    
    ActiveTrain = {}   #results file { Surrogate , Pf, CoV_Pf , eLoo , mse }

    #initial design of experiments (LHS) --------------------------------

    n = 10       # number of initial sampling

    xn = np.zeros((int(n), dim))      #normalized training points
    xr = np.zeros((int(n), dim))      #scaled training points
    yn = np.zeros((int(n)))           #observations

    mean_loo = np.zeros(len(xn))
    var_loo = np.zeros(len(xn))

    x1mean, x1sigma = 1.5 , 1.0  # normal distribution 
    x2mean, x2sigma = 2.5 , 1.0  # normal distribution 

    # Check the variables limits for space-filling distribution
    Xdoe = build.space_filling_lhs( {'x1':[-1, 1],      
                                     'x2':[-1, 1],} , 
                                      num_samples = n )
    #------------------------------------------------------------
    xn[:,0] = Xdoe['x1']
    xn[:,1] = Xdoe['x2']
    xr[:,0] = PCK1.scalehermite(xn[:,0], x1mean, x1sigma)
    xr[:,1] = PCK1.scalehermite(xn[:,1], x2mean, x2sigma)

    yn = function(xr)[0]

    for points in range(number_active_points):

        ModelName = 'PCK' + str(len(xn))

        ModelName = PC_Kriging(config)

        # Selecting the best model (length and order) 
        # kernel hyperparameters------------------------------
        v = 5/2
        #n = 11 
        #truncation term-------------------------------------
        p_max = 5  #for each variable → same truncation , degree of expansion

        mse_results = np.zeros(p_max-1)
        opt_length_it = np.zeros(p_max-1)

        mean_loo = np.zeros(len(xn))
        var_loo = np.zeros(len(xn))
        eloo_results = np.zeros(p_max-1)

        dist = PCK1.distance(xn, xn)
        lmax = np.max(dist)
        lmin = np.min(dist[dist!=0])

        # OPTIMAL SURROGATE MODEL -----------------------------------
        for p in range(1, p_max):
            results = dict()
            bounds = [(lmin, lmax)]
            results['shgo'] = optimize.shgo(L_Object, bounds)
            opt_length = results['shgo']['x'][0]

            theta = np.array([opt_length, v])

            #Generating PCK models for each reduced design of experiments 

            for i in range (0, len(xn) ):

                yn_loo= np.delete(yn,[i])                            #y_n-i      leaving element i out the observations 
                xr_loo= np.delete(xr,[i*2,i*2+1]).reshape(-1,dim)    #x1r_n-i   leaving element i out the inputs (xr)
                xn_loo= np.delete(xn,[i*2,i*2+1]).reshape(-1,dim)    #x_n-i     leaving element i out the nomalized inputs (xn)

                #training LOO
                modelpar_loo = PCK_loo.train (xn_loo , yn_loo , p , theta )

                #predicting LOO over each removed sample
                mean_loo[i], var_loo[i] = PCK_loo.predict_fast(xn[i].reshape(1,-1))

            e_loo = np.mean (yn - mean_loo)**2              #LOO CV squared errors

            eloo_results[p-1] = e_loo

            #--------------------------------------- error over a set of test points
            modelpar1 = PCK1.train (xn, yn, p, theta) 
            mean0, var0 = PCK1.predict_fast(XN)    # test points predictions mean, variance

            mse = np.mean ((YN - mean0)**2)

            mse_results[p-1] = mse
            opt_length_it[p-1] = opt_length

    #         print('Degree', p, 'MSE', "%.2f" % round(mse, 2) , 'e_LOO', "%.5f" % e_loo)

        ## training optimal model ----------------------------

        opt = np.argmin(eloo_results)    
        theta_opt = np.array([opt_length_it[opt], v]) 

        modelpar1 = ModelName.train (xn, yn, int(opt+1), theta_opt) 

        ## Pool of samples
        MCS_samples = 100000

        MCinputs_norm = np.zeros((int(MCS_samples), dim))
        MCinputs = np.zeros((int(MCS_samples), dim))

        MCinputs_norm[:,0] = np.random.normal(0, 1, size=int(MCS_samples))
        MCinputs_norm[:,1] = np.random.normal(0, 1, size=int(MCS_samples))

        MCinputs[:,0] = PCK1.scalehermite(MCinputs_norm[:,0], x1mean, x1sigma)  
        MCinputs[:,1] = PCK1.scalehermite(MCinputs_norm[:,1], x2mean, x2sigma)  

        # ---------------------------------------------------
        ymc = function(MCinputs)[0]  
        fail_samples = np.sum(ymc < 0 )
        Pf_ref = fail_samples/MCS_samples

        meanMC, varMC = ModelName.predict_fast(MCinputs_norm)    # mean, variance
        fail_samples_SUMO = np.sum(np.asarray(meanMC) < 0 )
        fail_prob_SUMO = fail_samples_SUMO / MCS_samples

        cov_pf = np.sqrt((1 - fail_prob_SUMO ) / (fail_prob_SUMO * MCS_samples) )


        print('Degree', int(opt+1), 'e_LOO', np.min(eloo_results) , 'Pf', fail_prob_SUMO , 'CoV', "%.5f" % round(cov_pf, 4))

        #saving results ----------------------------

        ActiveTrain[str(len(xn))+'points'] = ModelName , fail_prob_SUMO , cov_pf , np.min(eloo_results), np.min(mse_results)

        ### Evaluating new points
        eff1 = EFF(meanMC.reshape(-1),varMC.reshape(-1) , 0 )  #(mean, variance, target)  
        
        xr = np.append(xr, MCinputs[np.argmax(eff1)]).reshape(-1,2)
        xn = np.append(xn, MCinputs_norm[np.argmax(eff1)]).reshape(-1,2)
        yn = function(xr)[0] #Only one point needs to be evaluated here

        print('number of training points: ', len(xn))
    
    filename = 'Batch_'+ str(experiments+1) + results_file + 'p_LS1.sav'
    pickle.dump(ActiveTrain, open(filename, 'wb'))    #saving dictionary after each experiment
# Out:
# Experiment:  1 ------------------------------------------------------------
# C:\Users\Administrator\anaconda3\envs\surrogate\lib\site-packages\ipykernel_launcher.py:8: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# Degree 1 e_LOO 0.002328474726899101 Pf 0.07052 CoV 0.01150
# number of training points:  11
# Degree 3 e_LOO 0.005089218922686236 Pf 0.1078 CoV 0.00910
# number of training points:  12
# Degree 3 e_LOO 0.00791262397336823 Pf 0.10281 CoV 0.00930
# number of training points:  13
# Degree 1 e_LOO 0.0060862443055089335 Pf 0.014 CoV 0.02650
# number of training points:  14
# Degree 1 e_LOO 0.005670376101977913 Pf 0.008 CoV 0.03520
# number of training points:  15
# Degree 2 e_LOO 0.004662697633464333 Pf 0.01109 CoV 0.02990
# number of training points:  16
# Degree 1 e_LOO 9.223222008663385e-05 Pf 0.00269 CoV 0.06090
# number of training points:  17
# Degree 1 e_LOO 0.000507940031832551 Pf 0.02625 CoV 0.01930
# number of training points:  18
# Degree 1 e_LOO 0.0013870698837998132 Pf 0.02106 CoV 0.02160
# number of training points:  19
# Degree 1 e_LOO 0.0004905043116430428 Pf 0.02861 CoV 0.01840
# number of training points:  20
# Degree 1 e_LOO 0.0010054633426089354 Pf 0.02271 CoV 0.02070
# number of training points:  21
# Degree 1 e_LOO 0.0011445893212016641 Pf 0.0193 CoV 0.02250
# number of training points:  22
# Degree 2 e_LOO 0.00030737465194309767 Pf 0.01727 CoV 0.02390
# number of training points:  23
# Degree 2 e_LOO 0.00015248064837517262 Pf 0.01895 CoV 0.02280
# number of training points:  24
# Degree 2 e_LOO 0.00023191496777771967 Pf 0.0191 CoV 0.02270
# number of training points:  25
# Degree 2 e_LOO 7.194852009572104e-06 Pf 0.01012 CoV 0.03130
# number of training points:  26
# Degree 2 e_LOO 7.419542567077768e-05 Pf 0.00683 CoV 0.03810
# number of training points:  27
# Degree 2 e_LOO 0.0009090508061380786 Pf 0.00655 CoV 0.03890
# number of training points:  28
# Degree 2 e_LOO 0.00032813195702606837 Pf 0.00738 CoV 0.03670
# number of training points:  29
# Degree 2 e_LOO 6.468382598301246e-05 Pf 0.00855 CoV 0.03410
# number of training points:  30
# Degree 3 e_LOO 3.200052156459881e-06 Pf 0.00894 CoV 0.03330
# number of training points:  31
# Degree 2 e_LOO 4.781974797293733e-05 Pf 0.00797 CoV 0.03530
# number of training points:  32
# Degree 3 e_LOO 0.00016309772989058418 Pf 0.00959 CoV 0.03210
# number of training points:  33
# Degree 4 e_LOO 5.201832101594611e-05 Pf 0.00999 CoV 0.03150
# number of training points:  34
# Degree 3 e_LOO 8.173295590350742e-06 Pf 0.0094 CoV 0.03250
# number of training points:  35
# Degree 3 e_LOO 5.552931281239084e-05 Pf 0.0106 CoV 0.03060
# number of training points:  36
# Degree 3 e_LOO 1.627103378303035e-05 Pf 0.0094 CoV 0.03250
# number of training points:  37
# Degree 3 e_LOO 2.618147895876594e-06 Pf 0.01038 CoV 0.03090
# number of training points:  38
# Degree 1 e_LOO 6.932555715706562e-06 Pf 0.01014 CoV 0.03120
# number of training points:  39
# Degree 3 e_LOO 2.1260021661983664e-07 Pf 0.00982 CoV 0.03180
# number of training points:  40
# Experiment:  2 ------------------------------------------------------------
# Degree 1 e_LOO 0.000487533609581228 Pf 0.12122 CoV 0.00850
# number of training points:  11
# Degree 2 e_LOO 0.0001893962348015268 Pf 0.12025 CoV 0.00860
# number of training points:  12
# Degree 1 e_LOO 0.00157014799997363 Pf 0.12486 CoV 0.00840
# number of training points:  13
# Degree 2 e_LOO 0.025389284010292817 Pf 0.10599 CoV 0.00920
# number of training points:  14
# Degree 2 e_LOO 0.0014328175344333473 Pf 0.1083 CoV 0.00910
# number of training points:  15
# Degree 1 e_LOO 0.0063334820108282355 Pf 0.10731 CoV 0.00910
# number of training points:  16
# Degree 1 e_LOO 0.0006543316747489697 Pf 0.10694 CoV 0.00910
# number of training points:  17
# Degree 2 e_LOO 1.6125098004642216e-09 Pf 0.0866 CoV 0.01030
# number of training points:  18
# Degree 2 e_LOO 0.00010118174259933801 Pf 0.09853 CoV 0.00960
# number of training points:  19
# Degree 2 e_LOO 0.00013827114883879955 Pf 0.10692 CoV 0.00910
# number of training points:  20
# Degree 2 e_LOO 0.00033755179268043204 Pf 0.09086 CoV 0.01000
# number of training points:  21
# Degree 2 e_LOO 0.00034048577738737953 Pf 0.0903 CoV 0.01000
# number of training points:  22
# Degree 3 e_LOO 2.928154877983315e-07 Pf 0.09091 CoV 0.01000
# number of training points:  23
# Degree 2 e_LOO 0.0006788658224445968 Pf 0.08352 CoV 0.01050
# number of training points:  24
# Degree 2 e_LOO 9.191517565348453e-08 Pf 0.02174 CoV 0.02120
# number of training points:  25
# Degree 1 e_LOO 2.5134328188237373e-05 Pf 0.02009 CoV 0.02210
# number of training points:  26
# Degree 1 e_LOO 2.1249406879172013e-05 Pf 0.01989 CoV 0.02220
# number of training points:  27
# Degree 1 e_LOO 1.108845826375105e-05 Pf 0.01958 CoV 0.02240
# number of training points:  28
# Degree 4 e_LOO 1.962981992134286e-05 Pf 0.02475 CoV 0.01990
# number of training points:  29
# Degree 2 e_LOO 2.5469183579594217e-05 Pf 0.01608 CoV 0.02470
# number of training points:  30
# Degree 3 e_LOO 1.7813936955831535e-05 Pf 0.01789 CoV 0.02340
# number of training points:  31
# Degree 2 e_LOO 4.943602423854002e-06 Pf 0.01725 CoV 0.02390
# number of training points:  32
# Degree 3 e_LOO 2.840914083903908e-06 Pf 0.01863 CoV 0.02300
# number of training points:  33
# Degree 2 e_LOO 4.448377246049667e-07 Pf 0.01604 CoV 0.02480
# number of training points:  34
# Degree 2 e_LOO 9.87146568077221e-06 Pf 0.01761 CoV 0.02360
# number of training points:  35
# Degree 2 e_LOO 1.5723801554861146e-06 Pf 0.01706 CoV 0.02400
# number of training points:  36
# Degree 3 e_LOO 3.1079836276856604e-09 Pf 0.01737 CoV 0.02380
# number of training points:  37
# Degree 1 e_LOO 2.264524123012165e-06 Pf 0.01804 CoV 0.02330
# number of training points:  38
# Degree 2 e_LOO 5.256125501954857e-06 Pf 0.01782 CoV 0.02350
# number of training points:  39
# Degree 2 e_LOO 1.3958501269773767e-06 Pf 0.01782 CoV 0.02350
# number of training points:  40
# Experiment:  3 ------------------------------------------------------------
# Degree 1 e_LOO 0.003981277027197025 Pf 0.09758 CoV 0.00960
# number of training points:  11
# Degree 1 e_LOO 0.0008052698203437612 Pf 0.10484 CoV 0.00920
# number of training points:  12
# Degree 2 e_LOO 0.007242377362002843 Pf 0.07478 CoV 0.01110
# number of training points:  13
# Degree 1 e_LOO 5.715007031774369e-06 Pf 0.06098 CoV 0.01240
# number of training points:  14
# Degree 1 e_LOO 0.00016355316186667996 Pf 0.05744 CoV 0.01280
# number of training points:  15
# Degree 1 e_LOO 0.001943394233843127 Pf 0.09434 CoV 0.00980
# number of training points:  16
# Degree 1 e_LOO 0.001502692953955045 Pf 0.09352 CoV 0.00980
# number of training points:  17
# Degree 1 e_LOO 0.0008617887813192377 Pf 0.07379 CoV 0.01120
# number of training points:  18
# Degree 1 e_LOO 0.0004109559409592755 Pf 0.06968 CoV 0.01160
# number of training points:  19
# Degree 1 e_LOO 2.1282747508607105e-06 Pf 0.07433 CoV 0.01120
# number of training points:  20
# Degree 2 e_LOO 0.0002170342146009789 Pf 0.05615 CoV 0.01300
# number of training points:  21
# Degree 3 e_LOO 0.00021830667674453192 Pf 0.06444 CoV 0.01200
# number of training points:  22
# Degree 2 e_LOO 1.7513168080595503e-05 Pf 0.04141 CoV 0.01520
# number of training points:  23
# Degree 2 e_LOO 0.0007842393872766443 Pf 0.01177 CoV 0.02900
# number of training points:  24
# Degree 2 e_LOO 0.002306249593652436 Pf 0.01175 CoV 0.02900
# number of training points:  25
# Degree 2 e_LOO 0.0031835102431202037 Pf 0.01323 CoV 0.02730
# number of training points:  26
# Degree 2 e_LOO 0.0021425568985927205 Pf 0.01266 CoV 0.02790
# number of training points:  27
# Degree 2 e_LOO 7.725032121221886e-05 Pf 0.01305 CoV 0.02750
# number of training points:  28
# Degree 3 e_LOO 0.00010290908565686917 Pf 0.01939 CoV 0.02250
# number of training points:  29
# Degree 3 e_LOO 0.0002323126306984708 Pf 0.01664 CoV 0.02430
# number of training points:  30
# Degree 4 e_LOO 6.797060007597797e-06 Pf 0.0166 CoV 0.02430
# number of training points:  31
# Degree 1 e_LOO 0.000236492215325345 Pf 0.01302 CoV 0.02750
# number of training points:  32
# Degree 2 e_LOO 3.102363825565122e-05 Pf 0.01274 CoV 0.02780
# number of training points:  33
# Degree 3 e_LOO 4.230168329913717e-05 Pf 0.01128 CoV 0.02960
# number of training points:  34
# Degree 2 e_LOO 1.8505058936917529e-07 Pf 0.01128 CoV 0.02960
# number of training points:  35
# Degree 3 e_LOO 0.00028389734649162627 Pf 0.01147 CoV 0.02940
# number of training points:  36
# Degree 3 e_LOO 0.0008218312898288422 Pf 0.01146 CoV 0.02940
# number of training points:  37
# Degree 3 e_LOO 0.0006076012308697605 Pf 0.01188 CoV 0.02880
# number of training points:  38
# Degree 3 e_LOO 0.00037499905993942955 Pf 0.01162 CoV 0.02920
# number of training points:  39
# Degree 3 e_LOO 0.0006675881519275072 Pf 0.01162 CoV 0.02920
# number of training points:  40
# Experiment:  4 ------------------------------------------------------------
# Degree 1 e_LOO 0.002745609610418422 Pf 0.08186 CoV 0.01060
# number of training points:  11
# Degree 1 e_LOO 0.02391714683425778 Pf 0.13491 CoV 0.00800
# number of training points:  12
# Degree 1 e_LOO 3.1915697153927166e-05 Pf 0.12098 CoV 0.00850
# number of training points:  13
# Degree 2 e_LOO 0.0018808195626974762 Pf 0.10234 CoV 0.00940
# number of training points:  14
# Degree 1 e_LOO 0.021236584257827658 Pf 0.08904 CoV 0.01010
# number of training points:  15
# Degree 1 e_LOO 0.025842721652379403 Pf 0.08622 CoV 0.01030
# number of training points:  16
# Degree 2 e_LOO 0.0002891820138581591 Pf 0.07211 CoV 0.01130
# number of training points:  17
# Degree 2 e_LOO 0.0004181734627905606 Pf 0.07041 CoV 0.01150
# number of training points:  18
# Degree 2 e_LOO 0.0022761414375471133 Pf 0.07647 CoV 0.01100
# number of training points:  19
# Degree 2 e_LOO 0.004014138763035108 Pf 0.08893 CoV 0.01010
# number of training points:  20
# Degree 2 e_LOO 0.00017124106374982235 Pf 0.02901 CoV 0.01830
# number of training points:  21
# Degree 2 e_LOO 3.372345701824622e-05 Pf 0.01673 CoV 0.02420
# number of training points:  22
# Degree 2 e_LOO 0.00015277039964900873 Pf 0.01625 CoV 0.02460
# number of training points:  23
# Degree 2 e_LOO 0.0006832520688453992 Pf 0.01653 CoV 0.02440
# number of training points:  24
# Degree 2 e_LOO 0.001060145468819621 Pf 0.0147 CoV 0.02590
# number of training points:  25
# Degree 2 e_LOO 0.0009864214296826641 Pf 0.01579 CoV 0.02500
# number of training points:  26
# Degree 2 e_LOO 0.0004961926091523602 Pf 0.01591 CoV 0.02490
# number of training points:  27
# Degree 2 e_LOO 0.0002612322986822117 Pf 0.01681 CoV 0.02420
# number of training points:  28
# Degree 2 e_LOO 0.0006411559554387612 Pf 0.01634 CoV 0.02450
# number of training points:  29
# Degree 2 e_LOO 0.000644144018269784 Pf 0.01646 CoV 0.02440
# number of training points:  30
# Degree 2 e_LOO 0.0013867753085513711 Pf 0.0153 CoV 0.02540
# number of training points:  31
# Degree 3 e_LOO 0.000458044622991926 Pf 0.01191 CoV 0.02880
# number of training points:  32
# Degree 4 e_LOO 0.0013316538167617176 Pf 0.01163 CoV 0.02920
# number of training points:  33
# Degree 3 e_LOO 0.0002512321670446834 Pf 0.0117 CoV 0.02910
# number of training points:  34
# Degree 3 e_LOO 9.690278585136621e-05 Pf 0.01083 CoV 0.03020
# number of training points:  35
# Degree 4 e_LOO 1.189810855352016e-05 Pf 0.01049 CoV 0.03070
# number of training points:  36
# Degree 1 e_LOO 3.899314744521738e-05 Pf 0.02003 CoV 0.02210
# number of training points:  37
# Degree 1 e_LOO 1.8491249963919453e-05 Pf 0.01987 CoV 0.02220
# number of training points:  38
# Degree 1 e_LOO 2.78245791014769e-05 Pf 0.01948 CoV 0.02240
# number of training points:  39
# Degree 2 e_LOO 2.0151915964913432e-05 Pf 0.01394 CoV 0.02660
# number of training points:  40
# Experiment:  5 ------------------------------------------------------------
# Degree 1 e_LOO 1.3717137481588692e-05 Pf 0.11016 CoV 0.00900
# number of training points:  11
# Degree 1 e_LOO 0.0058699493309854614 Pf 0.086 CoV 0.01030
# number of training points:  12
# Degree 3 e_LOO 5.985195053940978e-05 Pf 0.18359 CoV 0.00670
# number of training points:  13
# Degree 1 e_LOO 1.4418074691483152e-05 Pf 0.00106 CoV 0.09710
# number of training points:  14
# Degree 1 e_LOO 0.00013929480028418545 Pf 0.00166 CoV 0.07760
# number of training points:  15
# Degree 1 e_LOO 0.005554126298970405 Pf 0.03184 CoV 0.01740
# number of training points:  16
# Degree 1 e_LOO 0.0021915026477159626 Pf 0.02672 CoV 0.01910
# number of training points:  17
# Degree 1 e_LOO 0.0031451663255228344 Pf 0.01348 CoV 0.02710
# number of training points:  18
# Degree 1 e_LOO 0.001988835230831172 Pf 0.00491 CoV 0.04500
# number of training points:  19
# Degree 1 e_LOO 0.00025030881670747967 Pf 0.00906 CoV 0.03310
# number of training points:  20
# Degree 1 e_LOO 1.9352539751972552e-05 Pf 0.00928 CoV 0.03270
# number of training points:  21
# Degree 1 e_LOO 0.0003792811733900033 Pf 0.00825 CoV 0.03470
# number of training points:  22
# Degree 1 e_LOO 0.0005348473490012057 Pf 0.00662 CoV 0.03870
# number of training points:  23
# Degree 1 e_LOO 0.00012939320641315027 Pf 0.00674 CoV 0.03840
# number of training points:  24
# Degree 2 e_LOO 0.0005011508541902849 Pf 0.00718 CoV 0.03720
# number of training points:  25
# Degree 3 e_LOO 5.853662009239636e-07 Pf 0.00896 CoV 0.03330
# number of training points:  26
# Degree 2 e_LOO 1.8704311895699855e-05 Pf 0.00728 CoV 0.03690
# number of training points:  27
# Degree 1 e_LOO 4.5927303672735865e-05 Pf 0.0088 CoV 0.03360
# number of training points:  28
# Degree 1 e_LOO 1.0918341226326454e-05 Pf 0.00928 CoV 0.03270
# number of training points:  29
# Degree 1 e_LOO 2.8127700488730504e-05 Pf 0.00889 CoV 0.03340
# number of training points:  30
# Degree 1 e_LOO 9.598762591065743e-06 Pf 0.00894 CoV 0.03330
# number of training points:  31
# Degree 1 e_LOO 3.39002377037872e-05 Pf 0.00914 CoV 0.03290
# number of training points:  32
# Degree 2 e_LOO 1.2032919197205802e-05 Pf 0.00911 CoV 0.03300
# number of training points:  33
# Degree 1 e_LOO 0.00010491713777200389 Pf 0.0089 CoV 0.03340
# number of training points:  34
# Degree 2 e_LOO 4.005891069951176e-05 Pf 0.02521 CoV 0.01970
# number of training points:  35
# Degree 2 e_LOO 1.47894910717082e-05 Pf 0.02352 CoV 0.02040
# number of training points:  36
# Degree 1 e_LOO 2.2591357279347714e-06 Pf 0.03851 CoV 0.01580
# number of training points:  37
# Degree 1 e_LOO 1.5021843158774367e-08 Pf 0.03512 CoV 0.01660
# number of training points:  38
# Degree 1 e_LOO 6.253914071258888e-08 Pf 0.03393 CoV 0.01690
# number of training points:  39
# Degree 1 e_LOO 9.953990248139155e-07 Pf 0.03451 CoV 0.01670
# number of training points:  40
# Experiment:  6 ------------------------------------------------------------
# Degree 1 e_LOO 0.00195434660600807 Pf 0.10458 CoV 0.00930
# number of training points:  11
# Degree 1 e_LOO 0.06814928958468716 Pf 0.06173 CoV 0.01230
# number of training points:  12
# Degree 1 e_LOO 0.006744941129095673 Pf 0.09534 CoV 0.00970
# number of training points:  13
# Degree 1 e_LOO 9.240982016629933e-05 Pf 0.0977 CoV 0.00960
# number of training points:  14
# Degree 1 e_LOO 0.004851431583096576 Pf 0.09619 CoV 0.00970
# number of training points:  15
# Degree 1 e_LOO 7.097587903325947e-06 Pf 0.09044 CoV 0.01000
# number of training points:  16
# Degree 2 e_LOO 4.773339719537116e-06 Pf 0.10067 CoV 0.00950
# number of training points:  17
# Degree 2 e_LOO 0.000631442455819774 Pf 0.09882 CoV 0.00950
# number of training points:  18
# Degree 2 e_LOO 4.524457084246452e-05 Pf 0.09584 CoV 0.00970
# number of training points:  19
# Degree 2 e_LOO 0.003674469644006311 Pf 0.09375 CoV 0.00980
# number of training points:  20
# Degree 2 e_LOO 0.024981405457535584 Pf 0.10317 CoV 0.00930
# number of training points:  21
# Degree 2 e_LOO 0.025192828587903622 Pf 0.1038 CoV 0.00930
# number of training points:  22
# Degree 2 e_LOO 0.022710005597577358 Pf 0.10643 CoV 0.00920
# number of training points:  23
# Degree 1 e_LOO 0.015751246922259265 Pf 0.10191 CoV 0.00940
# number of training points:  24
# Degree 4 e_LOO 1.5605813430865187e-05 Pf 0.10393 CoV 0.00930
# number of training points:  25
# Degree 2 e_LOO 0.001547139599697251 Pf 0.10212 CoV 0.00940
# number of training points:  26
# Degree 2 e_LOO 5.469124515135464e-05 Pf 0.05049 CoV 0.01370
# number of training points:  27
# Degree 2 e_LOO 3.277383690902473e-06 Pf 0.01892 CoV 0.02280
# number of training points:  28
# Degree 4 e_LOO 5.991908826158315e-05 Pf 0.01089 CoV 0.03010
# number of training points:  29
# Degree 4 e_LOO 0.00011863498251469264 Pf 0.01139 CoV 0.02950
# number of training points:  30
# Degree 2 e_LOO 5.3863166214925486e-05 Pf 0.01315 CoV 0.02740
# number of training points:  31
# Degree 4 e_LOO 8.23149198522168e-06 Pf 0.01115 CoV 0.02980
# number of training points:  32
# Degree 4 e_LOO 0.00036075958270277334 Pf 0.01114 CoV 0.02980
# number of training points:  33
# Degree 3 e_LOO 0.003685369746676651 Pf 0.01084 CoV 0.03020
# number of training points:  34
# Degree 2 e_LOO 0.003988831945915805 Pf 0.01418 CoV 0.02640
# number of training points:  35
# Degree 2 e_LOO 0.0031397004509665697 Pf 0.01353 CoV 0.02700
# number of training points:  36
# Degree 3 e_LOO 0.0019482914036756764 Pf 0.01039 CoV 0.03090
# number of training points:  37
# Degree 4 e_LOO 0.0005536759549196768 Pf 0.01074 CoV 0.03030
# number of training points:  38
# Degree 4 e_LOO 0.0003786520424274373 Pf 0.01119 CoV 0.02970
# number of training points:  39
# Degree 4 e_LOO 0.0020770511994679663 Pf 0.01228 CoV 0.02840
# number of training points:  40
# Experiment:  7 ------------------------------------------------------------
# Degree 1 e_LOO 0.000943683326169192 Pf 0.0891 CoV 0.01010
# number of training points:  11
# Degree 1 e_LOO 0.00020077232417652907 Pf 0.1107 CoV 0.00900
# number of training points:  12
# Degree 1 e_LOO 0.06638977653507552 Pf 0.03874 CoV 0.01580
# number of training points:  13
# Degree 1 e_LOO 0.0040128779242518 Pf 0.00893 CoV 0.03330
# number of training points:  14
# Degree 2 e_LOO 7.107138382701552e-05 Pf 0.04287 CoV 0.01490
# number of training points:  15
# Degree 1 e_LOO 0.01443431400152952 Pf 0.00346 CoV 0.05370
# number of training points:  16
# Degree 2 e_LOO 0.014397086424363372 Pf 0.0592 CoV 0.01260
# number of training points:  17
# Degree 2 e_LOO 0.00772887342186535 Pf 0.06393 CoV 0.01210
# number of training points:  18
# Degree 3 e_LOO 0.0027348066640476235 Pf 0.1071 CoV 0.00910
# number of training points:  19
# Degree 2 e_LOO 0.00033339003202633913 Pf 0.06884 CoV 0.01160
# number of training points:  20
# Degree 2 e_LOO 0.0019348164374028646 Pf 0.05784 CoV 0.01280
# number of training points:  21
# Degree 1 e_LOO 0.004576662244465607 Pf 0.07503 CoV 0.01110
# number of training points:  22
# Degree 1 e_LOO 0.0018171132037234693 Pf 0.07636 CoV 0.01100
# number of training points:  23
# Degree 2 e_LOO 0.002481556644775098 Pf 0.04278 CoV 0.01500
# number of training points:  24
# Degree 2 e_LOO 0.0014727655108478324 Pf 0.06346 CoV 0.01210
# number of training points:  25
# Degree 2 e_LOO 1.9571945462934854e-05 Pf 0.0627 CoV 0.01220
# number of training points:  26
# Degree 2 e_LOO 8.239116610481859e-06 Pf 0.06429 CoV 0.01210
# number of training points:  27
# Degree 2 e_LOO 0.0023400322144699654 Pf 0.06572 CoV 0.01190
# number of training points:  28
# Degree 3 e_LOO 0.001341758655320609 Pf 0.03448 CoV 0.01670
# number of training points:  29
# Degree 2 e_LOO 0.000876756339539703 Pf 0.06293 CoV 0.01220
# number of training points:  30
# Degree 4 e_LOO 6.097929018686795e-05 Pf 0.04478 CoV 0.01460
# number of training points:  31
# Degree 2 e_LOO 0.0007166633575173156 Pf 0.06277 CoV 0.01220
# number of training points:  32
# Degree 2 e_LOO 1.7835416582535585e-05 Pf 0.01557 CoV 0.02510
# number of training points:  33
# Degree 4 e_LOO 0.0005110384355431529 Pf 0.0164 CoV 0.02450
# number of training points:  34
# Degree 4 e_LOO 3.326225769747151e-05 Pf 0.01712 CoV 0.02400
# number of training points:  35
# Degree 3 e_LOO 0.0004427001450223399 Pf 0.01801 CoV 0.02340
# number of training points:  36
# Degree 2 e_LOO 3.9740233232231795e-05 Pf 0.01511 CoV 0.02550
# number of training points:  37
# Degree 2 e_LOO 6.515361808491192e-05 Pf 0.01563 CoV 0.02510
# number of training points:  38
# Degree 2 e_LOO 0.00021604778246927232 Pf 0.01433 CoV 0.02620
# number of training points:  39
# Degree 2 e_LOO 0.0005128240592577013 Pf 0.01483 CoV 0.02580
# number of training points:  40
# Experiment:  8 ------------------------------------------------------------
# Degree 2 e_LOO 0.0013947526596933748 Pf 0.04151 CoV 0.01520
# number of training points:  11
# Degree 1 e_LOO 0.06873217174530555 Pf 0.0636 CoV 0.01210
# number of training points:  12
# Degree 2 e_LOO 0.04035147022683205 Pf 0.05219 CoV 0.01350
# number of training points:  13
# Degree 1 e_LOO 0.01036710884444085 Pf 0.03745 CoV 0.01600
# number of training points:  14
# Degree 2 e_LOO 0.004042696171447771 Pf 0.04585 CoV 0.01440
# number of training points:  15
# Degree 2 e_LOO 0.07643426509867311 Pf 0.03561 CoV 0.01650
# number of training points:  16
# Degree 1 e_LOO 0.1550701303854537 Pf 0.03375 CoV 0.01690
# number of training points:  17
# Degree 2 e_LOO 0.0011215079906260425 Pf 0.03071 CoV 0.01780
# number of training points:  18
# Degree 2 e_LOO 8.497629715053619e-06 Pf 0.02844 CoV 0.01850
# number of training points:  19
# Degree 2 e_LOO 0.00011395461911308786 Pf 0.02543 CoV 0.01960
# number of training points:  20
# Degree 2 e_LOO 0.003932544180989259 Pf 0.00738 CoV 0.03670
# number of training points:  21
# Degree 2 e_LOO 0.0005882325270103423 Pf 0.02011 CoV 0.02210
# number of training points:  22
# Degree 2 e_LOO 0.0005390454977638809 Pf 0.02535 CoV 0.01960
# number of training points:  23
# Degree 2 e_LOO 0.004402954987394025 Pf 0.02763 CoV 0.01880
# number of training points:  24
# Degree 2 e_LOO 0.003105193358425001 Pf 0.03046 CoV 0.01780
# number of training points:  25
# Degree 2 e_LOO 0.0002391761317424791 Pf 0.03011 CoV 0.01790
# number of training points:  26
# Degree 2 e_LOO 2.2435513244539324e-05 Pf 0.02761 CoV 0.01880
# number of training points:  27
# Degree 2 e_LOO 0.0011556285677318413 Pf 0.02847 CoV 0.01850
# number of training points:  28
# Degree 2 e_LOO 0.0013355218456393835 Pf 0.0293 CoV 0.01820
# number of training points:  29
# Degree 2 e_LOO 0.00045371463248935134 Pf 0.01417 CoV 0.02640
# number of training points:  30
# Degree 2 e_LOO 8.413405125445855e-05 Pf 0.01527 CoV 0.02540
# number of training points:  31
# Degree 2 e_LOO 0.00017046426428068945 Pf 0.01543 CoV 0.02530
# number of training points:  32
# Degree 2 e_LOO 0.0036270023878368324 Pf 0.01407 CoV 0.02650
# number of training points:  33
# Degree 2 e_LOO 0.004890847131187968 Pf 0.01524 CoV 0.02540
# number of training points:  34
# Degree 2 e_LOO 0.004210991396781753 Pf 0.01255 CoV 0.02810
# number of training points:  35
# Degree 3 e_LOO 0.002618245362822977 Pf 0.01231 CoV 0.02830
# number of training points:  36
# Degree 4 e_LOO 1.838933357282601e-06 Pf 0.01367 CoV 0.02690
# number of training points:  37
# Degree 3 e_LOO 0.00015942127724759628 Pf 0.01319 CoV 0.02740
# number of training points:  38
# Degree 3 e_LOO 2.2268334855805354e-05 Pf 0.01293 CoV 0.02760
# number of training points:  39
# Degree 4 e_LOO 8.156594750495778e-05 Pf 0.01155 CoV 0.02930
# number of training points:  40
# Experiment:  9 ------------------------------------------------------------
# Degree 1 e_LOO 0.0044403462552509215 Pf 0.06301 CoV 0.01220
# number of training points:  11
# Degree 1 e_LOO 0.01653339827629257 Pf 0.03263 CoV 0.01720
# number of training points:  12
# Degree 1 e_LOO 0.06559771080281283 Pf 0.00261 CoV 0.06180
# number of training points:  13
# Degree 1 e_LOO 0.1232268609639503 Pf 0.00381 CoV 0.05110
# number of training points:  14
# Degree 2 e_LOO 0.05377986559495591 Pf 0.02136 CoV 0.02140
# number of training points:  15
# Degree 2 e_LOO 0.011584239719375184 Pf 0.0203 CoV 0.02200
# number of training points:  16
# Degree 2 e_LOO 0.00853385068976761 Pf 0.02847 CoV 0.01850
# number of training points:  17
# Degree 2 e_LOO 0.001507391626669872 Pf 0.02779 CoV 0.01870
# number of training points:  18
# Degree 3 e_LOO 0.00038363976901899526 Pf 0.09347 CoV 0.00980
# number of training points:  19
# Degree 3 e_LOO 0.0001011131031506993 Pf 0.11449 CoV 0.00880
# number of training points:  20
# Degree 1 e_LOO 0.021524679032611675 Pf 0.07054 CoV 0.01150
# number of training points:  21
# Degree 2 e_LOO 0.011150823872984326 Pf 0.05657 CoV 0.01290
# number of training points:  22
# Degree 2 e_LOO 0.009769037056864702 Pf 0.07509 CoV 0.01110
# number of training points:  23
# Degree 2 e_LOO 0.009408463162326793 Pf 0.07524 CoV 0.01110
# number of training points:  24
# Degree 2 e_LOO 0.010075134240481613 Pf 0.0735 CoV 0.01120
# number of training points:  25
# Degree 2 e_LOO 0.0017829706592545891 Pf 0.07402 CoV 0.01120
# number of training points:  26
# Degree 2 e_LOO 0.0013567405921425032 Pf 0.06825 CoV 0.01170
# number of training points:  27
# Degree 2 e_LOO 0.0011494858342340792 Pf 0.06498 CoV 0.01200
# number of training points:  28
# Degree 2 e_LOO 1.0462862284362036e-05 Pf 0.06509 CoV 0.01200
# number of training points:  29
# Degree 4 e_LOO 5.201607580604827e-09 Pf 0.04764 CoV 0.01410
# number of training points:  30
# Degree 3 e_LOO 0.0002015006330251971 Pf 0.05672 CoV 0.01290
# number of training points:  31
# Degree 3 e_LOO 0.00012987340481847046 Pf 0.05495 CoV 0.01310
# number of training points:  32
# Degree 2 e_LOO 0.0005530745801975693 Pf 0.06941 CoV 0.01160
# number of training points:  33
# Degree 2 e_LOO 2.3215198904156506e-05 Pf 0.02397 CoV 0.02020
# number of training points:  34
# Degree 2 e_LOO 2.322724834891692e-05 Pf 0.02346 CoV 0.02040
# number of training points:  35
# Degree 2 e_LOO 1.3897301568929158e-06 Pf 0.01648 CoV 0.02440
# number of training points:  36
# Degree 4 e_LOO 4.495884166178114e-05 Pf 0.01122 CoV 0.02970
# number of training points:  37
# Degree 2 e_LOO 8.480329429031133e-08 Pf 0.01554 CoV 0.02520
# number of training points:  38
# Degree 2 e_LOO 6.096754268230917e-06 Pf 0.01463 CoV 0.02600
# number of training points:  39
# Degree 2 e_LOO 9.861932775183201e-05 Pf 0.01483 CoV 0.02580
# number of training points:  40
# Experiment:  10 ------------------------------------------------------------
# Degree 1 e_LOO 0.014568640581209625 Pf 0.04735 CoV 0.01420
# number of training points:  11
# Degree 3 e_LOO 0.006026680171490102 Pf 0.16626 CoV 0.00710
# number of training points:  12
# Degree 2 e_LOO 0.00014760394989697304 Pf 0.00359 CoV 0.05270
# number of training points:  13
# Degree 1 e_LOO 0.03174255806563008 Pf 4e-05 CoV 0.50000
# number of training points:  14
# C:\Users\Administrator\anaconda3\envs\surrogate\lib\site-packages\ipykernel_launcher.py:127: RuntimeWarning: divide by zero encountered in double_scalars
# Degree 1 e_LOO 0.045632024508420944 Pf 0.0 CoV inf
# number of training points:  15
# Degree 1 e_LOO 0.0029736503539422744 Pf 0.00128 CoV 0.08830
# number of training points:  16
# Degree 1 e_LOO 0.004716338978831698 Pf 0.00187 CoV 0.07310
# number of training points:  17
# Degree 1 e_LOO 0.004561018452827755 Pf 0.00221 CoV 0.06720
# number of training points:  18
# Degree 1 e_LOO 4.729196663394916e-05 Pf 0.0117 CoV 0.02910
# number of training points:  19
# Degree 3 e_LOO 6.271977267744197e-06 Pf 0.06985 CoV 0.01150
# number of training points:  20
# Degree 2 e_LOO 0.00016284180891657052 Pf 0.01381 CoV 0.02670
# number of training points:  21
# Degree 2 e_LOO 0.00135107300382824 Pf 0.0217 CoV 0.02120
# number of training points:  22
# Degree 1 e_LOO 0.0019494896710939898 Pf 0.02114 CoV 0.02150
# number of training points:  23
# Degree 2 e_LOO 0.0019295026657366152 Pf 0.01998 CoV 0.02210
# number of training points:  24
# Degree 2 e_LOO 0.0019065341772600804 Pf 0.01942 CoV 0.02250
# number of training points:  25
# Degree 2 e_LOO 0.00034384059705189836 Pf 0.02142 CoV 0.02140
# number of training points:  26
# Degree 2 e_LOO 0.00014424904593107304 Pf 0.01968 CoV 0.02230
# number of training points:  27
# Degree 4 e_LOO 0.0005884593723061801 Pf 0.03481 CoV 0.01670
# number of training points:  28
# Degree 1 e_LOO 0.0036776162858117778 Pf 0.02144 CoV 0.02140
# number of training points:  29
# Degree 4 e_LOO 7.955782858152004e-05 Pf 0.03258 CoV 0.01720
# number of training points:  30
# Degree 1 e_LOO 0.0013917052973111666 Pf 0.02023 CoV 0.02200
# number of training points:  31
# Degree 3 e_LOO 0.00044105309813722226 Pf 0.02239 CoV 0.02090
# number of training points:  32
# Degree 3 e_LOO 0.0005169290687926222 Pf 0.02587 CoV 0.01940
# number of training points:  33
# Degree 3 e_LOO 0.000520146531173704 Pf 0.02895 CoV 0.01830
# number of training points:  34
# Degree 1 e_LOO 6.948609194538096e-05 Pf 0.02636 CoV 0.01920
# number of training points:  35
# Degree 2 e_LOO 2.2668000590967248e-05 Pf 0.02478 CoV 0.01980
# number of training points:  36
# Degree 1 e_LOO 3.086933320956577e-05 Pf 0.02503 CoV 0.01970
# number of training points:  37
# Degree 1 e_LOO 0.00016791503249723776 Pf 0.02569 CoV 0.01950
# number of training points:  38
# Degree 1 e_LOO 0.0005447956107113473 Pf 0.02581 CoV 0.01940
# number of training points:  39
# Degree 3 e_LOO 0.0008669509449134871 Pf 0.01873 CoV 0.02290
# number of training points:  40
# Experiment:  11 ------------------------------------------------------------
# Degree 1 e_LOO 0.0015853922679213248 Pf 0.08681 CoV 0.01030
# number of training points:  11
# Degree 1 e_LOO 0.0947813773760793 Pf 0.02837 CoV 0.01850
# number of training points:  12
# Degree 1 e_LOO 0.0490533001296936 Pf 0.02794 CoV 0.01870
# number of training points:  13
# Degree 1 e_LOO 0.0052965509977615744 Pf 0.03236 CoV 0.01730
# number of training points:  14
# Degree 1 e_LOO 0.00018829164619438637 Pf 0.00719 CoV 0.03720
# number of training points:  15
# Degree 2 e_LOO 1.6814170279763203e-07 Pf 0.01784 CoV 0.02350
# number of training points:  16
# Degree 1 e_LOO 0.008428816767122456 Pf 0.00044 CoV 0.15070
# number of training points:  17
# Degree 1 e_LOO 0.02934766779929673 Pf 0.00941 CoV 0.03240
# number of training points:  18
# Degree 2 e_LOO 0.0007564292690559704 Pf 0.01068 CoV 0.03040
# number of training points:  19
# Degree 3 e_LOO 0.006623742991339585 Pf 0.07908 CoV 0.01080
# number of training points:  20
# Degree 3 e_LOO 0.005908630217937631 Pf 0.03763 CoV 0.01600
# number of training points:  21
# Degree 3 e_LOO 0.0009142574372295125 Pf 0.03626 CoV 0.01630
# number of training points:  22
# Degree 2 e_LOO 2.9641545143544665e-05 Pf 0.01123 CoV 0.02970
# number of training points:  23
# Degree 3 e_LOO 6.19530873493157e-05 Pf 0.03644 CoV 0.01630
# number of training points:  24
# Degree 3 e_LOO 9.125064247479783e-05 Pf 0.04075 CoV 0.01530
# number of training points:  25
# Degree 3 e_LOO 1.9895204878147506e-05 Pf 0.01797 CoV 0.02340
# number of training points:  26
# Degree 3 e_LOO 0.00012771869620252594 Pf 0.01906 CoV 0.02270
# number of training points:  27
# Degree 3 e_LOO 2.686892406355484e-05 Pf 0.01341 CoV 0.02710
# number of training points:  28
# Degree 3 e_LOO 7.6544964538173e-06 Pf 0.01358 CoV 0.02700
# number of training points:  29
# Degree 2 e_LOO 0.0005634861486704858 Pf 0.01224 CoV 0.02840
# number of training points:  30
# Degree 3 e_LOO 6.608369038056841e-05 Pf 0.00889 CoV 0.03340
# number of training points:  31
# Degree 2 e_LOO 0.00029756645347422587 Pf 0.00839 CoV 0.03440
# number of training points:  32
# Degree 2 e_LOO 0.00013688824526219965 Pf 0.01033 CoV 0.03100
# number of training points:  33
# Degree 2 e_LOO 5.103744505046818e-05 Pf 0.01006 CoV 0.03140
# number of training points:  34
# Degree 3 e_LOO 0.000166077994891637 Pf 0.00993 CoV 0.03160
# number of training points:  35
# Degree 3 e_LOO 2.2282237843382888e-10 Pf 0.00945 CoV 0.03240
# number of training points:  36
# Degree 2 e_LOO 8.483198730188624e-07 Pf 0.01098 CoV 0.03000
# number of training points:  37
# Degree 3 e_LOO 4.89288649887912e-06 Pf 0.01099 CoV 0.03000
# number of training points:  38
# Degree 2 e_LOO 2.3864223020679764e-05 Pf 0.01105 CoV 0.02990
# number of training points:  39
# Degree 2 e_LOO 1.0967730340296073e-05 Pf 0.03067 CoV 0.01780
# number of training points:  40
# Experiment:  12 ------------------------------------------------------------
# Degree 1 e_LOO 3.302124245464074e-05 Pf 0.09971 CoV 0.00950
# number of training points:  11
# Degree 1 e_LOO 0.013010173814711583 Pf 0.09201 CoV 0.00990
# number of training points:  12
# Degree 1 e_LOO 0.02679883446601576 Pf 0.03699 CoV 0.01610
# number of training points:  13
# Degree 1 e_LOO 0.0010203700910325797 Pf 0.03447 CoV 0.01670
# number of training points:  14
# Degree 1 e_LOO 6.348005748865464e-06 Pf 0.03566 CoV 0.01640
# number of training points:  15
# Degree 1 e_LOO 2.4876422996145164e-06 Pf 0.03771 CoV 0.01600
# number of training points:  16
# Degree 1 e_LOO 2.7386406376579714e-05 Pf 0.01038 CoV 0.03090
# number of training points:  17
# Degree 1 e_LOO 9.264639964709687e-06 Pf 0.03152 CoV 0.01750
# number of training points:  18
# Degree 1 e_LOO 0.0002554968458127579 Pf 0.03818 CoV 0.01590
# number of training points:  19
# Degree 1 e_LOO 9.65147735692788e-05 Pf 0.04567 CoV 0.01450
# number of training points:  20
# Degree 1 e_LOO 6.960266887543975e-05 Pf 0.04655 CoV 0.01430
# number of training points:  21
# Degree 1 e_LOO 0.00019120835431018785 Pf 0.04656 CoV 0.01430
# number of training points:  22
# Degree 1 e_LOO 1.5660986484840337e-06 Pf 0.04475 CoV 0.01460
# number of training points:  23
# Degree 1 e_LOO 0.0002423759441391964 Pf 0.04036 CoV 0.01540
# number of training points:  24
# Degree 1 e_LOO 0.00023938757636060042 Pf 0.04049 CoV 0.01540
# number of training points:  25
# Degree 1 e_LOO 0.00011046611451358539 Pf 0.04007 CoV 0.01550
# number of training points:  26
# Degree 1 e_LOO 0.0005744137171639091 Pf 0.03782 CoV 0.01600
# number of training points:  27
# Degree 2 e_LOO 0.00318412949273541 Pf 0.03939 CoV 0.01560
# number of training points:  28
# Degree 2 e_LOO 5.210879845580192e-07 Pf 0.03891 CoV 0.01570
# number of training points:  29
# Degree 3 e_LOO 0.0005181536181910102 Pf 0.03517 CoV 0.01660
# number of training points:  30
# Degree 4 e_LOO 3.9040931124332645e-05 Pf 0.03952 CoV 0.01560
# number of training points:  31
# Degree 2 e_LOO 0.002059359209339833 Pf 0.03826 CoV 0.01590
# number of training points:  32
# Degree 4 e_LOO 0.0015459865685937177 Pf 0.02528 CoV 0.01960
# number of training points:  33
# Degree 4 e_LOO 3.5207973657788225e-06 Pf 0.02681 CoV 0.01910
# number of training points:  34
# Degree 4 e_LOO 0.00020226169092689861 Pf 0.02831 CoV 0.01850
# number of training points:  35
# Degree 4 e_LOO 0.0002465952419219215 Pf 0.02776 CoV 0.01870
# number of training points:  36
# Degree 4 e_LOO 1.667888535490979e-05 Pf 0.02813 CoV 0.01860
# number of training points:  37
# Degree 4 e_LOO 8.344621337704908e-05 Pf 0.02426 CoV 0.02010
# number of training points:  38
# Degree 3 e_LOO 0.0002714790542060924 Pf 0.02461 CoV 0.01990
# number of training points:  39
# Degree 3 e_LOO 0.00010755100345505806 Pf 0.02529 CoV 0.01960
# number of training points:  40
# Experiment:  13 ------------------------------------------------------------
# Degree 2 e_LOO 0.001275288549404395 Pf 0.2136 CoV 0.00610
# number of training points:  11
# Degree 1 e_LOO 0.0012172247467565885 Pf 0.06301 CoV 0.01220
# number of training points:  12
# Degree 1 e_LOO 0.061183576225642015 Pf 0.00428 CoV 0.04820
# number of training points:  13
# Degree 1 e_LOO 0.011553262064014209 Pf 0.00693 CoV 0.03790
# number of training points:  14
# Degree 1 e_LOO 0.013872908156748801 Pf 0.00289 CoV 0.05870
# number of training points:  15
# Degree 2 e_LOO 0.00692890783817889 Pf 0.03125 CoV 0.01760
# number of training points:  16
# Degree 2 e_LOO 5.007238715341128e-05 Pf 0.02899 CoV 0.01830
# number of training points:  17
# Degree 2 e_LOO 8.506030819764121e-05 Pf 0.03215 CoV 0.01740
# number of training points:  18
# Degree 1 e_LOO 0.001419105475108919 Pf 0.00958 CoV 0.03220
# number of training points:  19
# Degree 1 e_LOO 0.0009878595992119153 Pf 0.00791 CoV 0.03540
# number of training points:  20
# Degree 1 e_LOO 0.0007891279898501379 Pf 0.00734 CoV 0.03680
# number of training points:  21
# Degree 2 e_LOO 8.43394046810027e-05 Pf 0.00814 CoV 0.03490
# number of training points:  22
# Degree 2 e_LOO 0.0005149649338061688 Pf 0.00674 CoV 0.03840
# number of training points:  23
# Degree 3 e_LOO 0.00018595689436687579 Pf 0.00774 CoV 0.03580
# number of training points:  24
# Degree 2 e_LOO 0.0012375142617091057 Pf 0.00667 CoV 0.03860
# number of training points:  25
# Degree 2 e_LOO 0.00028108109304277436 Pf 0.00663 CoV 0.03870
# number of training points:  26
# Degree 2 e_LOO 0.00017700413980289997 Pf 0.00696 CoV 0.03780
# number of training points:  27
# Degree 2 e_LOO 0.0003592697907232662 Pf 0.01553 CoV 0.02520
# number of training points:  28
# Degree 2 e_LOO 8.046545226619704e-06 Pf 0.01523 CoV 0.02540
# number of training points:  29
# Degree 2 e_LOO 5.801275346181115e-06 Pf 0.02004 CoV 0.02210
# number of training points:  30
# Degree 2 e_LOO 0.0017375727600675913 Pf 0.01949 CoV 0.02240
# number of training points:  31
# Degree 4 e_LOO 1.8735576017495242e-06 Pf 0.02386 CoV 0.02020
# number of training points:  32
# Degree 2 e_LOO 0.004924876790255698 Pf 0.02001 CoV 0.02210
# number of training points:  33
# Degree 2 e_LOO 0.003209528445680332 Pf 0.01956 CoV 0.02240
# number of training points:  34
# Degree 2 e_LOO 0.0018288186249595 Pf 0.01948 CoV 0.02240
# number of training points:  35
# Degree 2 e_LOO 0.004763846083730157 Pf 0.01911 CoV 0.02270
# number of training points:  36
# Degree 2 e_LOO 0.004814420634908299 Pf 0.01924 CoV 0.02260
# number of training points:  37
# Degree 4 e_LOO 4.241872042478589e-05 Pf 0.02501 CoV 0.01970
# number of training points:  38
# Degree 4 e_LOO 4.346895490706486e-05 Pf 0.01777 CoV 0.02350
# number of training points:  39
# Degree 3 e_LOO 0.0008190069162159584 Pf 0.01522 CoV 0.02540
# number of training points:  40
# Experiment:  14 ------------------------------------------------------------
# Degree 1 e_LOO 0.000626185445211039 Pf 0.02131 CoV 0.02140
# number of training points:  11
# Degree 1 e_LOO 0.052651421750375356 Pf 0.10222 CoV 0.00940
# number of training points:  12
# Degree 1 e_LOO 0.008588775792726358 Pf 0.09901 CoV 0.00950
# number of training points:  13
# Degree 1 e_LOO 2.2891805080059048e-07 Pf 0.09792 CoV 0.00960
# number of training points:  14
# Degree 1 e_LOO 0.007678402781744151 Pf 0.07122 CoV 0.01140
# number of training points:  15
# Degree 1 e_LOO 0.0003098280828478485 Pf 0.06599 CoV 0.01190
# number of training points:  16
# Degree 1 e_LOO 0.0214532308269095 Pf 0.08363 CoV 0.01050
# number of training points:  17
# Degree 1 e_LOO 0.009922873613900677 Pf 0.08919 CoV 0.01010
# number of training points:  18
# Degree 1 e_LOO 0.0003471337859037265 Pf 0.07024 CoV 0.01150
# number of training points:  19
# Degree 3 e_LOO 9.219934769144836e-05 Pf 0.01064 CoV 0.03050
# number of training points:  20
# Degree 1 e_LOO 0.000627187408973427 Pf 0.00579 CoV 0.04140
# number of training points:  21
# Degree 1 e_LOO 0.0013979723165207136 Pf 0.00267 CoV 0.06110
# number of training points:  22
# Degree 1 e_LOO 0.0008294043151681851 Pf 0.0026 CoV 0.06190
# number of training points:  23
# Degree 2 e_LOO 0.002223285440631588 Pf 0.00231 CoV 0.06570
# number of training points:  24
# Degree 2 e_LOO 0.0009759528570981549 Pf 0.01085 CoV 0.03020
# number of training points:  25
# Degree 2 e_LOO 0.0004320262654012116 Pf 0.0115 CoV 0.02930
# number of training points:  26
# Degree 3 e_LOO 6.479226053870293e-05 Pf 0.0124 CoV 0.02820
# number of training points:  27
# Degree 3 e_LOO 6.348167148066156e-06 Pf 0.01678 CoV 0.02420
# number of training points:  28
# Degree 3 e_LOO 4.949944338765124e-07 Pf 0.01712 CoV 0.02400
# number of training points:  29
# Degree 2 e_LOO 9.19942064661335e-05 Pf 0.01525 CoV 0.02540
# number of training points:  30
# Degree 1 e_LOO 0.0002685396450920877 Pf 0.01762 CoV 0.02360
# number of training points:  31
# Degree 2 e_LOO 1.6314690201845545e-06 Pf 0.0153 CoV 0.02540
# number of training points:  32
# Degree 1 e_LOO 0.0002056201263450086 Pf 0.00814 CoV 0.03490
# number of training points:  33
# Degree 2 e_LOO 1.5199855868428258e-05 Pf 0.00799 CoV 0.03520
# number of training points:  34
# Degree 2 e_LOO 0.00011446522048453224 Pf 0.00853 CoV 0.03410
# number of training points:  35
# Degree 2 e_LOO 0.0002795714159363318 Pf 0.00933 CoV 0.03260
# number of training points:  36
# Degree 2 e_LOO 2.078050004933643e-05 Pf 0.00943 CoV 0.03240
# number of training points:  37
# Degree 2 e_LOO 3.2871659193366814e-05 Pf 0.01736 CoV 0.02380
# number of training points:  38
# Degree 3 e_LOO 2.9651770931531183e-05 Pf 0.0156 CoV 0.02510
# number of training points:  39
# Degree 3 e_LOO 2.954845711340064e-06 Pf 0.01495 CoV 0.02570
# number of training points:  40
# Experiment:  15 ------------------------------------------------------------
# Degree 2 e_LOO 0.0006438109141594866 Pf 0.0258 CoV 0.01940
# number of training points:  11
# Degree 1 e_LOO 0.02091132202529309 Pf 0.0074 CoV 0.03660
# number of training points:  12
# Degree 1 e_LOO 0.008027037721563712 Pf 0.0001 CoV 0.31620
# number of training points:  13
# Degree 1 e_LOO 0.00022400025126882242 Pf 1e-05 CoV 1.00000
# number of training points:  14
# Degree 2 e_LOO 0.0036200951928873604 Pf 0.14397 CoV 0.00770
# number of training points:  15
# Degree 1 e_LOO 0.04005631975141487 Pf 0.03835 CoV 0.01580
# number of training points:  16
# Degree 2 e_LOO 0.009384483593679226 Pf 0.03658 CoV 0.01620
# number of training points:  17
# Degree 2 e_LOO 0.0043846328328096835 Pf 0.01191 CoV 0.02880
# number of training points:  18
# Degree 2 e_LOO 0.011515405217338206 Pf 0.00882 CoV 0.03350
# number of training points:  19
# Degree 1 e_LOO 0.008262839018186882 Pf 0.00271 CoV 0.06070
# number of training points:  20
# Degree 1 e_LOO 0.0044226281639403705 Pf 0.00253 CoV 0.06280
# number of training points:  21
# Degree 1 e_LOO 0.00284671468613339 Pf 0.00308 CoV 0.05690
# number of training points:  22
# Degree 1 e_LOO 0.0018783725971631732 Pf 0.01433 CoV 0.02620
# number of training points:  23
# Degree 1 e_LOO 0.0005887827486029339 Pf 0.01353 CoV 0.02700
# number of training points:  24
# Degree 1 e_LOO 0.00011275677665860432 Pf 0.01338 CoV 0.02720
# number of training points:  25
# Degree 1 e_LOO 0.0008531175111577885 Pf 0.01337 CoV 0.02720
# number of training points:  26
# Degree 1 e_LOO 0.0012471523207858355 Pf 0.01356 CoV 0.02700
# number of training points:  27
# Degree 2 e_LOO 0.0012220041243169578 Pf 0.01334 CoV 0.02720
# number of training points:  28
# Degree 3 e_LOO 0.0003528367886856738 Pf 0.02334 CoV 0.02050
# number of training points:  29
# Degree 3 e_LOO 0.000973606010311071 Pf 0.02869 CoV 0.01840
# number of training points:  30
# Degree 2 e_LOO 0.0014112703280774442 Pf 0.01731 CoV 0.02380
# number of training points:  31
# Degree 3 e_LOO 6.22104006604721e-05 Pf 0.01128 CoV 0.02960
# number of training points:  32
# Degree 3 e_LOO 0.0004221627922110309 Pf 0.00987 CoV 0.03170
# number of training points:  33
# Degree 3 e_LOO 3.491548501222186e-05 Pf 0.00856 CoV 0.03400
# number of training points:  34
# Degree 1 e_LOO 0.0004224648429681445 Pf 0.00893 CoV 0.03330
# number of training points:  35
# Degree 1 e_LOO 2.716531543297304e-05 Pf 0.00864 CoV 0.03390
# number of training points:  36
# Degree 1 e_LOO 3.152540156501336e-07 Pf 0.00896 CoV 0.03330
# number of training points:  37
# Degree 1 e_LOO 6.6599410348965e-06 Pf 0.00852 CoV 0.03410
# number of training points:  38
# Degree 1 e_LOO 0.0002408436118121922 Pf 0.00861 CoV 0.03390
# number of training points:  39
# Degree 1 e_LOO 0.0005065674074100175 Pf 0.00921 CoV 0.03280
# number of training points:  40

# %% [markdown]
# # Active training - U - LOO - 1 LS

# %%
number_experiments = 15
number_active_points = 40

results_file = '_AT_U_Loo_' + str(number_active_points)   # index for results files

# to select the best model (length and order) 
# kernel hyperparameters------------------------------
v = 5/2
#truncation term-------------------------------------
p_max = 5  #for each variable → same truncation , degree of expansion
        
for experiments in range(number_experiments):
    print('Experiment: ', experiments+1 , '------------------------------------------------------------' )
    
    ActiveTrain = {}   #results file { Surrogate , Pf, CoV_Pf , eLoo , mse }

    #initial design of experiments (LHS) --------------------------------

    n = 10       # number of initial sampling

    xn = np.zeros((int(n), dim))      #normalized training points
    xr = np.zeros((int(n), dim))      #scaled training points
    yn = np.zeros((int(n)))           #observations

    mean_loo = np.zeros(len(xn))
    var_loo = np.zeros(len(xn))

    x1mean, x1sigma = 1.5 , 1.0  # normal distribution 
    x2mean, x2sigma = 2.5 , 1.0  # normal distribution 

    # Check the variables limits for space-filling distribution
    Xdoe = build.space_filling_lhs( {'x1':[-1, 1],      
                                     'x2':[-1, 1],} , 
                                      num_samples = n )
    #------------------------------------------------------------
    xn[:,0] = Xdoe['x1']
    xn[:,1] = Xdoe['x2']
    xr[:,0] = PCK1.scalehermite(xn[:,0], x1mean, x1sigma)
    xr[:,1] = PCK1.scalehermite(xn[:,1], x2mean, x2sigma)

    yn = function(xr)[0]

    for points in range(number_active_points):

        ModelName = 'PCK' + str(len(xn))

        ModelName = PC_Kriging(config)
        
        mse_results = np.zeros(p_max-1)
        opt_length_it = np.zeros(p_max-1)

        mean_loo = np.zeros(len(xn))
        var_loo = np.zeros(len(xn))
        eloo_results = np.zeros(p_max-1)
        sumat = np.zeros((len(xn),(p_max-1)))

        dist = PCK1.distance(xn, xn)
        lmax = np.max(dist)
        lmin = np.min(dist[dist!=0])

        # OPTIMAL SURROGATE MODEL -----------------------------------
        for p in range(1, p_max):
            results = dict()
            bounds = [(lmin, lmax)]
            results['shgo'] = optimize.shgo(L_Object, bounds)
            opt_length = results['shgo']['x'][0]

            theta = np.array([opt_length, v])

            #Generating PCK models for each reduced design of experiments 

            for i in range (0, len(xn) ):

                yn_loo= np.delete(yn,[i])                            #y_n-i      leaving element i out the observations 
                xr_loo= np.delete(xr,[i*2,i*2+1]).reshape(-1,dim)    #x1r_n-i   leaving element i out the inputs (xr)
                xn_loo= np.delete(xn,[i*2,i*2+1]).reshape(-1,dim)    #x_n-i     leaving element i out the nomalized inputs (xn)

                #training LOO
                modelpar_loo = PCK_loo.train (xn_loo , yn_loo , p , theta )

                #predicting LOO over each removed sample
                mean_loo[i], var_loo[i] = PCK_loo.predict_fast(xn[i].reshape(1,-1))

            e_loo = np.mean (yn - mean_loo)**2              #LOO CV squared errors
            sumat[:,p-1] = np.divide(e_loo, var_loo)
            
            eloo_results[p-1] = e_loo

            #--------------------------------------- error over a set of test points
            modelpar1 = PCK1.train (xn, yn, p, theta) 
            mean0, var0 = PCK1.predict_fast(XN)    # test points predictions mean, variance

            mse = np.mean ((YN - mean0)**2)

            mse_results[p-1] = mse
            opt_length_it[p-1] = opt_length

    #         print('Degree', p, 'MSE', "%.2f" % round(mse, 2) , 'e_LOO', "%.5f" % e_loo)

        ## training optimal model ----------------------------

        opt = np.argmin(eloo_results)    
        theta_opt = np.array([opt_length_it[opt], v]) 

        modelpar1 = ModelName.train (xn, yn, int(opt+1), theta_opt) 

        ## Pool of samples
        MCS_samples = 100000
        LOOCV = np.zeros(MCS_samples)

        MCinputs_norm = np.zeros((int(MCS_samples), dim))
        MCinputs = np.zeros((int(MCS_samples), dim))

        MCinputs_norm[:,0] = np.random.normal(0, 1, size=int(MCS_samples))
        MCinputs_norm[:,1] = np.random.normal(0, 1, size=int(MCS_samples))

        MCinputs[:,0] = PCK1.scalehermite(MCinputs_norm[:,0], x1mean, x1sigma)  
        MCinputs[:,1] = PCK1.scalehermite(MCinputs_norm[:,1], x2mean, x2sigma)  

        # ---------------------------------------------------
        ymc = function(MCinputs)[0]  
        fail_samples = np.sum(ymc < 0 )
        Pf_ref = fail_samples/MCS_samples

        meanMC, varMC = ModelName.predict_fast(MCinputs_norm)    # mean, variance
        fail_samples_SUMO = np.sum(np.asarray(meanMC) < 0 )
        fail_prob_SUMO = fail_samples_SUMO / MCS_samples

        cov_pf = np.sqrt((1 - fail_prob_SUMO ) / (fail_prob_SUMO * MCS_samples) )

        # LOO CV errors ###################################################

        for k in range (0, MCS_samples):               #variance enhancement based LOO CV erros around voronoi cells
            voro = VoronoiCell(MCinputs[k], xr)
            LOOCV[k]= varMC[k]*(1+sumat[voro, opt])   
        ####################################################
        
        print('Degree', int(opt+1), 'e_LOO', np.min(eloo_results) , 'Pf', fail_prob_SUMO , 'CoV', "%.5f" % round(cov_pf, 4))

        #saving results ----------------------------

        ActiveTrain[str(len(xn))+'points'] = ModelName , fail_prob_SUMO , cov_pf , np.min(eloo_results), np.min(mse_results)

        ### Evaluating new points
        U_f = U_function(meanMC.reshape(-1), LOOCV.reshape(-1))
        xr = np.append(xr, MCinputs[np.argmin(U_f)]).reshape(-1,2)
        xn = np.append(xn, MCinputs_norm[np.argmin(U_f)])w.reshape(-1,2)
        yn = function(xr)[0] #Only one point needs to be evaluated here

        print('number of training points: ', len(xn))
    
    filename = 'Batch_'+ str(experiments+1) + results_file + 'p_LS1.sav'
    pickle.dump(ActiveTrain, open(filename, 'wb'))
# Out:
# Experiment:  1 ------------------------------------------------------------
# C:\Users\Administrator\anaconda3\envs\surrogate\lib\site-packages\ipykernel_launcher.py:8: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# Degree 1 e_LOO 0.00016988837566974703 Pf 0.06674 CoV 0.01180
# number of training points:  11
# Degree 1 e_LOO 9.054516411266028e-05 Pf 0.08575 CoV 0.01030
# number of training points:  12
# Degree 1 e_LOO 5.100865294683073e-05 Pf 0.0372 CoV 0.01610
# number of training points:  13
# Degree 1 e_LOO 1.2474324086100414e-05 Pf 0.02471 CoV 0.01990
# number of training points:  14
# Degree 1 e_LOO 0.005790585287708486 Pf 0.03791 CoV 0.01590
# number of training points:  15
# Degree 1 e_LOO 0.0013792074652899619 Pf 0.03475 CoV 0.01670
# number of training points:  16
# Degree 2 e_LOO 7.13098338986533e-05 Pf 0.02367 CoV 0.02030
# number of training points:  17
# Degree 1 e_LOO 0.0005558999643936644 Pf 0.02303 CoV 0.02060
# number of training points:  18
# Degree 1 e_LOO 0.0008333248009063205 Pf 0.02779 CoV 0.01870
# number of training points:  19
# Degree 2 e_LOO 4.7909123079586004e-05 Pf 0.02615 CoV 0.01930
# number of training points:  20
# Degree 2 e_LOO 0.00022568922411852238 Pf 0.0257 CoV 0.01950
# number of training points:  21
# Degree 2 e_LOO 0.0005914612916158113 Pf 0.0278 CoV 0.01870
# number of training points:  22
# Degree 2 e_LOO 0.0005123079083616545 Pf 0.0274 CoV 0.01880
# number of training points:  23
# Degree 2 e_LOO 0.0005577565751297599 Pf 0.02806 CoV 0.01860
# number of training points:  24
# Degree 2 e_LOO 0.0005863218592332919 Pf 0.02979 CoV 0.01800
# number of training points:  25
# Degree 2 e_LOO 0.0006736504201267804 Pf 0.02898 CoV 0.01830
# number of training points:  26
# Degree 2 e_LOO 0.001037287692112634 Pf 0.0283 CoV 0.01850
# number of training points:  27
# Degree 2 e_LOO 0.0005292374384847098 Pf 0.02696 CoV 0.01900
# number of training points:  28
# Degree 1 e_LOO 0.001604576703393934 Pf 0.02863 CoV 0.01840
# number of training points:  29
# Degree 1 e_LOO 0.001321532221224824 Pf 0.02844 CoV 0.01850
# number of training points:  30
# Degree 1 e_LOO 0.0013454035383975848 Pf 0.0291 CoV 0.01830
# number of training points:  31
# Degree 1 e_LOO 0.003025314367236163 Pf 0.03047 CoV 0.01780
# number of training points:  32
# Degree 1 e_LOO 0.0030376104121865514 Pf 0.03054 CoV 0.01780
# number of training points:  33
# Degree 1 e_LOO 0.005420910117709442 Pf 0.0305 CoV 0.01780
# number of training points:  34
# Degree 1 e_LOO 0.005419935413549261 Pf 0.02999 CoV 0.01800
# number of training points:  35
# Degree 4 e_LOO 0.000667077189447068 Pf 0.05153 CoV 0.01360
# number of training points:  36
# Degree 2 e_LOO 0.0003461608943258943 Pf 0.0316 CoV 0.01750
# number of training points:  37
# Degree 4 e_LOO 0.0003598091139834593 Pf 0.03281 CoV 0.01720
# number of training points:  38
# Degree 4 e_LOO 0.0002013232652332854 Pf 0.03262 CoV 0.01720
# number of training points:  39
# Degree 4 e_LOO 0.0002598280385106908 Pf 0.03319 CoV 0.01710
# number of training points:  40
# Experiment:  2 ------------------------------------------------------------
# Degree 4 e_LOO 0.0006189539268937453 Pf 0.35475 CoV 0.00430
# number of training points:  11
# C:\Users\Administrator\anaconda3\envs\surrogate\lib\site-packages\ipykernel_launcher.py:129: RuntimeWarning: divide by zero encountered in double_scalars
# Degree 2 e_LOO 0.015497381644452274 Pf 0.0 CoV inf
# number of training points:  12
# Degree 3 e_LOO 0.00020171443552573863 Pf 0.10343 CoV 0.00930
# number of training points:  13
# Degree 3 e_LOO 0.0013703619378320488 Pf 0.0681 CoV 0.01170
# number of training points:  14
# Degree 3 e_LOO 6.0318970466081866e-05 Pf 0.06576 CoV 0.01190
# number of training points:  15
# Degree 3 e_LOO 0.006428881822019729 Pf 0.06005 CoV 0.01250
# number of training points:  16
# Degree 3 e_LOO 0.004854098798838517 Pf 0.05971 CoV 0.01250
# number of training points:  17
# Degree 3 e_LOO 0.012480018347100157 Pf 0.05133 CoV 0.01360
# number of training points:  18
# Degree 1 e_LOO 0.019866166184342827 Pf 0.02752 CoV 0.01880
# number of training points:  19
# Degree 4 e_LOO 0.0018151018627029418 Pf 0.04811 CoV 0.01410
# number of training points:  20
# Degree 1 e_LOO 0.0001245444857610885 Pf 0.02515 CoV 0.01970
# number of training points:  21
# Degree 1 e_LOO 0.00011583828885974115 Pf 0.02521 CoV 0.01970
# number of training points:  22
# Degree 1 e_LOO 0.00022894089444999705 Pf 0.02475 CoV 0.01990
# number of training points:  23
# Degree 1 e_LOO 0.0001950698793546191 Pf 0.02476 CoV 0.01980
# number of training points:  24
# Degree 1 e_LOO 0.00012166703730948645 Pf 0.02516 CoV 0.01970
# number of training points:  25
# Degree 1 e_LOO 0.00011054906908121521 Pf 0.02514 CoV 0.01970
# number of training points:  26
# Degree 1 e_LOO 0.00017355734278409407 Pf 0.02439 CoV 0.02000
# number of training points:  27
# Degree 1 e_LOO 2.290784621482111e-05 Pf 0.02423 CoV 0.02010
# number of training points:  28
# Degree 1 e_LOO 1.7689429531907082e-05 Pf 0.02485 CoV 0.01980
# number of training points:  29
# Degree 1 e_LOO 1.5332009179434727e-05 Pf 0.02495 CoV 0.01980
# number of training points:  30
# Degree 1 e_LOO 7.465349330488046e-06 Pf 0.02428 CoV 0.02000
# number of training points:  31
# Degree 1 e_LOO 1.6588187067597608e-07 Pf 0.02443 CoV 0.02000
# number of training points:  32
# Degree 1 e_LOO 7.211720447258008e-07 Pf 0.02506 CoV 0.01970
# number of training points:  33
# Degree 1 e_LOO 7.683066313630318e-07 Pf 0.02495 CoV 0.01980
# number of training points:  34
# Degree 1 e_LOO 9.495450042279782e-08 Pf 0.02498 CoV 0.01980
# number of training points:  35
# Degree 1 e_LOO 6.888099034638726e-08 Pf 0.02576 CoV 0.01940
# number of training points:  36
# Degree 1 e_LOO 2.2516363597549946e-07 Pf 0.02426 CoV 0.02010
# number of training points:  37
# Degree 1 e_LOO 1.1643859475302666e-07 Pf 0.02429 CoV 0.02000
# number of training points:  38
# Degree 1 e_LOO 1.2977423222997358e-07 Pf 0.02528 CoV 0.01960
# number of training points:  39
# Degree 1 e_LOO 9.387820260012933e-07 Pf 0.02502 CoV 0.01970
# number of training points:  40
# Experiment:  3 ------------------------------------------------------------
# Degree 2 e_LOO 0.00730209150777086 Pf 0.14735 CoV 0.00760
# number of training points:  11
# Degree 2 e_LOO 0.007123150106403626 Pf 0.08189 CoV 0.01060
# number of training points:  12
# Degree 2 e_LOO 0.006692608392453217 Pf 0.0 CoV inf
# number of training points:  13
# Degree 1 e_LOO 0.016368495770128357 Pf 0.02058 CoV 0.02180
# number of training points:  14
# Degree 1 e_LOO 0.005096510373941318 Pf 0.00306 CoV 0.05710
# number of training points:  15
# Degree 2 e_LOO 0.0005778025138052523 Pf 0.00655 CoV 0.03890
# number of training points:  16
# Degree 2 e_LOO 1.7882772539803935e-06 Pf 0.01511 CoV 0.02550
# number of training points:  17
# Degree 2 e_LOO 8.859554709823366e-05 Pf 0.01605 CoV 0.02480
# number of training points:  18
# Degree 2 e_LOO 1.3533826937205087e-06 Pf 0.02146 CoV 0.02140
# number of training points:  19
# Degree 2 e_LOO 4.887389736880869e-05 Pf 0.01899 CoV 0.02270
# number of training points:  20
# Degree 2 e_LOO 0.00014074557976280955 Pf 0.02013 CoV 0.02210
# number of training points:  21
# Degree 4 e_LOO 4.204640607338731e-05 Pf 0.12515 CoV 0.00840
# number of training points:  22
# Degree 4 e_LOO 2.6877783756271113e-05 Pf 0.10477 CoV 0.00920
# number of training points:  23
# Degree 1 e_LOO 3.453441787576176e-05 Pf 0.01826 CoV 0.02320
# number of training points:  24
# Degree 2 e_LOO 0.00033001239503899807 Pf 0.01572 CoV 0.02500
# number of training points:  25
# Degree 1 e_LOO 0.0002292684957668421 Pf 0.02087 CoV 0.02170
# number of training points:  26
# Degree 1 e_LOO 0.0020598501151212725 Pf 0.0289 CoV 0.01830
# number of training points:  27
# Degree 2 e_LOO 0.00036577671626510805 Pf 0.02939 CoV 0.01820
# number of training points:  28
# Degree 2 e_LOO 5.2507557094710326e-05 Pf 0.02808 CoV 0.01860
# number of training points:  29
# Degree 2 e_LOO 2.3652088416603344e-05 Pf 0.02908 CoV 0.01830
# number of training points:  30
# Degree 2 e_LOO 3.1030565511666275e-06 Pf 0.02908 CoV 0.01830
# number of training points:  31
# Degree 2 e_LOO 2.0031881448959506e-08 Pf 0.03101 CoV 0.01770
# number of training points:  32
# Degree 1 e_LOO 0.002146100007349504 Pf 0.03178 CoV 0.01750
# number of training points:  33
# Degree 2 e_LOO 0.0021872562138548126 Pf 0.03018 CoV 0.01790
# number of training points:  34
# Degree 2 e_LOO 0.002391907154191064 Pf 0.03062 CoV 0.01780
# number of training points:  35
# Degree 2 e_LOO 0.0025147134097706345 Pf 0.03022 CoV 0.01790
# number of training points:  36
# Degree 1 e_LOO 0.0024594402274063162 Pf 0.03059 CoV 0.01780
# number of training points:  37
# Degree 1 e_LOO 0.002245795016842748 Pf 0.03091 CoV 0.01770
# number of training points:  38
# Degree 1 e_LOO 0.001943437913322439 Pf 0.0316 CoV 0.01750
# number of training points:  39
# Degree 3 e_LOO 0.00021499450034033046 Pf 0.03158 CoV 0.01750
# number of training points:  40
# Experiment:  4 ------------------------------------------------------------
# Degree 1 e_LOO 0.0006707892533096252 Pf 0.12551 CoV 0.00830
# number of training points:  11
# Degree 2 e_LOO 3.6873599642322334e-09 Pf 0.12271 CoV 0.00850
# number of training points:  12
# Degree 2 e_LOO 0.00033293915070490063 Pf 0.12415 CoV 0.00840
# number of training points:  13
# Degree 1 e_LOO 0.0013159751813005033 Pf 0.03294 CoV 0.01710
# number of training points:  14
# Degree 1 e_LOO 0.002593368530594504 Pf 0.01925 CoV 0.02260
# number of training points:  15
# Degree 1 e_LOO 0.0028346095680628243 Pf 0.02143 CoV 0.02140
# number of training points:  16
# Degree 1 e_LOO 0.00273883860906812 Pf 0.02891 CoV 0.01830
# number of training points:  17
# Degree 1 e_LOO 0.002459498300242922 Pf 0.0283 CoV 0.01850
# number of training points:  18
# Degree 3 e_LOO 0.002926703812433696 Pf 0.0317 CoV 0.01750
# number of training points:  19
# Degree 3 e_LOO 0.002101837712226549 Pf 0.03269 CoV 0.01720
# number of training points:  20
# Degree 1 e_LOO 8.11127062376886e-06 Pf 0.02984 CoV 0.01800
# number of training points:  21
# Degree 1 e_LOO 0.0004330461498663706 Pf 0.02507 CoV 0.01970
# number of training points:  22
# Degree 1 e_LOO 0.00044562324839212417 Pf 0.02475 CoV 0.01990
# number of training points:  23
# Degree 1 e_LOO 7.04910703287885e-05 Pf 0.02466 CoV 0.01990
# number of training points:  24
# Degree 1 e_LOO 0.00013864476188808398 Pf 0.02615 CoV 0.01930
# number of training points:  25
# Degree 2 e_LOO 0.00017100026768094692 Pf 0.02482 CoV 0.01980
# number of training points:  26
# Degree 2 e_LOO 0.0006883977294925828 Pf 0.02671 CoV 0.01910
# number of training points:  27
# Degree 2 e_LOO 4.701292173106404e-05 Pf 0.02662 CoV 0.01910
# number of training points:  28
# Degree 2 e_LOO 5.8837263980200396e-05 Pf 0.02684 CoV 0.01900
# number of training points:  29
# Degree 2 e_LOO 7.213396757054011e-05 Pf 0.02876 CoV 0.01840
# number of training points:  30
# Degree 3 e_LOO 1.1500839522674191e-06 Pf 0.02993 CoV 0.01800
# number of training points:  31
# Degree 2 e_LOO 1.6129441839145997e-05 Pf 0.03035 CoV 0.01790
# number of training points:  32
# Degree 3 e_LOO 9.455878041933747e-05 Pf 0.02922 CoV 0.01820
# number of training points:  33
# Degree 3 e_LOO 3.3801213613402605e-05 Pf 0.02928 CoV 0.01820
# number of training points:  34
# Degree 3 e_LOO 4.881968719869995e-05 Pf 0.02933 CoV 0.01820
# number of training points:  35
# Degree 1 e_LOO 0.00017938069309546105 Pf 0.03099 CoV 0.01770
# number of training points:  36
# Degree 1 e_LOO 1.017975530374098e-05 Pf 0.03141 CoV 0.01760
# number of training points:  37
# Degree 1 e_LOO 4.584944416628273e-05 Pf 0.03253 CoV 0.01720
# number of training points:  38
# Degree 1 e_LOO 3.792411202247767e-05 Pf 0.03072 CoV 0.01780
# number of training points:  39
# Degree 1 e_LOO 3.989802602673499e-05 Pf 0.03154 CoV 0.01750
# number of training points:  40
# Experiment:  5 ------------------------------------------------------------
# Degree 2 e_LOO 0.0002687611908227912 Pf 0.05403 CoV 0.01320
# number of training points:  11
# Degree 2 e_LOO 0.006710963686685201 Pf 0.01121 CoV 0.02970
# number of training points:  12
# Degree 2 e_LOO 0.0004541352768892054 Pf 0.01975 CoV 0.02230
# number of training points:  13
# Degree 2 e_LOO 0.00012918682857019728 Pf 0.0191 CoV 0.02270
# number of training points:  14
# Degree 2 e_LOO 0.00028476124554014314 Pf 0.02348 CoV 0.02040
# number of training points:  15
# Degree 2 e_LOO 0.00040356555647705236 Pf 0.0272 CoV 0.01890
# number of training points:  16
# Degree 2 e_LOO 0.0014822030046251129 Pf 0.01938 CoV 0.02250
# number of training points:  17
# Degree 1 e_LOO 0.002068797720916333 Pf 0.09097 CoV 0.01000
# number of training points:  18
# Degree 2 e_LOO 9.902454081637563e-05 Pf 0.01789 CoV 0.02340
# number of training points:  19
# Degree 2 e_LOO 2.060568134315908e-05 Pf 0.01862 CoV 0.02300
# number of training points:  20
# Degree 1 e_LOO 0.00013882924595497533 Pf 0.02206 CoV 0.02110
# number of training points:  21
# Degree 2 e_LOO 0.00014536960308065373 Pf 0.01967 CoV 0.02230
# number of training points:  22
# Degree 4 e_LOO 2.3860487857760387e-05 Pf 0.13378 CoV 0.00800
# number of training points:  23
# Degree 1 e_LOO 0.00024531283887937035 Pf 0.02302 CoV 0.02060
# number of training points:  24
# Degree 1 e_LOO 0.003801795342754038 Pf 0.02776 CoV 0.01870
# number of training points:  25
# Degree 1 e_LOO 0.004540179446294514 Pf 0.0297 CoV 0.01810
# number of training points:  26
# Degree 1 e_LOO 0.0018885917898532787 Pf 0.03148 CoV 0.01750
# number of training points:  27
# Degree 1 e_LOO 0.0019908609395930784 Pf 0.02986 CoV 0.01800
# number of training points:  28
# Degree 2 e_LOO 7.044863757050699e-07 Pf 0.03046 CoV 0.01780
# number of training points:  29
# Degree 2 e_LOO 2.6043004495980463e-05 Pf 0.02959 CoV 0.01810
# number of training points:  30
# Degree 2 e_LOO 8.38625841936471e-06 Pf 0.03037 CoV 0.01790
# number of training points:  31
# Degree 3 e_LOO 6.538912547772186e-05 Pf 0.03517 CoV 0.01660
# number of training points:  32
# Degree 2 e_LOO 0.00012682120020763974 Pf 0.03004 CoV 0.01800
# number of training points:  33
# Degree 2 e_LOO 0.0006767295023743599 Pf 0.03 CoV 0.01800
# number of training points:  34
# Degree 2 e_LOO 0.0006872850794554443 Pf 0.03045 CoV 0.01780
# number of training points:  35
# Degree 2 e_LOO 0.001304585348578958 Pf 0.03011 CoV 0.01790
# number of training points:  36
# Degree 2 e_LOO 0.00012276306645041382 Pf 0.03007 CoV 0.01800
# number of training points:  37
# Degree 2 e_LOO 7.243370995561986e-05 Pf 0.03119 CoV 0.01760
# number of training points:  38
# Degree 2 e_LOO 6.539458218163069e-07 Pf 0.03037 CoV 0.01790
# number of training points:  39
# Degree 2 e_LOO 5.094355826510419e-07 Pf 0.03103 CoV 0.01770
# number of training points:  40
# Experiment:  6 ------------------------------------------------------------
# Degree 2 e_LOO 1.075796154982478e-05 Pf 0.1137 CoV 0.00880
# number of training points:  11
# Degree 3 e_LOO 6.94515515578079e-05 Pf 0.06843 CoV 0.01170
# number of training points:  12
# Degree 3 e_LOO 0.015444335151585638 Pf 0.06078 CoV 0.01240
# number of training points:  13
# Degree 1 e_LOO 0.00018116650784530744 Pf 0.0058 CoV 0.04140
# number of training points:  14
# Degree 1 e_LOO 0.00207884489796163 Pf 0.0612 CoV 0.01240
# number of training points:  15
# Degree 1 e_LOO 0.0017119388481582093 Pf 0.03049 CoV 0.01780
# number of training points:  16
# Degree 1 e_LOO 0.0003111669903840238 Pf 0.01519 CoV 0.02550
# number of training points:  17
# Degree 1 e_LOO 0.0005734656082470496 Pf 0.01148 CoV 0.02930
# number of training points:  18
# Degree 1 e_LOO 0.0010136784811469008 Pf 0.01419 CoV 0.02640
# number of training points:  19
# Degree 1 e_LOO 0.0009632492502409648 Pf 0.01086 CoV 0.03020
# number of training points:  20
# Degree 1 e_LOO 0.0019479654937849858 Pf 0.01004 CoV 0.03140
# number of training points:  21
# Degree 1 e_LOO 0.0019038776510591185 Pf 0.00859 CoV 0.03400
# number of training points:  22
# Degree 1 e_LOO 0.003686837498147259 Pf 0.00853 CoV 0.03410
# number of training points:  23
# Degree 1 e_LOO 0.003767455721732379 Pf 0.01596 CoV 0.02480
# number of training points:  24
# Degree 1 e_LOO 0.004308880269681851 Pf 0.02554 CoV 0.01950
# number of training points:  25
# Degree 1 e_LOO 0.0037534399332961204 Pf 0.0212 CoV 0.02150
# number of training points:  26
# Degree 1 e_LOO 0.0043553240152263886 Pf 0.02613 CoV 0.01930
# number of training points:  27
# Degree 1 e_LOO 0.005917157027949986 Pf 0.02724 CoV 0.01890
# number of training points:  28
# Degree 1 e_LOO 0.008259146191228408 Pf 0.02887 CoV 0.01830
# number of training points:  29
# Degree 1 e_LOO 7.191773521210565e-07 Pf 0.0282 CoV 0.01860
# number of training points:  30
# Degree 1 e_LOO 2.8438902674491506e-06 Pf 0.0289 CoV 0.01830
# number of training points:  31
# Degree 1 e_LOO 0.0009434639438542823 Pf 0.02995 CoV 0.01800
# number of training points:  32
# Degree 1 e_LOO 0.0008655836384344182 Pf 0.03148 CoV 0.01750
# number of training points:  33
# Degree 3 e_LOO 0.00022838514978107158 Pf 0.03995 CoV 0.01550
# number of training points:  34
# Degree 1 e_LOO 0.0011092818952774522 Pf 0.03023 CoV 0.01790
# number of training points:  35
# Degree 1 e_LOO 0.0008958128702823208 Pf 0.02944 CoV 0.01820
# number of training points:  36
# Degree 1 e_LOO 0.000842745214995308 Pf 0.03153 CoV 0.01750
# number of training points:  37
# Degree 4 e_LOO 4.716134129795254e-05 Pf 0.04108 CoV 0.01530
# number of training points:  38
# Degree 1 e_LOO 0.0015934144860128819 Pf 0.03155 CoV 0.01750
# number of training points:  39
# Degree 1 e_LOO 6.444513505085197e-06 Pf 0.03203 CoV 0.01740
# number of training points:  40
# Experiment:  7 ------------------------------------------------------------
# Degree 1 e_LOO 0.0002643795671868299 Pf 0.11382 CoV 0.00880
# number of training points:  11
# Degree 1 e_LOO 0.0016754111902935436 Pf 0.07147 CoV 0.01140
# number of training points:  12
# Degree 2 e_LOO 0.0031339554510367434 Pf 0.04821 CoV 0.01410
# number of training points:  13
# Degree 2 e_LOO 0.003558288096034624 Pf 0.05713 CoV 0.01280
# number of training points:  14
# Degree 1 e_LOO 0.0029517945916586455 Pf 0.01992 CoV 0.02220
# number of training points:  15
# Degree 2 e_LOO 0.001497723508118802 Pf 0.0274 CoV 0.01880
# number of training points:  16
# Degree 3 e_LOO 2.9552425782643367e-06 Pf 0.02594 CoV 0.01940
# number of training points:  17
# Degree 3 e_LOO 0.0004061867252280992 Pf 0.0243 CoV 0.02000
# number of training points:  18
# Degree 3 e_LOO 0.00014171479366075415 Pf 0.02588 CoV 0.01940
# number of training points:  19
# Degree 1 e_LOO 0.0015114110619064312 Pf 0.00891 CoV 0.03340
# number of training points:  20
# Degree 2 e_LOO 0.0003238914251392061 Pf 0.01109 CoV 0.02990
# number of training points:  21
# Degree 2 e_LOO 0.0002503556456366337 Pf 0.02315 CoV 0.02050
# number of training points:  22
# Degree 2 e_LOO 0.00026480521472237 Pf 0.02412 CoV 0.02010
# number of training points:  23
# Degree 2 e_LOO 0.00020326322703869548 Pf 0.02269 CoV 0.02080
# number of training points:  24
# Degree 2 e_LOO 0.00020643264051300078 Pf 0.02214 CoV 0.02100
# number of training points:  25
# Degree 2 e_LOO 2.6153002759926346e-05 Pf 0.02389 CoV 0.02020
# number of training points:  26
# Degree 2 e_LOO 0.00046517611375853095 Pf 0.03002 CoV 0.01800
# number of training points:  27
# Degree 2 e_LOO 6.41647482526693e-06 Pf 0.02854 CoV 0.01840
# number of training points:  28
# Degree 2 e_LOO 0.0007772106444672367 Pf 0.02868 CoV 0.01840
# number of training points:  29
# Degree 2 e_LOO 0.0003424114829807322 Pf 0.02882 CoV 0.01840
# number of training points:  30
# Degree 2 e_LOO 0.00019479344882928387 Pf 0.03037 CoV 0.01790
# number of training points:  31
# Degree 2 e_LOO 5.4319843583698006e-05 Pf 0.03014 CoV 0.01790
# number of training points:  32
# Degree 2 e_LOO 5.064838989927806e-05 Pf 0.03091 CoV 0.01770
# number of training points:  33
# Degree 1 e_LOO 1.2169162207838737e-05 Pf 0.03101 CoV 0.01770
# number of training points:  34
# Degree 2 e_LOO 2.410130243646641e-07 Pf 0.03176 CoV 0.01750
# number of training points:  35
# Degree 2 e_LOO 2.4751334289829255e-07 Pf 0.0314 CoV 0.01760
# number of training points:  36
# Degree 2 e_LOO 5.5546050799089395e-05 Pf 0.03264 CoV 0.01720
# number of training points:  37
# Degree 2 e_LOO 7.200686268028978e-05 Pf 0.03182 CoV 0.01740
# number of training points:  38
# Degree 1 e_LOO 2.6170179136125786e-07 Pf 0.03108 CoV 0.01770
# number of training points:  39
# Degree 2 e_LOO 1.860288536883112e-06 Pf 0.03094 CoV 0.01770
# number of training points:  40
# Experiment:  8 ------------------------------------------------------------
# Degree 1 e_LOO 0.00012061877825156554 Pf 0.07701 CoV 0.01090
# number of training points:  11
# Degree 1 e_LOO 1.3062003883140992e-05 Pf 0.03599 CoV 0.01640
# number of training points:  12
# Degree 1 e_LOO 0.0007270507118539575 Pf 0.00069 CoV 0.12030
# number of training points:  13
# Degree 1 e_LOO 0.0006814296217617339 Pf 0.00014 CoV 0.26720
# number of training points:  14
# Degree 1 e_LOO 0.01115110692445752 Pf 0.01074 CoV 0.03030
# number of training points:  15
# Degree 1 e_LOO 0.0025978721332584223 Pf 0.00826 CoV 0.03470
# number of training points:  16
# Degree 1 e_LOO 0.001659155234708606 Pf 0.01056 CoV 0.03060
# number of training points:  17
# Degree 1 e_LOO 3.0064997530230224e-05 Pf 0.01782 CoV 0.02350
# number of training points:  18
# Degree 1 e_LOO 0.0002976244538051945 Pf 0.0179 CoV 0.02340
# number of training points:  19
# Degree 1 e_LOO 2.3851259136898246e-06 Pf 0.02112 CoV 0.02150
# number of training points:  20
# Degree 1 e_LOO 8.394156013811938e-07 Pf 0.02079 CoV 0.02170
# number of training points:  21
# Degree 1 e_LOO 4.998083015938503e-05 Pf 0.02448 CoV 0.02000
# number of training points:  22
# Degree 1 e_LOO 2.163207101735917e-05 Pf 0.02441 CoV 0.02000
# number of training points:  23
# Degree 1 e_LOO 0.0003599857158774992 Pf 0.02524 CoV 0.01970
# number of training points:  24
# Degree 2 e_LOO 0.0003262907962931936 Pf 0.0287 CoV 0.01840
# number of training points:  25
# Degree 1 e_LOO 0.006041578981379458 Pf 0.02627 CoV 0.01930
# number of training points:  26
# Degree 1 e_LOO 0.005147988865181262 Pf 0.02874 CoV 0.01840
# number of training points:  27
# Degree 1 e_LOO 0.004484320281170892 Pf 0.02685 CoV 0.01900
# number of training points:  28
# Degree 1 e_LOO 0.004124634394336416 Pf 0.03074 CoV 0.01780
# number of training points:  29
# Degree 1 e_LOO 0.0037093826564124437 Pf 0.03174 CoV 0.01750
# number of training points:  30
# Degree 1 e_LOO 0.0035712634368201546 Pf 0.03077 CoV 0.01770
# number of training points:  31
# Degree 1 e_LOO 0.003528230602251197 Pf 0.03129 CoV 0.01760
# number of training points:  32
# Degree 2 e_LOO 0.002606966627899967 Pf 0.0312 CoV 0.01760
# number of training points:  33
# Degree 1 e_LOO 0.0027319496619300212 Pf 0.03106 CoV 0.01770
# number of training points:  34
# Degree 1 e_LOO 0.002517940701215799 Pf 0.03115 CoV 0.01760
# number of training points:  35
# Degree 1 e_LOO 0.0022500879334729344 Pf 0.0314 CoV 0.01760
# number of training points:  36
# Degree 1 e_LOO 0.002022421513187452 Pf 0.03042 CoV 0.01790
# number of training points:  37
# Degree 1 e_LOO 0.0017276346077477517 Pf 0.03119 CoV 0.01760
# number of training points:  38
# Degree 1 e_LOO 2.3164630589828194e-07 Pf 0.03099 CoV 0.01770
# number of training points:  39
# Degree 1 e_LOO 2.1820768154217966e-05 Pf 0.03061 CoV 0.01780
# number of training points:  40
# Experiment:  9 ------------------------------------------------------------
# Degree 1 e_LOO 0.005362863745372354 Pf 0.05321 CoV 0.01330
# number of training points:  11
# Degree 2 e_LOO 0.0010163536550381923 Pf 0.00755 CoV 0.03630
# number of training points:  12
# Degree 1 e_LOO 0.0008879749575813767 Pf 0.06204 CoV 0.01230
# number of training points:  13
# Degree 1 e_LOO 0.0004250679880612227 Pf 0.02118 CoV 0.02150
# number of training points:  14
# Degree 1 e_LOO 0.009056729182924345 Pf 0.03298 CoV 0.01710
# number of training points:  15
# Degree 1 e_LOO 2.8705340530587243e-05 Pf 0.03323 CoV 0.01710
# number of training points:  16
# Degree 1 e_LOO 0.008463284615930624 Pf 0.0252 CoV 0.01970
# number of training points:  17
# Degree 2 e_LOO 0.008106649289572523 Pf 0.02286 CoV 0.02070
# number of training points:  18
# Degree 2 e_LOO 4.7252742081597907e-05 Pf 0.02455 CoV 0.01990
# number of training points:  19
# Degree 2 e_LOO 2.2118961565482312e-05 Pf 0.02503 CoV 0.01970
# number of training points:  20
# Degree 2 e_LOO 0.0009333350909496432 Pf 0.02303 CoV 0.02060
# number of training points:  21
# Degree 2 e_LOO 0.0005291198773152791 Pf 0.02454 CoV 0.01990
# number of training points:  22
# Degree 2 e_LOO 1.0764402652397269e-06 Pf 0.02264 CoV 0.02080
# number of training points:  23
# Degree 3 e_LOO 0.0015232535467659266 Pf 0.08734 CoV 0.01020
# number of training points:  24
# Degree 2 e_LOO 0.002909203341894787 Pf 0.02413 CoV 0.02010
# number of training points:  25
# Degree 2 e_LOO 0.00258414000777066 Pf 0.02785 CoV 0.01870
# number of training points:  26
# Degree 2 e_LOO 0.0014931108209610075 Pf 0.02836 CoV 0.01850
# number of training points:  27
# Degree 2 e_LOO 0.0004402060142269822 Pf 0.02889 CoV 0.01830
# number of training points:  28
# Degree 2 e_LOO 0.0006852468134908257 Pf 0.03109 CoV 0.01770
# number of training points:  29
# Degree 2 e_LOO 0.001372075896377202 Pf 0.03038 CoV 0.01790
# number of training points:  30
# Degree 2 e_LOO 0.0017563654563961745 Pf 0.03156 CoV 0.01750
# number of training points:  31
# Degree 2 e_LOO 0.0023405346000120383 Pf 0.03108 CoV 0.01770
# number of training points:  32
# Degree 2 e_LOO 0.0024065526392124657 Pf 0.03143 CoV 0.01760
# number of training points:  33
# Degree 2 e_LOO 0.002376551822905566 Pf 0.03043 CoV 0.01790
# number of training points:  34
# Degree 2 e_LOO 0.0023874521397977207 Pf 0.0308 CoV 0.01770
# number of training points:  35
# Degree 2 e_LOO 0.0023858410966992524 Pf 0.03169 CoV 0.01750
# number of training points:  36
# Degree 2 e_LOO 0.0010893807296873392 Pf 0.03122 CoV 0.01760
# number of training points:  37
# Degree 2 e_LOO 0.0013937630356390175 Pf 0.0312 CoV 0.01760
# number of training points:  38
# Degree 2 e_LOO 0.0011222910315082004 Pf 0.03068 CoV 0.01780
# number of training points:  39
# Degree 2 e_LOO 0.0007096607435538431 Pf 0.03038 CoV 0.01790
# number of training points:  40
# Experiment:  10 ------------------------------------------------------------
# Degree 1 e_LOO 0.0022678474936320006 Pf 0.07672 CoV 0.01100
# number of training points:  11
# Degree 1 e_LOO 0.012540051749100984 Pf 0.07735 CoV 0.01090
# number of training points:  12
# Degree 1 e_LOO 0.02182374892851708 Pf 0.03776 CoV 0.01600
# number of training points:  13
# Degree 1 e_LOO 0.01682174208037364 Pf 0.04309 CoV 0.01490
# number of training points:  14
# Degree 1 e_LOO 0.011488294930970892 Pf 0.00938 CoV 0.03250
# number of training points:  15
# Degree 1 e_LOO 0.0049166175637064624 Pf 0.01879 CoV 0.02290
# number of training points:  16
# Degree 1 e_LOO 0.005963824036099542 Pf 0.02972 CoV 0.01810
# number of training points:  17
# Degree 1 e_LOO 0.004694010840507747 Pf 0.02797 CoV 0.01860
# number of training points:  18
# Degree 1 e_LOO 0.002856427978685154 Pf 0.0257 CoV 0.01950
# number of training points:  19
# Degree 1 e_LOO 0.003167262641178635 Pf 0.02617 CoV 0.01930
# number of training points:  20
# Degree 2 e_LOO 0.0009004163664970889 Pf 0.03081 CoV 0.01770
# number of training points:  21
# Degree 2 e_LOO 0.00038821806618275314 Pf 0.03267 CoV 0.01720
# number of training points:  22
# Degree 1 e_LOO 0.0009998481548691665 Pf 0.0328 CoV 0.01720
# number of training points:  23
# Degree 1 e_LOO 0.00011231082205824266 Pf 0.03362 CoV 0.01700
# number of training points:  24
# Degree 1 e_LOO 6.794017594127989e-05 Pf 0.03252 CoV 0.01720
# number of training points:  25
# Degree 1 e_LOO 0.002476217976446076 Pf 0.03218 CoV 0.01730
# number of training points:  26
# Degree 2 e_LOO 0.0006281794414737273 Pf 0.03022 CoV 0.01790
# number of training points:  27
# Degree 1 e_LOO 0.005177621912051774 Pf 0.03065 CoV 0.01780
# number of training points:  28
# Degree 1 e_LOO 0.005599309538817618 Pf 0.03051 CoV 0.01780
# number of training points:  29
# Degree 1 e_LOO 0.005370385975175026 Pf 0.03131 CoV 0.01760
# number of training points:  30
# Degree 1 e_LOO 0.004748661380353303 Pf 0.03096 CoV 0.01770
# number of training points:  31
# Degree 1 e_LOO 0.004639804994284945 Pf 0.03163 CoV 0.01750
# number of training points:  32
# Degree 1 e_LOO 0.002942495465729806 Pf 0.03172 CoV 0.01750
# number of training points:  33
# Degree 1 e_LOO 0.0027523199717953716 Pf 0.0312 CoV 0.01760
# number of training points:  34
# Degree 1 e_LOO 0.004067608025963386 Pf 0.03098 CoV 0.01770
# number of training points:  35
# Degree 1 e_LOO 0.004025610641584862 Pf 0.02996 CoV 0.01800
# number of training points:  36
# Degree 1 e_LOO 0.0038233847624410174 Pf 0.0305 CoV 0.01780
# number of training points:  37
# Degree 1 e_LOO 0.0028712008969239014 Pf 0.03137 CoV 0.01760
# number of training points:  38
# Degree 3 e_LOO 0.0006943347618718426 Pf 0.0501 CoV 0.01380
# number of training points:  39
# Degree 1 e_LOO 0.0011356702586115676 Pf 0.03012 CoV 0.01790
# number of training points:  40
# Experiment:  11 ------------------------------------------------------------
# Degree 2 e_LOO 0.00022419129750216857 Pf 0.0 CoV inf
# number of training points:  11
# Degree 1 e_LOO 0.0002923513747727694 Pf 0.07841 CoV 0.01080
# number of training points:  12
# Degree 2 e_LOO 0.006736248428350061 Pf 0.00061 CoV 0.12800
# number of training points:  13
# Degree 2 e_LOO 0.006558174007720463 Pf 0.01001 CoV 0.03140
# number of training points:  14
# Degree 1 e_LOO 0.024172738791297214 Pf 0.02307 CoV 0.02060
# number of training points:  15
# Degree 1 e_LOO 0.017781760514594402 Pf 0.01421 CoV 0.02630
# number of training points:  16
# Degree 4 e_LOO 0.00537527217294218 Pf 0.09737 CoV 0.00960
# number of training points:  17
# Degree 2 e_LOO 0.0005559343484803234 Pf 0.03143 CoV 0.01760
# number of training points:  18
# Degree 2 e_LOO 0.0020684545778468563 Pf 0.01236 CoV 0.02830
# number of training points:  19
# Degree 2 e_LOO 0.0015838779675941348 Pf 0.01398 CoV 0.02660
# number of training points:  20
# Degree 1 e_LOO 0.002874783659496327 Pf 0.01758 CoV 0.02360
# number of training points:  21
# Degree 1 e_LOO 0.009466400636265512 Pf 0.0186 CoV 0.02300
# number of training points:  22
# Degree 1 e_LOO 0.009561925314433313 Pf 0.02643 CoV 0.01920
# number of training points:  23
# Degree 1 e_LOO 0.009372323558790013 Pf 0.0256 CoV 0.01950
# number of training points:  24
# Degree 1 e_LOO 0.011065195220244404 Pf 0.03061 CoV 0.01780
# number of training points:  25
# Degree 1 e_LOO 0.011155614260384084 Pf 0.03062 CoV 0.01780
# number of training points:  26
# Degree 1 e_LOO 0.011929975343802177 Pf 0.03171 CoV 0.01750
# number of training points:  27
# Degree 2 e_LOO 0.010400323960918828 Pf 0.03082 CoV 0.01770
# number of training points:  28
# Degree 2 e_LOO 0.007875431992287813 Pf 0.03292 CoV 0.01710
# number of training points:  29
# Degree 1 e_LOO 0.00715669197606237 Pf 0.03083 CoV 0.01770
# number of training points:  30
# Degree 1 e_LOO 0.008091816970186006 Pf 0.03181 CoV 0.01740
# number of training points:  31
# Degree 2 e_LOO 0.0061038835018508075 Pf 0.03252 CoV 0.01720
# number of training points:  32
# Degree 2 e_LOO 0.005549289587221052 Pf 0.03289 CoV 0.01710
# number of training points:  33
# Degree 2 e_LOO 0.008265281630455042 Pf 0.03205 CoV 0.01740
# number of training points:  34
# Degree 2 e_LOO 0.007486198281407378 Pf 0.03274 CoV 0.01720
# number of training points:  35
# Degree 2 e_LOO 0.006839277220068491 Pf 0.03276 CoV 0.01720
# number of training points:  36
# Degree 2 e_LOO 0.005771986420138594 Pf 0.03272 CoV 0.01720
# number of training points:  37
# Degree 2 e_LOO 0.005176678289407558 Pf 0.03219 CoV 0.01730
# number of training points:  38
# Degree 2 e_LOO 0.004583271890020154 Pf 0.0325 CoV 0.01730
# number of training points:  39
# Degree 2 e_LOO 0.003744355611563301 Pf 0.0321 CoV 0.01740
# number of training points:  40
# Experiment:  12 ------------------------------------------------------------
# Degree 1 e_LOO 0.005115314855195369 Pf 0.09041 CoV 0.01000
# number of training points:  11
# Degree 1 e_LOO 0.0199113492527761 Pf 0.00441 CoV 0.04750
# number of training points:  12
# Degree 2 e_LOO 0.0033135771960649918 Pf 0.00466 CoV 0.04620
# number of training points:  13
# Degree 1 e_LOO 0.011818494556052323 Pf 0.01553 CoV 0.02520
# number of training points:  14
# Degree 1 e_LOO 0.005925068497621758 Pf 0.02782 CoV 0.01870
# number of training points:  15
# Degree 1 e_LOO 0.007176657083286749 Pf 0.01722 CoV 0.02390
# number of training points:  16
# Degree 4 e_LOO 0.00010124166652230728 Pf 0.1744 CoV 0.00690
# number of training points:  17
# Degree 4 e_LOO 0.0009630989135180347 Pf 0.17275 CoV 0.00690
# number of training points:  18
# Degree 4 e_LOO 0.008205621402369905 Pf 0.13767 CoV 0.00790
# number of training points:  19
# Degree 1 e_LOO 0.0024045419245060542 Pf 0.02335 CoV 0.02050
# number of training points:  20
# Degree 1 e_LOO 0.0015321359457353822 Pf 0.02288 CoV 0.02070
# number of training points:  21
# Degree 1 e_LOO 0.0003018676106647283 Pf 0.02381 CoV 0.02020
# number of training points:  22
# Degree 4 e_LOO 0.001070313962325008 Pf 0.13034 CoV 0.00820
# number of training points:  23
# Degree 2 e_LOO 0.0004397735402208321 Pf 0.01963 CoV 0.02230
# number of training points:  24
# Degree 2 e_LOO 0.0007811511458653561 Pf 0.02054 CoV 0.02180
# number of training points:  25
# Degree 2 e_LOO 4.709547741509834e-05 Pf 0.02106 CoV 0.02160
# number of training points:  26
# Degree 2 e_LOO 0.00015923528237775912 Pf 0.0216 CoV 0.02130
# number of training points:  27
# Degree 1 e_LOO 0.0002146063082380242 Pf 0.02278 CoV 0.02070
# number of training points:  28
# Degree 1 e_LOO 0.0001471848637016681 Pf 0.02555 CoV 0.01950
# number of training points:  29
# Degree 1 e_LOO 0.00014139233139584537 Pf 0.02882 CoV 0.01840
# number of training points:  30
# Degree 2 e_LOO 0.00029492526175968085 Pf 0.02938 CoV 0.01820
# number of training points:  31
# Degree 1 e_LOO 0.0029735537364815883 Pf 0.03121 CoV 0.01760
# number of training points:  32
# Degree 1 e_LOO 0.002082376615339543 Pf 0.03162 CoV 0.01750
# number of training points:  33
# Degree 2 e_LOO 0.0013749586936883868 Pf 0.03117 CoV 0.01760
# number of training points:  34
# Degree 2 e_LOO 0.0012689474120504405 Pf 0.03078 CoV 0.01770
# number of training points:  35
# Degree 2 e_LOO 0.0023392651214435493 Pf 0.03075 CoV 0.01780
# number of training points:  36
# Degree 2 e_LOO 0.000466543755072403 Pf 0.03056 CoV 0.01780
# number of training points:  37
# Degree 2 e_LOO 0.00027289400421313503 Pf 0.03048 CoV 0.01780
# number of training points:  38
# Degree 2 e_LOO 0.00044767695518008925 Pf 0.03005 CoV 0.01800
# number of training points:  39
# Degree 2 e_LOO 0.00032140411333948755 Pf 0.03027 CoV 0.01790
# number of training points:  40
# Experiment:  13 ------------------------------------------------------------
# Degree 2 e_LOO 0.001265081995063405 Pf 0.0 CoV inf
# number of training points:  11
# Degree 1 e_LOO 0.013027042172103162 Pf 0.06539 CoV 0.01200
# number of training points:  12
# Degree 3 e_LOO 0.008714023186417117 Pf 0.24559 CoV 0.00550
# number of training points:  13
# Degree 2 e_LOO 0.03350644008392659 Pf 0.00745 CoV 0.03650
# number of training points:  14
# Degree 2 e_LOO 0.006153922662960609 Pf 0.00318 CoV 0.05600
# number of training points:  15
# Degree 2 e_LOO 0.005530121013913476 Pf 0.00382 CoV 0.05110
# number of training points:  16
# Degree 2 e_LOO 0.008208052477840184 Pf 0.00338 CoV 0.05430
# number of training points:  17
# Degree 2 e_LOO 0.004692383396789456 Pf 0.0111 CoV 0.02980
# number of training points:  18
# Degree 2 e_LOO 0.003644134448636113 Pf 0.01653 CoV 0.02440
# number of training points:  19
# Degree 2 e_LOO 0.0006022806468997226 Pf 0.0121 CoV 0.02860
# number of training points:  20
# Degree 2 e_LOO 0.0003286615542328932 Pf 0.01294 CoV 0.02760
# number of training points:  21
# Degree 2 e_LOO 0.00020388091692979075 Pf 0.01461 CoV 0.02600
# number of training points:  22
# Degree 2 e_LOO 0.0002568130592529092 Pf 0.01938 CoV 0.02250
# number of training points:  23
# Degree 2 e_LOO 0.0006107677803050482 Pf 0.01954 CoV 0.02240
# number of training points:  24
# Degree 2 e_LOO 0.0007402593985869359 Pf 0.02091 CoV 0.02160
# number of training points:  25
# Degree 2 e_LOO 0.00037085811247381586 Pf 0.02309 CoV 0.02060
# number of training points:  26
# Degree 2 e_LOO 7.904636568447129e-05 Pf 0.02472 CoV 0.01990
# number of training points:  27
# Degree 2 e_LOO 4.1821730966827596e-06 Pf 0.02396 CoV 0.02020
# number of training points:  28
# Degree 2 e_LOO 2.5463233653300033e-05 Pf 0.02775 CoV 0.01870
# number of training points:  29
# Degree 2 e_LOO 1.6836519988095357e-05 Pf 0.03384 CoV 0.01690
# number of training points:  30
# Degree 1 e_LOO 0.0007514678931494543 Pf 0.03237 CoV 0.01730
# number of training points:  31
# Degree 3 e_LOO 4.0683259130111164e-05 Pf 0.03039 CoV 0.01790
# number of training points:  32
# Degree 1 e_LOO 4.7890044301768746e-05 Pf 0.03189 CoV 0.01740
# number of training points:  33
# Degree 3 e_LOO 9.85349138346529e-06 Pf 0.03137 CoV 0.01760
# number of training points:  34
# Degree 3 e_LOO 0.00013148772269797623 Pf 0.03095 CoV 0.01770
# number of training points:  35
# Degree 1 e_LOO 8.330010238784422e-05 Pf 0.03065 CoV 0.01780
# number of training points:  36
# Degree 1 e_LOO 4.2876905143927964e-05 Pf 0.02997 CoV 0.01800
# number of training points:  37
# Degree 2 e_LOO 0.0001192727362018814 Pf 0.03037 CoV 0.01790
# number of training points:  38
# Degree 2 e_LOO 5.812931530442466e-05 Pf 0.03032 CoV 0.01790
# number of training points:  39
# Degree 2 e_LOO 4.6709308503535865e-05 Pf 0.03071 CoV 0.01780
# number of training points:  40
# Experiment:  14 ------------------------------------------------------------
# Degree 2 e_LOO 2.3058878637066145e-05 Pf 0.09011 CoV 0.01000
# number of training points:  11
# Degree 1 e_LOO 0.0002914019474952422 Pf 0.0847 CoV 0.01040
# number of training points:  12
# Degree 1 e_LOO 0.0007574555929471924 Pf 0.0736 CoV 0.01120
# number of training points:  13
# Degree 2 e_LOO 0.0007668982367712867 Pf 0.00022 CoV 0.21320
# number of training points:  14
# Degree 2 e_LOO 0.001004395162074037 Pf 0.00097 CoV 0.10150
# number of training points:  15
# Degree 2 e_LOO 0.0006515059960013473 Pf 0.00054 CoV 0.13600
# number of training points:  16
# Degree 2 e_LOO 0.00039909598552715714 Pf 0.00354 CoV 0.05310
# number of training points:  17
# Degree 2 e_LOO 7.728915865876356e-07 Pf 0.00573 CoV 0.04170
# number of training points:  18
# Degree 2 e_LOO 9.688175435383967e-06 Pf 0.00789 CoV 0.03550
# number of training points:  19
# Degree 2 e_LOO 7.536513016354311e-07 Pf 0.01108 CoV 0.02990
# number of training points:  20
# Degree 2 e_LOO 6.643270733519076e-06 Pf 0.01244 CoV 0.02820
# number of training points:  21
# Degree 2 e_LOO 1.78348061834193e-07 Pf 0.01607 CoV 0.02470
# number of training points:  22
# Degree 2 e_LOO 1.4445156432918764e-05 Pf 0.01651 CoV 0.02440
# number of training points:  23
# Degree 2 e_LOO 6.216382684419298e-05 Pf 0.01831 CoV 0.02320
# number of training points:  24
# Degree 1 e_LOO 6.278070054266777e-05 Pf 0.02435 CoV 0.02000
# number of training points:  25
# Degree 1 e_LOO 8.138268683320956e-05 Pf 0.0247 CoV 0.01990
# number of training points:  26
# Degree 1 e_LOO 4.869987777734496e-05 Pf 0.02452 CoV 0.01990
# number of training points:  27
# Degree 2 e_LOO 1.919555194428556e-05 Pf 0.02366 CoV 0.02030
# number of training points:  28
# Degree 2 e_LOO 2.214685966793662e-06 Pf 0.02392 CoV 0.02020
# number of training points:  29
# Degree 2 e_LOO 3.8710335385422776e-05 Pf 0.02394 CoV 0.02020
# number of training points:  30
# Degree 1 e_LOO 8.847647152423751e-05 Pf 0.02364 CoV 0.02030
# number of training points:  31
# Degree 4 e_LOO 2.01856830606248e-05 Pf 0.09729 CoV 0.00960
# number of training points:  32
# Degree 4 e_LOO 0.0003831781532558588 Pf 0.08775 CoV 0.01020
# number of training points:  33
# Degree 4 e_LOO 0.000408137696444564 Pf 0.08896 CoV 0.01010
# number of training points:  34
# Degree 4 e_LOO 0.0002897877348616242 Pf 0.08541 CoV 0.01030
# number of training points:  35
# Degree 4 e_LOO 0.001048391724741829 Pf 0.08312 CoV 0.01050
# number of training points:  36
# Degree 1 e_LOO 0.00469455335553351 Pf 0.02371 CoV 0.02030
# number of training points:  37
# Degree 2 e_LOO 0.005132302233315374 Pf 0.02856 CoV 0.01840
# number of training points:  38
# Degree 2 e_LOO 0.002446570632841843 Pf 0.02646 CoV 0.01920
# number of training points:  39
# Degree 2 e_LOO 0.0021315636492670585 Pf 0.02687 CoV 0.01900
# number of training points:  40
# Experiment:  15 ------------------------------------------------------------
# Degree 1 e_LOO 3.794734757660992e-05 Pf 0.10224 CoV 0.00940
# number of training points:  11
# Degree 1 e_LOO 1.3616519139239526e-05 Pf 0.10981 CoV 0.00900
# number of training points:  12
# Degree 1 e_LOO 0.000735989440299785 Pf 0.10654 CoV 0.00920
# number of training points:  13
# Degree 1 e_LOO 0.0008744676491415918 Pf 0.02331 CoV 0.02050
# number of training points:  14
# Degree 1 e_LOO 0.00042349889072818486 Pf 0.00952 CoV 0.03230
# number of training points:  15
# Degree 2 e_LOO 1.7994285203544796e-05 Pf 0.02539 CoV 0.01960
# number of training points:  16
# Degree 2 e_LOO 0.00016301128176143392 Pf 0.02444 CoV 0.02000
# number of training points:  17
# Degree 2 e_LOO 0.0001613853743942413 Pf 0.02812 CoV 0.01860
# number of training points:  18
# Degree 2 e_LOO 2.2665398603048783e-07 Pf 0.02261 CoV 0.02080
# number of training points:  19
# Degree 2 e_LOO 1.2496318597869385e-05 Pf 0.02338 CoV 0.02040
# number of training points:  20
# Degree 2 e_LOO 6.873123948339934e-06 Pf 0.02417 CoV 0.02010
# number of training points:  21
# Degree 1 e_LOO 4.881599824446691e-05 Pf 0.02323 CoV 0.02050
# number of training points:  22
# Degree 1 e_LOO 4.573532612378089e-07 Pf 0.02467 CoV 0.01990
# number of training points:  23
# Degree 1 e_LOO 0.0013863187342475084 Pf 0.02508 CoV 0.01970
# number of training points:  24
# Degree 1 e_LOO 0.0013361787811350064 Pf 0.02447 CoV 0.02000
# number of training points:  25
# Degree 1 e_LOO 0.00038997757169026876 Pf 0.02473 CoV 0.01990
# number of training points:  26
# Degree 3 e_LOO 4.642503720093061e-05 Pf 0.03225 CoV 0.01730
# number of training points:  27
# Degree 1 e_LOO 0.004487025284786438 Pf 0.0264 CoV 0.01920
# number of training points:  28
# Degree 1 e_LOO 0.003298712192821493 Pf 0.03122 CoV 0.01760
# number of training points:  29
# Degree 2 e_LOO 0.0023734551560548075 Pf 0.03169 CoV 0.01750
# number of training points:  30
# Degree 2 e_LOO 0.0029258067462028066 Pf 0.02999 CoV 0.01800
# number of training points:  31
# Degree 2 e_LOO 0.0037981936763486204 Pf 0.03003 CoV 0.01800
# number of training points:  32
# Degree 2 e_LOO 0.0021392572105048786 Pf 0.02915 CoV 0.01820
# number of training points:  33
# Degree 3 e_LOO 0.0014185764051822297 Pf 0.0289 CoV 0.01830
# number of training points:  34
# Degree 3 e_LOO 3.008414691574643e-06 Pf 0.02871 CoV 0.01840
# number of training points:  35
# Degree 3 e_LOO 7.237648225322936e-05 Pf 0.02984 CoV 0.01800
# number of training points:  36
# Degree 3 e_LOO 0.0002793904182451874 Pf 0.02972 CoV 0.01810
# number of training points:  37
# Degree 2 e_LOO 0.0003820803646936989 Pf 0.02885 CoV 0.01830
# number of training points:  38
# Degree 2 e_LOO 0.000430533030926182 Pf 0.03042 CoV 0.01790
# number of training points:  39
# Degree 2 e_LOO 0.0002007913020599924 Pf 0.03027 CoV 0.01790
# number of training points:  40

# %% [markdown]
# # Active training - EFF - LOO - 1 LS

# %%
number_experiments = 13
number_active_points = 40

results_file = '_AT_EFF_Loo_' + str(number_active_points)   # index for results files

# to select the best model (length and order) 
# kernel hyperparameters------------------------------
v = 5/2
#truncation term-------------------------------------
p_max = 5  #for each variable → same truncation , degree of expansion
        
for experiments in range(number_experiments):
    print('Experiment: ', experiments+1 , '------------------------------------------------------------' )
    
    ActiveTrain = {}   #results file { Surrogate , Pf, CoV_Pf , eLoo , mse }

    #initial design of experiments (LHS) --------------------------------

    n = 10       # number of initial sampling

    xn = np.zeros((int(n), dim))      #normalized training points
    xr = np.zeros((int(n), dim))      #scaled training points
    yn = np.zeros((int(n)))           #observations

    mean_loo = np.zeros(len(xn))
    var_loo = np.zeros(len(xn))

    x1mean, x1sigma = 1.5 , 1.0  # normal distribution 
    x2mean, x2sigma = 2.5 , 1.0  # normal distribution 

    # Check the variables limits for space-filling distribution
    Xdoe = build.space_filling_lhs( {'x1':[-1, 1],      
                                     'x2':[-1, 1],} , 
                                      num_samples = n )
    #------------------------------------------------------------
    xn[:,0] = Xdoe['x1']
    xn[:,1] = Xdoe['x2']
    xr[:,0] = PCK1.scalehermite(xn[:,0], x1mean, x1sigma)
    xr[:,1] = PCK1.scalehermite(xn[:,1], x2mean, x2sigma)

    yn = function(xr)[0]

    for points in range(number_active_points):

        ModelName = 'PCK' + str(len(xn))

        ModelName = PC_Kriging(config)
        
        mse_results = np.zeros(p_max-1)
        opt_length_it = np.zeros(p_max-1)

        mean_loo = np.zeros(len(xn))
        var_loo = np.zeros(len(xn))
        eloo_results = np.zeros(p_max-1)
        sumat = np.zeros((len(xn),(p_max-1)))

        dist = PCK1.distance(xr, xr)
        lmax = np.max(dist)
        lmin = np.min(dist[dist!=0])

        # OPTIMAL SURROGATE MODEL -----------------------------------
        for p in range(1, p_max):
            results = dict()
            bounds = [(lmin, lmax)]
            results['shgo'] = optimize.shgo(L_Object, bounds)
            opt_length = results['shgo']['x'][0]

            theta = np.array([opt_length, v])

            #Generating PCK models for each reduced design of experiments 

            for i in range (0, len(xn) ):

                yn_loo= np.delete(yn,[i])                            #y_n-i      leaving element i out the observations 
                xr_loo= np.delete(xr,[i*2,i*2+1]).reshape(-1,dim)    #x1r_n-i   leaving element i out the inputs (xr)
                xn_loo= np.delete(xn,[i*2,i*2+1]).reshape(-1,dim)    #x_n-i     leaving element i out the nomalized inputs (xn)

                #training LOO
                modelpar_loo = PCK_loo.train (xn_loo , yn_loo , p , theta )

                #predicting LOO over each removed sample
                mean_loo[i], var_loo[i] = PCK_loo.predict_fast(xn[i].reshape(1,-1))

            e_loo = np.mean (yn - mean_loo)**2              #LOO CV squared errors
            sumat[:,p-1] = np.divide(e_loo, var_loo)
            
            eloo_results[p-1] = e_loo

            #--------------------------------------- error over a set of test points
            modelpar1 = PCK1.train (xn, yn, p, theta) 
            mean0, var0 = PCK1.predict_fast(XN)    # test points predictions mean, variance

            mse = np.mean ((YN - mean0)**2)

            mse_results[p-1] = mse
            opt_length_it[p-1] = opt_length

    #         print('Degree', p, 'MSE', "%.2f" % round(mse, 2) , 'e_LOO', "%.5f" % e_loo)

        ## training optimal model ----------------------------

        opt = np.argmin(eloo_results)    
        theta_opt = np.array([opt_length_it[opt], v]) 

        modelpar1 = ModelName.train (xn, yn, int(opt+1), theta_opt) 

        ## Pool of samples
        MCS_samples = 100000
        LOOCV = np.zeros(MCS_samples)

        MCinputs_norm = np.zeros((int(MCS_samples), dim))
        MCinputs = np.zeros((int(MCS_samples), dim))

        MCinputs_norm[:,0] = np.random.normal(0, 1, size=int(MCS_samples))
        MCinputs_norm[:,1] = np.random.normal(0, 1, size=int(MCS_samples))

        MCinputs[:,0] = PCK1.scalehermite(MCinputs_norm[:,0], x1mean, x1sigma)  
        MCinputs[:,1] = PCK1.scalehermite(MCinputs_norm[:,1], x2mean, x2sigma)  

        # ---------------------------------------------------
        ymc = function(MCinputs)[0]  
        fail_samples = np.sum(ymc < 0 )
        Pf_ref = fail_samples/MCS_samples

        meanMC, varMC = ModelName.predict_fast(MCinputs_norm)    # mean, variance
        fail_samples_SUMO = np.sum(np.asarray(meanMC) < 0 )
        fail_prob_SUMO = fail_samples_SUMO / MCS_samples

        cov_pf = np.sqrt((1 - fail_prob_SUMO ) / (fail_prob_SUMO * MCS_samples) )

        # LOO CV errors ###################################################

        for k in range (0, MCS_samples):               #variance enhancement based LOO CV erros around voronoi cells
            voro = VoronoiCell(MCinputs[k], xr)
            LOOCV[k]= varMC[k]*(1+sumat[voro, opt])   
        ####################################################
        
        print('Degree', int(opt+1), 'e_LOO', np.min(eloo_results) , 'Pf', fail_prob_SUMO , 'CoV', "%.5f" % round(cov_pf, 4))

        #saving results ----------------------------

        ActiveTrain[str(len(xn))+'points'] = ModelName , fail_prob_SUMO , cov_pf , np.min(eloo_results), np.min(mse_results)

        ### Evaluating new points
                ### Evaluating new points
        eff1 = EFF(meanMC.reshape(-1),LOOCV.reshape(-1) , 0 )  #(mean, variance, target)  
        xr = np.append(xr, MCinputs[np.argmax(eff1)]).reshape(-1,2)
        xn = np.append(xn, MCinputs_norm[np.argmax(eff1)]).reshape(-1,2)
        
        yn = function(xr)[0] #Only one point needs to be evaluated here

        print('number of training points: ', len(xn))
    
    filename = 'Batch_'+ str(experiments+1) + results_file + 'p_LS1.sav'
    pickle.dump(ActiveTrain, open(filename, 'wb'))

# %% [markdown]
# # LeaveOneOut CrossValidation

# %%
#Generating PCK models for each reduced design of experiments 
PCK_loo = PC_Kriging(config)    # same 'config' as specified in the original model

mean_loo = np.zeros(n)
var_loo = np.zeros(n)

for i in range (0,n):             
    yn_loo=  np.delete(yn,[i])                              #y_n-i      leaving element i out the observations 
    xr_loo= np.delete(xr,[i*2,i*2+1]).reshape(-1,dim)      #x1r_n-i   leaving element i out the inputs (xr)
    xn_loo= np.delete(xn,[i*2,i*2+1]).reshape(-1,dim)      #x_n-i     leaving element i out the nomalized inputs (xn)

    #training LOO
    modelpar_loo = PCK_loo.train (xn_loo,yn_loo,p,theta)   # same (p, theta) as specified in the original model
     
    #predicting LOO
    mean_loo[i], var_loo[i] = PCK_loo.predict(xn[i].reshape(1,-1))
               
e_loo = (yn - mean_loo)**2              #LOO CV squared errors
sumat = np.divide(e_loo,var_loo)        #vector (e_loo / s_loo) for each observed point

LOOCV=np.zeros(ntest)

for k in range (0,ntest):               #variance enhancement based LOO CV erros around voronoi cells
    voro = VoronoiCell(XR[k],xr)
    
    LOOCV[k]= var_plot[k]*(1+sumat[voro])

# %% [markdown]
# # 2D Plot

# %%
# %%time
#predictions over a grid (for plotting)--------------------------------------------------

X1t,X2t = np.meshgrid(np.sort(XN[:,0]), np.sort(XN[:,1])) #grid over normalized points
Xt=np.stack((X1t,X2t),axis=2).reshape(-1,2) #sorting the random sampling (graphing purpose)

X1m,X2m = np.meshgrid(np.sort(XR[:,0]), np.sort(XR[:,1])) #grid over non-normalized points
Xtm=np.stack((X1m,X2m),axis=2).reshape(-1,2) #sorting the random sampling (graphing purpose)

yt=function(Xtm)    #test points
Mtest=yt[0]

response_plot=PCK1.predict(Xt)   #model predictions over (ntest x ntest) points
mean_plot=response_plot[0]
var_plot=response_plot[1]

# %%
fig =plt.subplots(figsize=(12, 8), dpi=80)

levels = 7
cs = plt.contourf(np.sort(XR[:,0]), np.sort(XR[:,1]), Mtest.reshape(ntest,-1), levels)
cbar=plt.colorbar(cs)

csm = plt.contour(np.sort(XR[:,0]), np.sort(XR[:,1]), mean_plot.reshape(ntest,-1) ,levels, colors='k')
plt.clabel(csm, fontsize=9, inline=1)

plt.scatter(xr[:,0],xr[:,1],color='red')

#-------------------------------------------------------------------------
# # # to check Voronoi cells influence vs observed points
point = 44    #point index from MCinputs(any test array) 

argum = VoronoiCell(XR[point],xr)

print(XR[point], xr[argum], argum)

plt.scatter(xr[argum,0],xr[argum,1],color='blue',marker = "x", s = 200)  #observations
plt.scatter(XR[point,0],XR[point,1],color='blue',marker = "*", s = 200)  #test point
#-------------------------------------------------------------------------

cs.changed()
